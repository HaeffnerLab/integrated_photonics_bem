# %% [markdown]
# # `Documention & Tutorial`
# This BEM package is used for for numerical simulation of the electric field of ion traps in python. Some external packages are wrapped into it:
#
# * fast triangulation (http://www.cs.cmu.edu/~quake/triangle.research.html)
# * fastlap boundary element method (Nabors K S. Efficient three-dimensional capacitance calculation[D]. Massachusetts Institute of Technology, 1993.)
#
# This document, also as a tutorial, explains how to use these packages to compute the electric field and compute its multipole expansion coefficient starting from scratch with a fusion 360 trap model(take `./f3d/htrap_overhang_9x5mm.f3d` for example). Our document consists of three .ipynb files:
#
# * `I_Mesh_Processing.ipynb`
# * `II_Field_Simulation.ipynb`
# * `III_Multipole_Expansion.ipynb`
#
# We split the document into three files for two reasons:
# 1. The most time consuming part `II_Field_Simulation.ipynb` could be taken out alone and run on a high peformance computer.
# 2. The intermediate result between files can be checked- 'intermediate files' refer to the inital mesh grid (that corresponds to the charge distribution), the simulation values and the simulation coordinates, all of which are saved in the inter_results folder. So if the voltage solution files for the trap don't make sense, it is possible to go back through saved data to see where things have gone wrong.
# Here are the three jupyter notebooks and what:
# 1. I_Mesh_Processing- this notebook generates a mesh of the trap, saved in inter_results as a .pkl file
#
#
# Going through three files in order and running their python code will help you understand our workflow. Generally our workflow divides into three steps, corresponding to the above three .ipynb files. First, in I_Mesh_Processing, we identify different electrodes of the trap model by different colors. Also, we refine the trap model meshes to prepare for the second step. The result is stored in `mesh_result.pkl`.
#
# Secondly, in II_Field_Simulation, we simulate the electric potential with fastlap boundary element method(FMM), the accuracy of this step depends on the mesh size in the first step. The result is stored in `field_result.pkl`.
#
# Thirdly, in III_Multipole_Expansion, we analyze the electric field and electric potential. This notebook generates the multipole coefficients of the fields and potentials for each electrode and uses that information to generate a solution file with the function call `write_csv`. If your solution don't make sense, a good place to start is to insure that the mesh you are using is fine enough (generate several field results for different meshes)- if the potentials and fields are converging to specific values, this suggests there is something wrong with the multipole expansion. If you start with multipole expansion, you do not know if it is a problem with the expansion or with the field.
#
# Before running codes, you must set up the environment according to instructions in `README`
#
# notes
# * Our workflow, as indicated by this document, abandons mayavi(with its embeded package tvtk). But we reserve mayavi in our Bem source code, if you want to use mayavi related functions, you must set up environment with files in`./backup/setup_with_mayavi`, just replace corresponding files in the root folder with them and set up.
#     * why we abandon mayavi: because its python interface(with its dependence vtk and PyQt5) requires complex package dependencies and version controls especially for new python versions. This makes it difficult to maintain this project.
#     * why we still keep mayavi in the source code? Because it is rooted in our source code deeply. We can just avoid invoking related functions instead of deleting them, because they may make sense in the future.

# %% [markdown]
# # `I. Mesh Processing`
# This .pynb file reads a colored model file `./inter_results/htrap.stl`, and assigns a name for each color(thus for each electrode). The result is stored in `./inter_results/mesh_result.pkl`.
#
# In this file we name different electrodes and refine the meshes. The size of mesh determines the accuracy in next step. You should set the mesh finer and finer until the result converges. Also, you can set the mesh finer and test the convergence.
#
# ## (1) color your electrodes (in fusion 360) and export stl
# First of all, you have a trap model in fusion 360 project, for example, `./f3d/htrap_overhang_9x5mm.f3d`. Here we use different color to identify different electrodes(STL file stores color for each mesh). In fusion 360, you can assign different appearance for different electrodes. We recommend to use ../../bemCol_lib/bemCol.adsklib for different electrodes. Same color for two electrodes means they are treated as the same electrode. Then we get `./f3d/htrap_overhang_9x5mm_my_colored.f3d`
#
# Then export to an stl file in fusion360 file>export tab and move the file in `./inter_results`. We export our stl in mm, so we set the mesh unit to mm.

# %% [markdown]
# Furthurmore, it's our convention to use unit mm in our traps. e.g. [Electric field] = V/mm , [harmonic confining potential] = V/mm^2.so we set

# %%
# this is the unit for our Mesh structure
# in the following code, this is the default unit for python variables
#units 
mesh_unit = 1e-3

# %% [markdown]
# Additional notes (from Wenhao):
# * Why use standard color? We define a set of standard color lib `../../../bemCol_lib/bemCol.adsklib` for two reasons: 1. when exporting to .stl file, fusion 360 will compress 0-256 color(RGBA32) into 0-32 color(RGBA16), which means that some similar colors in fusion 360 will become same color after export to .stl file. Our standard color lib avoid this problem. 2.If you use .stl file exported from fusion 360 DIRECTLY, naming the electrodes would be very convinient. If you use other apps such as Inventor or Meshlab to generate .stl file, you can ignore the second reason because color encoding are quite different in different apps

# %% [markdown]
# ## (2) assign a name for each color

# %%
import pickle
import numpy as np
import matplotlib as mpl
import sys
from utils.helper_functions import *
from bem.bemColors_lib.bemColors import bemColors
from bem import Electrodes, Sphere, Mesh, Grid, Configuration, Result, Box
# load stl geometry file
from bem.formats import stl
# stl_path = "roughness/"+"basic_excitation"+".stl"  


#radius is the radius of the sphere from the ions location to generate a finer
#electrode mesh
radius= 500e-3
#'area' is the area of the triangles inside the sphere
area = 1e-4
# file = 'mit_charge'
# file = 'htrap_overhang_taper_2'
# file_out = 'htrap_overhang_taper_el3'
# stl_path = 'inter_results/taper_overhang/'+file+'.stl'
# fout_name = 'inter_results/taper_overhang/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


file_out = 'htrap_el3.5'
stl_path = 'inter_results/htrap/htrap.stl'
fout_name = 'inter_results/htrap/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


module_path = os.path.abspath('')


s_nta = stl.read_stl(open(stl_path, "rb"))

# %% [markdown]
# Firstly, we print all the colors appear in the stl file. If a color is of standard colors in `bemCol.adsklib` or named manually by function `bemCol.set_my_color()`, then the color will appear in a straightforward name, such as `bem0`,`bem1` ...... . Otherwise, the color will simply be named as `'_unkCol0'` , `'_unkCol1'`, ...
#
# notes
# * try to comment out the line of `ele_col.set_my_color()` in the following block, name `'_unkCol0'` will appear.

# %%
ele_col = bemColors(np.array(list(set(s_nta[2]))),('fusion360','export_stl'))
ele_col.set_my_color(value = (178,178,178),cl_format = ('fusion360','export_stl','RGBA64'),name = 'self_defined')
ele_col.print_stl_colors()
# Out:
# COLORS in the stl:
# ['bem6']
# ['bem13']
# ['bem19']
# ['bem11']
# ['bem17']
# ['bem15']
# ['bem30']
# ['bem1']
# ['bem12']
# ['bem5']
# ['bem25']
# ['bem18']
# ['bem16']
# ['bem3']
# ['bem7']
# ['bem9']
# ['bem2']
# ['bem4']
# ['bem20']
# ['bem10']
# ['bem14']
# ['bem8']
# ['bem21']
# ['_unkColor0']
# TOTAL COLORS:  24

# %% [markdown]
# Next, you need to assign a name for each color that appeared above. With standard colors defined in `bemCol.adsklib`, the correspondence between color and electrode is clear, which make it easy for this step. You can also comment out some `ele_col.set_color_name()`, run all the codes again and observe the missing part in the printed figure, which corresponds to the electrode you comment out. The second method also serves as a double check. Besides, parameter in `stl.stl_to_mesh()` can be set as `quiet = False` to check whether the program reads planes correctly.

# %%
# assign a name for each color
# taper htrap 2022
# assign a name for each color

# In od[key] = value, key is the color from the Fusion360 color library we made
# value assigns a specific name to that color in this program. 
# In future version, we may want to consider getting rid of this step for simplification
# then you just assign the color in fusion 360 and be done with it. The only concern there is you
from collections import OrderedDict
od = OrderedDict()
od['bem1']='DC1'
od['bem2']='DC2'
od['bem3']='DC3'
od['bem4']='DC4'
od['bem5']='DC5'
od['bem6']='DC6'
od['bem7']='DC7'
od['bem8']='DC8'
od['bem9']='DC9'
od['bem10']='DC10'
od['bem11']='DC11'
od['bem12']='DC12'
od['bem13']='DC13'
od['bem14']='DC14'
od['bem15']='DC15'
od['bem16']='DC16'
od['bem17']='DC17'
od['bem18']='DC18'
od['bem19']='DC19'
od['bem20']='DC20'
od['bem21'] = 'DC21'
od['bem25'] = 'RF'
od['bem30'] = 'gnd'
for key in list(od.keys()):
    ele_col.color_electrode(color=key,name=od[key])

# print colors still with no name. These meshes will be neglected in the code below. 
ele_col.drop_colors()

# read stl into mesh with electrode names
# unnamed meshes will not be imported at all

mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=1,
    rename=ele_col.electrode_colors, quiet=True))
# Out:
# dropping color ['_unkColor0']
# TOTAL COLORS DROPPED:  1
# dropping 20083

# %% [markdown]
# ## (3) remesh
#
# In this step, we generate triangle mesh with constraints. The meshes are 2-dimensional triangles on the surface of electrodes. The region enclosed by constraint shape can have finer mesh. Triangulation is done by `triangle` C library. Folowing variables are all in unit `mesh_unit` now.
#
# Our remesh strategy consists of two steps of triangulation:
# 1. global triangulation without constraint. This step eliminate some long and sharp triangles by combining and dividing, and obtains a coarse grain triangulated model.
# 2. local triangulation with constraint. This step refines each triangles in step 1, the triangle density is defined by `mesh.areas_from_constraints
#
# parameters in the below code block should be tuned specificly for different trap geometries.`

# %%
# here we define a spherical constriant zone:
# xl = 270*1e-3
# yl = -3.5*1e-3
# zl = 72.5*1e-3

#here is the location that will be the reference point for further meshing
#usually, this is the ion's location, specified in appropriate units (usually millimeters)
zl = -210*1e-3
yl = 75*1e-3
xl = 3.75*1e-3


mesh.triangulate(opts="",new = False)

# for z in np.arange(-400e-3,700e-3,100e-3):
print('first triangulation:')
# for z in np.arange(-200e-3, 200e-3, 50e-3):
rad = radius*2
inside=area*20
outside=1
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="a2Q",new = False)

# what happened to this feature (Box)? is this on bem savio?
# mesh.areas_from_constraints(Box(start=-0.5, end= 0.5,inside=inside, outside=outside))



# areas_from_constraints specifies sphere with finer mesh inside it.
#  "inside", "outside" set different mesh densities. 
print('second triangulation:')
rad =radius
inside=area
outside=1e4
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="q5Q",new = False)

# save base mesh to a pickle file
# with open(fout_name,'wb') as f:
#     data = (mesh_unit,
#             xl,
#             yl,
#             zl,
#             mesh,
#             list(od.values()))
#     pickle.dump(data,f)
# Out:
# start triangulate RF
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate RF
# start triangulate DC21
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC21
# start triangulate DC2
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC2
# start triangulate DC7
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC7
# start triangulate DC11
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC11
# start triangulate DC12
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC12
# start triangulate DC13
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC13
# start triangulate DC14
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC14
# start triangulate DC15
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC15
# start triangulate DC16
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC16
# start triangulate DC17
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC17
# start triangulate DC18
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC18
# start triangulate DC19
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC19
# start triangulate DC20
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC20
# start triangulate gnd
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate gnd
# start triangulate DC1
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC1
# start triangulate DC3
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC3
# start triangulate DC4
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC4
# start triangulate DC5
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC5
# start triangulate DC6
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC6
# start triangulate DC8
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC8
# start triangulate DC9
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC9
# start triangulate DC10
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC10
# first triangulation:
# start triangulate RF
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate RF
# start triangulate DC21
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC10
# second triangulation:
# start triangulate RF
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate RF
# start triangulate DC21
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC10
# Mesh([('RF',
#        [<bem.triangulation.Triangulation at 0x22c7fb7de80>,
#         <bem.triangulation.Triangulation at 0x22c46a93f40>,
#         <bem.triangulation.Triangulation at 0x22c46a93d60>,
#         <bem.triangulation.Triangulation at 0x22c46aa2310>,
#         <bem.triangulation.Triangulation at 0x22c46aa23d0>,
#         <bem.triangulation.Triangulation at 0x22c46aa2490>,
#         <bem.triangulation.Triangulation at 0x22c46aa2550>,
#         <bem.triangulation.Triangulation at 0x22c46aa2610>,
#         <bem.triangulation.Triangulation at 0x22c46aa26d0>,
#         <bem.triangulation.Triangulation at 0x22c46aa2790>,
#         <bem.triangulation.Triangulation at 0x22c64b48400>,
#         <bem.triangulation.Triangulation at 0x22c7fac03d0>,
#         <bem.triangulation.Triangulation at 0x22c7fb831f0>,
#         <bem.triangulation.Triangulation at 0x22c7f8d79a0>,
#         <bem.triangulation.Triangulation at 0x22c7f8d76a0>,
#         <bem.triangulation.Triangulation at 0x22c46ab20a0>,
#         <bem.triangulation.Triangulation at 0x22c46ab2160>]),
#       ('DC21',
#        [<bem.triangulation.Triangulation at 0x22c46ab2220>,
#         <bem.triangulation.Triangulation at 0x22c46ab22e0>,
#         <bem.triangulation.Triangulation at 0x22c46ab23a0>,
#         <bem.triangulation.Triangulation at 0x22c46ab2460>,
#         <bem.triangulation.Triangulation at 0x22c46ab2520>,
#         <bem.triangulation.Triangulation at 0x22c46ab25e0>,
#         <bem.triangulation.Triangulation at 0x22c46ab26a0>]),
#       ('DC2',
#        [<bem.triangulation.Triangulation at 0x22c46ab2760>,
#         <bem.triangulation.Triangulation at 0x22c46ab2820>,
#         <bem.triangulation.Triangulation at 0x22c46ab28e0>,
#         <bem.triangulation.Triangulation at 0x22c46ab29a0>,
#         <bem.triangulation.Triangulation at 0x22c46ab2a60>,
#         <bem.triangulation.Triangulation at 0x22c46ab2b20>,
#         <bem.triangulation.Triangulation at 0x22c46ab2be0>,
#         <bem.triangulation.Triangulation at 0x22c46ab2ca0>,
#         <bem.triangulation.Triangulation at 0x22c46ab2d60>,
#         <bem.triangulation.Triangulation at 0x22c46ab2e20>,
#         <bem.triangulation.Triangulation at 0x22c46ab2ee0>,
#         <bem.triangulation.Triangulation at 0x22c46ab2fa0>,
#         <bem.triangulation.Triangulation at 0x22c46ab40a0>]),
#       ('DC7',
#        [<bem.triangulation.Triangulation at 0x22c46ab4160>,
#         <bem.triangulation.Triangulation at 0x22c46ab4220>,
#         <bem.triangulation.Triangulation at 0x22c46ab42e0>,
#         <bem.triangulation.Triangulation at 0x22c46ab43a0>,
#         <bem.triangulation.Triangulation at 0x22c46ab4460>,
#         <bem.triangulation.Triangulation at 0x22c46ab4520>,
#         <bem.triangulation.Triangulation at 0x22c46ab45e0>,
#         <bem.triangulation.Triangulation at 0x22c46ab46a0>,
#         <bem.triangulation.Triangulation at 0x22c46ab4760>,
#         <bem.triangulation.Triangulation at 0x22c46ab4820>,
#         <bem.triangulation.Triangulation at 0x22c46ab48e0>,
#         <bem.triangulation.Triangulation at 0x22c46ab49a0>,
#         <bem.triangulation.Triangulation at 0x22c46ab4a60>]),
#       ('DC11',
#        [<bem.triangulation.Triangulation at 0x22c46ab4b20>,
#         <bem.triangulation.Triangulation at 0x22c46ab4be0>,
#         <bem.triangulation.Triangulation at 0x22c46ab4ca0>,
#         <bem.triangulation.Triangulation at 0x22c46ab4d60>,
#         <bem.triangulation.Triangulation at 0x22c46ab4e20>,
#         <bem.triangulation.Triangulation at 0x22c46ab4ee0>,
#         <bem.triangulation.Triangulation at 0x22c46ab4fa0>,
#         <bem.triangulation.Triangulation at 0x22c46ab70a0>,
#         <bem.triangulation.Triangulation at 0x22c46ab7160>,
#         <bem.triangulation.Triangulation at 0x22c46ab7220>,
#         <bem.triangulation.Triangulation at 0x22c46ab72e0>,
#         <bem.triangulation.Triangulation at 0x22c46ab73a0>,
#         <bem.triangulation.Triangulation at 0x22c46ab7460>,
#         <bem.triangulation.Triangulation at 0x22c46ab7520>]),
#       ('DC12',
#        [<bem.triangulation.Triangulation at 0x22c46ab75e0>,
#         <bem.triangulation.Triangulation at 0x22c46ab76a0>,
#         <bem.triangulation.Triangulation at 0x22c46ab7760>,
#         <bem.triangulation.Triangulation at 0x22c46ab7820>,
#         <bem.triangulation.Triangulation at 0x22c46ab78e0>,
#         <bem.triangulation.Triangulation at 0x22c46ab79a0>,
#         <bem.triangulation.Triangulation at 0x22c46ab7a60>,
#         <bem.triangulation.Triangulation at 0x22c46ab7b20>,
#         <bem.triangulation.Triangulation at 0x22c46ab7be0>,
#         <bem.triangulation.Triangulation at 0x22c46ab7ca0>,
#         <bem.triangulation.Triangulation at 0x22c46ab7d60>,
#         <bem.triangulation.Triangulation at 0x22c46ab7e20>,
#         <bem.triangulation.Triangulation at 0x22c46ab7ee0>,
#         <bem.triangulation.Triangulation at 0x22c46ab7fa0>]),
#       ('DC13',
#        [<bem.triangulation.Triangulation at 0x22c46abc0a0>,
#         <bem.triangulation.Triangulation at 0x22c46abc160>,
#         <bem.triangulation.Triangulation at 0x22c46abc220>,
#         <bem.triangulation.Triangulation at 0x22c46abc2e0>,
#         <bem.triangulation.Triangulation at 0x22c46abc3a0>,
#         <bem.triangulation.Triangulation at 0x22c46abc460>,
#         <bem.triangulation.Triangulation at 0x22c46abc520>,
#         <bem.triangulation.Triangulation at 0x22c46abc5e0>,
#         <bem.triangulation.Triangulation at 0x22c46abc6a0>,
#         <bem.triangulation.Triangulation at 0x22c46abc760>,
#         <bem.triangulation.Triangulation at 0x22c46abc820>,
#         <bem.triangulation.Triangulation at 0x22c46abc8e0>,
#         <bem.triangulation.Triangulation at 0x22c46abc9a0>]),
#       ('DC14',
#        [<bem.triangulation.Triangulation at 0x22c46abca60>,
#         <bem.triangulation.Triangulation at 0x22c46abcb20>,
#         <bem.triangulation.Triangulation at 0x22c46abcbe0>,
#         <bem.triangulation.Triangulation at 0x22c46abcca0>,
#         <bem.triangulation.Triangulation at 0x22c46abcd60>,
#         <bem.triangulation.Triangulation at 0x22c46abce20>,
#         <bem.triangulation.Triangulation at 0x22c46abcee0>,
#         <bem.triangulation.Triangulation at 0x22c46abcfa0>,
#         <bem.triangulation.Triangulation at 0x22c46bc30a0>,
#         <bem.triangulation.Triangulation at 0x22c46bc3160>,
#         <bem.triangulation.Triangulation at 0x22c46bc3220>,
#         <bem.triangulation.Triangulation at 0x22c46bc32e0>,
#         <bem.triangulation.Triangulation at 0x22c46bc33a0>]),
#       ('DC15',
#        [<bem.triangulation.Triangulation at 0x22c46bc3460>,
#         <bem.triangulation.Triangulation at 0x22c46bc3520>,
#         <bem.triangulation.Triangulation at 0x22c46bc35e0>,
#         <bem.triangulation.Triangulation at 0x22c46bc36a0>,
#         <bem.triangulation.Triangulation at 0x22c46bc3760>,
#         <bem.triangulation.Triangulation at 0x22c46bc3820>,
#         <bem.triangulation.Triangulation at 0x22c46bc38e0>,
#         <bem.triangulation.Triangulation at 0x22c46bc39a0>,
#         <bem.triangulation.Triangulation at 0x22c46bc3a60>,
#         <bem.triangulation.Triangulation at 0x22c46bc3b20>,
#         <bem.triangulation.Triangulation at 0x22c46bc3be0>,
#         <bem.triangulation.Triangulation at 0x22c46bc3ca0>,
#         <bem.triangulation.Triangulation at 0x22c46bc3d60>]),
#       ('DC16',
#        [<bem.triangulation.Triangulation at 0x22c46bc3e20>,
#         <bem.triangulation.Triangulation at 0x22c46bc3ee0>,
#         <bem.triangulation.Triangulation at 0x22c46bc3fa0>,
#         <bem.triangulation.Triangulation at 0x22c46bc60a0>,
#         <bem.triangulation.Triangulation at 0x22c46bc6160>,
#         <bem.triangulation.Triangulation at 0x22c46bc6220>,
#         <bem.triangulation.Triangulation at 0x22c46bc62e0>,
#         <bem.triangulation.Triangulation at 0x22c46bc63a0>,
#         <bem.triangulation.Triangulation at 0x22c46bc6460>,
#         <bem.triangulation.Triangulation at 0x22c46bc6520>,
#         <bem.triangulation.Triangulation at 0x22c46bc6610>,
#         <bem.triangulation.Triangulation at 0x22c46bc66a0>,
#         <bem.triangulation.Triangulation at 0x22c46bc6760>]),
#       ('DC17',
#        [<bem.triangulation.Triangulation at 0x22c46bc6820>,
#         <bem.triangulation.Triangulation at 0x22c46bc68e0>,
#         <bem.triangulation.Triangulation at 0x22c46bc69a0>,
#         <bem.triangulation.Triangulation at 0x22c46bc6a60>,
#         <bem.triangulation.Triangulation at 0x22c46bc6b20>,
#         <bem.triangulation.Triangulation at 0x22c46bc6be0>,
#         <bem.triangulation.Triangulation at 0x22c46bc6ca0>,
#         <bem.triangulation.Triangulation at 0x22c46bc6d60>,
#         <bem.triangulation.Triangulation at 0x22c46bc6e20>,
#         <bem.triangulation.Triangulation at 0x22c46bc6ee0>,
#         <bem.triangulation.Triangulation at 0x22c46bc6fa0>,
#         <bem.triangulation.Triangulation at 0x22c46bf40a0>,
#         <bem.triangulation.Triangulation at 0x22c46bf4160>]),
#       ('DC18',
#        [<bem.triangulation.Triangulation at 0x22c46bf4220>,
# ...
#         <bem.triangulation.Triangulation at 0x22c46c21ee0>,
#         <bem.triangulation.Triangulation at 0x22c46c21fa0>,
#         <bem.triangulation.Triangulation at 0x22c46c2c0a0>,
#         <bem.triangulation.Triangulation at 0x22c46c2c160>,
#         <bem.triangulation.Triangulation at 0x22c46c2c220>,
#         <bem.triangulation.Triangulation at 0x22c46c2c2e0>,
#         <bem.triangulation.Triangulation at 0x22c46c2c3a0>,
#         <bem.triangulation.Triangulation at 0x22c46c2c460>,
#         <bem.triangulation.Triangulation at 0x22c46c2c520>,
#         <bem.triangulation.Triangulation at 0x22c46c2c5e0>,
#         <bem.triangulation.Triangulation at 0x22c46c2c6a0>,
#         <bem.triangulation.Triangulation at 0x22c46c2c760>,
#         <bem.triangulation.Triangulation at 0x22c46c2c820>,
#         <bem.triangulation.Triangulation at 0x22c46c2c8e0>,
#         <bem.triangulation.Triangulation at 0x22c46c2c9a0>,
#         <bem.triangulation.Triangulation at 0x22c46c2ca60>,
#         <bem.triangulation.Triangulation at 0x22c46c2cb20>,
#         <bem.triangulation.Triangulation at 0x22c46c2cbe0>,
#         <bem.triangulation.Triangulation at 0x22c46c2cca0>,
#         <bem.triangulation.Triangulation at 0x22c46c2cd60>,
#         <bem.triangulation.Triangulation at 0x22c46c2ce20>,
#         <bem.triangulation.Triangulation at 0x22c46c2cee0>,
#         <bem.triangulation.Triangulation at 0x22c46c2cfa0>,
#         <bem.triangulation.Triangulation at 0x22c46c4e0a0>,
#         <bem.triangulation.Triangulation at 0x22c46c4e160>,
#         <bem.triangulation.Triangulation at 0x22c46c4e220>,
#         <bem.triangulation.Triangulation at 0x22c46c4e2e0>,
#         <bem.triangulation.Triangulation at 0x22c46c4e3a0>,
#         <bem.triangulation.Triangulation at 0x22c46c4e460>,
#         <bem.triangulation.Triangulation at 0x22c46c4e520>,
#         <bem.triangulation.Triangulation at 0x22c46c4e5e0>,
#         <bem.triangulation.Triangulation at 0x22c46c4e6a0>,
#         <bem.triangulation.Triangulation at 0x22c46c4e760>,
#         <bem.triangulation.Triangulation at 0x22c46c4e820>,
#         <bem.triangulation.Triangulation at 0x22c46c4e8e0>,
#         <bem.triangulation.Triangulation at 0x22c46c4e9a0>,
#         <bem.triangulation.Triangulation at 0x22c46c4ea60>,
#         <bem.triangulation.Triangulation at 0x22c46c4eb20>,
#         <bem.triangulation.Triangulation at 0x22c46c4ebe0>,
#         <bem.triangulation.Triangulation at 0x22c46c4eca0>,
#         <bem.triangulation.Triangulation at 0x22c46c4ed60>,
#         <bem.triangulation.Triangulation at 0x22c46c4ee20>,
#         <bem.triangulation.Triangulation at 0x22c46c4eee0>,
#         <bem.triangulation.Triangulation at 0x22c46c4efa0>,
#         <bem.triangulation.Triangulation at 0x22c46c530a0>,
#         <bem.triangulation.Triangulation at 0x22c46c53160>,
#         <bem.triangulation.Triangulation at 0x22c46c53220>,
#         <bem.triangulation.Triangulation at 0x22c46c532e0>,
#         <bem.triangulation.Triangulation at 0x22c46c533a0>,
#         <bem.triangulation.Triangulation at 0x22c46c53460>,
#         <bem.triangulation.Triangulation at 0x22c46c53520>,
#         <bem.triangulation.Triangulation at 0x22c46c535e0>,
#         <bem.triangulation.Triangulation at 0x22c46c536a0>,
#         <bem.triangulation.Triangulation at 0x22c46c53760>,
#         <bem.triangulation.Triangulation at 0x22c46c53820>,
#         <bem.triangulation.Triangulation at 0x22c46c538e0>,
#         <bem.triangulation.Triangulation at 0x22c46c539a0>,
#         <bem.triangulation.Triangulation at 0x22c46c53a60>,
#         <bem.triangulation.Triangulation at 0x22c46c53b20>,
#         <bem.triangulation.Triangulation at 0x22c46c53be0>,
#         <bem.triangulation.Triangulation at 0x22c46c53ca0>,
#         <bem.triangulation.Triangulation at 0x22c46c53d60>,
#         <bem.triangulation.Triangulation at 0x22c46c53e20>,
#         <bem.triangulation.Triangulation at 0x22c46c53ee0>,
#         <bem.triangulation.Triangulation at 0x22c46c53fa0>,
#         <bem.triangulation.Triangulation at 0x22c46c580a0>,
#         <bem.triangulation.Triangulation at 0x22c46c58160>,
#         <bem.triangulation.Triangulation at 0x22c46c58220>,
#         <bem.triangulation.Triangulation at 0x22c46c582e0>,
#         <bem.triangulation.Triangulation at 0x22c46c583a0>,
#         <bem.triangulation.Triangulation at 0x22c46c58460>,
#         <bem.triangulation.Triangulation at 0x22c46c58520>,
#         <bem.triangulation.Triangulation at 0x22c46c585e0>,
#         <bem.triangulation.Triangulation at 0x22c46c586a0>,
#         <bem.triangulation.Triangulation at 0x22c46c58760>,
#         <bem.triangulation.Triangulation at 0x22c46c58820>,
#         <bem.triangulation.Triangulation at 0x22c46c588e0>,
#         <bem.triangulation.Triangulation at 0x22c46c589a0>,
#         <bem.triangulation.Triangulation at 0x22c46c58a60>,
#         <bem.triangulation.Triangulation at 0x22c46c58b20>,
#         <bem.triangulation.Triangulation at 0x22c46c58be0>,
#         <bem.triangulation.Triangulation at 0x22c46c58ca0>,
#         <bem.triangulation.Triangulation at 0x22c46c58d60>,
#         <bem.triangulation.Triangulation at 0x22c46c58e20>,
#         <bem.triangulation.Triangulation at 0x22c46c58ee0>,
#         <bem.triangulation.Triangulation at 0x22c46c58fa0>,
#         <bem.triangulation.Triangulation at 0x22c46c5d0a0>,
#         <bem.triangulation.Triangulation at 0x22c46c5d160>,
#         <bem.triangulation.Triangulation at 0x22c46c5d220>,
#         <bem.triangulation.Triangulation at 0x22c46c5d2e0>,
#         <bem.triangulation.Triangulation at 0x22c46c5d400>,
#         <bem.triangulation.Triangulation at 0x22c46c5d460>,
#         <bem.triangulation.Triangulation at 0x22c46c5d520>,
#         <bem.triangulation.Triangulation at 0x22c46c5d5e0>,
#         <bem.triangulation.Triangulation at 0x22c46c5d6a0>,
#         <bem.triangulation.Triangulation at 0x22c46c5d760>,
#         <bem.triangulation.Triangulation at 0x22c46c5d820>,
#         <bem.triangulation.Triangulation at 0x22c46c5d8e0>,
#         <bem.triangulation.Triangulation at 0x22c46c5d9a0>,
#         <bem.triangulation.Triangulation at 0x22c46c5da60>,
#         <bem.triangulation.Triangulation at 0x22c46c5db20>,
#         <bem.triangulation.Triangulation at 0x22c46c5dbe0>,
#         <bem.triangulation.Triangulation at 0x22c46c5dca0>,
#         <bem.triangulation.Triangulation at 0x22c46c5dd60>,
#         <bem.triangulation.Triangulation at 0x22c46c5de20>,
#         <bem.triangulation.Triangulation at 0x22c46c5dee0>,
#         <bem.triangulation.Triangulation at 0x22c46c5dfa0>,
#         <bem.triangulation.Triangulation at 0x22c46c620a0>,
#         <bem.triangulation.Triangulation at 0x22c46c62160>,
#         <bem.triangulation.Triangulation at 0x22c46c62220>,
#         <bem.triangulation.Triangulation at 0x22c46c622e0>,
#         <bem.triangulation.Triangulation at 0x22c46c623a0>,
#         <bem.triangulation.Triangulation at 0x22c46c62460>,
#         <bem.triangulation.Triangulation at 0x22c46c62520>,
#         <bem.triangulation.Triangulation at 0x22c46c625e0>,
#         <bem.triangulation.Triangulation at 0x22c46c626a0>,
#         <bem.triangulation.Triangulation at 0x22c46c62760>,
#         <bem.triangulation.Triangulation at 0x22c46c62820>,
#         <bem.triangulation.Triangulation at 0x22c46c628e0>,
#         <bem.triangulation.Triangulation at 0x22c46c629a0>,
#         <bem.triangulation.Triangulation at 0x22c46c62a60>,
#         <bem.triangulation.Triangulation at 0x22c46c62b20>,
#         <bem.triangulation.Triangulation at 0x22c46c62be0>,
#         <bem.triangulation.Triangulation at 0x22c46c62ca0>,
#         <bem.triangulation.Triangulation at 0x22c46c62d60>,
#         <bem.triangulation.Triangulation at 0x22c46c62e20>,
#         <bem.triangulation.Triangulation at 0x22c46c62ee0>,
#         <bem.triangulation.Triangulation at 0x22c46c62fa0>,
#         <bem.triangulation.Triangulation at 0x22c46c670a0>,
#         <bem.triangulation.Triangulation at 0x22c46c67160>,
#         <bem.triangulation.Triangulation at 0x22c46c67220>,
#         <bem.triangulation.Triangulation at 0x22c46c672e0>,
#         <bem.triangulation.Triangulation at 0x22c46c673a0>,
#         <bem.triangulation.Triangulation at 0x22c46c67460>,
#         <bem.triangulation.Triangulation at 0x22c46c67520>,
#         <bem.triangulation.Triangulation at 0x22c46c675e0>,
#         <bem.triangulation.Triangulation at 0x22c46c676a0>,
#         <bem.triangulation.Triangulation at 0x22c46c67760>,
#         <bem.triangulation.Triangulation at 0x22c46c67820>,
#         <bem.triangulation.Triangulation at 0x22c46c678e0>,
#         <bem.triangulation.Triangulation at 0x22c46c679a0>,
#         <bem.triangulation.Triangulation at 0x22c46c67a60>,
#         <bem.triangulation.Triangulation at 0x22c46c67b20>,
#         <bem.triangulation.Triangulation at 0x22c46c67be0>,
#         <bem.triangulation.Triangulation at 0x22c46c67ca0>,
#         <bem.triangulation.Triangulation at 0x22c46c67d60>,
#         <bem.triangulation.Triangulation at 0x22c46c67e20>,
#         <bem.triangulation.Triangulation at 0x22c46c67ee0>,
#         <bem.triangulation.Triangulation at 0x22c46c67fa0>,
#         <bem.triangulation.Triangulation at 0x22c46c6c0a0>,
#         <bem.triangulation.Triangulation at 0x22c46c6c160>,
#         <bem.triangulation.Triangulation at 0x22c46c6c220>]),
#       ('DC1',
#        [<bem.triangulation.Triangulation at 0x22c46c6c2e0>,
#         <bem.triangulation.Triangulation at 0x22c46c6c3a0>,
#         <bem.triangulation.Triangulation at 0x22c46c6c460>,
#         <bem.triangulation.Triangulation at 0x22c46c6c520>,
#         <bem.triangulation.Triangulation at 0x22c46c6c5e0>,
#         <bem.triangulation.Triangulation at 0x22c46c6c6a0>,
#         <bem.triangulation.Triangulation at 0x22c46c6c760>,
#         <bem.triangulation.Triangulation at 0x22c46c6c820>,
#         <bem.triangulation.Triangulation at 0x22c46c6c8e0>,
#         <bem.triangulation.Triangulation at 0x22c46c6c9a0>,
#         <bem.triangulation.Triangulation at 0x22c46c6ca60>,
#         <bem.triangulation.Triangulation at 0x22c46c6cb20>,
#         <bem.triangulation.Triangulation at 0x22c46c6cbe0>,
#         <bem.triangulation.Triangulation at 0x22c46c6cca0>,
#         <bem.triangulation.Triangulation at 0x22c46c6cd60>,
#         <bem.triangulation.Triangulation at 0x22c46c6ce20>]),
#       ('DC3',
#        [<bem.triangulation.Triangulation at 0x22c46c6cee0>,
#         <bem.triangulation.Triangulation at 0x22c46c6cfa0>,
#         <bem.triangulation.Triangulation at 0x22c46c710a0>,
#         <bem.triangulation.Triangulation at 0x22c46c71160>,
#         <bem.triangulation.Triangulation at 0x22c46c71220>,
#         <bem.triangulation.Triangulation at 0x22c46c712e0>,
#         <bem.triangulation.Triangulation at 0x22c46c713a0>,
#         <bem.triangulation.Triangulation at 0x22c46c71460>,
#         <bem.triangulation.Triangulation at 0x22c46c71520>,
#         <bem.triangulation.Triangulation at 0x22c46c715e0>,
#         <bem.triangulation.Triangulation at 0x22c46c716a0>,
#         <bem.triangulation.Triangulation at 0x22c46c71760>,
#         <bem.triangulation.Triangulation at 0x22c46c71820>,
#         <bem.triangulation.Triangulation at 0x22c46c718e0>]),
#       ('DC4',
#        [<bem.triangulation.Triangulation at 0x22c46c719a0>,
#         <bem.triangulation.Triangulation at 0x22c46c71a60>,
#         <bem.triangulation.Triangulation at 0x22c46c71b20>,
#         <bem.triangulation.Triangulation at 0x22c46c71be0>,
#         <bem.triangulation.Triangulation at 0x22c46c71ca0>,
#         <bem.triangulation.Triangulation at 0x22c46c71d60>,
#         <bem.triangulation.Triangulation at 0x22c46c71e20>,
#         <bem.triangulation.Triangulation at 0x22c46c71ee0>,
#         <bem.triangulation.Triangulation at 0x22c46c71fa0>,
#         <bem.triangulation.Triangulation at 0x22c46c760a0>,
#         <bem.triangulation.Triangulation at 0x22c46c76160>,
#         <bem.triangulation.Triangulation at 0x22c46c76220>,
#         <bem.triangulation.Triangulation at 0x22c46c762e0>,
#         <bem.triangulation.Triangulation at 0x22c46c763a0>,
#         <bem.triangulation.Triangulation at 0x22c46c76460>]),
#       ('DC5',
#        [<bem.triangulation.Triangulation at 0x22c46c76520>,
#         <bem.triangulation.Triangulation at 0x22c46c765e0>,
#         <bem.triangulation.Triangulation at 0x22c46c766a0>,
#         <bem.triangulation.Triangulation at 0x22c46c76760>,
#         <bem.triangulation.Triangulation at 0x22c46c76820>,
#         <bem.triangulation.Triangulation at 0x22c46c768e0>,
#         <bem.triangulation.Triangulation at 0x22c46c769a0>,
#         <bem.triangulation.Triangulation at 0x22c46c76a60>,
#         <bem.triangulation.Triangulation at 0x22c46c76b20>,
#         <bem.triangulation.Triangulation at 0x22c46c76be0>,
#         <bem.triangulation.Triangulation at 0x22c46c76ca0>,
#         <bem.triangulation.Triangulation at 0x22c46c76d60>,
#         <bem.triangulation.Triangulation at 0x22c46c76e20>,
#         <bem.triangulation.Triangulation at 0x22c46c76ee0>]),
#       ('DC6',
#        [<bem.triangulation.Triangulation at 0x22c46c76fa0>,
#         <bem.triangulation.Triangulation at 0x22c46c7b0a0>,
#         <bem.triangulation.Triangulation at 0x22c46c7b160>,
#         <bem.triangulation.Triangulation at 0x22c46c7b220>,
#         <bem.triangulation.Triangulation at 0x22c46c7b2e0>,
#         <bem.triangulation.Triangulation at 0x22c46c7b3a0>,
#         <bem.triangulation.Triangulation at 0x22c46c7b460>,
#         <bem.triangulation.Triangulation at 0x22c46c7b520>,
#         <bem.triangulation.Triangulation at 0x22c46c7b5e0>,
#         <bem.triangulation.Triangulation at 0x22c46c7b6a0>,
#         <bem.triangulation.Triangulation at 0x22c46c7b760>,
#         <bem.triangulation.Triangulation at 0x22c46c7b820>,
#         <bem.triangulation.Triangulation at 0x22c46c7b8e0>,
#         <bem.triangulation.Triangulation at 0x22c46c7b9a0>]),
#       ('DC8',
#        [<bem.triangulation.Triangulation at 0x22c46c7ba60>,
#         <bem.triangulation.Triangulation at 0x22c46c7bb20>,
#         <bem.triangulation.Triangulation at 0x22c46c7bbe0>,
#         <bem.triangulation.Triangulation at 0x22c46c7bca0>,
#         <bem.triangulation.Triangulation at 0x22c46c7bdc0>,
#         <bem.triangulation.Triangulation at 0x22c46c7be20>,
#         <bem.triangulation.Triangulation at 0x22c46c7bee0>,
#         <bem.triangulation.Triangulation at 0x22c46c7bfa0>,
#         <bem.triangulation.Triangulation at 0x22c46c7f0a0>,
#         <bem.triangulation.Triangulation at 0x22c46c7f160>,
#         <bem.triangulation.Triangulation at 0x22c46c7f220>,
#         <bem.triangulation.Triangulation at 0x22c46c7f2e0>,
#         <bem.triangulation.Triangulation at 0x22c46c7f3a0>,
#         <bem.triangulation.Triangulation at 0x22c46c7f460>]),
#       ('DC9',
#        [<bem.triangulation.Triangulation at 0x22c46c7f520>,
#         <bem.triangulation.Triangulation at 0x22c46c7f5e0>,
#         <bem.triangulation.Triangulation at 0x22c46c7f6a0>,
#         <bem.triangulation.Triangulation at 0x22c46c7f760>,
#         <bem.triangulation.Triangulation at 0x22c46c7f820>,
#         <bem.triangulation.Triangulation at 0x22c46c7f8e0>,
#         <bem.triangulation.Triangulation at 0x22c46c7f9a0>,
#         <bem.triangulation.Triangulation at 0x22c46c7fa60>,
#         <bem.triangulation.Triangulation at 0x22c46c7fb20>,
#         <bem.triangulation.Triangulation at 0x22c46c7fbe0>,
#         <bem.triangulation.Triangulation at 0x22c46c7fca0>,
#         <bem.triangulation.Triangulation at 0x22c46c7fd60>,
#         <bem.triangulation.Triangulation at 0x22c46c7fe20>,
#         <bem.triangulation.Triangulation at 0x22c46c7fee0>]),
#       ('DC10',
#        [<bem.triangulation.Triangulation at 0x22c46c7ffa0>,
#         <bem.triangulation.Triangulation at 0x22c46afc0a0>,
#         <bem.triangulation.Triangulation at 0x22c46afc160>,
#         <bem.triangulation.Triangulation at 0x22c46afc220>,
#         <bem.triangulation.Triangulation at 0x22c46afc2e0>,
#         <bem.triangulation.Triangulation at 0x22c46afc3a0>,
#         <bem.triangulation.Triangulation at 0x22c46afc460>,
#         <bem.triangulation.Triangulation at 0x22c46afc520>,
#         <bem.triangulation.Triangulation at 0x22c46afc5e0>,
#         <bem.triangulation.Triangulation at 0x22c46afc6a0>,
#         <bem.triangulation.Triangulation at 0x22c46afc760>])])

# %%
# save base mesh to a pickle file
with open(fout_name,'wb') as f:
    data = (mesh_unit,
            xl,
            yl,
            zl,
            mesh,
            list(od.values()))
    pickle.dump(data,f)

# %% [markdown]
# ## view mesh
# Uses Pyvista package to generate interactive 3-d plot of the mesh

# %%
# Plot triangle mezshes of the final mesh
mesh.plot()

# %% [markdown]
# Show number of points included in the mesh

# %%
print(len(mesh.points))
# Out:
# 10440
