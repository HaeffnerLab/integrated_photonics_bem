# %% [markdown]
# # `Documention & Tutorial`
# This BEM package is used for for numerical simulation of the electric field of ion traps in python. Some external packages are wrapped into it:
#
# * fast triangulation (http://www.cs.cmu.edu/~quake/triangle.research.html)
# * fastlap boundary element method (Nabors K S. Efficient three-dimensional capacitance calculation[D]. Massachusetts Institute of Technology, 1993.)
#
# This document, also as a tutorial, explains how to use these packages to compute the electric field and compute its multipole expansion coefficient starting from scratch with a fusion 360 trap model(take `./f3d/htrap_cutout_overhang_9x5mm.f3d` for example). Our document consists of three .ipynb files:
#
# * `I_Mesh_Processing.ipynb`
# * `II_Field_Simulation.ipynb`
# * `III_Multipole_Expansion.ipynb`
#
# We split the document into three files for two reasons:
# 1. The most time consuming part `II_Field_Simulation.ipynb` could be taken out alone and run on a high peformance computer.
# 2. The intermediate result between files can be checked- 'intermediate files' refer to the inital mesh grid (that corresponds to the charge distribution), the simulation values and the simulation coordinates, all of which are saved in the inter_results folder. So if the voltage solution files for the trap don't make sense, it is possible to go back through saved data to see where things have gone wrong.
# Here are the three jupyter notebooks and what:
# 1. I_Mesh_Processing- this notebook generates a mesh of the trap, saved in inter_results as a .pkl file
#
#
# Going through three files in order and running their python code will help you understand our workflow. Generally our workflow divides into three steps, corresponding to the above three .ipynb files. First, in I_Mesh_Processing, we identify different electrodes of the trap model by different colors. Also, we refine the trap model meshes to prepare for the second step. The result is stored in `mesh_result.pkl`.
#
# Secondly, in II_Field_Simulation, we simulate the electric potential with fastlap boundary element method(FMM), the accuracy of this step depends on the mesh size in the first step. The result is stored in `field_result.pkl`.
#
# Thirdly, in III_Multipole_Expansion, we analyze the electric field and electric potential. This notebook generates the multipole coefficients of the fields and potentials for each electrode and uses that information to generate a solution file with the function call `write_csv`. If your solution don't make sense, a good place to start is to insure that the mesh you are using is fine enough (generate several field results for different meshes)- if the potentials and fields are converging to specific values, this suggests there is something wrong with the multipole expansion. If you start with multipole expansion, you do not know if it is a problem with the expansion or with the field.
#
# Before running codes, you must set up the environment according to instructions in `README`
#
# notes
# * Our workflow, as indicated by this document, abandons mayavi(with its embeded package tvtk). But we reserve mayavi in our Bem source code, if you want to use mayavi related functions, you must set up environment with files in`./backup/setup_with_mayavi`, just replace corresponding files in the root folder with them and set up.
#     * why we abandon mayavi: because its python interface(with its dependence vtk and PyQt5) requires complex package dependencies and version controls especially for new python versions. This makes it difficult to maintain this project.
#     * why we still keep mayavi in the source code? Because it is rooted in our source code deeply. We can just avoid invoking related functions instead of deleting them, because they may make sense in the future.

# %% [markdown]
# # `I. Mesh Processing`
# This .pynb file reads a colored model file `./inter_results/htrap_cutout.stl`, and assigns a name for each color(thus for each electrode). The result is stored in `./inter_results/mesh_result.pkl`.
#
# In this file we name different electrodes and refine the meshes. The size of mesh determines the accuracy in next step. You should set the mesh finer and finer until the result converges. Also, you can set the mesh finer and test the convergence.
#
# ## (1) color your electrodes (in fusion 360) and export stl
# First of all, you have a trap model in fusion 360 project, for example, `./f3d/htrap_cutout_overhang_9x5mm.f3d`. Here we use different color to identify different electrodes(STL file stores color for each mesh). In fusion 360, you can assign different appearance for different electrodes. We recommend to use ../../bemCol_lib/bemCol.adsklib for different electrodes. Same color for two electrodes means they are treated as the same electrode. Then we get `./f3d/htrap_cutout_overhang_9x5mm_my_colored.f3d`
#
# Then export to an stl file in fusion360 file>export tab and move the file in `./inter_results`. We export our stl in mm, so we set the mesh unit to mm.

# %% [markdown]
# Furthurmore, it's our convention to use unit mm in our traps. e.g. [Electric field] = V/mm , [harmonic confining potential] = V/mm^2.so we set

# %%
# this is the unit for our Mesh structure
# in the following code, this is the default unit for python variables
#units 
mesh_unit = 1e-3

# %% [markdown]
# Additional notes (from Wenhao):
# * Why use standard color? We define a set of standard color lib `../../../bemCol_lib/bemCol.adsklib` for two reasons: 1. when exporting to .stl file, fusion 360 will compress 0-256 color(RGBA32) into 0-32 color(RGBA16), which means that some similar colors in fusion 360 will become same color after export to .stl file. Our standard color lib avoid this problem. 2.If you use .stl file exported from fusion 360 DIRECTLY, naming the electrodes would be very convinient. If you use other apps such as Inventor or Meshlab to generate .stl file, you can ignore the second reason because color encoding are quite different in different apps

# %% [markdown]
# ## (2) assign a name for each color

# %%
import pickle
import numpy as np
import matplotlib as mpl
import sys
from utils.helper_functions import *
from bem.bemColors_lib.bemColors import bemColors
from bem import Electrodes, Sphere, Mesh, Grid, Configuration, Result, Box
# load stl geometry file
from bem.formats import stl
# stl_path = "roughness/"+"basic_excitation"+".stl"  


#radius is the radius of the sphere from the ions location to generate a finer
#electrode mesh
radius= 500e-3
#'area' is the area of the triangles inside the sphere
area = 1e-4
# file = 'mit_charge'
# file = 'htrap_cutout_overhang_taper_2'
# file_out = 'htrap_cutout_overhang_taper_el3'
# stl_path = 'inter_results/taper_overhang/'+file+'.stl'
# fout_name = 'inter_results/taper_overhang/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


file_out = 'Zhi_trap_100um_el2'
stl_path = 'inter_results/Zhi_trap_100um/Zhi_Trap_100um.stl'
fout_name = 'inter_results/Zhi_trap_100um/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


module_path = os.path.abspath('')


s_nta = stl.read_stl(open(stl_path, "rb"))

# %% [markdown]
# Firstly, we print all the colors appear in the stl file. If a color is of standard colors in `bemCol.adsklib` or named manually by function `bemCol.set_my_color()`, then the color will appear in a straightforward name, such as `bem0`,`bem1` ...... . Otherwise, the color will simply be named as `'_unkCol0'` , `'_unkCol1'`, ...
#
# notes
# * try to comment out the line of `ele_col.set_my_color()` in the following block, name `'_unkCol0'` will appear.

# %%
ele_col = bemColors(np.array(list(set(s_nta[2]))),('fusion360','export_stl'))
ele_col.set_my_color(value = (178,178,178),cl_format = ('fusion360','export_stl','RGBA64'),name = 'self_defined')
ele_col.print_stl_colors()
# Out:
# COLORS in the stl:
# ['bem6']
# ['bem13']
# ['bem19']
# ['bem11']
# ['bem17']
# ['bem15']
# ['bem1']
# ['bem12']
# ['bem22']
# ['bem5']
# ['bem18']
# ['bem3']
# ['bem16']
# ['bem7']
# ['bem23']
# ['bem9']
# ['bem4']
# ['bem2']
# ['bem20']
# ['bem10']
# ['bem14']
# ['bem8']
# ['bem21']
# ['_unkColor0']
# TOTAL COLORS:  24

# %% [markdown]
# Next, you need to assign a name for each color that appeared above. With standard colors defined in `bemCol.adsklib`, the correspondence between color and electrode is clear, which make it easy for this step. You can also comment out some `ele_col.set_color_name()`, run all the codes again and observe the missing part in the printed figure, which corresponds to the electrode you comment out. The second method also serves as a double check. Besides, parameter in `stl.stl_to_mesh()` can be set as `quiet = False` to check whether the program reads planes correctly.

# %%
# assign a name for each color
# taper htrap_cutout 2022
# assign a name for each color

# In od[key] = value, key is the color from the Fusion360 color library we made
# value assigns a specific name to that color in this program. 
# In future version, we may want to consider getting rid of this step for simplification
# then you just assign the color in fusion 360 and be done with it. The only concern there is you
from collections import OrderedDict
od = OrderedDict()
od['bem1']='GND'
od['bem2']='DC1'
od['bem3']='DC2'
od['bem4']='DC3'
od['bem5']='DC4'
od['bem6']='DC5'
od['bem7']='DC6'
od['bem8']='DC7'
od['bem9']='DC8'
od['bem10']='DC9'
od['bem11']='DC10'
od['bem12']='DC11'
od['bem13']='RF'
od['bem14']='DC12'
od['bem15']='DC13'
od['bem16']='DC14'
od['bem17']='DC15'
od['bem18']='DC16'
od['bem19']='DC17'
od['bem20']='DC18'
od['bem21'] = 'DC19'
od['bem22'] = 'DC20'
od['bem23'] = 'DC21'
for key in list(od.keys()):
    ele_col.color_electrode(color=key,name=od[key])

# print colors still with no name. These meshes will be neglected in the code below. 
ele_col.drop_colors()

# read stl into mesh with electrode names
# unnamed meshes will not be imported at all

mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=1,
    rename=ele_col.electrode_colors, quiet=True))
# Out:
# dropping color ['_unkColor0']
# TOTAL COLORS DROPPED:  1
# dropping 20083

# %% [markdown]
# ## (3) remesh
#
# In this step, we generate triangle mesh with constraints. The meshes are 2-dimensional triangles on the surface of electrodes. The region enclosed by constraint shape can have finer mesh. Triangulation is done by `triangle` C library. Folowing variables are all in unit `mesh_unit` now.
#
# Our remesh strategy consists of two steps of triangulation:
# 1. global triangulation without constraint. This step eliminate some long and sharp triangles by combining and dividing, and obtains a coarse grain triangulated model.
# 2. local triangulation with constraint. This step refines each triangles in step 1, the triangle density is defined by `mesh.areas_from_constraints
#
# parameters in the below code block should be tuned specificly for different trap geometries.`

# %%
# here we define a spherical constriant zone:
# xl = 270*1e-3
# yl = -3.5*1e-3
# zl = 72.5*1e-3

#here is the location that will be the reference point for further meshing
#usually, this is the ion's location, specified in appropriate units (usually millimeters)
zl = 570*1e-3
yl = 100*1e-3
xl = 0*1e-3


mesh.triangulate(opts="",new = False)

# for z in np.arange(-400e-3,700e-3,100e-3):
print('first triangulation:')
# for z in np.arange(-200e-3, 200e-3, 50e-3):
rad = radius*10
inside=area*500
outside=1e6
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="a2Q",new = False)

# # what happened to this feature (Box)? is this on bem savio?
# # mesh.areas_from_constraints(Box(start=-0.5, end= 0.5,inside=inside, outside=outside))


# areas_from_constraints specifies sphere with finer mesh inside it.
#  "inside", "outside" set different mesh densities. 
print('second triangulation:')
rad =radius*2
inside=area*3
outside=1e4
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="q5Q",new = False)

# save base mesh to a pickle file
# with open(fout_name,'wb') as f:
#     data = (mesh_unit,
#             xl,
#             yl,
#             zl,
#             mesh,
#             list(od.values()))
#     pickle.dump(data,f)
# Out:
# start triangulate GND
# final opts zr
# finish triangulate GND
# start triangulate DC21
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC21
# start triangulate DC17
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC17
# start triangulate DC13
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC13
# start triangulate DC10
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC10
# start triangulate DC6
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC6
# start triangulate DC2
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC2
# start triangulate DC3
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC3
# start triangulate DC7
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC7
# start triangulate DC11
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC11
# start triangulate DC14
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC14
# start triangulate DC18
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC18
# start triangulate DC20
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC20
# start triangulate DC16
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC16
# start triangulate DC12
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC12
# start triangulate DC9
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC9
# start triangulate DC5
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC5
# start triangulate DC1
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC1
# start triangulate DC4
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC4
# start triangulate DC8
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC8
# start triangulate RF
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate RF
# start triangulate DC15
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC15
# start triangulate DC19
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC19
# first triangulation:
# start triangulate GND
# final opts a2Qzra
# finish triangulate GND
# start triangulate DC21
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC21
# start triangulate DC17
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC17
# start triangulate DC13
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC13
# start triangulate DC10
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC10
# start triangulate DC6
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC6
# start triangulate DC2
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC2
# start triangulate DC3
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC3
# start triangulate DC7
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC11
# start triangulate DC14
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC14
# start triangulate DC18
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC18
# start triangulate DC20
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC20
# start triangulate DC16
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC16
# start triangulate DC12
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC12
# start triangulate DC9
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC9
# start triangulate DC5
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC5
# start triangulate DC1
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC1
# start triangulate DC4
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC4
# start triangulate DC8
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC8
# start triangulate RF
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate RF
# start triangulate DC15
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC15
# start triangulate DC19
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC19
# second triangulation:
# start triangulate GND
# final opts q5Qzra
# finish triangulate GND
# start triangulate DC21
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC21
# start triangulate DC17
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC17
# start triangulate DC13
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC13
# start triangulate DC10
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC10
# start triangulate DC6
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC6
# start triangulate DC2
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC2
# start triangulate DC3
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC3
# start triangulate DC7
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC11
# start triangulate DC14
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC14
# start triangulate DC18
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC18
# start triangulate DC20
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC20
# start triangulate DC16
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC16
# start triangulate DC12
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC12
# start triangulate DC9
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC9
# start triangulate DC5
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC5
# start triangulate DC1
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC1
# start triangulate DC4
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC4
# start triangulate DC8
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC8
# start triangulate RF
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate RF
# start triangulate DC15
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC15
# start triangulate DC19
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC19
# Mesh([('GND', [<bem.triangulation.Triangulation at 0x24a8b06b4c0>]),
#       ('DC21',
#        [<bem.triangulation.Triangulation at 0x24a8fa10fd0>,
#         <bem.triangulation.Triangulation at 0x24a8fa10a90>,
#         <bem.triangulation.Triangulation at 0x24a8fc0a580>,
#         <bem.triangulation.Triangulation at 0x24a8fc0a550>,
#         <bem.triangulation.Triangulation at 0x24a8fc9e430>,
#         <bem.triangulation.Triangulation at 0x24a8fc9e370>]),
#       ('DC17',
#        [<bem.triangulation.Triangulation at 0x24a8fcc1a60>,
#         <bem.triangulation.Triangulation at 0x24a8fcc1b20>,
#         <bem.triangulation.Triangulation at 0x24a8fcc1be0>,
#         <bem.triangulation.Triangulation at 0x24a8fcc1ca0>,
#         <bem.triangulation.Triangulation at 0x24a8fcc1d60>,
#         <bem.triangulation.Triangulation at 0x24a8fcc1e20>]),
#       ('DC13',
#        [<bem.triangulation.Triangulation at 0x24a8fcc1ee0>,
#         <bem.triangulation.Triangulation at 0x24a8fcc1fa0>,
#         <bem.triangulation.Triangulation at 0x24a8f782ca0>,
#         <bem.triangulation.Triangulation at 0x24a8fbcd8b0>,
#         <bem.triangulation.Triangulation at 0x24a8fbcd9a0>,
#         <bem.triangulation.Triangulation at 0x24a8fbcd430>,
#         <bem.triangulation.Triangulation at 0x24a8fbcdaf0>]),
#       ('DC10',
#        [<bem.triangulation.Triangulation at 0x24a8fbcd9d0>,
#         <bem.triangulation.Triangulation at 0x24a8fbcdb80>,
#         <bem.triangulation.Triangulation at 0x24a8fbcd6d0>,
#         <bem.triangulation.Triangulation at 0x24a8fbcd970>,
#         <bem.triangulation.Triangulation at 0x24a8fbcdca0>,
#         <bem.triangulation.Triangulation at 0x24a8fbcdd90>]),
#       ('DC6',
#        [<bem.triangulation.Triangulation at 0x24a8fbcd400>,
#         <bem.triangulation.Triangulation at 0x24a8b042610>,
#         <bem.triangulation.Triangulation at 0x24a8fca4e50>,
#         <bem.triangulation.Triangulation at 0x24a8fca4fa0>,
#         <bem.triangulation.Triangulation at 0x24a8fca4dc0>,
#         <bem.triangulation.Triangulation at 0x24a8fca4f10>,
#         <bem.triangulation.Triangulation at 0x24a8fc23640>]),
#       ('DC2',
#        [<bem.triangulation.Triangulation at 0x24a8fc23550>,
#         <bem.triangulation.Triangulation at 0x24a8fc23760>,
#         <bem.triangulation.Triangulation at 0x24a8fc23c40>,
#         <bem.triangulation.Triangulation at 0x24a8fc23910>,
#         <bem.triangulation.Triangulation at 0x24a8fc23fd0>,
#         <bem.triangulation.Triangulation at 0x24a8fc23e80>,
#         <bem.triangulation.Triangulation at 0x24a8fc23ac0>,
#         <bem.triangulation.Triangulation at 0x24a8fc51ac0>]),
#       ('DC3',
#        [<bem.triangulation.Triangulation at 0x24a8fc51880>,
#         <bem.triangulation.Triangulation at 0x24a8fc51c10>,
#         <bem.triangulation.Triangulation at 0x24a8fc51b80>,
#         <bem.triangulation.Triangulation at 0x24a8fc51af0>,
#         <bem.triangulation.Triangulation at 0x24a8fc51be0>,
#         <bem.triangulation.Triangulation at 0x24a8fcf70a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcf7160>]),
#       ('DC7',
#        [<bem.triangulation.Triangulation at 0x24a8fcf7220>,
#         <bem.triangulation.Triangulation at 0x24a8fcf72e0>,
#         <bem.triangulation.Triangulation at 0x24a8fcf73a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcf7460>,
#         <bem.triangulation.Triangulation at 0x24a8fcf7520>,
#         <bem.triangulation.Triangulation at 0x24a8fcf75e0>,
#         <bem.triangulation.Triangulation at 0x24a8fcf76a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcf7760>]),
#       ('DC11',
#        [<bem.triangulation.Triangulation at 0x24a8fcf7820>,
#         <bem.triangulation.Triangulation at 0x24a8fcf78e0>,
#         <bem.triangulation.Triangulation at 0x24a8fcf79a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcf7a60>,
#         <bem.triangulation.Triangulation at 0x24a8fcf7b20>,
#         <bem.triangulation.Triangulation at 0x24a8fcf7be0>,
#         <bem.triangulation.Triangulation at 0x24a8fcf7ca0>,
#         <bem.triangulation.Triangulation at 0x24a8fcf7d60>,
#         <bem.triangulation.Triangulation at 0x24a8fcf7e20>,
#         <bem.triangulation.Triangulation at 0x24a8fcf7ee0>,
#         <bem.triangulation.Triangulation at 0x24a8fcf7fa0>]),
#       ('DC14',
#        [<bem.triangulation.Triangulation at 0x24a8fcfd0a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfd160>,
#         <bem.triangulation.Triangulation at 0x24a8fcfd220>,
#         <bem.triangulation.Triangulation at 0x24a8fcfd2e0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfd3a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfd460>,
#         <bem.triangulation.Triangulation at 0x24a8fcfd520>,
#         <bem.triangulation.Triangulation at 0x24a8fcfd5e0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfd6a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfd760>]),
#       ('DC18',
#        [<bem.triangulation.Triangulation at 0x24a8fcfd820>,
#         <bem.triangulation.Triangulation at 0x24a8fcfd8e0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfd9a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfda60>,
#         <bem.triangulation.Triangulation at 0x24a8fcfdb20>,
#         <bem.triangulation.Triangulation at 0x24a8fcfdbe0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfdca0>]),
#       ('DC20',
#        [<bem.triangulation.Triangulation at 0x24a8fcfdd60>,
#         <bem.triangulation.Triangulation at 0x24a8fcfde20>,
#         <bem.triangulation.Triangulation at 0x24a8fcfdee0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfdfa0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfe0a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfe160>]),
#       ('DC16',
#        [<bem.triangulation.Triangulation at 0x24a8fcfe220>,
#         <bem.triangulation.Triangulation at 0x24a8fcfe2e0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfe3a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfe460>,
#         <bem.triangulation.Triangulation at 0x24a8fcfe520>,
#         <bem.triangulation.Triangulation at 0x24a8fcfe5e0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfe6a0>]),
#       ('DC12',
#        [<bem.triangulation.Triangulation at 0x24a8fcfe760>,
#         <bem.triangulation.Triangulation at 0x24a8fcfe820>,
#         <bem.triangulation.Triangulation at 0x24a8fcfe8e0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfe9a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfea60>,
#         <bem.triangulation.Triangulation at 0x24a8fcfeb20>,
#         <bem.triangulation.Triangulation at 0x24a8fcfebe0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfeca0>]),
#       ('DC9',
#        [<bem.triangulation.Triangulation at 0x24a8fcfed60>,
#         <bem.triangulation.Triangulation at 0x24a8fcfee20>,
#         <bem.triangulation.Triangulation at 0x24a8fcfeee0>,
#         <bem.triangulation.Triangulation at 0x24a8fcfefa0>,
#         <bem.triangulation.Triangulation at 0x24a8fcd10a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcd1160>,
#         <bem.triangulation.Triangulation at 0x24a8fcd1220>,
#         <bem.triangulation.Triangulation at 0x24a8fcd12e0>]),
#       ('DC5',
#        [<bem.triangulation.Triangulation at 0x24a8fcd13a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcd1460>,
#         <bem.triangulation.Triangulation at 0x24a8fcd1520>,
#         <bem.triangulation.Triangulation at 0x24a8fcd15e0>,
#         <bem.triangulation.Triangulation at 0x24a8fcd16a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcd1760>,
#         <bem.triangulation.Triangulation at 0x24a8fcd1820>,
#         <bem.triangulation.Triangulation at 0x24a8fcd18e0>,
#         <bem.triangulation.Triangulation at 0x24a8fcd19a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcd1a60>]),
#       ('DC1',
#        [<bem.triangulation.Triangulation at 0x24a8fcd1b20>,
#         <bem.triangulation.Triangulation at 0x24a8fcd1be0>,
#         <bem.triangulation.Triangulation at 0x24a8fcd1ca0>,
#         <bem.triangulation.Triangulation at 0x24a8fcd1d60>,
#         <bem.triangulation.Triangulation at 0x24a8fcd1e20>,
#         <bem.triangulation.Triangulation at 0x24a8fcd1ee0>]),
#       ('DC4',
#        [<bem.triangulation.Triangulation at 0x24a8fcd1fa0>,
#         <bem.triangulation.Triangulation at 0x24a8fce90a0>,
#         <bem.triangulation.Triangulation at 0x24a8fce9160>,
#         <bem.triangulation.Triangulation at 0x24a8fce9220>,
#         <bem.triangulation.Triangulation at 0x24a8fce92e0>,
#         <bem.triangulation.Triangulation at 0x24a8fce93a0>,
#         <bem.triangulation.Triangulation at 0x24a8fce9460>,
#         <bem.triangulation.Triangulation at 0x24a8fce9520>,
#         <bem.triangulation.Triangulation at 0x24a8fce95e0>,
#         <bem.triangulation.Triangulation at 0x24a8fce96a0>,
#         <bem.triangulation.Triangulation at 0x24a8fce9760>,
#         <bem.triangulation.Triangulation at 0x24a8fce9820>,
#         <bem.triangulation.Triangulation at 0x24a8fce98e0>,
#         <bem.triangulation.Triangulation at 0x24a8fce99d0>]),
#       ('DC8',
#        [<bem.triangulation.Triangulation at 0x24a8fce9a60>,
#         <bem.triangulation.Triangulation at 0x24a8fce9b20>,
#         <bem.triangulation.Triangulation at 0x24a8fce9be0>,
#         <bem.triangulation.Triangulation at 0x24a8fce9ca0>,
#         <bem.triangulation.Triangulation at 0x24a8fce9d60>]),
#       ('RF',
#        [<bem.triangulation.Triangulation at 0x24a8fce9e20>,
#         <bem.triangulation.Triangulation at 0x24a8fce9ee0>,
#         <bem.triangulation.Triangulation at 0x24a8fce9fa0>,
#         <bem.triangulation.Triangulation at 0x24a8fce20a0>,
#         <bem.triangulation.Triangulation at 0x24a8fce2160>,
#         <bem.triangulation.Triangulation at 0x24a8fce2220>,
#         <bem.triangulation.Triangulation at 0x24a8fce22e0>,
#         <bem.triangulation.Triangulation at 0x24a8fce23a0>]),
#       ('DC15',
#        [<bem.triangulation.Triangulation at 0x24a8fce2460>,
#         <bem.triangulation.Triangulation at 0x24a8fce2520>,
#         <bem.triangulation.Triangulation at 0x24a8fce25e0>,
#         <bem.triangulation.Triangulation at 0x24a8fce26a0>,
#         <bem.triangulation.Triangulation at 0x24a8fce2760>,
#         <bem.triangulation.Triangulation at 0x24a8fce2820>,
#         <bem.triangulation.Triangulation at 0x24a8fce28e0>]),
#       ('DC19',
#        [<bem.triangulation.Triangulation at 0x24a8fce29a0>,
#         <bem.triangulation.Triangulation at 0x24a8fce2a60>,
#         <bem.triangulation.Triangulation at 0x24a8fce2b20>,
#         <bem.triangulation.Triangulation at 0x24a8fce2be0>,
#         <bem.triangulation.Triangulation at 0x24a8fce2ca0>,
#         <bem.triangulation.Triangulation at 0x24a8fce2d60>,
#         <bem.triangulation.Triangulation at 0x24a8fce2e20>,
#         <bem.triangulation.Triangulation at 0x24a8fce2ee0>,
#         <bem.triangulation.Triangulation at 0x24a8fce2fa0>,
#         <bem.triangulation.Triangulation at 0x24a8fcee0a0>,
#         <bem.triangulation.Triangulation at 0x24a8fcee160>])])

# %%
# save base mesh to a pickle file
with open(fout_name,'wb') as f:
    data = (mesh_unit,
            xl,
            yl,
            zl,
            mesh,
            list(od.values()))
    pickle.dump(data,f)

# %% [markdown]
# ## view mesh
# Uses Pyvista package to generate interactive 3-d plot of the mesh

# %%
# Plot triangle mezshes of the final mesh
mesh.plot()

# %% [markdown]
# Show number of points included in the mesh

# %%
print(len(mesh.points))
# Out:
# 18749
