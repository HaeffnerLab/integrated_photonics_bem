# %% [markdown]
# # `Documention & Tutorial`
# This BEM package is used for for numerical simulation of the electric field of ion traps in python. Some external packages are wrapped into it:
#
# * fast triangulation (http://www.cs.cmu.edu/~quake/triangle.research.html)
# * fastlap boundary element method (Nabors K S. Efficient three-dimensional capacitance calculation[D]. Massachusetts Institute of Technology, 1993.)
#
# This document, also as a tutorial, explains how to use these packages to compute the electric field and compute its multipole expansion coefficient starting from scratch with a fusion 360 trap model(take `./f3d/htrap_overhang_9x5mm.f3d` for example). Our document consists of three .ipynb files:
#
# * `I_Mesh_Processing.ipynb`
# * `II_Field_Simulation.ipynb`
# * `III_Multipole_Expansion.ipynb`
#
# We split the document into three files for two reasons:
# 1. The most time consuming part `II_Field_Simulation.ipynb` could be taken out alone and run on a high peformance computer.
# 2. The intermediate result between files can be checked- 'intermediate files' refer to the inital mesh grid (that corresponds to the charge distribution), the simulation values and the simulation coordinates, all of which are saved in the inter_results folder. So if the voltage solution files for the trap don't make sense, it is possible to go back through saved data to see where things have gone wrong.
# Here are the three jupyter notebooks and what:
# 1. I_Mesh_Processing- this notebook generates a mesh of the trap, saved in inter_results as a .pkl file
#
#
# Going through three files in order and running their python code will help you understand our workflow. Generally our workflow divides into three steps, corresponding to the above three .ipynb files. First, in I_Mesh_Processing, we identify different electrodes of the trap model by different colors. Also, we refine the trap model meshes to prepare for the second step. The result is stored in `mesh_result.pkl`.
#
# Secondly, in II_Field_Simulation, we simulate the electric potential with fastlap boundary element method(FMM), the accuracy of this step depends on the mesh size in the first step. The result is stored in `field_result.pkl`.
#
# Thirdly, in III_Multipole_Expansion, we analyze the electric field and electric potential. This notebook generates the multipole coefficients of the fields and potentials for each electrode and uses that information to generate a solution file with the function call `write_csv`. If your solution don't make sense, a good place to start is to insure that the mesh you are using is fine enough (generate several field results for different meshes)- if the potentials and fields are converging to specific values, this suggests there is something wrong with the multipole expansion. If you start with multipole expansion, you do not know if it is a problem with the expansion or with the field.
#
# Before running codes, you must set up the environment according to instructions in `README`
#
# notes
# * Our workflow, as indicated by this document, abandons mayavi(with its embeded package tvtk). But we reserve mayavi in our Bem source code, if you want to use mayavi related functions, you must set up environment with files in`./backup/setup_with_mayavi`, just replace corresponding files in the root folder with them and set up.
#     * why we abandon mayavi: because its python interface(with its dependence vtk and PyQt5) requires complex package dependencies and version controls especially for new python versions. This makes it difficult to maintain this project.
#     * why we still keep mayavi in the source code? Because it is rooted in our source code deeply. We can just avoid invoking related functions instead of deleting them, because they may make sense in the future.

# %% [markdown]
# # `I. Mesh Processing`
# This .pynb file reads a colored model file `./inter_results/htrap.stl`, and assigns a name for each color(thus for each electrode). The result is stored in `./inter_results/mesh_result.pkl`.
#
# In this file we name different electrodes and refine the meshes. The size of mesh determines the accuracy in next step. You should set the mesh finer and finer until the result converges. Also, you can set the mesh finer and test the convergence.
#
# ## (1) color your electrodes (in fusion 360) and export stl
# First of all, you have a trap model in fusion 360 project, for example, `./f3d/htrap_overhang_9x5mm.f3d`. Here we use different color to identify different electrodes(STL file stores color for each mesh). In fusion 360, you can assign different appearance for different electrodes. We recommend to use ../../bemCol_lib/bemCol.adsklib for different electrodes. Same color for two electrodes means they are treated as the same electrode. Then we get `./f3d/htrap_overhang_9x5mm_my_colored.f3d`
#
# Then export to an stl file in fusion360 file>export tab and move the file in `./inter_results`. We export our stl in mm, so we set the mesh unit to mm.

# %% [markdown]
# Furthurmore, it's our convention to use unit mm in our traps. e.g. [Electric field] = V/mm , [harmonic confining potential] = V/mm^2.so we set

# %%
# this is the unit for our Mesh structure
# in the following code, this is the default unit for python variables
#units 
mesh_unit = 1e-3

# %% [markdown]
# Additional notes (from Wenhao):
# * Why use standard color? We define a set of standard color lib `../../../bemCol_lib/bemCol.adsklib` for two reasons: 1. when exporting to .stl file, fusion 360 will compress 0-256 color(RGBA32) into 0-32 color(RGBA16), which means that some similar colors in fusion 360 will become same color after export to .stl file. Our standard color lib avoid this problem. 2.If you use .stl file exported from fusion 360 DIRECTLY, naming the electrodes would be very convinient. If you use other apps such as Inventor or Meshlab to generate .stl file, you can ignore the second reason because color encoding are quite different in different apps

# %% [markdown]
# ## (2) assign a name for each color

# %%
import pickle
import numpy as np
import matplotlib as mpl
import sys
from utils.helper_functions import *
from bem.bemColors_lib.bemColors import bemColors
from bem import Electrodes, Sphere, Mesh, Grid, Configuration, Result, Box
# load stl geometry file
from bem.formats import stl
# stl_path = "roughness/"+"basic_excitation"+".stl"  


#radius is the radius of the sphere from the ions location to generate a finer
#electrode mesh
radius= 500e-3
#'area' is the area of the triangles inside the sphere
area = 1e-4
# file = 'mit_charge'
# file = 'htrap_overhang_taper_2'
# file_out = 'htrap_overhang_taper_el3'
# stl_path = 'inter_results/taper_overhang/'+file+'.stl'
# fout_name = 'inter_results/taper_overhang/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


file_out = 'htrap_el2'
stl_path = 'inter_results/htrap/htrap.stl'
fout_name = 'inter_results/htrap/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


module_path = os.path.abspath('')


s_nta = stl.read_stl(open(stl_path, "rb"))

# %% [markdown]
# Firstly, we print all the colors appear in the stl file. If a color is of standard colors in `bemCol.adsklib` or named manually by function `bemCol.set_my_color()`, then the color will appear in a straightforward name, such as `bem0`,`bem1` ...... . Otherwise, the color will simply be named as `'_unkCol0'` , `'_unkCol1'`, ...
#
# notes
# * try to comment out the line of `ele_col.set_my_color()` in the following block, name `'_unkCol0'` will appear.

# %%
ele_col = bemColors(np.array(list(set(s_nta[2]))),('fusion360','export_stl'))
ele_col.set_my_color(value = (178,178,178),cl_format = ('fusion360','export_stl','RGBA64'),name = 'self_defined')
ele_col.print_stl_colors()
# Out:
# COLORS in the stl:
# ['bem6']
# ['bem13']
# ['bem19']
# ['bem11']
# ['bem17']
# ['bem15']
# ['bem30']
# ['bem1']
# ['bem12']
# ['bem5']
# ['bem25']
# ['bem18']
# ['bem16']
# ['bem3']
# ['bem7']
# ['bem9']
# ['bem2']
# ['bem4']
# ['bem20']
# ['bem10']
# ['bem14']
# ['bem8']
# ['bem21']
# ['_unkColor0']
# TOTAL COLORS:  24

# %% [markdown]
# Next, you need to assign a name for each color that appeared above. With standard colors defined in `bemCol.adsklib`, the correspondence between color and electrode is clear, which make it easy for this step. You can also comment out some `ele_col.set_color_name()`, run all the codes again and observe the missing part in the printed figure, which corresponds to the electrode you comment out. The second method also serves as a double check. Besides, parameter in `stl.stl_to_mesh()` can be set as `quiet = False` to check whether the program reads planes correctly.

# %%
# assign a name for each color
# taper htrap 2022
# assign a name for each color

# In od[key] = value, key is the color from the Fusion360 color library we made
# value assigns a specific name to that color in this program. 
# In future version, we may want to consider getting rid of this step for simplification
# then you just assign the color in fusion 360 and be done with it. The only concern there is you
from collections import OrderedDict
od = OrderedDict()
od['bem1']='DC1'
od['bem2']='DC2'
od['bem3']='DC3'
od['bem4']='DC4'
od['bem5']='DC5'
od['bem6']='DC6'
od['bem7']='DC7'
od['bem8']='DC8'
od['bem9']='DC9'
od['bem10']='DC10'
od['bem11']='DC11'
od['bem12']='DC12'
od['bem13']='DC13'
od['bem14']='DC14'
od['bem15']='DC15'
od['bem16']='DC16'
od['bem17']='DC17'
od['bem18']='DC18'
od['bem19']='DC19'
od['bem20']='DC20'
od['bem21'] = 'DC21'
od['bem25'] = 'RF'
od['bem30'] = 'gnd'
for key in list(od.keys()):
    ele_col.color_electrode(color=key,name=od[key])

# print colors still with no name. These meshes will be neglected in the code below. 
ele_col.drop_colors()

# read stl into mesh with electrode names
# unnamed meshes will not be imported at all

mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=1,
    rename=ele_col.electrode_colors, quiet=True))
# Out:
# dropping color ['_unkColor0']
# TOTAL COLORS DROPPED:  1
# dropping 20083

# %% [markdown]
# ## (3) remesh
#
# In this step, we generate triangle mesh with constraints. The meshes are 2-dimensional triangles on the surface of electrodes. The region enclosed by constraint shape can have finer mesh. Triangulation is done by `triangle` C library. Folowing variables are all in unit `mesh_unit` now.
#
# Our remesh strategy consists of two steps of triangulation:
# 1. global triangulation without constraint. This step eliminate some long and sharp triangles by combining and dividing, and obtains a coarse grain triangulated model.
# 2. local triangulation with constraint. This step refines each triangles in step 1, the triangle density is defined by `mesh.areas_from_constraints
#
# parameters in the below code block should be tuned specificly for different trap geometries.`

# %%
# here we define a spherical constriant zone:
# xl = 270*1e-3
# yl = -3.5*1e-3
# zl = 72.5*1e-3

#here is the location that will be the reference point for further meshing
#usually, this is the ion's location, specified in appropriate units (usually millimeters)
zl = -450*1e-3
yl = 75*1e-3
xl = 3.75*1e-3


mesh.triangulate(opts="",new = False)

# for z in np.arange(-400e-3,700e-3,100e-3):
print('first triangulation:')
# for z in np.arange(-200e-3, 200e-3, 50e-3):
rad = radius*2
inside=area*35
outside=1
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="a2Q",new = False)

# # what happened to this feature (Box)? is this on bem savio?
# # mesh.areas_from_constraints(Box(start=-0.5, end= 0.5,inside=inside, outside=outside))



# areas_from_constraints specifies sphere with finer mesh inside it.
#  "inside", "outside" set different mesh densities. 
print('second triangulation:')
rad =radius
inside=area*5
outside=1e4
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="q5Q",new = False)

# save base mesh to a pickle file
# with open(fout_name,'wb') as f:
#     data = (mesh_unit,
#             xl,
#             yl,
#             zl,
#             mesh,
#             list(od.values()))
#     pickle.dump(data,f)
# Out:
# start triangulate RF
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate RF
# start triangulate DC21
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC21
# start triangulate DC2
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC2
# start triangulate DC7
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC7
# start triangulate DC11
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC11
# start triangulate DC12
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC12
# start triangulate DC13
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC13
# start triangulate DC14
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC14
# start triangulate DC15
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC15
# start triangulate DC16
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC16
# start triangulate DC17
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC17
# start triangulate DC18
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC18
# start triangulate DC19
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC19
# start triangulate DC20
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC20
# start triangulate gnd
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate gnd
# start triangulate DC1
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC1
# start triangulate DC3
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC3
# start triangulate DC4
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC4
# start triangulate DC5
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC5
# start triangulate DC6
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC6
# start triangulate DC8
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC8
# start triangulate DC9
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC9
# start triangulate DC10
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC10
# first triangulation:
# start triangulate RF
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate RF
# start triangulate DC21
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC10
# second triangulation:
# start triangulate RF
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate RF
# start triangulate DC21
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC10
# Mesh([('RF',
#        [<bem.triangulation.Triangulation at 0x1a5910add30>,
#         <bem.triangulation.Triangulation at 0x1a5922086d0>,
#         <bem.triangulation.Triangulation at 0x1a592208490>,
#         <bem.triangulation.Triangulation at 0x1a5921fec40>,
#         <bem.triangulation.Triangulation at 0x1a5f3aa2c40>,
#         <bem.triangulation.Triangulation at 0x1a5f3aa2f10>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab29a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2b20>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2be0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2d60>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2e20>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab8760>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab8820>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab88e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab89a0>]),
#       ('DC21',
#        [<bem.triangulation.Triangulation at 0x1a5f3ab8a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab8b20>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab8be0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab8ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab8d60>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab8e20>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab8ee0>]),
#       ('DC2',
#        [<bem.triangulation.Triangulation at 0x1a5f3ab8190>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab80d0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab8fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c400a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c40160>,
#         <bem.triangulation.Triangulation at 0x1a5f3c40220>,
#         <bem.triangulation.Triangulation at 0x1a5f3c402e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c403a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c40460>,
#         <bem.triangulation.Triangulation at 0x1a5f3c40520>,
#         <bem.triangulation.Triangulation at 0x1a5f3c405e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c406a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c40760>]),
#       ('DC7',
#        [<bem.triangulation.Triangulation at 0x1a5f3c40820>,
#         <bem.triangulation.Triangulation at 0x1a5f3c408e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c409a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c40a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c40b20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c40be0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c40ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c40d60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c40e20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c40ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c40fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c610a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c61160>]),
#       ('DC11',
#        [<bem.triangulation.Triangulation at 0x1a5f3c61220>,
#         <bem.triangulation.Triangulation at 0x1a5f3c612e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c613a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c61460>,
#         <bem.triangulation.Triangulation at 0x1a5f3c61520>,
#         <bem.triangulation.Triangulation at 0x1a5f3c615e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c616a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c61760>,
#         <bem.triangulation.Triangulation at 0x1a5f3c61820>,
#         <bem.triangulation.Triangulation at 0x1a5f3c618e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c619a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c61a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c61b20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c61be0>]),
#       ('DC12',
#        [<bem.triangulation.Triangulation at 0x1a5f3c61ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c61d60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c61e20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c61ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c61fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c660a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c66160>,
#         <bem.triangulation.Triangulation at 0x1a5f3c66220>,
#         <bem.triangulation.Triangulation at 0x1a5f3c662e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c663a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c66460>,
#         <bem.triangulation.Triangulation at 0x1a5f3c66520>,
#         <bem.triangulation.Triangulation at 0x1a5f3c665e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c666a0>]),
#       ('DC13',
#        [<bem.triangulation.Triangulation at 0x1a5f3c66760>,
#         <bem.triangulation.Triangulation at 0x1a5f3c66820>,
#         <bem.triangulation.Triangulation at 0x1a5f3c668e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c669a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c66a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c66b20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c66be0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c66ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c66d60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c66e20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c66ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c66fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6b0a0>]),
#       ('DC14',
#        [<bem.triangulation.Triangulation at 0x1a5f3c6b160>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6b220>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6b2e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6b3a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6b460>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6b520>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6b5e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6b6a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6b760>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6b820>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6b8e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6b9a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6ba60>]),
#       ('DC15',
#        [<bem.triangulation.Triangulation at 0x1a5f3c6bb20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6bbe0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6bca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6bd60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6be20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6bee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c6bfa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c700a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c70160>,
#         <bem.triangulation.Triangulation at 0x1a5f3c70220>,
#         <bem.triangulation.Triangulation at 0x1a5f3c702e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c703a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c70460>]),
#       ('DC16',
#        [<bem.triangulation.Triangulation at 0x1a5f3c70520>,
#         <bem.triangulation.Triangulation at 0x1a5f3c70610>,
#         <bem.triangulation.Triangulation at 0x1a5f3c706a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c70760>,
#         <bem.triangulation.Triangulation at 0x1a5f3c70820>,
#         <bem.triangulation.Triangulation at 0x1a5f3c708e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c709a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c70a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c70b20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c70be0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c70ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c70d60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c70e20>]),
#       ('DC17',
#        [<bem.triangulation.Triangulation at 0x1a5f3c70ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c70fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c750a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c75160>,
#         <bem.triangulation.Triangulation at 0x1a5f3c75220>,
#         <bem.triangulation.Triangulation at 0x1a5f3c752e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c753a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c75460>,
#         <bem.triangulation.Triangulation at 0x1a5f3c75520>,
#         <bem.triangulation.Triangulation at 0x1a5f3c755e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c756a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c75760>,
#         <bem.triangulation.Triangulation at 0x1a5f3c75820>]),
#       ('DC18',
#        [<bem.triangulation.Triangulation at 0x1a5f3c758e0>,
# ...
#         <bem.triangulation.Triangulation at 0x1a5f3adb5e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3adb6a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3adb760>,
#         <bem.triangulation.Triangulation at 0x1a5f3adb820>,
#         <bem.triangulation.Triangulation at 0x1a5f3adb8e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3adb9a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3adba60>,
#         <bem.triangulation.Triangulation at 0x1a5f3adbb20>,
#         <bem.triangulation.Triangulation at 0x1a5f3adbbe0>,
#         <bem.triangulation.Triangulation at 0x1a5f3adbca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3adbd60>,
#         <bem.triangulation.Triangulation at 0x1a5f3adbe20>,
#         <bem.triangulation.Triangulation at 0x1a5f3adbee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3adbfa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae00a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0160>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0220>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae02e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae03a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0460>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0520>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae05e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae06a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0760>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0820>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae08e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae09a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0b20>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0be0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0d60>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0e20>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae0fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae50a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5160>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5220>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae52e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae53a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5460>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5520>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae55e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae56a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5760>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5820>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae58e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae59a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5b20>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5be0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5d60>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5e20>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ae5fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aea0a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aea160>,
#         <bem.triangulation.Triangulation at 0x1a5f3aea220>,
#         <bem.triangulation.Triangulation at 0x1a5f3aea2e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aea3a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aea460>,
#         <bem.triangulation.Triangulation at 0x1a5f3aea520>,
#         <bem.triangulation.Triangulation at 0x1a5f3aea5e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aea6a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aea760>,
#         <bem.triangulation.Triangulation at 0x1a5f3aea820>,
#         <bem.triangulation.Triangulation at 0x1a5f3aea8e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aea9a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aeaa60>,
#         <bem.triangulation.Triangulation at 0x1a5f3aeab20>,
#         <bem.triangulation.Triangulation at 0x1a5f3aeabe0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aeaca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aead60>,
#         <bem.triangulation.Triangulation at 0x1a5f3aeae20>,
#         <bem.triangulation.Triangulation at 0x1a5f3aeaee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aeafa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aef0a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aef160>,
#         <bem.triangulation.Triangulation at 0x1a5f3aef220>,
#         <bem.triangulation.Triangulation at 0x1a5f3aef2e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aef400>,
#         <bem.triangulation.Triangulation at 0x1a5f3aef460>,
#         <bem.triangulation.Triangulation at 0x1a5f3aef520>,
#         <bem.triangulation.Triangulation at 0x1a5f3aef5e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aef6a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aef760>,
#         <bem.triangulation.Triangulation at 0x1a5f3aef820>,
#         <bem.triangulation.Triangulation at 0x1a5f3aef8e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aef9a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aefa60>,
#         <bem.triangulation.Triangulation at 0x1a5f3aefb20>,
#         <bem.triangulation.Triangulation at 0x1a5f3aefbe0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aefca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aefd60>,
#         <bem.triangulation.Triangulation at 0x1a5f3aefe20>,
#         <bem.triangulation.Triangulation at 0x1a5f3aefee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3aeffa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af40a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4160>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4220>,
#         <bem.triangulation.Triangulation at 0x1a5f3af42e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af43a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4460>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4520>,
#         <bem.triangulation.Triangulation at 0x1a5f3af45e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af46a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4760>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4820>,
#         <bem.triangulation.Triangulation at 0x1a5f3af48e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af49a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4b20>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4be0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4d60>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4e20>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af4fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af90a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9160>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9220>,
#         <bem.triangulation.Triangulation at 0x1a5f3af92e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af93a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9460>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9520>,
#         <bem.triangulation.Triangulation at 0x1a5f3af95e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af96a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9760>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9820>,
#         <bem.triangulation.Triangulation at 0x1a5f3af98e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af99a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9b20>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9be0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9d60>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9e20>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3af9fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3afe0a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3afe160>,
#         <bem.triangulation.Triangulation at 0x1a5f3afe220>,
#         <bem.triangulation.Triangulation at 0x1a5f3afe2e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3afe3a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3afe460>,
#         <bem.triangulation.Triangulation at 0x1a5f3afe520>,
#         <bem.triangulation.Triangulation at 0x1a5f3afe5e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3afe6a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3afe760>,
#         <bem.triangulation.Triangulation at 0x1a5f3afe820>,
#         <bem.triangulation.Triangulation at 0x1a5f3afe8e0>]),
#       ('DC1',
#        [<bem.triangulation.Triangulation at 0x1a5f3afe9a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3afea60>,
#         <bem.triangulation.Triangulation at 0x1a5f3afeb20>,
#         <bem.triangulation.Triangulation at 0x1a5f3afebe0>,
#         <bem.triangulation.Triangulation at 0x1a5f3afeca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3afed60>,
#         <bem.triangulation.Triangulation at 0x1a5f3afee20>,
#         <bem.triangulation.Triangulation at 0x1a5f3afeee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3afefa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c070a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07160>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07220>,
#         <bem.triangulation.Triangulation at 0x1a5f3c072e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c073a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07460>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07520>]),
#       ('DC3',
#        [<bem.triangulation.Triangulation at 0x1a5f3c075e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c076a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07760>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07820>,
#         <bem.triangulation.Triangulation at 0x1a5f3c078e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c079a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07b20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07be0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07d60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07e20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c07fa0>]),
#       ('DC4',
#        [<bem.triangulation.Triangulation at 0x1a5f3c050a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c05160>,
#         <bem.triangulation.Triangulation at 0x1a5f3c05220>,
#         <bem.triangulation.Triangulation at 0x1a5f3c052e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c053a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c05460>,
#         <bem.triangulation.Triangulation at 0x1a5f3c05520>,
#         <bem.triangulation.Triangulation at 0x1a5f3c055e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c056a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c05760>,
#         <bem.triangulation.Triangulation at 0x1a5f3c05820>,
#         <bem.triangulation.Triangulation at 0x1a5f3c058e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c059a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c05a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c05b20>]),
#       ('DC5',
#        [<bem.triangulation.Triangulation at 0x1a5f3c05be0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c05ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c05d60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c05e20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c05ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c05fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c000a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00160>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00220>,
#         <bem.triangulation.Triangulation at 0x1a5f3c002e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c003a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00460>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00520>,
#         <bem.triangulation.Triangulation at 0x1a5f3c005e0>]),
#       ('DC6',
#        [<bem.triangulation.Triangulation at 0x1a5f3c006a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00760>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00820>,
#         <bem.triangulation.Triangulation at 0x1a5f3c008e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c009a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00b20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00be0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00dc0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00e20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c00fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c090a0>]),
#       ('DC8',
#        [<bem.triangulation.Triangulation at 0x1a5f3c09160>,
#         <bem.triangulation.Triangulation at 0x1a5f3c09220>,
#         <bem.triangulation.Triangulation at 0x1a5f3c092e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c093a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c09460>,
#         <bem.triangulation.Triangulation at 0x1a5f3c09520>,
#         <bem.triangulation.Triangulation at 0x1a5f3c095e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c096a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c09760>,
#         <bem.triangulation.Triangulation at 0x1a5f3c09820>,
#         <bem.triangulation.Triangulation at 0x1a5f3c098e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c099a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c09a60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c09b20>]),
#       ('DC9',
#        [<bem.triangulation.Triangulation at 0x1a5f3c09be0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c09ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c09d60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c09e20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c09ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c09fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0c0a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0c160>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0c220>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0c2e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0c3a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0c460>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0c520>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0c5e0>]),
#       ('DC10',
#        [<bem.triangulation.Triangulation at 0x1a5f3c0c6a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0c760>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0c820>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0c8e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0c9a0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0ca60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0cb20>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0cbe0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0cca0>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0cd60>,
#         <bem.triangulation.Triangulation at 0x1a5f3c0ce20>])])

# %%
# save base mesh to a pickle file
with open(fout_name,'wb') as f:
    data = (mesh_unit,
            xl,
            yl,
            zl,
            mesh,
            list(od.values()))
    pickle.dump(data,f)

# %% [markdown]
# ## view mesh
# Uses Pyvista package to generate interactive 3-d plot of the mesh

# %%
# Plot triangle mezshes of the final mesh
mesh.plot()

# %% [markdown]
# Show number of points included in the mesh

# %%
print(len(mesh.points))
# Out:
# 5392
