# %% [markdown]
# # `Documention & Tutorial`
# This BEM package is used for for numerical simulation of the electric field of ion traps in python. Some external packages are wrapped into it:
#
# * fast triangulation (http://www.cs.cmu.edu/~quake/triangle.research.html)
# * fastlap boundary element method (Nabors K S. Efficient three-dimensional capacitance calculation[D]. Massachusetts Institute of Technology, 1993.)
#
# This document, also as a tutorial, explains how to use these packages to compute the electric field and compute its multipole expansion coefficient starting from scratch with a fusion 360 trap model(take `./f3d/htrap_overhang_9x5mm.f3d` for example). Our document consists of three .ipynb files:
#
# * `I_Mesh_Processing.ipynb`
# * `II_Field_Simulation.ipynb`
# * `III_Multipole_Expansion.ipynb`
#
# We split the document into three files for two reasons:
# 1. The most time consuming part `II_Field_Simulation.ipynb` could be taken out alone and run on a high peformance computer.
# 2. The intermediate result between files can be checked- 'intermediate files' refer to the inital mesh grid (that corresponds to the charge distribution), the simulation values and the simulation coordinates, all of which are saved in the inter_results folder. So if the voltage solution files for the trap don't make sense, it is possible to go back through saved data to see where things have gone wrong.
# Here are the three jupyter notebooks and what:
# 1. I_Mesh_Processing- this notebook generates a mesh of the trap, saved in inter_results as a .pkl file
#
#
# Going through three files in order and running their python code will help you understand our workflow. Generally our workflow divides into three steps, corresponding to the above three .ipynb files. First, in I_Mesh_Processing, we identify different electrodes of the trap model by different colors. Also, we refine the trap model meshes to prepare for the second step. The result is stored in `mesh_result.pkl`.
#
# Secondly, in II_Field_Simulation, we simulate the electric potential with fastlap boundary element method(FMM), the accuracy of this step depends on the mesh size in the first step. The result is stored in `field_result.pkl`.
#
# Thirdly, in III_Multipole_Expansion, we analyze the electric field and electric potential. This notebook generates the multipole coefficients of the fields and potentials for each electrode and uses that information to generate a solution file with the function call `write_csv`. If your solution don't make sense, a good place to start is to insure that the mesh you are using is fine enough (generate several field results for different meshes)- if the potentials and fields are converging to specific values, this suggests there is something wrong with the multipole expansion. If you start with multipole expansion, you do not know if it is a problem with the expansion or with the field.
#
# Before running codes, you must set up the environment according to instructions in `README`
#
# notes
# * Our workflow, as indicated by this document, abandons mayavi(with its embeded package tvtk). But we reserve mayavi in our Bem source code, if you want to use mayavi related functions, you must set up environment with files in`./backup/setup_with_mayavi`, just replace corresponding files in the root folder with them and set up.
#     * why we abandon mayavi: because its python interface(with its dependence vtk and PyQt5) requires complex package dependencies and version controls especially for new python versions. This makes it difficult to maintain this project.
#     * why we still keep mayavi in the source code? Because it is rooted in our source code deeply. We can just avoid invoking related functions instead of deleting them, because they may make sense in the future.

# %% [markdown]
# # `I. Mesh Processing`
# This .pynb file reads a colored model file `./inter_results/htrap.stl`, and assigns a name for each color(thus for each electrode). The result is stored in `./inter_results/mesh_result.pkl`.
#
# In this file we name different electrodes and refine the meshes. The size of mesh determines the accuracy in next step. You should set the mesh finer and finer until the result converges. Also, you can set the mesh finer and test the convergence.
#
# ## (1) color your electrodes (in fusion 360) and export stl
# First of all, you have a trap model in fusion 360 project, for example, `./f3d/htrap_overhang_9x5mm.f3d`. Here we use different color to identify different electrodes(STL file stores color for each mesh). In fusion 360, you can assign different appearance for different electrodes. We recommend to use ../../bemCol_lib/bemCol.adsklib for different electrodes. Same color for two electrodes means they are treated as the same electrode. Then we get `./f3d/htrap_overhang_9x5mm_my_colored.f3d`
#
# Then export to an stl file in fusion360 file>export tab and move the file in `./inter_results`. We export our stl in mm, so we set the mesh unit to mm.

# %% [markdown]
# Furthurmore, it's our convention to use unit mm in our traps. e.g. [Electric field] = V/mm , [harmonic confining potential] = V/mm^2.so we set

# %%
# this is the unit for our Mesh structure
# in the following code, this is the default unit for python variables
#units 
mesh_unit = 1e-3

# %% [markdown]
# Additional notes (from Wenhao):
# * Why use standard color? We define a set of standard color lib `../../../bemCol_lib/bemCol.adsklib` for two reasons: 1. when exporting to .stl file, fusion 360 will compress 0-256 color(RGBA32) into 0-32 color(RGBA16), which means that some similar colors in fusion 360 will become same color after export to .stl file. Our standard color lib avoid this problem. 2.If you use .stl file exported from fusion 360 DIRECTLY, naming the electrodes would be very convinient. If you use other apps such as Inventor or Meshlab to generate .stl file, you can ignore the second reason because color encoding are quite different in different apps

# %% [markdown]
# ## (2) assign a name for each color

# %%
import pickle
import numpy as np
import matplotlib as mpl
import sys
from utils.helper_functions import *
from bem.bemColors_lib.bemColors import bemColors
from bem import Electrodes, Sphere, Mesh, Grid, Configuration, Result, Box
# load stl geometry file
from bem.formats import stl
# stl_path = "roughness/"+"basic_excitation"+".stl"  


#radius is the radius of the sphere from the ions location to generate a finer
#electrode mesh
radius= 500e-3
#'area' is the area of the triangles inside the sphere
area = 1e-4
# file = 'mit_charge'
# file = 'htrap_overhang_taper_2'
# file_out = 'htrap_overhang_taper_el3'
# stl_path = 'inter_results/taper_overhang/'+file+'.stl'
# fout_name = 'inter_results/taper_overhang/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


file_out = 'htrap_el3.5'
stl_path = 'inter_results/htrap/htrap.stl'
fout_name = 'inter_results/htrap/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


module_path = os.path.abspath('')


s_nta = stl.read_stl(open(stl_path, "rb"))

# %% [markdown]
# Firstly, we print all the colors appear in the stl file. If a color is of standard colors in `bemCol.adsklib` or named manually by function `bemCol.set_my_color()`, then the color will appear in a straightforward name, such as `bem0`,`bem1` ...... . Otherwise, the color will simply be named as `'_unkCol0'` , `'_unkCol1'`, ...
#
# notes
# * try to comment out the line of `ele_col.set_my_color()` in the following block, name `'_unkCol0'` will appear.

# %%
ele_col = bemColors(np.array(list(set(s_nta[2]))),('fusion360','export_stl'))
ele_col.set_my_color(value = (178,178,178),cl_format = ('fusion360','export_stl','RGBA64'),name = 'self_defined')
ele_col.print_stl_colors()
# Out:
# COLORS in the stl:
# ['bem6']
# ['bem13']
# ['bem19']
# ['bem11']
# ['bem17']
# ['bem15']
# ['bem30']
# ['bem1']
# ['bem12']
# ['bem5']
# ['bem25']
# ['bem18']
# ['bem16']
# ['bem3']
# ['bem7']
# ['bem9']
# ['bem2']
# ['bem4']
# ['bem20']
# ['bem10']
# ['bem14']
# ['bem8']
# ['bem21']
# ['_unkColor0']
# TOTAL COLORS:  24

# %% [markdown]
# Next, you need to assign a name for each color that appeared above. With standard colors defined in `bemCol.adsklib`, the correspondence between color and electrode is clear, which make it easy for this step. You can also comment out some `ele_col.set_color_name()`, run all the codes again and observe the missing part in the printed figure, which corresponds to the electrode you comment out. The second method also serves as a double check. Besides, parameter in `stl.stl_to_mesh()` can be set as `quiet = False` to check whether the program reads planes correctly.

# %%
# assign a name for each color
# taper htrap 2022
# assign a name for each color

# In od[key] = value, key is the color from the Fusion360 color library we made
# value assigns a specific name to that color in this program. 
# In future version, we may want to consider getting rid of this step for simplification
# then you just assign the color in fusion 360 and be done with it. The only concern there is you
from collections import OrderedDict
od = OrderedDict()
od['bem1']='DC1'
od['bem2']='DC2'
od['bem3']='DC3'
od['bem4']='DC4'
od['bem5']='DC5'
od['bem6']='DC6'
od['bem7']='DC7'
od['bem8']='DC8'
od['bem9']='DC9'
od['bem10']='DC10'
od['bem11']='DC11'
od['bem12']='DC12'
od['bem13']='DC13'
od['bem14']='DC14'
od['bem15']='DC15'
od['bem16']='DC16'
od['bem17']='DC17'
od['bem18']='DC18'
od['bem19']='DC19'
od['bem20']='DC20'
od['bem21'] = 'DC21'
od['bem25'] = 'RF'
od['bem30'] = 'gnd'
for key in list(od.keys()):
    ele_col.color_electrode(color=key,name=od[key])

# print colors still with no name. These meshes will be neglected in the code below. 
ele_col.drop_colors()

# read stl into mesh with electrode names
# unnamed meshes will not be imported at all

mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=1,
    rename=ele_col.electrode_colors, quiet=True))
# Out:
# dropping color ['_unkColor0']
# TOTAL COLORS DROPPED:  1
# dropping 20083

# %% [markdown]
# ## (3) remesh
#
# In this step, we generate triangle mesh with constraints. The meshes are 2-dimensional triangles on the surface of electrodes. The region enclosed by constraint shape can have finer mesh. Triangulation is done by `triangle` C library. Folowing variables are all in unit `mesh_unit` now.
#
# Our remesh strategy consists of two steps of triangulation:
# 1. global triangulation without constraint. This step eliminate some long and sharp triangles by combining and dividing, and obtains a coarse grain triangulated model.
# 2. local triangulation with constraint. This step refines each triangles in step 1, the triangle density is defined by `mesh.areas_from_constraints
#
# parameters in the below code block should be tuned specificly for different trap geometries.`

# %%
# here we define a spherical constriant zone:
# xl = 270*1e-3
# yl = -3.5*1e-3
# zl = 72.5*1e-3

#here is the location that will be the reference point for further meshing
#usually, this is the ion's location, specified in appropriate units (usually millimeters)
zl = -210*1e-3
yl = 75*1e-3
xl = 3.75*1e-3


mesh.triangulate(opts="",new = False)

# for z in np.arange(-400e-3,700e-3,100e-3):
print('first triangulation:')
# for z in np.arange(-200e-3, 200e-3, 50e-3):
rad = radius*2
inside=area*20
outside=1
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="a2Q",new = False)

# what happened to this feature (Box)? is this on bem savio?
# mesh.areas_from_constraints(Box(start=-0.5, end= 0.5,inside=inside, outside=outside))



# areas_from_constraints specifies sphere with finer mesh inside it.
#  "inside", "outside" set different mesh densities. 
print('second triangulation:')
rad =radius
inside=area
outside=1e4
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="q5Q",new = False)

# save base mesh to a pickle file
# with open(fout_name,'wb') as f:
#     data = (mesh_unit,
#             xl,
#             yl,
#             zl,
#             mesh,
#             list(od.values()))
#     pickle.dump(data,f)
# Out:
# start triangulate RF
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate RF
# start triangulate DC21
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC21
# start triangulate DC2
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC2
# start triangulate DC7
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC7
# start triangulate DC11
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC11
# start triangulate DC12
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC12
# start triangulate DC13
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC13
# start triangulate DC14
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC14
# start triangulate DC15
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC15
# start triangulate DC16
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC16
# start triangulate DC17
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC17
# start triangulate DC18
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC18
# start triangulate DC19
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC19
# start triangulate DC20
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC20
# start triangulate gnd
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate gnd
# start triangulate DC1
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC1
# start triangulate DC3
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC3
# start triangulate DC4
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC4
# start triangulate DC5
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC5
# start triangulate DC6
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC6
# start triangulate DC8
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC8
# start triangulate DC9
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC9
# start triangulate DC10
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC10
# first triangulation:
# start triangulate RF
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate RF
# start triangulate DC21
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC10
# second triangulation:
# start triangulate RF
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate RF
# start triangulate DC21
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC10
# Mesh([('RF',
#        [<bem.triangulation.Triangulation at 0x1592bf41bb0>,
#         <bem.triangulation.Triangulation at 0x15913428e80>,
#         <bem.triangulation.Triangulation at 0x15913424b20>,
#         <bem.triangulation.Triangulation at 0x15913424fa0>,
#         <bem.triangulation.Triangulation at 0x159135891c0>,
#         <bem.triangulation.Triangulation at 0x159132d6d90>,
#         <bem.triangulation.Triangulation at 0x15910fda5b0>,
#         <bem.triangulation.Triangulation at 0x159133beee0>,
#         <bem.triangulation.Triangulation at 0x159133be9a0>,
#         <bem.triangulation.Triangulation at 0x159131ca2e0>,
#         <bem.triangulation.Triangulation at 0x159135e26a0>,
#         <bem.triangulation.Triangulation at 0x159135e23a0>,
#         <bem.triangulation.Triangulation at 0x159135e21c0>,
#         <bem.triangulation.Triangulation at 0x159135e2250>,
#         <bem.triangulation.Triangulation at 0x159135e2f10>,
#         <bem.triangulation.Triangulation at 0x159135e2820>,
#         <bem.triangulation.Triangulation at 0x159135e2730>]),
#       ('DC21',
#        [<bem.triangulation.Triangulation at 0x159135e20a0>,
#         <bem.triangulation.Triangulation at 0x159135e2df0>,
#         <bem.triangulation.Triangulation at 0x159135e2d30>,
#         <bem.triangulation.Triangulation at 0x159135e2a30>,
#         <bem.triangulation.Triangulation at 0x159135e23d0>,
#         <bem.triangulation.Triangulation at 0x159135e2340>,
#         <bem.triangulation.Triangulation at 0x159135e2910>]),
#       ('DC2',
#        [<bem.triangulation.Triangulation at 0x159135e22e0>,
#         <bem.triangulation.Triangulation at 0x159135e2190>,
#         <bem.triangulation.Triangulation at 0x159135e2b80>,
#         <bem.triangulation.Triangulation at 0x159135e25e0>,
#         <bem.triangulation.Triangulation at 0x159131c7bb0>,
#         <bem.triangulation.Triangulation at 0x159133bc670>,
#         <bem.triangulation.Triangulation at 0x159133bc1c0>,
#         <bem.triangulation.Triangulation at 0x159133bccd0>,
#         <bem.triangulation.Triangulation at 0x1597fec8370>,
#         <bem.triangulation.Triangulation at 0x159134e7ac0>,
#         <bem.triangulation.Triangulation at 0x159134e7850>,
#         <bem.triangulation.Triangulation at 0x159135b9bb0>,
#         <bem.triangulation.Triangulation at 0x1597fecb7c0>]),
#       ('DC7',
#        [<bem.triangulation.Triangulation at 0x1597fecbb80>,
#         <bem.triangulation.Triangulation at 0x159134d6b50>,
#         <bem.triangulation.Triangulation at 0x1591351e670>,
#         <bem.triangulation.Triangulation at 0x15913629f40>,
#         <bem.triangulation.Triangulation at 0x15913629100>,
#         <bem.triangulation.Triangulation at 0x159136291c0>,
#         <bem.triangulation.Triangulation at 0x15913629280>,
#         <bem.triangulation.Triangulation at 0x15913629340>,
#         <bem.triangulation.Triangulation at 0x159136294c0>,
#         <bem.triangulation.Triangulation at 0x159136295e0>,
#         <bem.triangulation.Triangulation at 0x159136296a0>,
#         <bem.triangulation.Triangulation at 0x15913629760>,
#         <bem.triangulation.Triangulation at 0x15913629880>]),
#       ('DC11',
#        [<bem.triangulation.Triangulation at 0x15913629940>,
#         <bem.triangulation.Triangulation at 0x15913629a30>,
#         <bem.triangulation.Triangulation at 0x15913629af0>,
#         <bem.triangulation.Triangulation at 0x15913629be0>,
#         <bem.triangulation.Triangulation at 0x15913629ca0>,
#         <bem.triangulation.Triangulation at 0x15913629d90>,
#         <bem.triangulation.Triangulation at 0x15913629e80>,
#         <bem.triangulation.Triangulation at 0x15913629bb0>,
#         <bem.triangulation.Triangulation at 0x15913629400>,
#         <bem.triangulation.Triangulation at 0x159136295b0>,
#         <bem.triangulation.Triangulation at 0x159133df970>,
#         <bem.triangulation.Triangulation at 0x159133df370>,
#         <bem.triangulation.Triangulation at 0x15910fe8f70>,
#         <bem.triangulation.Triangulation at 0x15910fe8a30>]),
#       ('DC12',
#        [<bem.triangulation.Triangulation at 0x15910fe8190>,
#         <bem.triangulation.Triangulation at 0x15910fe8fa0>,
#         <bem.triangulation.Triangulation at 0x15913526eb0>,
#         <bem.triangulation.Triangulation at 0x159131f45b0>,
#         <bem.triangulation.Triangulation at 0x15910fd0970>,
#         <bem.triangulation.Triangulation at 0x159135dbeb0>,
#         <bem.triangulation.Triangulation at 0x159135db100>,
#         <bem.triangulation.Triangulation at 0x159135db340>,
#         <bem.triangulation.Triangulation at 0x159135db5b0>,
#         <bem.triangulation.Triangulation at 0x159135db880>,
#         <bem.triangulation.Triangulation at 0x159135dba00>,
#         <bem.triangulation.Triangulation at 0x159135dbd00>,
#         <bem.triangulation.Triangulation at 0x159135db8e0>,
#         <bem.triangulation.Triangulation at 0x159135db520>]),
#       ('DC13',
#        [<bem.triangulation.Triangulation at 0x159135dba30>,
#         <bem.triangulation.Triangulation at 0x159135dbee0>,
#         <bem.triangulation.Triangulation at 0x159135db2b0>,
#         <bem.triangulation.Triangulation at 0x159135db280>,
#         <bem.triangulation.Triangulation at 0x159135dbd30>,
#         <bem.triangulation.Triangulation at 0x159135db820>,
#         <bem.triangulation.Triangulation at 0x159135dbbb0>,
#         <bem.triangulation.Triangulation at 0x159135dbe20>,
#         <bem.triangulation.Triangulation at 0x1597fef06a0>,
#         <bem.triangulation.Triangulation at 0x15910ff2550>,
#         <bem.triangulation.Triangulation at 0x1597fef3370>,
#         <bem.triangulation.Triangulation at 0x1597fef30a0>,
#         <bem.triangulation.Triangulation at 0x159131da100>]),
#       ('DC14',
#        [<bem.triangulation.Triangulation at 0x15910ff6b50>,
#         <bem.triangulation.Triangulation at 0x15910ff6d60>,
#         <bem.triangulation.Triangulation at 0x15910ffa0d0>,
#         <bem.triangulation.Triangulation at 0x15910ffab80>,
#         <bem.triangulation.Triangulation at 0x15910ffdac0>,
#         <bem.triangulation.Triangulation at 0x15910ffd970>,
#         <bem.triangulation.Triangulation at 0x159131fb580>,
#         <bem.triangulation.Triangulation at 0x159131fb1f0>,
#         <bem.triangulation.Triangulation at 0x1597fefe3d0>,
#         <bem.triangulation.Triangulation at 0x159131f8730>,
#         <bem.triangulation.Triangulation at 0x15910fef880>,
#         <bem.triangulation.Triangulation at 0x15910fef670>,
#         <bem.triangulation.Triangulation at 0x1591112a100>]),
#       ('DC15',
#        [<bem.triangulation.Triangulation at 0x159132fc370>,
#         <bem.triangulation.Triangulation at 0x159135a0e20>,
#         <bem.triangulation.Triangulation at 0x159135a0670>,
#         <bem.triangulation.Triangulation at 0x1591359a7c0>,
#         <bem.triangulation.Triangulation at 0x1591359a790>,
#         <bem.triangulation.Triangulation at 0x1591359a0d0>,
#         <bem.triangulation.Triangulation at 0x1591359a1c0>,
#         <bem.triangulation.Triangulation at 0x1591359a2b0>,
#         <bem.triangulation.Triangulation at 0x1591359a3a0>,
#         <bem.triangulation.Triangulation at 0x1591359a490>,
#         <bem.triangulation.Triangulation at 0x1591359a550>,
#         <bem.triangulation.Triangulation at 0x1591359a610>,
#         <bem.triangulation.Triangulation at 0x1591359a6d0>]),
#       ('DC16',
#        [<bem.triangulation.Triangulation at 0x1591359a8b0>,
#         <bem.triangulation.Triangulation at 0x1591359a9d0>,
#         <bem.triangulation.Triangulation at 0x1591359aa90>,
#         <bem.triangulation.Triangulation at 0x1591359ab80>,
#         <bem.triangulation.Triangulation at 0x1591359ac40>,
#         <bem.triangulation.Triangulation at 0x1591359ad30>,
#         <bem.triangulation.Triangulation at 0x1591359ae20>,
#         <bem.triangulation.Triangulation at 0x1591359af10>,
#         <bem.triangulation.Triangulation at 0x1591359a100>,
#         <bem.triangulation.Triangulation at 0x1591359a880>,
#         <bem.triangulation.Triangulation at 0x1591359ad00>,
#         <bem.triangulation.Triangulation at 0x159134bd100>,
#         <bem.triangulation.Triangulation at 0x159135a30d0>]),
#       ('DC17',
#        [<bem.triangulation.Triangulation at 0x159135a3340>,
#         <bem.triangulation.Triangulation at 0x159135a3580>,
#         <bem.triangulation.Triangulation at 0x159135a3820>,
#         <bem.triangulation.Triangulation at 0x159132f95e0>,
#         <bem.triangulation.Triangulation at 0x159132f9610>,
#         <bem.triangulation.Triangulation at 0x1597febe5e0>,
#         <bem.triangulation.Triangulation at 0x1597febeca0>,
#         <bem.triangulation.Triangulation at 0x1591369a7f0>,
#         <bem.triangulation.Triangulation at 0x1591369a9a0>,
#         <bem.triangulation.Triangulation at 0x1591369abb0>,
#         <bem.triangulation.Triangulation at 0x1591369ae20>,
#         <bem.triangulation.Triangulation at 0x1591369afd0>,
#         <bem.triangulation.Triangulation at 0x1591369a2e0>]),
#       ('DC18',
#        [<bem.triangulation.Triangulation at 0x1591369a130>,
# ...
#         <bem.triangulation.Triangulation at 0x159135b8e20>,
#         <bem.triangulation.Triangulation at 0x1591111fa30>,
#         <bem.triangulation.Triangulation at 0x159136bcc70>,
#         <bem.triangulation.Triangulation at 0x159136bcfa0>,
#         <bem.triangulation.Triangulation at 0x159136bc8e0>,
#         <bem.triangulation.Triangulation at 0x159136bca90>,
#         <bem.triangulation.Triangulation at 0x159136bc100>,
#         <bem.triangulation.Triangulation at 0x159136bc5e0>,
#         <bem.triangulation.Triangulation at 0x159136bc070>,
#         <bem.triangulation.Triangulation at 0x159136bc3a0>,
#         <bem.triangulation.Triangulation at 0x159136bc4f0>,
#         <bem.triangulation.Triangulation at 0x159136bca60>,
#         <bem.triangulation.Triangulation at 0x159136bcfd0>,
#         <bem.triangulation.Triangulation at 0x159136bcb80>,
#         <bem.triangulation.Triangulation at 0x159136bcdf0>,
#         <bem.triangulation.Triangulation at 0x159136bc1c0>,
#         <bem.triangulation.Triangulation at 0x159136bc520>,
#         <bem.triangulation.Triangulation at 0x159136bce80>,
#         <bem.triangulation.Triangulation at 0x1591341f220>,
#         <bem.triangulation.Triangulation at 0x1591341f2b0>,
#         <bem.triangulation.Triangulation at 0x1591341f3d0>,
#         <bem.triangulation.Triangulation at 0x1591341f6d0>,
#         <bem.triangulation.Triangulation at 0x1591341f8b0>,
#         <bem.triangulation.Triangulation at 0x1591341fcd0>,
#         <bem.triangulation.Triangulation at 0x1591341fe20>,
#         <bem.triangulation.Triangulation at 0x1591341ffd0>,
#         <bem.triangulation.Triangulation at 0x159135b3760>,
#         <bem.triangulation.Triangulation at 0x159135b3100>,
#         <bem.triangulation.Triangulation at 0x159135b37c0>,
#         <bem.triangulation.Triangulation at 0x159135b3dc0>,
#         <bem.triangulation.Triangulation at 0x159135b30a0>,
#         <bem.triangulation.Triangulation at 0x159135b3190>,
#         <bem.triangulation.Triangulation at 0x159135b3280>,
#         <bem.triangulation.Triangulation at 0x159135b3340>,
#         <bem.triangulation.Triangulation at 0x159135b3430>,
#         <bem.triangulation.Triangulation at 0x159135b34f0>,
#         <bem.triangulation.Triangulation at 0x159135b35b0>,
#         <bem.triangulation.Triangulation at 0x159135b3670>,
#         <bem.triangulation.Triangulation at 0x159135b37f0>,
#         <bem.triangulation.Triangulation at 0x159135b38b0>,
#         <bem.triangulation.Triangulation at 0x159135b39a0>,
#         <bem.triangulation.Triangulation at 0x159135b3a60>,
#         <bem.triangulation.Triangulation at 0x159135b3b50>,
#         <bem.triangulation.Triangulation at 0x159135b3ca0>,
#         <bem.triangulation.Triangulation at 0x159135b3d90>,
#         <bem.triangulation.Triangulation at 0x159135b3e80>,
#         <bem.triangulation.Triangulation at 0x159135b3fa0>,
#         <bem.triangulation.Triangulation at 0x1591361f070>,
#         <bem.triangulation.Triangulation at 0x1591361f190>,
#         <bem.triangulation.Triangulation at 0x1591361f250>,
#         <bem.triangulation.Triangulation at 0x1591361f310>,
#         <bem.triangulation.Triangulation at 0x1591361f400>,
#         <bem.triangulation.Triangulation at 0x1591361f550>,
#         <bem.triangulation.Triangulation at 0x1591361f640>,
#         <bem.triangulation.Triangulation at 0x1591361f760>,
#         <bem.triangulation.Triangulation at 0x1591361f880>,
#         <bem.triangulation.Triangulation at 0x1591361f9a0>,
#         <bem.triangulation.Triangulation at 0x1591361fa90>,
#         <bem.triangulation.Triangulation at 0x1591361fb50>,
#         <bem.triangulation.Triangulation at 0x1591361fc70>,
#         <bem.triangulation.Triangulation at 0x1591361fdc0>,
#         <bem.triangulation.Triangulation at 0x1591361feb0>,
#         <bem.triangulation.Triangulation at 0x1591361f430>,
#         <bem.triangulation.Triangulation at 0x1591361f6a0>,
#         <bem.triangulation.Triangulation at 0x1591361fc40>,
#         <bem.triangulation.Triangulation at 0x1591361f040>,
#         <bem.triangulation.Triangulation at 0x1591361fd60>,
#         <bem.triangulation.Triangulation at 0x159132c3790>,
#         <bem.triangulation.Triangulation at 0x159132c36a0>,
#         <bem.triangulation.Triangulation at 0x159135f40a0>,
#         <bem.triangulation.Triangulation at 0x159135f4fd0>,
#         <bem.triangulation.Triangulation at 0x159135f4eb0>,
#         <bem.triangulation.Triangulation at 0x159135f4220>,
#         <bem.triangulation.Triangulation at 0x159135f4640>,
#         <bem.triangulation.Triangulation at 0x159135f48e0>,
#         <bem.triangulation.Triangulation at 0x159135f4af0>,
#         <bem.triangulation.Triangulation at 0x159135f4ca0>,
#         <bem.triangulation.Triangulation at 0x159135f4dc0>,
#         <bem.triangulation.Triangulation at 0x159135f4f70>,
#         <bem.triangulation.Triangulation at 0x159135f46a0>,
#         <bem.triangulation.Triangulation at 0x159135f4d30>,
#         <bem.triangulation.Triangulation at 0x159135f43d0>,
#         <bem.triangulation.Triangulation at 0x159135f4100>,
#         <bem.triangulation.Triangulation at 0x159135f47c0>,
#         <bem.triangulation.Triangulation at 0x159135f4a90>,
#         <bem.triangulation.Triangulation at 0x159135c9fa0>,
#         <bem.triangulation.Triangulation at 0x159135c93a0>,
#         <bem.triangulation.Triangulation at 0x159135c9310>,
#         <bem.triangulation.Triangulation at 0x159135c94c0>,
#         <bem.triangulation.Triangulation at 0x159135c9520>,
#         <bem.triangulation.Triangulation at 0x159135c9a60>,
#         <bem.triangulation.Triangulation at 0x159135c9100>,
#         <bem.triangulation.Triangulation at 0x159135c90a0>,
#         <bem.triangulation.Triangulation at 0x159135c93d0>,
#         <bem.triangulation.Triangulation at 0x159135c96a0>,
#         <bem.triangulation.Triangulation at 0x159135c99d0>,
#         <bem.triangulation.Triangulation at 0x159135c9be0>,
#         <bem.triangulation.Triangulation at 0x159135c9cd0>,
#         <bem.triangulation.Triangulation at 0x159135c9eb0>,
#         <bem.triangulation.Triangulation at 0x159135c9c70>,
#         <bem.triangulation.Triangulation at 0x159135c9040>,
#         <bem.triangulation.Triangulation at 0x159135c9250>,
#         <bem.triangulation.Triangulation at 0x159135c9460>,
#         <bem.triangulation.Triangulation at 0x159135c98b0>,
#         <bem.triangulation.Triangulation at 0x159135c9b80>,
#         <bem.triangulation.Triangulation at 0x159135cc190>,
#         <bem.triangulation.Triangulation at 0x159135cc520>,
#         <bem.triangulation.Triangulation at 0x159135cc400>,
#         <bem.triangulation.Triangulation at 0x159136a2070>,
#         <bem.triangulation.Triangulation at 0x159136a2eb0>,
#         <bem.triangulation.Triangulation at 0x159136a2280>,
#         <bem.triangulation.Triangulation at 0x159136a2340>,
#         <bem.triangulation.Triangulation at 0x159136a2580>,
#         <bem.triangulation.Triangulation at 0x159136a2760>,
#         <bem.triangulation.Triangulation at 0x159136a2970>,
#         <bem.triangulation.Triangulation at 0x159136a2b20>,
#         <bem.triangulation.Triangulation at 0x159136a2ca0>,
#         <bem.triangulation.Triangulation at 0x159136a21f0>,
#         <bem.triangulation.Triangulation at 0x159136a23a0>,
#         <bem.triangulation.Triangulation at 0x159136a24c0>,
#         <bem.triangulation.Triangulation at 0x159136a2730>,
#         <bem.triangulation.Triangulation at 0x159136a2850>,
#         <bem.triangulation.Triangulation at 0x159136a2a30>,
#         <bem.triangulation.Triangulation at 0x159136a2bb0>,
#         <bem.triangulation.Triangulation at 0x159136a2d00>,
#         <bem.triangulation.Triangulation at 0x159136a2e20>,
#         <bem.triangulation.Triangulation at 0x159136a2f70>,
#         <bem.triangulation.Triangulation at 0x1597feded90>,
#         <bem.triangulation.Triangulation at 0x1597fede790>,
#         <bem.triangulation.Triangulation at 0x15910feb490>,
#         <bem.triangulation.Triangulation at 0x15910feb0a0>,
#         <bem.triangulation.Triangulation at 0x159132d39a0>,
#         <bem.triangulation.Triangulation at 0x159133d4d30>,
#         <bem.triangulation.Triangulation at 0x159133d4b50>,
#         <bem.triangulation.Triangulation at 0x159133d4e50>,
#         <bem.triangulation.Triangulation at 0x159133d47f0>,
#         <bem.triangulation.Triangulation at 0x159133d4070>,
#         <bem.triangulation.Triangulation at 0x159133d7130>,
#         <bem.triangulation.Triangulation at 0x159133d7b20>,
#         <bem.triangulation.Triangulation at 0x15913523040>,
#         <bem.triangulation.Triangulation at 0x15913523160>,
#         <bem.triangulation.Triangulation at 0x15913523250>,
#         <bem.triangulation.Triangulation at 0x15913523340>,
#         <bem.triangulation.Triangulation at 0x15913523400>,
#         <bem.triangulation.Triangulation at 0x159135234f0>,
#         <bem.triangulation.Triangulation at 0x159135235e0>,
#         <bem.triangulation.Triangulation at 0x159135236a0>,
#         <bem.triangulation.Triangulation at 0x15913523760>,
#         <bem.triangulation.Triangulation at 0x15913523ac0>,
#         <bem.triangulation.Triangulation at 0x15913523dc0>,
#         <bem.triangulation.Triangulation at 0x15913523e80>,
#         <bem.triangulation.Triangulation at 0x15913523fa0>]),
#       ('DC1',
#        [<bem.triangulation.Triangulation at 0x15913523310>,
#         <bem.triangulation.Triangulation at 0x15913523f10>,
#         <bem.triangulation.Triangulation at 0x159135f79a0>,
#         <bem.triangulation.Triangulation at 0x159135f7d90>,
#         <bem.triangulation.Triangulation at 0x159135f7ee0>,
#         <bem.triangulation.Triangulation at 0x159135f7130>,
#         <bem.triangulation.Triangulation at 0x159135f7040>,
#         <bem.triangulation.Triangulation at 0x159135f7340>,
#         <bem.triangulation.Triangulation at 0x159135f7640>,
#         <bem.triangulation.Triangulation at 0x159135f72e0>,
#         <bem.triangulation.Triangulation at 0x159135f78b0>,
#         <bem.triangulation.Triangulation at 0x15910fddc10>,
#         <bem.triangulation.Triangulation at 0x15910fddeb0>,
#         <bem.triangulation.Triangulation at 0x159135dec40>,
#         <bem.triangulation.Triangulation at 0x159135de4f0>,
#         <bem.triangulation.Triangulation at 0x159135de5b0>]),
#       ('DC3',
#        [<bem.triangulation.Triangulation at 0x159135de1c0>,
#         <bem.triangulation.Triangulation at 0x159135de2b0>,
#         <bem.triangulation.Triangulation at 0x159135de640>,
#         <bem.triangulation.Triangulation at 0x159135dea30>,
#         <bem.triangulation.Triangulation at 0x159135de3d0>,
#         <bem.triangulation.Triangulation at 0x159135de8b0>,
#         <bem.triangulation.Triangulation at 0x159135de400>,
#         <bem.triangulation.Triangulation at 0x159135de670>,
#         <bem.triangulation.Triangulation at 0x159135ded60>,
#         <bem.triangulation.Triangulation at 0x159135defd0>,
#         <bem.triangulation.Triangulation at 0x159135de5e0>,
#         <bem.triangulation.Triangulation at 0x159135de700>,
#         <bem.triangulation.Triangulation at 0x1597fee9f10>,
#         <bem.triangulation.Triangulation at 0x1597fee9910>]),
#       ('DC4',
#        [<bem.triangulation.Triangulation at 0x1597fee9730>,
#         <bem.triangulation.Triangulation at 0x159135fa250>,
#         <bem.triangulation.Triangulation at 0x159135fa580>,
#         <bem.triangulation.Triangulation at 0x159135fa7c0>,
#         <bem.triangulation.Triangulation at 0x159135faac0>,
#         <bem.triangulation.Triangulation at 0x159135fad00>,
#         <bem.triangulation.Triangulation at 0x159135fae80>,
#         <bem.triangulation.Triangulation at 0x159135fa1f0>,
#         <bem.triangulation.Triangulation at 0x159135fad30>,
#         <bem.triangulation.Triangulation at 0x159135fae20>,
#         <bem.triangulation.Triangulation at 0x159135fa340>,
#         <bem.triangulation.Triangulation at 0x159135fa730>,
#         <bem.triangulation.Triangulation at 0x159135fab20>,
#         <bem.triangulation.Triangulation at 0x15913627040>,
#         <bem.triangulation.Triangulation at 0x159136270d0>]),
#       ('DC5',
#        [<bem.triangulation.Triangulation at 0x15913627190>,
#         <bem.triangulation.Triangulation at 0x15913627250>,
#         <bem.triangulation.Triangulation at 0x15913627310>,
#         <bem.triangulation.Triangulation at 0x15913627400>,
#         <bem.triangulation.Triangulation at 0x159136274c0>,
#         <bem.triangulation.Triangulation at 0x15913627580>,
#         <bem.triangulation.Triangulation at 0x15913627640>,
#         <bem.triangulation.Triangulation at 0x15913627730>,
#         <bem.triangulation.Triangulation at 0x15913627820>,
#         <bem.triangulation.Triangulation at 0x159136278e0>,
#         <bem.triangulation.Triangulation at 0x159136279a0>,
#         <bem.triangulation.Triangulation at 0x15913627a60>,
#         <bem.triangulation.Triangulation at 0x15913627b20>,
#         <bem.triangulation.Triangulation at 0x15913627be0>]),
#       ('DC6',
#        [<bem.triangulation.Triangulation at 0x15913627cd0>,
#         <bem.triangulation.Triangulation at 0x15913627dc0>,
#         <bem.triangulation.Triangulation at 0x15913627eb0>,
#         <bem.triangulation.Triangulation at 0x15913627f70>,
#         <bem.triangulation.Triangulation at 0x15913627d30>,
#         <bem.triangulation.Triangulation at 0x1597feecf70>,
#         <bem.triangulation.Triangulation at 0x1597fef6ca0>,
#         <bem.triangulation.Triangulation at 0x1597fef64f0>,
#         <bem.triangulation.Triangulation at 0x1597fef6820>,
#         <bem.triangulation.Triangulation at 0x1597fee66a0>,
#         <bem.triangulation.Triangulation at 0x1597fee6d60>,
#         <bem.triangulation.Triangulation at 0x1597fee6be0>,
#         <bem.triangulation.Triangulation at 0x159135f0f10>,
#         <bem.triangulation.Triangulation at 0x159135f0dc0>]),
#       ('DC8',
#        [<bem.triangulation.Triangulation at 0x159135f05e0>,
#         <bem.triangulation.Triangulation at 0x159135f06d0>,
#         <bem.triangulation.Triangulation at 0x159135f07f0>,
#         <bem.triangulation.Triangulation at 0x159135f08e0>,
#         <bem.triangulation.Triangulation at 0x159135f0ac0>,
#         <bem.triangulation.Triangulation at 0x159135f0bb0>,
#         <bem.triangulation.Triangulation at 0x159135f0d90>,
#         <bem.triangulation.Triangulation at 0x159135f0160>,
#         <bem.triangulation.Triangulation at 0x159135f0040>,
#         <bem.triangulation.Triangulation at 0x159135f0190>,
#         <bem.triangulation.Triangulation at 0x159135f01c0>,
#         <bem.triangulation.Triangulation at 0x159135f0490>,
#         <bem.triangulation.Triangulation at 0x159135f03a0>,
#         <bem.triangulation.Triangulation at 0x159135f0730>]),
#       ('DC9',
#        [<bem.triangulation.Triangulation at 0x159135f02e0>,
#         <bem.triangulation.Triangulation at 0x159135f0e50>,
#         <bem.triangulation.Triangulation at 0x159135ff5e0>,
#         <bem.triangulation.Triangulation at 0x159135ff0a0>,
#         <bem.triangulation.Triangulation at 0x159135ff460>,
#         <bem.triangulation.Triangulation at 0x159135ff190>,
#         <bem.triangulation.Triangulation at 0x159135ff340>,
#         <bem.triangulation.Triangulation at 0x159135ff8e0>,
#         <bem.triangulation.Triangulation at 0x159135ff9a0>,
#         <bem.triangulation.Triangulation at 0x159135ffa60>,
#         <bem.triangulation.Triangulation at 0x159135ffb20>,
#         <bem.triangulation.Triangulation at 0x159135ffbe0>,
#         <bem.triangulation.Triangulation at 0x159135ffca0>,
#         <bem.triangulation.Triangulation at 0x159135ffd60>]),
#       ('DC10',
#        [<bem.triangulation.Triangulation at 0x159135ffe20>,
#         <bem.triangulation.Triangulation at 0x159135ffee0>,
#         <bem.triangulation.Triangulation at 0x159135fffa0>,
#         <bem.triangulation.Triangulation at 0x1591370f0a0>,
#         <bem.triangulation.Triangulation at 0x1591370f160>,
#         <bem.triangulation.Triangulation at 0x1591370f220>,
#         <bem.triangulation.Triangulation at 0x1591370f2e0>,
#         <bem.triangulation.Triangulation at 0x1591370f3a0>,
#         <bem.triangulation.Triangulation at 0x1591370f460>,
#         <bem.triangulation.Triangulation at 0x1591370f520>,
#         <bem.triangulation.Triangulation at 0x1591370f5e0>])])

# %%
# save base mesh to a pickle file
with open(fout_name,'wb') as f:
    data = (mesh_unit,
            xl,
            yl,
            zl,
            mesh,
            list(od.values()))
    pickle.dump(data,f)

# %% [markdown]
# ## view mesh
# Uses Pyvista package to generate interactive 3-d plot of the mesh

# %%
# Plot triangle mezshes of the final mesh
mesh.plot()

# %% [markdown]
# Show number of points included in the mesh

# %%
print(len(mesh.points))
# Out:
# 10440
