# %% [markdown]
# # `Documention & Tutorial`
# This BEM package is used for for numerical simulation of the electric field of ion traps in python. Some external packages are wrapped into it:
#
# * fast triangulation (http://www.cs.cmu.edu/~quake/triangle.research.html)
# * fastlap boundary element method (Nabors K S. Efficient three-dimensional capacitance calculation[D]. Massachusetts Institute of Technology, 1993.)
#
# This document, also as a tutorial, explains how to use these packages to compute the electric field and compute its multipole expansion coefficient starting from scratch with a fusion 360 trap model(take `./f3d/htrap_cutout_overhang_9x5mm.f3d` for example). Our document consists of three .ipynb files:
#
# * `I_Mesh_Processing.ipynb`
# * `II_Field_Simulation.ipynb`
# * `III_Multipole_Expansion.ipynb`
#
# We split the document into three files for two reasons:
# 1. The most time consuming part `II_Field_Simulation.ipynb` could be taken out alone and run on a high peformance computer.
# 2. The intermediate result between files can be checked- 'intermediate files' refer to the inital mesh grid (that corresponds to the charge distribution), the simulation values and the simulation coordinates, all of which are saved in the inter_results folder. So if the voltage solution files for the trap don't make sense, it is possible to go back through saved data to see where things have gone wrong.
# Here are the three jupyter notebooks and what:
# 1. I_Mesh_Processing- this notebook generates a mesh of the trap, saved in inter_results as a .pkl file
#
#
# Going through three files in order and running their python code will help you understand our workflow. Generally our workflow divides into three steps, corresponding to the above three .ipynb files. First, in I_Mesh_Processing, we identify different electrodes of the trap model by different colors. Also, we refine the trap model meshes to prepare for the second step. The result is stored in `mesh_result.pkl`.
#
# Secondly, in II_Field_Simulation, we simulate the electric potential with fastlap boundary element method(FMM), the accuracy of this step depends on the mesh size in the first step. The result is stored in `field_result.pkl`.
#
# Thirdly, in III_Multipole_Expansion, we analyze the electric field and electric potential. This notebook generates the multipole coefficients of the fields and potentials for each electrode and uses that information to generate a solution file with the function call `write_csv`. If your solution don't make sense, a good place to start is to insure that the mesh you are using is fine enough (generate several field results for different meshes)- if the potentials and fields are converging to specific values, this suggests there is something wrong with the multipole expansion. If you start with multipole expansion, you do not know if it is a problem with the expansion or with the field.
#
# Before running codes, you must set up the environment according to instructions in `README`
#
# notes
# * Our workflow, as indicated by this document, abandons mayavi(with its embeded package tvtk). But we reserve mayavi in our Bem source code, if you want to use mayavi related functions, you must set up environment with files in`./backup/setup_with_mayavi`, just replace corresponding files in the root folder with them and set up.
#     * why we abandon mayavi: because its python interface(with its dependence vtk and PyQt5) requires complex package dependencies and version controls especially for new python versions. This makes it difficult to maintain this project.
#     * why we still keep mayavi in the source code? Because it is rooted in our source code deeply. We can just avoid invoking related functions instead of deleting them, because they may make sense in the future.

# %% [markdown]
# # `I. Mesh Processing`
# This .pynb file reads a colored model file `./inter_results/htrap_cutout.stl`, and assigns a name for each color(thus for each electrode). The result is stored in `./inter_results/mesh_result.pkl`.
#
# In this file we name different electrodes and refine the meshes. The size of mesh determines the accuracy in next step. You should set the mesh finer and finer until the result converges. Also, you can set the mesh finer and test the convergence.
#
# ## (1) color your electrodes (in fusion 360) and export stl
# First of all, you have a trap model in fusion 360 project, for example, `./f3d/htrap_cutout_overhang_9x5mm.f3d`. Here we use different color to identify different electrodes(STL file stores color for each mesh). In fusion 360, you can assign different appearance for different electrodes. We recommend to use ../../bemCol_lib/bemCol.adsklib for different electrodes. Same color for two electrodes means they are treated as the same electrode. Then we get `./f3d/htrap_cutout_overhang_9x5mm_my_colored.f3d`
#
# Then export to an stl file in fusion360 file>export tab and move the file in `./inter_results`. We export our stl in mm, so we set the mesh unit to mm.

# %% [markdown]
# Furthurmore, it's our convention to use unit mm in our traps. e.g. [Electric field] = V/mm , [harmonic confining potential] = V/mm^2.so we set

# %%
# this is the unit for our Mesh structure
# in the following code, this is the default unit for python variables
#units 
mesh_unit = 1e-3

# %% [markdown]
# Additional notes (from Wenhao):
# * Why use standard color? We define a set of standard color lib `../../../bemCol_lib/bemCol.adsklib` for two reasons: 1. when exporting to .stl file, fusion 360 will compress 0-256 color(RGBA32) into 0-32 color(RGBA16), which means that some similar colors in fusion 360 will become same color after export to .stl file. Our standard color lib avoid this problem. 2.If you use .stl file exported from fusion 360 DIRECTLY, naming the electrodes would be very convinient. If you use other apps such as Inventor or Meshlab to generate .stl file, you can ignore the second reason because color encoding are quite different in different apps

# %% [markdown]
# ## (2) assign a name for each color

# %%
import pickle
import numpy as np
import matplotlib as mpl
import sys
from utils.helper_functions import *
from bem.bemColors_lib.bemColors import bemColors
from bem import Electrodes, Sphere, Mesh, Grid, Configuration, Result, Box
# load stl geometry file
from bem.formats import stl
# stl_path = "roughness/"+"basic_excitation"+".stl"  


#radius is the radius of the sphere from the ions location to generate a finer
#electrode mesh
radius= 500e-3
#'area' is the area of the triangles inside the sphere
area = 1e-4
# file = 'mit_charge'
# file = 'htrap_cutout_overhang_taper_2'
# file_out = 'htrap_cutout_overhang_taper_el3'
# stl_path = 'inter_results/taper_overhang/'+file+'.stl'
# fout_name = 'inter_results/taper_overhang/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


file_out = 'htrap_cutout_el2'
stl_path = 'inter_results/htrap_cutout/htrap_cutout.stl'
fout_name = 'inter_results/htrap_cutout/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


module_path = os.path.abspath('')


s_nta = stl.read_stl(open(stl_path, "rb"))

# %% [markdown]
# Firstly, we print all the colors appear in the stl file. If a color is of standard colors in `bemCol.adsklib` or named manually by function `bemCol.set_my_color()`, then the color will appear in a straightforward name, such as `bem0`,`bem1` ...... . Otherwise, the color will simply be named as `'_unkCol0'` , `'_unkCol1'`, ...
#
# notes
# * try to comment out the line of `ele_col.set_my_color()` in the following block, name `'_unkCol0'` will appear.

# %%
ele_col = bemColors(np.array(list(set(s_nta[2]))),('fusion360','export_stl'))
ele_col.set_my_color(value = (178,178,178),cl_format = ('fusion360','export_stl','RGBA64'),name = 'self_defined')
ele_col.print_stl_colors()
# Out:
# COLORS in the stl:
# ['bem6']
# ['bem13']
# ['bem19']
# ['bem11']
# ['bem17']
# ['bem15']
# ['bem30']
# ['bem1']
# ['bem12']
# ['bem5']
# ['bem25']
# ['bem18']
# ['bem16']
# ['bem3']
# ['bem7']
# ['bem9']
# ['bem2']
# ['bem4']
# ['bem20']
# ['bem10']
# ['bem14']
# ['bem8']
# ['bem21']
# ['_unkColor0']
# TOTAL COLORS:  24

# %% [markdown]
# Next, you need to assign a name for each color that appeared above. With standard colors defined in `bemCol.adsklib`, the correspondence between color and electrode is clear, which make it easy for this step. You can also comment out some `ele_col.set_color_name()`, run all the codes again and observe the missing part in the printed figure, which corresponds to the electrode you comment out. The second method also serves as a double check. Besides, parameter in `stl.stl_to_mesh()` can be set as `quiet = False` to check whether the program reads planes correctly.

# %%
# assign a name for each color
# taper htrap_cutout 2022
# assign a name for each color

# In od[key] = value, key is the color from the Fusion360 color library we made
# value assigns a specific name to that color in this program. 
# In future version, we may want to consider getting rid of this step for simplification
# then you just assign the color in fusion 360 and be done with it. The only concern there is you
from collections import OrderedDict
od = OrderedDict()
od['bem1']='DC1'
od['bem2']='DC2'
od['bem3']='DC3'
od['bem4']='DC4'
od['bem5']='DC5'
od['bem6']='DC6'
od['bem7']='DC7'
od['bem8']='DC8'
od['bem9']='DC9'
od['bem10']='DC10'
od['bem11']='DC11'
od['bem12']='DC12'
od['bem13']='DC13'
od['bem14']='DC14'
od['bem15']='DC15'
od['bem16']='DC16'
od['bem17']='DC17'
od['bem18']='DC18'
od['bem19']='DC19'
od['bem20']='DC20'
od['bem21'] = 'DC21'
od['bem25'] = 'RF'
od['bem30'] = 'gnd'
for key in list(od.keys()):
    ele_col.color_electrode(color=key,name=od[key])

# print colors still with no name. These meshes will be neglected in the code below. 
ele_col.drop_colors()

# read stl into mesh with electrode names
# unnamed meshes will not be imported at all

mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=1,
    rename=ele_col.electrode_colors, quiet=True))
# Out:
# dropping color ['_unkColor0']
# TOTAL COLORS DROPPED:  1
# dropping 20083

# %% [markdown]
# ## (3) remesh
#
# In this step, we generate triangle mesh with constraints. The meshes are 2-dimensional triangles on the surface of electrodes. The region enclosed by constraint shape can have finer mesh. Triangulation is done by `triangle` C library. Folowing variables are all in unit `mesh_unit` now.
#
# Our remesh strategy consists of two steps of triangulation:
# 1. global triangulation without constraint. This step eliminate some long and sharp triangles by combining and dividing, and obtains a coarse grain triangulated model.
# 2. local triangulation with constraint. This step refines each triangles in step 1, the triangle density is defined by `mesh.areas_from_constraints
#
# parameters in the below code block should be tuned specificly for different trap geometries.`

# %%
# here we define a spherical constriant zone:
# xl = 270*1e-3
# yl = -3.5*1e-3
# zl = 72.5*1e-3

#here is the location that will be the reference point for further meshing
#usually, this is the ion's location, specified in appropriate units (usually millimeters)
zl = -450*1e-3
yl = 75*1e-3
xl = 3.75*1e-3


mesh.triangulate(opts="",new = False)

# for z in np.arange(-400e-3,700e-3,100e-3):
print('first triangulation:')
# for z in np.arange(-200e-3, 200e-3, 50e-3):
rad = radius*3
inside=area*30
outside=1
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="a2Q",new = False)

# # what happened to this feature (Box)? is this on bem savio?
# # mesh.areas_from_constraints(Box(start=-0.5, end= 0.5,inside=inside, outside=outside))



# areas_from_constraints specifies sphere with finer mesh inside it.
#  "inside", "outside" set different mesh densities. 
print('second triangulation:')
rad =radius
inside=area*2
outside=1e4
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="q5Q",new = False)

# save base mesh to a pickle file
# with open(fout_name,'wb') as f:
#     data = (mesh_unit,
#             xl,
#             yl,
#             zl,
#             mesh,
#             list(od.values()))
#     pickle.dump(data,f)
# Out:
# start triangulate RF
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate RF
# start triangulate DC21
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC21
# start triangulate DC2
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC2
# start triangulate DC7
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC7
# start triangulate DC11
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC11
# start triangulate DC12
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC12
# start triangulate DC13
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC13
# start triangulate DC14
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC14
# start triangulate DC15
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC15
# start triangulate DC16
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC16
# start triangulate DC17
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC17
# start triangulate DC18
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC18
# start triangulate DC19
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC19
# start triangulate DC20
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC20
# start triangulate gnd
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate gnd
# start triangulate DC1
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC1
# start triangulate DC3
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC3
# start triangulate DC4
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC4
# start triangulate DC5
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC5
# start triangulate DC6
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC6
# start triangulate DC8
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC8
# start triangulate DC9
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC9
# start triangulate DC10
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC10
# first triangulation:
# start triangulate RF
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate RF
# start triangulate DC21
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC10
# second triangulation:
# start triangulate RF
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate RF
# start triangulate DC21
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC10
# Mesh([('RF',
#        [<bem.triangulation.Triangulation at 0x1a5f3c0cfa0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73d60>,
#         <bem.triangulation.Triangulation at 0x1a5815c50d0>,
#         <bem.triangulation.Triangulation at 0x1a5815c5070>,
#         <bem.triangulation.Triangulation at 0x1a5815c5190>,
#         <bem.triangulation.Triangulation at 0x1a5815c52b0>,
#         <bem.triangulation.Triangulation at 0x1a5815c5370>,
#         <bem.triangulation.Triangulation at 0x1a5815c0370>,
#         <bem.triangulation.Triangulation at 0x1a5815c02e0>,
#         <bem.triangulation.Triangulation at 0x1a5815c0220>,
#         <bem.triangulation.Triangulation at 0x1a5815c0160>,
#         <bem.triangulation.Triangulation at 0x1a5815c00a0>,
#         <bem.triangulation.Triangulation at 0x1a5815ce0a0>,
#         <bem.triangulation.Triangulation at 0x1a5815ce160>,
#         <bem.triangulation.Triangulation at 0x1a5815ce220>,
#         <bem.triangulation.Triangulation at 0x1a5815ceee0>,
#         <bem.triangulation.Triangulation at 0x1a5815ce2e0>]),
#       ('DC21',
#        [<bem.triangulation.Triangulation at 0x1a5815cea60>,
#         <bem.triangulation.Triangulation at 0x1a5815ceb20>,
#         <bem.triangulation.Triangulation at 0x1a5815cebe0>,
#         <bem.triangulation.Triangulation at 0x1a5815ceca0>,
#         <bem.triangulation.Triangulation at 0x1a5815ced60>,
#         <bem.triangulation.Triangulation at 0x1a5815cee20>,
#         <bem.triangulation.Triangulation at 0x1a5815cefa0>]),
#       ('DC2',
#        [<bem.triangulation.Triangulation at 0x1a5f5cec5b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5cecd90>,
#         <bem.triangulation.Triangulation at 0x1a5f5cec0d0>,
#         <bem.triangulation.Triangulation at 0x1a5f5ceca00>,
#         <bem.triangulation.Triangulation at 0x1a5f5cecb80>,
#         <bem.triangulation.Triangulation at 0x1a5f5cec220>,
#         <bem.triangulation.Triangulation at 0x1a5f5cec970>,
#         <bem.triangulation.Triangulation at 0x1a5f5cec310>,
#         <bem.triangulation.Triangulation at 0x1a5f5cec9d0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16820>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16d30>,
#         <bem.triangulation.Triangulation at 0x1a5f5cd75e0>,
#         <bem.triangulation.Triangulation at 0x1a5f5cd7ca0>]),
#       ('DC7',
#        [<bem.triangulation.Triangulation at 0x1a5f5cd7e80>,
#         <bem.triangulation.Triangulation at 0x1a5f5cd7e50>,
#         <bem.triangulation.Triangulation at 0x1a5f5cd7820>,
#         <bem.triangulation.Triangulation at 0x1a5f5cdc4f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5cdc2b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5cdcac0>,
#         <bem.triangulation.Triangulation at 0x1a5f5cdcd60>,
#         <bem.triangulation.Triangulation at 0x1a5f5cdc100>,
#         <bem.triangulation.Triangulation at 0x1a5815c9040>,
#         <bem.triangulation.Triangulation at 0x1a5815c90d0>,
#         <bem.triangulation.Triangulation at 0x1a5815c9190>,
#         <bem.triangulation.Triangulation at 0x1a5815c9250>,
#         <bem.triangulation.Triangulation at 0x1a5815c9310>]),
#       ('DC11',
#        [<bem.triangulation.Triangulation at 0x1a5815c93d0>,
#         <bem.triangulation.Triangulation at 0x1a5815c9490>,
#         <bem.triangulation.Triangulation at 0x1a5815c9550>,
#         <bem.triangulation.Triangulation at 0x1a5815c9610>,
#         <bem.triangulation.Triangulation at 0x1a5815c96d0>,
#         <bem.triangulation.Triangulation at 0x1a5815c9790>,
#         <bem.triangulation.Triangulation at 0x1a5815c9850>,
#         <bem.triangulation.Triangulation at 0x1a5815c9910>,
#         <bem.triangulation.Triangulation at 0x1a5815c99d0>,
#         <bem.triangulation.Triangulation at 0x1a5815c9a90>,
#         <bem.triangulation.Triangulation at 0x1a5815c9b50>,
#         <bem.triangulation.Triangulation at 0x1a5815c9c10>,
#         <bem.triangulation.Triangulation at 0x1a5815c9cd0>,
#         <bem.triangulation.Triangulation at 0x1a5815c9d90>]),
#       ('DC12',
#        [<bem.triangulation.Triangulation at 0x1a5815c9e50>,
#         <bem.triangulation.Triangulation at 0x1a5815c9f10>,
#         <bem.triangulation.Triangulation at 0x1a5815d9040>,
#         <bem.triangulation.Triangulation at 0x1a5815d90d0>,
#         <bem.triangulation.Triangulation at 0x1a5815d9190>,
#         <bem.triangulation.Triangulation at 0x1a5815d9250>,
#         <bem.triangulation.Triangulation at 0x1a5815d9310>,
#         <bem.triangulation.Triangulation at 0x1a5815d93d0>,
#         <bem.triangulation.Triangulation at 0x1a5815d9490>,
#         <bem.triangulation.Triangulation at 0x1a5815d9550>,
#         <bem.triangulation.Triangulation at 0x1a5815d9610>,
#         <bem.triangulation.Triangulation at 0x1a5815d96d0>,
#         <bem.triangulation.Triangulation at 0x1a5815d9790>,
#         <bem.triangulation.Triangulation at 0x1a5815d9850>]),
#       ('DC13',
#        [<bem.triangulation.Triangulation at 0x1a5815d9910>,
#         <bem.triangulation.Triangulation at 0x1a5815d99d0>,
#         <bem.triangulation.Triangulation at 0x1a5815d9a90>,
#         <bem.triangulation.Triangulation at 0x1a5815d9b50>,
#         <bem.triangulation.Triangulation at 0x1a5815d9c10>,
#         <bem.triangulation.Triangulation at 0x1a5815d9cd0>,
#         <bem.triangulation.Triangulation at 0x1a5815d9d90>,
#         <bem.triangulation.Triangulation at 0x1a5815d9e50>,
#         <bem.triangulation.Triangulation at 0x1a5815d9f10>,
#         <bem.triangulation.Triangulation at 0x1a5815dc040>,
#         <bem.triangulation.Triangulation at 0x1a5815dc0d0>,
#         <bem.triangulation.Triangulation at 0x1a5815dc190>,
#         <bem.triangulation.Triangulation at 0x1a5815dc250>]),
#       ('DC14',
#        [<bem.triangulation.Triangulation at 0x1a5815dc310>,
#         <bem.triangulation.Triangulation at 0x1a5815dc3d0>,
#         <bem.triangulation.Triangulation at 0x1a5815dc490>,
#         <bem.triangulation.Triangulation at 0x1a5815dc550>,
#         <bem.triangulation.Triangulation at 0x1a5815dc610>,
#         <bem.triangulation.Triangulation at 0x1a5815dc6d0>,
#         <bem.triangulation.Triangulation at 0x1a5815dc790>,
#         <bem.triangulation.Triangulation at 0x1a5815dc850>,
#         <bem.triangulation.Triangulation at 0x1a5815dc910>,
#         <bem.triangulation.Triangulation at 0x1a5815dc9d0>,
#         <bem.triangulation.Triangulation at 0x1a5815dca90>,
#         <bem.triangulation.Triangulation at 0x1a5815dcb50>,
#         <bem.triangulation.Triangulation at 0x1a5815dcc10>]),
#       ('DC15',
#        [<bem.triangulation.Triangulation at 0x1a5815dccd0>,
#         <bem.triangulation.Triangulation at 0x1a5815dcd90>,
#         <bem.triangulation.Triangulation at 0x1a5815dce50>,
#         <bem.triangulation.Triangulation at 0x1a5815dcf10>,
#         <bem.triangulation.Triangulation at 0x1a58173c040>,
#         <bem.triangulation.Triangulation at 0x1a58173c0d0>,
#         <bem.triangulation.Triangulation at 0x1a58173c190>,
#         <bem.triangulation.Triangulation at 0x1a58173c250>,
#         <bem.triangulation.Triangulation at 0x1a58173c310>,
#         <bem.triangulation.Triangulation at 0x1a58173c3d0>,
#         <bem.triangulation.Triangulation at 0x1a58173c490>,
#         <bem.triangulation.Triangulation at 0x1a58173c550>,
#         <bem.triangulation.Triangulation at 0x1a58173c610>]),
#       ('DC16',
#        [<bem.triangulation.Triangulation at 0x1a58173c6d0>,
#         <bem.triangulation.Triangulation at 0x1a58173c790>,
#         <bem.triangulation.Triangulation at 0x1a58173c850>,
#         <bem.triangulation.Triangulation at 0x1a58173c910>,
#         <bem.triangulation.Triangulation at 0x1a58173c9d0>,
#         <bem.triangulation.Triangulation at 0x1a58173ca90>,
#         <bem.triangulation.Triangulation at 0x1a58173cb50>,
#         <bem.triangulation.Triangulation at 0x1a58173cc10>,
#         <bem.triangulation.Triangulation at 0x1a58173ccd0>,
#         <bem.triangulation.Triangulation at 0x1a58173cd90>,
#         <bem.triangulation.Triangulation at 0x1a58173ce50>,
#         <bem.triangulation.Triangulation at 0x1a58173cf10>,
#         <bem.triangulation.Triangulation at 0x1a581721040>]),
#       ('DC17',
#        [<bem.triangulation.Triangulation at 0x1a5817210d0>,
#         <bem.triangulation.Triangulation at 0x1a581721190>,
#         <bem.triangulation.Triangulation at 0x1a581721250>,
#         <bem.triangulation.Triangulation at 0x1a581721310>,
#         <bem.triangulation.Triangulation at 0x1a5817213d0>,
#         <bem.triangulation.Triangulation at 0x1a581721490>,
#         <bem.triangulation.Triangulation at 0x1a581721550>,
#         <bem.triangulation.Triangulation at 0x1a581721610>,
#         <bem.triangulation.Triangulation at 0x1a5817216d0>,
#         <bem.triangulation.Triangulation at 0x1a581721790>,
#         <bem.triangulation.Triangulation at 0x1a581721850>,
#         <bem.triangulation.Triangulation at 0x1a581721910>,
#         <bem.triangulation.Triangulation at 0x1a5f3ba4280>]),
#       ('DC18',
#        [<bem.triangulation.Triangulation at 0x1a581721a00>,
# ...
#         <bem.triangulation.Triangulation at 0x1a58171b6d0>,
#         <bem.triangulation.Triangulation at 0x1a58171b790>,
#         <bem.triangulation.Triangulation at 0x1a58171b850>,
#         <bem.triangulation.Triangulation at 0x1a58171b910>,
#         <bem.triangulation.Triangulation at 0x1a58171b9d0>,
#         <bem.triangulation.Triangulation at 0x1a58171ba90>,
#         <bem.triangulation.Triangulation at 0x1a58171bb50>,
#         <bem.triangulation.Triangulation at 0x1a58171bc10>,
#         <bem.triangulation.Triangulation at 0x1a58171bcd0>,
#         <bem.triangulation.Triangulation at 0x1a58171bd90>,
#         <bem.triangulation.Triangulation at 0x1a58171be50>,
#         <bem.triangulation.Triangulation at 0x1a58171bf10>,
#         <bem.triangulation.Triangulation at 0x1a581715040>,
#         <bem.triangulation.Triangulation at 0x1a5817150d0>,
#         <bem.triangulation.Triangulation at 0x1a581715190>,
#         <bem.triangulation.Triangulation at 0x1a581715250>,
#         <bem.triangulation.Triangulation at 0x1a581715310>,
#         <bem.triangulation.Triangulation at 0x1a5817153d0>,
#         <bem.triangulation.Triangulation at 0x1a581715490>,
#         <bem.triangulation.Triangulation at 0x1a581715550>,
#         <bem.triangulation.Triangulation at 0x1a581715610>,
#         <bem.triangulation.Triangulation at 0x1a5817156d0>,
#         <bem.triangulation.Triangulation at 0x1a581715790>,
#         <bem.triangulation.Triangulation at 0x1a581715850>,
#         <bem.triangulation.Triangulation at 0x1a581715910>,
#         <bem.triangulation.Triangulation at 0x1a5817159d0>,
#         <bem.triangulation.Triangulation at 0x1a581715a90>,
#         <bem.triangulation.Triangulation at 0x1a581715b50>,
#         <bem.triangulation.Triangulation at 0x1a581715c10>,
#         <bem.triangulation.Triangulation at 0x1a581715cd0>,
#         <bem.triangulation.Triangulation at 0x1a581715d90>,
#         <bem.triangulation.Triangulation at 0x1a581715e50>,
#         <bem.triangulation.Triangulation at 0x1a581715f10>,
#         <bem.triangulation.Triangulation at 0x1a58170f040>,
#         <bem.triangulation.Triangulation at 0x1a58170f0d0>,
#         <bem.triangulation.Triangulation at 0x1a58170f190>,
#         <bem.triangulation.Triangulation at 0x1a58170f250>,
#         <bem.triangulation.Triangulation at 0x1a58170f310>,
#         <bem.triangulation.Triangulation at 0x1a58170f3d0>,
#         <bem.triangulation.Triangulation at 0x1a58170f490>,
#         <bem.triangulation.Triangulation at 0x1a58170f550>,
#         <bem.triangulation.Triangulation at 0x1a58170f610>,
#         <bem.triangulation.Triangulation at 0x1a58170f6d0>,
#         <bem.triangulation.Triangulation at 0x1a58170f790>,
#         <bem.triangulation.Triangulation at 0x1a58170f850>,
#         <bem.triangulation.Triangulation at 0x1a58170f910>,
#         <bem.triangulation.Triangulation at 0x1a58170f9d0>,
#         <bem.triangulation.Triangulation at 0x1a58170fa90>,
#         <bem.triangulation.Triangulation at 0x1a58170fb50>,
#         <bem.triangulation.Triangulation at 0x1a58170fc10>,
#         <bem.triangulation.Triangulation at 0x1a58170fcd0>,
#         <bem.triangulation.Triangulation at 0x1a58170fd90>,
#         <bem.triangulation.Triangulation at 0x1a58170fe50>,
#         <bem.triangulation.Triangulation at 0x1a58170ff10>,
#         <bem.triangulation.Triangulation at 0x1a581714040>,
#         <bem.triangulation.Triangulation at 0x1a5817140d0>,
#         <bem.triangulation.Triangulation at 0x1a581714190>,
#         <bem.triangulation.Triangulation at 0x1a581714250>,
#         <bem.triangulation.Triangulation at 0x1a581714310>,
#         <bem.triangulation.Triangulation at 0x1a5817143d0>,
#         <bem.triangulation.Triangulation at 0x1a581714490>,
#         <bem.triangulation.Triangulation at 0x1a581714550>,
#         <bem.triangulation.Triangulation at 0x1a581714610>,
#         <bem.triangulation.Triangulation at 0x1a5817146d0>,
#         <bem.triangulation.Triangulation at 0x1a581714790>,
#         <bem.triangulation.Triangulation at 0x1a581714850>,
#         <bem.triangulation.Triangulation at 0x1a581714910>,
#         <bem.triangulation.Triangulation at 0x1a5817149d0>,
#         <bem.triangulation.Triangulation at 0x1a581714a90>,
#         <bem.triangulation.Triangulation at 0x1a581714b50>,
#         <bem.triangulation.Triangulation at 0x1a581714c10>,
#         <bem.triangulation.Triangulation at 0x1a581714cd0>,
#         <bem.triangulation.Triangulation at 0x1a581714d90>,
#         <bem.triangulation.Triangulation at 0x1a581714e50>,
#         <bem.triangulation.Triangulation at 0x1a581714f10>,
#         <bem.triangulation.Triangulation at 0x1a58171e040>,
#         <bem.triangulation.Triangulation at 0x1a58171e0d0>,
#         <bem.triangulation.Triangulation at 0x1a58171e190>,
#         <bem.triangulation.Triangulation at 0x1a58171e250>,
#         <bem.triangulation.Triangulation at 0x1a58171e310>,
#         <bem.triangulation.Triangulation at 0x1a58171e3d0>,
#         <bem.triangulation.Triangulation at 0x1a58171e490>,
#         <bem.triangulation.Triangulation at 0x1a58171e550>,
#         <bem.triangulation.Triangulation at 0x1a58171e610>,
#         <bem.triangulation.Triangulation at 0x1a58171e6d0>,
#         <bem.triangulation.Triangulation at 0x1a58171e790>,
#         <bem.triangulation.Triangulation at 0x1a58171e850>,
#         <bem.triangulation.Triangulation at 0x1a58171e910>,
#         <bem.triangulation.Triangulation at 0x1a58171e9d0>,
#         <bem.triangulation.Triangulation at 0x1a58171ea90>,
#         <bem.triangulation.Triangulation at 0x1a58171eb50>,
#         <bem.triangulation.Triangulation at 0x1a58171ec10>,
#         <bem.triangulation.Triangulation at 0x1a58171ecd0>,
#         <bem.triangulation.Triangulation at 0x1a58171ed90>,
#         <bem.triangulation.Triangulation at 0x1a58171ee50>,
#         <bem.triangulation.Triangulation at 0x1a58171ef10>,
#         <bem.triangulation.Triangulation at 0x1a5816f8040>,
#         <bem.triangulation.Triangulation at 0x1a5816f80d0>,
#         <bem.triangulation.Triangulation at 0x1a5816f8190>,
#         <bem.triangulation.Triangulation at 0x1a5816f8250>,
#         <bem.triangulation.Triangulation at 0x1a5816f8310>,
#         <bem.triangulation.Triangulation at 0x1a5816f83d0>,
#         <bem.triangulation.Triangulation at 0x1a5816f8490>,
#         <bem.triangulation.Triangulation at 0x1a5816f8550>,
#         <bem.triangulation.Triangulation at 0x1a5816f8610>,
#         <bem.triangulation.Triangulation at 0x1a5816f86d0>,
#         <bem.triangulation.Triangulation at 0x1a5816f87f0>,
#         <bem.triangulation.Triangulation at 0x1a5816f8850>,
#         <bem.triangulation.Triangulation at 0x1a5816f8910>,
#         <bem.triangulation.Triangulation at 0x1a5816f89d0>,
#         <bem.triangulation.Triangulation at 0x1a5816f8a90>,
#         <bem.triangulation.Triangulation at 0x1a5816f8b50>,
#         <bem.triangulation.Triangulation at 0x1a5816f8c10>,
#         <bem.triangulation.Triangulation at 0x1a5816f8cd0>,
#         <bem.triangulation.Triangulation at 0x1a5816f8d90>,
#         <bem.triangulation.Triangulation at 0x1a5816f8e50>,
#         <bem.triangulation.Triangulation at 0x1a5816f8f10>,
#         <bem.triangulation.Triangulation at 0x1a58161d040>,
#         <bem.triangulation.Triangulation at 0x1a58161d0d0>,
#         <bem.triangulation.Triangulation at 0x1a58161d190>,
#         <bem.triangulation.Triangulation at 0x1a58161d250>,
#         <bem.triangulation.Triangulation at 0x1a58161d310>,
#         <bem.triangulation.Triangulation at 0x1a58161d3d0>,
#         <bem.triangulation.Triangulation at 0x1a58161d490>,
#         <bem.triangulation.Triangulation at 0x1a58161d550>,
#         <bem.triangulation.Triangulation at 0x1a58161d610>,
#         <bem.triangulation.Triangulation at 0x1a58161d6d0>,
#         <bem.triangulation.Triangulation at 0x1a58161d790>,
#         <bem.triangulation.Triangulation at 0x1a58161d850>,
#         <bem.triangulation.Triangulation at 0x1a58161d910>,
#         <bem.triangulation.Triangulation at 0x1a58161d9d0>,
#         <bem.triangulation.Triangulation at 0x1a58161da90>,
#         <bem.triangulation.Triangulation at 0x1a58161db50>,
#         <bem.triangulation.Triangulation at 0x1a58161dc10>,
#         <bem.triangulation.Triangulation at 0x1a58161dcd0>,
#         <bem.triangulation.Triangulation at 0x1a58161dd90>,
#         <bem.triangulation.Triangulation at 0x1a58161de50>,
#         <bem.triangulation.Triangulation at 0x1a58161df10>,
#         <bem.triangulation.Triangulation at 0x1a5815e2040>,
#         <bem.triangulation.Triangulation at 0x1a5815e20d0>,
#         <bem.triangulation.Triangulation at 0x1a5815e2190>,
#         <bem.triangulation.Triangulation at 0x1a5815e2250>,
#         <bem.triangulation.Triangulation at 0x1a5815e2310>,
#         <bem.triangulation.Triangulation at 0x1a5815e23d0>,
#         <bem.triangulation.Triangulation at 0x1a5815e2490>,
#         <bem.triangulation.Triangulation at 0x1a5815e2550>,
#         <bem.triangulation.Triangulation at 0x1a5815e2610>,
#         <bem.triangulation.Triangulation at 0x1a5815e26d0>,
#         <bem.triangulation.Triangulation at 0x1a5815e2790>,
#         <bem.triangulation.Triangulation at 0x1a5815e2850>,
#         <bem.triangulation.Triangulation at 0x1a5815e2910>,
#         <bem.triangulation.Triangulation at 0x1a5815e29d0>]),
#       ('DC1',
#        [<bem.triangulation.Triangulation at 0x1a5815e2a90>,
#         <bem.triangulation.Triangulation at 0x1a5815e2b50>,
#         <bem.triangulation.Triangulation at 0x1a5815e2c10>,
#         <bem.triangulation.Triangulation at 0x1a5815e2cd0>,
#         <bem.triangulation.Triangulation at 0x1a5815e2d90>,
#         <bem.triangulation.Triangulation at 0x1a5815e2e50>,
#         <bem.triangulation.Triangulation at 0x1a5815e2f10>,
#         <bem.triangulation.Triangulation at 0x1a5815e7040>,
#         <bem.triangulation.Triangulation at 0x1a5815e70d0>,
#         <bem.triangulation.Triangulation at 0x1a5815e7190>,
#         <bem.triangulation.Triangulation at 0x1a5815e7250>,
#         <bem.triangulation.Triangulation at 0x1a5815e7310>,
#         <bem.triangulation.Triangulation at 0x1a5815e73d0>,
#         <bem.triangulation.Triangulation at 0x1a5815e7490>,
#         <bem.triangulation.Triangulation at 0x1a5815e7550>,
#         <bem.triangulation.Triangulation at 0x1a5815e7610>]),
#       ('DC3',
#        [<bem.triangulation.Triangulation at 0x1a5815e76d0>,
#         <bem.triangulation.Triangulation at 0x1a5815e7790>,
#         <bem.triangulation.Triangulation at 0x1a5815e7850>,
#         <bem.triangulation.Triangulation at 0x1a5815e7910>,
#         <bem.triangulation.Triangulation at 0x1a5815e79d0>,
#         <bem.triangulation.Triangulation at 0x1a5815e7a90>,
#         <bem.triangulation.Triangulation at 0x1a5815e7b50>,
#         <bem.triangulation.Triangulation at 0x1a5815e7c10>,
#         <bem.triangulation.Triangulation at 0x1a5815e7cd0>,
#         <bem.triangulation.Triangulation at 0x1a5815e7d90>,
#         <bem.triangulation.Triangulation at 0x1a5815e7e50>,
#         <bem.triangulation.Triangulation at 0x1a5815e7f10>,
#         <bem.triangulation.Triangulation at 0x1a5815ec040>,
#         <bem.triangulation.Triangulation at 0x1a5815ec0d0>]),
#       ('DC4',
#        [<bem.triangulation.Triangulation at 0x1a5815ec190>,
#         <bem.triangulation.Triangulation at 0x1a5815ec250>,
#         <bem.triangulation.Triangulation at 0x1a5815ec310>,
#         <bem.triangulation.Triangulation at 0x1a5815ec3d0>,
#         <bem.triangulation.Triangulation at 0x1a5815ec490>,
#         <bem.triangulation.Triangulation at 0x1a5815ec550>,
#         <bem.triangulation.Triangulation at 0x1a5815ec610>,
#         <bem.triangulation.Triangulation at 0x1a5815ec6d0>,
#         <bem.triangulation.Triangulation at 0x1a5815ec790>,
#         <bem.triangulation.Triangulation at 0x1a5815ec850>,
#         <bem.triangulation.Triangulation at 0x1a5815ec910>,
#         <bem.triangulation.Triangulation at 0x1a5815ec9d0>,
#         <bem.triangulation.Triangulation at 0x1a5815eca90>,
#         <bem.triangulation.Triangulation at 0x1a5815ecb50>,
#         <bem.triangulation.Triangulation at 0x1a5815ecc10>]),
#       ('DC5',
#        [<bem.triangulation.Triangulation at 0x1a5815eccd0>,
#         <bem.triangulation.Triangulation at 0x1a5815ecd90>,
#         <bem.triangulation.Triangulation at 0x1a5815ece50>,
#         <bem.triangulation.Triangulation at 0x1a5815ecf10>,
#         <bem.triangulation.Triangulation at 0x1a5815f1040>,
#         <bem.triangulation.Triangulation at 0x1a5815f10d0>,
#         <bem.triangulation.Triangulation at 0x1a5815f1190>,
#         <bem.triangulation.Triangulation at 0x1a5815f1250>,
#         <bem.triangulation.Triangulation at 0x1a5815f1310>,
#         <bem.triangulation.Triangulation at 0x1a5815f13d0>,
#         <bem.triangulation.Triangulation at 0x1a5815f1490>,
#         <bem.triangulation.Triangulation at 0x1a5815f1550>,
#         <bem.triangulation.Triangulation at 0x1a5815f1610>,
#         <bem.triangulation.Triangulation at 0x1a5815f16d0>]),
#       ('DC6',
#        [<bem.triangulation.Triangulation at 0x1a5815f1790>,
#         <bem.triangulation.Triangulation at 0x1a5815f1850>,
#         <bem.triangulation.Triangulation at 0x1a5815f1910>,
#         <bem.triangulation.Triangulation at 0x1a5815f19d0>,
#         <bem.triangulation.Triangulation at 0x1a5815f1a90>,
#         <bem.triangulation.Triangulation at 0x1a5815f1b50>,
#         <bem.triangulation.Triangulation at 0x1a5815f1c10>,
#         <bem.triangulation.Triangulation at 0x1a5815f1cd0>,
#         <bem.triangulation.Triangulation at 0x1a5815f1d90>,
#         <bem.triangulation.Triangulation at 0x1a5815f1e50>,
#         <bem.triangulation.Triangulation at 0x1a5815f1f10>,
#         <bem.triangulation.Triangulation at 0x1a5815f6040>,
#         <bem.triangulation.Triangulation at 0x1a5815f60d0>,
#         <bem.triangulation.Triangulation at 0x1a5815f6190>]),
#       ('DC8',
#        [<bem.triangulation.Triangulation at 0x1a5815f6250>,
#         <bem.triangulation.Triangulation at 0x1a5815f6310>,
#         <bem.triangulation.Triangulation at 0x1a5815f63d0>,
#         <bem.triangulation.Triangulation at 0x1a5815f6490>,
#         <bem.triangulation.Triangulation at 0x1a5815f6550>,
#         <bem.triangulation.Triangulation at 0x1a5815f6610>,
#         <bem.triangulation.Triangulation at 0x1a5815f66d0>,
#         <bem.triangulation.Triangulation at 0x1a5815f6790>,
#         <bem.triangulation.Triangulation at 0x1a5815f6850>,
#         <bem.triangulation.Triangulation at 0x1a5815f6910>,
#         <bem.triangulation.Triangulation at 0x1a5815f69d0>,
#         <bem.triangulation.Triangulation at 0x1a5815f6a90>,
#         <bem.triangulation.Triangulation at 0x1a5815f6b50>,
#         <bem.triangulation.Triangulation at 0x1a5815f6c10>]),
#       ('DC9',
#        [<bem.triangulation.Triangulation at 0x1a5815f6cd0>,
#         <bem.triangulation.Triangulation at 0x1a5815f6d90>,
#         <bem.triangulation.Triangulation at 0x1a5815f6e50>,
#         <bem.triangulation.Triangulation at 0x1a5815f6f10>,
#         <bem.triangulation.Triangulation at 0x1a5815fb040>,
#         <bem.triangulation.Triangulation at 0x1a5815fb0d0>,
#         <bem.triangulation.Triangulation at 0x1a5815fb1f0>,
#         <bem.triangulation.Triangulation at 0x1a5815fb250>,
#         <bem.triangulation.Triangulation at 0x1a5815fb310>,
#         <bem.triangulation.Triangulation at 0x1a5815fb3d0>,
#         <bem.triangulation.Triangulation at 0x1a5815fb490>,
#         <bem.triangulation.Triangulation at 0x1a5815fb550>,
#         <bem.triangulation.Triangulation at 0x1a5815fb610>,
#         <bem.triangulation.Triangulation at 0x1a5815fb6d0>]),
#       ('DC10',
#        [<bem.triangulation.Triangulation at 0x1a5815fb790>,
#         <bem.triangulation.Triangulation at 0x1a5815fb850>,
#         <bem.triangulation.Triangulation at 0x1a5815fb910>,
#         <bem.triangulation.Triangulation at 0x1a5815fb9d0>,
#         <bem.triangulation.Triangulation at 0x1a5815fba90>,
#         <bem.triangulation.Triangulation at 0x1a5815fbb50>,
#         <bem.triangulation.Triangulation at 0x1a5815fbc10>,
#         <bem.triangulation.Triangulation at 0x1a5815fbcd0>,
#         <bem.triangulation.Triangulation at 0x1a5815fbd90>,
#         <bem.triangulation.Triangulation at 0x1a5815fbe50>,
#         <bem.triangulation.Triangulation at 0x1a5815fbf10>])])

# %%
# save base mesh to a pickle file
with open(fout_name,'wb') as f:
    data = (mesh_unit,
            xl,
            yl,
            zl,
            mesh,
            list(od.values()))
    pickle.dump(data,f)

# %% [markdown]
# ## view mesh
# Uses Pyvista package to generate interactive 3-d plot of the mesh

# %%
# Plot triangle mezshes of the final mesh
mesh.plot()

# %% [markdown]
# Show number of points included in the mesh

# %%
print(len(mesh.points))
# Out:
# 8692
