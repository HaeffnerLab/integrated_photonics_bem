# %% [markdown]
# # `Documention & Tutorial`
# This BEM package is used for for numerical simulation of the electric field of ion traps in python. Some external packages are wrapped into it:
#
# * fast triangulation (http://www.cs.cmu.edu/~quake/triangle.research.html)
# * fastlap boundary element method (Nabors K S. Efficient three-dimensional capacitance calculation[D]. Massachusetts Institute of Technology, 1993.)
#
# This document, also as a tutorial, explains how to use these packages to compute the electric field and compute its multipole expansion coefficient starting from scratch with a fusion 360 trap model(take `./f3d/htrap_overhang_9x5mm.f3d` for example). Our document consists of three .ipynb files:
#
# * `I_Mesh_Processing.ipynb`
# * `II_Field_Simulation.ipynb`
# * `III_Multipole_Expansion.ipynb`
#
# We split the document into three files for two reasons:
# 1. The most time consuming part `II_Field_Simulation.ipynb` could be taken out alone and run on a high peformance computer.
# 2. The intermediate result between files can be checked- 'intermediate files' refer to the inital mesh grid (that corresponds to the charge distribution), the simulation values and the simulation coordinates, all of which are saved in the inter_results folder. So if the voltage solution files for the trap don't make sense, it is possible to go back through saved data to see where things have gone wrong.
# Here are the three jupyter notebooks and what:
# 1. I_Mesh_Processing- this notebook generates a mesh of the trap, saved in inter_results as a .pkl file
#
#
# Going through three files in order and running their python code will help you understand our workflow. Generally our workflow divides into three steps, corresponding to the above three .ipynb files. First, in I_Mesh_Processing, we identify different electrodes of the trap model by different colors. Also, we refine the trap model meshes to prepare for the second step. The result is stored in `mesh_result.pkl`.
#
# Secondly, in II_Field_Simulation, we simulate the electric potential with fastlap boundary element method(FMM), the accuracy of this step depends on the mesh size in the first step. The result is stored in `field_result.pkl`.
#
# Thirdly, in III_Multipole_Expansion, we analyze the electric field and electric potential. This notebook generates the multipole coefficients of the fields and potentials for each electrode and uses that information to generate a solution file with the function call `write_csv`. If your solution don't make sense, a good place to start is to insure that the mesh you are using is fine enough (generate several field results for different meshes)- if the potentials and fields are converging to specific values, this suggests there is something wrong with the multipole expansion. If you start with multipole expansion, you do not know if it is a problem with the expansion or with the field.
#
# Before running codes, you must set up the environment according to instructions in `README`
#
# notes
# * Our workflow, as indicated by this document, abandons mayavi(with its embeded package tvtk). But we reserve mayavi in our Bem source code, if you want to use mayavi related functions, you must set up environment with files in`./backup/setup_with_mayavi`, just replace corresponding files in the root folder with them and set up.
#     * why we abandon mayavi: because its python interface(with its dependence vtk and PyQt5) requires complex package dependencies and version controls especially for new python versions. This makes it difficult to maintain this project.
#     * why we still keep mayavi in the source code? Because it is rooted in our source code deeply. We can just avoid invoking related functions instead of deleting them, because they may make sense in the future.

# %% [markdown]
# # `I. Mesh Processing`
# This .pynb file reads a colored model file `./inter_results/htrap.stl`, and assigns a name for each color(thus for each electrode). The result is stored in `./inter_results/mesh_result.pkl`.
#
# In this file we name different electrodes and refine the meshes. The size of mesh determines the accuracy in next step. You should set the mesh finer and finer until the result converges. Also, you can set the mesh finer and test the convergence.
#
# ## (1) color your electrodes (in fusion 360) and export stl
# First of all, you have a trap model in fusion 360 project, for example, `./f3d/htrap_overhang_9x5mm.f3d`. Here we use different color to identify different electrodes(STL file stores color for each mesh). In fusion 360, you can assign different appearance for different electrodes. We recommend to use ../../bemCol_lib/bemCol.adsklib for different electrodes. Same color for two electrodes means they are treated as the same electrode. Then we get `./f3d/htrap_overhang_9x5mm_my_colored.f3d`
#
# Then export to an stl file in fusion360 file>export tab and move the file in `./inter_results`. We export our stl in mm, so we set the mesh unit to mm.

# %% [markdown]
# Furthurmore, it's our convention to use unit mm in our traps. e.g. [Electric field] = V/mm , [harmonic confining potential] = V/mm^2.so we set

# %%
# this is the unit for our Mesh structure
# in the following code, this is the default unit for python variables
#units 
mesh_unit = 1e-3

# %% [markdown]
# Additional notes (from Wenhao):
# * Why use standard color? We define a set of standard color lib `../../../bemCol_lib/bemCol.adsklib` for two reasons: 1. when exporting to .stl file, fusion 360 will compress 0-256 color(RGBA32) into 0-32 color(RGBA16), which means that some similar colors in fusion 360 will become same color after export to .stl file. Our standard color lib avoid this problem. 2.If you use .stl file exported from fusion 360 DIRECTLY, naming the electrodes would be very convinient. If you use other apps such as Inventor or Meshlab to generate .stl file, you can ignore the second reason because color encoding are quite different in different apps

# %% [markdown]
# ## (2) assign a name for each color

# %%
import pickle
import numpy as np
import matplotlib as mpl
import sys
from utils.helper_functions import *
from bem.bemColors_lib.bemColors import bemColors
from bem import Electrodes, Sphere, Mesh, Grid, Configuration, Result, Box
# load stl geometry file
from bem.formats import stl
# stl_path = "roughness/"+"basic_excitation"+".stl"  


#radius is the radius of the sphere from the ions location to generate a finer
#electrode mesh
radius= 500e-3
#'area' is the area of the triangles inside the sphere
area = 1e-4
# file = 'mit_charge'
# file = 'htrap_overhang_taper_2'
# file_out = 'htrap_overhang_taper_el3'
# stl_path = 'inter_results/taper_overhang/'+file+'.stl'
# fout_name = 'inter_results/taper_overhang/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


file_out = 'htrap_el3.5'
stl_path = 'inter_results/htrap/htrap.stl'
fout_name = 'inter_results/htrap/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


module_path = os.path.abspath('')


s_nta = stl.read_stl(open(stl_path, "rb"))

# %% [markdown]
# Firstly, we print all the colors appear in the stl file. If a color is of standard colors in `bemCol.adsklib` or named manually by function `bemCol.set_my_color()`, then the color will appear in a straightforward name, such as `bem0`,`bem1` ...... . Otherwise, the color will simply be named as `'_unkCol0'` , `'_unkCol1'`, ...
#
# notes
# * try to comment out the line of `ele_col.set_my_color()` in the following block, name `'_unkCol0'` will appear.

# %%
ele_col = bemColors(np.array(list(set(s_nta[2]))),('fusion360','export_stl'))
ele_col.set_my_color(value = (178,178,178),cl_format = ('fusion360','export_stl','RGBA64'),name = 'self_defined')
ele_col.print_stl_colors()
# Out:
# COLORS in the stl:
# ['bem6']
# ['bem13']
# ['bem19']
# ['bem11']
# ['bem17']
# ['bem15']
# ['bem30']
# ['bem1']
# ['bem12']
# ['bem5']
# ['bem25']
# ['bem18']
# ['bem16']
# ['bem3']
# ['bem7']
# ['bem9']
# ['bem2']
# ['bem4']
# ['bem20']
# ['bem10']
# ['bem14']
# ['bem8']
# ['bem21']
# ['_unkColor0']
# TOTAL COLORS:  24

# %% [markdown]
# Next, you need to assign a name for each color that appeared above. With standard colors defined in `bemCol.adsklib`, the correspondence between color and electrode is clear, which make it easy for this step. You can also comment out some `ele_col.set_color_name()`, run all the codes again and observe the missing part in the printed figure, which corresponds to the electrode you comment out. The second method also serves as a double check. Besides, parameter in `stl.stl_to_mesh()` can be set as `quiet = False` to check whether the program reads planes correctly.

# %%
# assign a name for each color
# taper htrap 2022
# assign a name for each color

# In od[key] = value, key is the color from the Fusion360 color library we made
# value assigns a specific name to that color in this program. 
# In future version, we may want to consider getting rid of this step for simplification
# then you just assign the color in fusion 360 and be done with it. The only concern there is you
from collections import OrderedDict
od = OrderedDict()
od['bem1']='DC1'
od['bem2']='DC2'
od['bem3']='DC3'
od['bem4']='DC4'
od['bem5']='DC5'
od['bem6']='DC6'
od['bem7']='DC7'
od['bem8']='DC8'
od['bem9']='DC9'
od['bem10']='DC10'
od['bem11']='DC11'
od['bem12']='DC12'
od['bem13']='DC13'
od['bem14']='DC14'
od['bem15']='DC15'
od['bem16']='DC16'
od['bem17']='DC17'
od['bem18']='DC18'
od['bem19']='DC19'
od['bem20']='DC20'
od['bem21'] = 'DC21'
od['bem25'] = 'RF'
od['bem30'] = 'gnd'
for key in list(od.keys()):
    ele_col.color_electrode(color=key,name=od[key])

# print colors still with no name. These meshes will be neglected in the code below. 
ele_col.drop_colors()

# read stl into mesh with electrode names
# unnamed meshes will not be imported at all

mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=1,
    rename=ele_col.electrode_colors, quiet=True))
# Out:
# dropping color ['_unkColor0']
# TOTAL COLORS DROPPED:  1
# dropping 20083

# %% [markdown]
# ## (3) remesh
#
# In this step, we generate triangle mesh with constraints. The meshes are 2-dimensional triangles on the surface of electrodes. The region enclosed by constraint shape can have finer mesh. Triangulation is done by `triangle` C library. Folowing variables are all in unit `mesh_unit` now.
#
# Our remesh strategy consists of two steps of triangulation:
# 1. global triangulation without constraint. This step eliminate some long and sharp triangles by combining and dividing, and obtains a coarse grain triangulated model.
# 2. local triangulation with constraint. This step refines each triangles in step 1, the triangle density is defined by `mesh.areas_from_constraints
#
# parameters in the below code block should be tuned specificly for different trap geometries.`

# %%
# here we define a spherical constriant zone:
# xl = 270*1e-3
# yl = -3.5*1e-3
# zl = 72.5*1e-3

#here is the location that will be the reference point for further meshing
#usually, this is the ion's location, specified in appropriate units (usually millimeters)
zl = -210*1e-3
yl = 75*1e-3
xl = 3.75*1e-3


mesh.triangulate(opts="",new = False)

# for z in np.arange(100e-3,700e-3,-210e-3):
print('first triangulation:')
# for z in np.arange(-200e-3, 200e-3, 50e-3):
rad = radius*2
inside=area*20
outside=1
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="a2Q",new = False)

# what happened to this feature (Box)? is this on bem savio?
# mesh.areas_from_constraints(Box(start=-0.5, end= 0.5,inside=inside, outside=outside))



# areas_from_constraints specifies sphere with finer mesh inside it.
#  "inside", "outside" set different mesh densities. 
print('second triangulation:')
rad =radius
inside=area
outside=1e4
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="q5Q",new = False)

# save base mesh to a pickle file
# with open(fout_name,'wb') as f:
#     data = (mesh_unit,
#             xl,
#             yl,
#             zl,
#             mesh,
#             list(od.values()))
#     pickle.dump(data,f)
# Out:
# start triangulate RF
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate RF
# start triangulate DC21
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC21
# start triangulate DC2
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC2
# start triangulate DC7
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC7
# start triangulate DC11
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC11
# start triangulate DC12
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC12
# start triangulate DC13
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC13
# start triangulate DC14
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC14
# start triangulate DC15
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC15
# start triangulate DC16
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC16
# start triangulate DC17
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC17
# start triangulate DC18
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC18
# start triangulate DC19
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC19
# start triangulate DC20
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC20
# start triangulate gnd
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate gnd
# start triangulate DC1
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC1
# start triangulate DC3
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC3
# start triangulate DC4
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC4
# start triangulate DC5
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC5
# start triangulate DC6
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC6
# start triangulate DC8
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC8
# start triangulate DC9
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC9
# start triangulate DC10
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC10
# first triangulation:
# start triangulate RF
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate RF
# start triangulate DC21
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC10
# second triangulation:
# start triangulate RF
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate RF
# start triangulate DC21
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC10
# Mesh([('RF',
#        [<bem.triangulation.Triangulation at 0x21a0a059f10>,
#         <bem.triangulation.Triangulation at 0x21a3f726160>,
#         <bem.triangulation.Triangulation at 0x21a3f7261c0>,
#         <bem.triangulation.Triangulation at 0x21a3f726c40>,
#         <bem.triangulation.Triangulation at 0x21a3f726d00>,
#         <bem.triangulation.Triangulation at 0x21a3f726eb0>,
#         <bem.triangulation.Triangulation at 0x21a3f7262b0>,
#         <bem.triangulation.Triangulation at 0x21a3d6009a0>,
#         <bem.triangulation.Triangulation at 0x21a3d600be0>,
#         <bem.triangulation.Triangulation at 0x21a3d600d60>,
#         <bem.triangulation.Triangulation at 0x21a3d600a60>,
#         <bem.triangulation.Triangulation at 0x21a3d600040>,
#         <bem.triangulation.Triangulation at 0x21a3d600460>,
#         <bem.triangulation.Triangulation at 0x21a3d600850>,
#         <bem.triangulation.Triangulation at 0x21a3d600430>,
#         <bem.triangulation.Triangulation at 0x21a3d600f10>,
#         <bem.triangulation.Triangulation at 0x21a3d600b80>]),
#       ('DC21',
#        [<bem.triangulation.Triangulation at 0x21a3d600c40>,
#         <bem.triangulation.Triangulation at 0x21a3d600b20>,
#         <bem.triangulation.Triangulation at 0x21a3d600970>,
#         <bem.triangulation.Triangulation at 0x21a3d6001c0>,
#         <bem.triangulation.Triangulation at 0x21a3d526850>,
#         <bem.triangulation.Triangulation at 0x21a3d526be0>,
#         <bem.triangulation.Triangulation at 0x21a3d526cd0>]),
#       ('DC2',
#        [<bem.triangulation.Triangulation at 0x21a3d526460>,
#         <bem.triangulation.Triangulation at 0x21a3d526b20>,
#         <bem.triangulation.Triangulation at 0x21a3d5265e0>,
#         <bem.triangulation.Triangulation at 0x21a3d526d30>,
#         <bem.triangulation.Triangulation at 0x21a3d526b50>,
#         <bem.triangulation.Triangulation at 0x21a3d526ee0>,
#         <bem.triangulation.Triangulation at 0x21a3d526d00>,
#         <bem.triangulation.Triangulation at 0x21a3d5262e0>,
#         <bem.triangulation.Triangulation at 0x21a3d526a30>,
#         <bem.triangulation.Triangulation at 0x21a3d5261c0>,
#         <bem.triangulation.Triangulation at 0x21a3d5269a0>,
#         <bem.triangulation.Triangulation at 0x21a3d526700>,
#         <bem.triangulation.Triangulation at 0x21a3f74e5e0>]),
#       ('DC7',
#        [<bem.triangulation.Triangulation at 0x21a3f74e7f0>,
#         <bem.triangulation.Triangulation at 0x21a3f74e460>,
#         <bem.triangulation.Triangulation at 0x21a3f74ea60>,
#         <bem.triangulation.Triangulation at 0x21a3f74ef40>,
#         <bem.triangulation.Triangulation at 0x21a3f74eb20>,
#         <bem.triangulation.Triangulation at 0x21a3f74ed90>,
#         <bem.triangulation.Triangulation at 0x21a3f74e0d0>,
#         <bem.triangulation.Triangulation at 0x21a3f74e040>,
#         <bem.triangulation.Triangulation at 0x21a3f74e730>,
#         <bem.triangulation.Triangulation at 0x21a3f74e310>,
#         <bem.triangulation.Triangulation at 0x21a3f74e520>,
#         <bem.triangulation.Triangulation at 0x21a3f74e3d0>,
#         <bem.triangulation.Triangulation at 0x21a3f74e8b0>]),
#       ('DC11',
#        [<bem.triangulation.Triangulation at 0x21a3f74eaf0>,
#         <bem.triangulation.Triangulation at 0x21a3f74ecd0>,
#         <bem.triangulation.Triangulation at 0x21a3f74ef70>,
#         <bem.triangulation.Triangulation at 0x21a3f74e820>,
#         <bem.triangulation.Triangulation at 0x21a3f74e9a0>,
#         <bem.triangulation.Triangulation at 0x21a3f74ed60>,
#         <bem.triangulation.Triangulation at 0x21a5bc54880>,
#         <bem.triangulation.Triangulation at 0x21a5bc54b50>,
#         <bem.triangulation.Triangulation at 0x21a5bc54cd0>,
#         <bem.triangulation.Triangulation at 0x21a5bc54b20>,
#         <bem.triangulation.Triangulation at 0x21a3d4eaf70>,
#         <bem.triangulation.Triangulation at 0x21a3d4eae20>,
#         <bem.triangulation.Triangulation at 0x21a3d4eabb0>,
#         <bem.triangulation.Triangulation at 0x21a3d4fe8e0>]),
#       ('DC12',
#        [<bem.triangulation.Triangulation at 0x21a3d4fe400>,
#         <bem.triangulation.Triangulation at 0x21a3d4fe700>,
#         <bem.triangulation.Triangulation at 0x21a3d4fefa0>,
#         <bem.triangulation.Triangulation at 0x21a3d4fe250>,
#         <bem.triangulation.Triangulation at 0x21a3d4fe820>,
#         <bem.triangulation.Triangulation at 0x21a3d4fe7c0>,
#         <bem.triangulation.Triangulation at 0x21a3d4fe340>,
#         <bem.triangulation.Triangulation at 0x21a3d4fe6d0>,
#         <bem.triangulation.Triangulation at 0x21a3d4fe4c0>,
#         <bem.triangulation.Triangulation at 0x21a3d4fe520>,
#         <bem.triangulation.Triangulation at 0x21a3d4fe1c0>,
#         <bem.triangulation.Triangulation at 0x21a3d4fe160>,
#         <bem.triangulation.Triangulation at 0x21a3d4fe760>,
#         <bem.triangulation.Triangulation at 0x21a3f9a5250>]),
#       ('DC13',
#        [<bem.triangulation.Triangulation at 0x21a3f9a5340>,
#         <bem.triangulation.Triangulation at 0x21a3f9a5af0>,
#         <bem.triangulation.Triangulation at 0x21a3f9a5160>,
#         <bem.triangulation.Triangulation at 0x21a3f9a51c0>,
#         <bem.triangulation.Triangulation at 0x21a3f9a53a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9a5310>,
#         <bem.triangulation.Triangulation at 0x21a3f9a5d00>,
#         <bem.triangulation.Triangulation at 0x21a3f9a5520>,
#         <bem.triangulation.Triangulation at 0x21a3f9a57f0>,
#         <bem.triangulation.Triangulation at 0x21a3f9a5ac0>,
#         <bem.triangulation.Triangulation at 0x21a3f9a5e20>,
#         <bem.triangulation.Triangulation at 0x21a3f9a54f0>,
#         <bem.triangulation.Triangulation at 0x21a3f9a5610>]),
#       ('DC14',
#        [<bem.triangulation.Triangulation at 0x21a3f9a56d0>,
#         <bem.triangulation.Triangulation at 0x21a3f9a59d0>,
#         <bem.triangulation.Triangulation at 0x21a3f9a5a60>,
#         <bem.triangulation.Triangulation at 0x21a3f9a5c40>,
#         <bem.triangulation.Triangulation at 0x21a3f9a5df0>,
#         <bem.triangulation.Triangulation at 0x21a3f9aaac0>,
#         <bem.triangulation.Triangulation at 0x21a3f9aac40>,
#         <bem.triangulation.Triangulation at 0x21a3f9aaf40>,
#         <bem.triangulation.Triangulation at 0x21a3f9aa490>,
#         <bem.triangulation.Triangulation at 0x21a3f9aaee0>,
#         <bem.triangulation.Triangulation at 0x21a3f9aaa30>,
#         <bem.triangulation.Triangulation at 0x21a3f9aa070>,
#         <bem.triangulation.Triangulation at 0x21a3f9aa100>]),
#       ('DC15',
#        [<bem.triangulation.Triangulation at 0x21a3f9aa1c0>,
#         <bem.triangulation.Triangulation at 0x21a3f9aa520>,
#         <bem.triangulation.Triangulation at 0x21a3f9aa730>,
#         <bem.triangulation.Triangulation at 0x21a3f9aaa00>,
#         <bem.triangulation.Triangulation at 0x21a3f9aa370>,
#         <bem.triangulation.Triangulation at 0x21a3f9aa550>,
#         <bem.triangulation.Triangulation at 0x21a3f9aa700>,
#         <bem.triangulation.Triangulation at 0x21a3f9aa9d0>,
#         <bem.triangulation.Triangulation at 0x21a3f9aac10>,
#         <bem.triangulation.Triangulation at 0x21a3f9aad60>,
#         <bem.triangulation.Triangulation at 0x21a3f9aae80>,
#         <bem.triangulation.Triangulation at 0x21a3f9aafa0>,
#         <bem.triangulation.Triangulation at 0x21a3f980250>]),
#       ('DC16',
#        [<bem.triangulation.Triangulation at 0x21a3f980880>,
#         <bem.triangulation.Triangulation at 0x21a3f980fd0>,
#         <bem.triangulation.Triangulation at 0x21a3f980610>,
#         <bem.triangulation.Triangulation at 0x21a3f980820>,
#         <bem.triangulation.Triangulation at 0x21a3f980ac0>,
#         <bem.triangulation.Triangulation at 0x21a3f980dc0>,
#         <bem.triangulation.Triangulation at 0x21a3f980970>,
#         <bem.triangulation.Triangulation at 0x21a3f980160>,
#         <bem.triangulation.Triangulation at 0x21a3f980220>,
#         <bem.triangulation.Triangulation at 0x21a3f980550>,
#         <bem.triangulation.Triangulation at 0x21a3f9802b0>,
#         <bem.triangulation.Triangulation at 0x21a3f980430>,
#         <bem.triangulation.Triangulation at 0x21a3f9806a0>]),
#       ('DC17',
#        [<bem.triangulation.Triangulation at 0x21a3f980910>,
#         <bem.triangulation.Triangulation at 0x21a3f980be0>,
#         <bem.triangulation.Triangulation at 0x21a3f980cd0>,
#         <bem.triangulation.Triangulation at 0x21a3f980ee0>,
#         <bem.triangulation.Triangulation at 0x21a3f980280>,
#         <bem.triangulation.Triangulation at 0x21a3f980700>,
#         <bem.triangulation.Triangulation at 0x21a3f9804f0>,
#         <bem.triangulation.Triangulation at 0x21a3f99e220>,
#         <bem.triangulation.Triangulation at 0x21a3f99e100>,
#         <bem.triangulation.Triangulation at 0x21a3f99e2e0>,
#         <bem.triangulation.Triangulation at 0x21a3f99e0a0>,
#         <bem.triangulation.Triangulation at 0x21a3f99e400>,
#         <bem.triangulation.Triangulation at 0x21a3f99e6a0>]),
#       ('DC18',
#        [<bem.triangulation.Triangulation at 0x21a3f99eb20>,
# ...
#         <bem.triangulation.Triangulation at 0x21a3f9c0820>,
#         <bem.triangulation.Triangulation at 0x21a3f9c08e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c09a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c0a60>,
#         <bem.triangulation.Triangulation at 0x21a3f9c0b20>,
#         <bem.triangulation.Triangulation at 0x21a3f9c0be0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c0ca0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c0d60>,
#         <bem.triangulation.Triangulation at 0x21a3f9c0e20>,
#         <bem.triangulation.Triangulation at 0x21a3f9c0ee0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c0fa0>,
#         <bem.triangulation.Triangulation at 0x21a3d5c70a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7160>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7220>,
#         <bem.triangulation.Triangulation at 0x21a3d5c72e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5c73a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7460>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7520>,
#         <bem.triangulation.Triangulation at 0x21a3d5c75e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5c76a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7760>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7820>,
#         <bem.triangulation.Triangulation at 0x21a3d5c78e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5c79a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7a60>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7b20>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7be0>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7ca0>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7d60>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7e20>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7ee0>,
#         <bem.triangulation.Triangulation at 0x21a3d5c7fa0>,
#         <bem.triangulation.Triangulation at 0x21a3d5af0a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5af160>,
#         <bem.triangulation.Triangulation at 0x21a3d5af220>,
#         <bem.triangulation.Triangulation at 0x21a3d5af2e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5af3a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5af460>,
#         <bem.triangulation.Triangulation at 0x21a3d5af520>,
#         <bem.triangulation.Triangulation at 0x21a3d5af5e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5af6a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5af760>,
#         <bem.triangulation.Triangulation at 0x21a3d5af820>,
#         <bem.triangulation.Triangulation at 0x21a3d5af8e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5af9a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5afa60>,
#         <bem.triangulation.Triangulation at 0x21a3d5afb20>,
#         <bem.triangulation.Triangulation at 0x21a3d5afbe0>,
#         <bem.triangulation.Triangulation at 0x21a3d5afca0>,
#         <bem.triangulation.Triangulation at 0x21a3d5afd60>,
#         <bem.triangulation.Triangulation at 0x21a3d5afe20>,
#         <bem.triangulation.Triangulation at 0x21a3d5afee0>,
#         <bem.triangulation.Triangulation at 0x21a3d5affa0>,
#         <bem.triangulation.Triangulation at 0x21a3d5b20a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2160>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2220>,
#         <bem.triangulation.Triangulation at 0x21a3d5b22e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5b23a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2460>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2520>,
#         <bem.triangulation.Triangulation at 0x21a3d5b25e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5b26a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2760>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2820>,
#         <bem.triangulation.Triangulation at 0x21a3d5b28e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5b29a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2a60>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2b20>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2be0>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2ca0>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2d60>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2e20>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2ee0>,
#         <bem.triangulation.Triangulation at 0x21a3d5b2fa0>,
#         <bem.triangulation.Triangulation at 0x21a3d5900a0>,
#         <bem.triangulation.Triangulation at 0x21a3d590160>,
#         <bem.triangulation.Triangulation at 0x21a3d590220>,
#         <bem.triangulation.Triangulation at 0x21a3d5902e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5903a0>,
#         <bem.triangulation.Triangulation at 0x21a3d590460>,
#         <bem.triangulation.Triangulation at 0x21a3d590520>,
#         <bem.triangulation.Triangulation at 0x21a3d5905e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5906a0>,
#         <bem.triangulation.Triangulation at 0x21a3d590760>,
#         <bem.triangulation.Triangulation at 0x21a3d590820>,
#         <bem.triangulation.Triangulation at 0x21a3d5908e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5909a0>,
#         <bem.triangulation.Triangulation at 0x21a3d590a60>,
#         <bem.triangulation.Triangulation at 0x21a3d590b20>,
#         <bem.triangulation.Triangulation at 0x21a3d590be0>,
#         <bem.triangulation.Triangulation at 0x21a3d590ca0>,
#         <bem.triangulation.Triangulation at 0x21a3d590d60>,
#         <bem.triangulation.Triangulation at 0x21a3d590e20>,
#         <bem.triangulation.Triangulation at 0x21a3d590ee0>,
#         <bem.triangulation.Triangulation at 0x21a3d590fa0>,
#         <bem.triangulation.Triangulation at 0x21a3d5a10a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1160>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1220>,
#         <bem.triangulation.Triangulation at 0x21a3d5a12e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5a13a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1460>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1520>,
#         <bem.triangulation.Triangulation at 0x21a3d5a15e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5a16a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1760>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1880>,
#         <bem.triangulation.Triangulation at 0x21a3d5a18e0>,
#         <bem.triangulation.Triangulation at 0x21a3d5a19a0>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1a60>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1b20>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1be0>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1ca0>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1d60>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1e20>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1ee0>,
#         <bem.triangulation.Triangulation at 0x21a3d5a1fa0>,
#         <bem.triangulation.Triangulation at 0x21a3d59d0a0>,
#         <bem.triangulation.Triangulation at 0x21a3d59d160>,
#         <bem.triangulation.Triangulation at 0x21a3d59d220>,
#         <bem.triangulation.Triangulation at 0x21a3d59d2e0>,
#         <bem.triangulation.Triangulation at 0x21a3d59d3a0>,
#         <bem.triangulation.Triangulation at 0x21a3d59d460>,
#         <bem.triangulation.Triangulation at 0x21a3d59d520>,
#         <bem.triangulation.Triangulation at 0x21a3d59d5e0>,
#         <bem.triangulation.Triangulation at 0x21a3d59d6a0>,
#         <bem.triangulation.Triangulation at 0x21a3d59d760>,
#         <bem.triangulation.Triangulation at 0x21a3d59d820>,
#         <bem.triangulation.Triangulation at 0x21a3d59d8e0>,
#         <bem.triangulation.Triangulation at 0x21a3d59d9a0>,
#         <bem.triangulation.Triangulation at 0x21a3d59da60>,
#         <bem.triangulation.Triangulation at 0x21a3d59db20>,
#         <bem.triangulation.Triangulation at 0x21a3d59dbe0>,
#         <bem.triangulation.Triangulation at 0x21a3d59dca0>,
#         <bem.triangulation.Triangulation at 0x21a3d59dd60>,
#         <bem.triangulation.Triangulation at 0x21a3d59de20>,
#         <bem.triangulation.Triangulation at 0x21a3d59dee0>,
#         <bem.triangulation.Triangulation at 0x21a3d59dfa0>,
#         <bem.triangulation.Triangulation at 0x21a3f9db0a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9db160>,
#         <bem.triangulation.Triangulation at 0x21a3f9db220>,
#         <bem.triangulation.Triangulation at 0x21a3f9db2e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9db3a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9db460>,
#         <bem.triangulation.Triangulation at 0x21a3f9db520>,
#         <bem.triangulation.Triangulation at 0x21a3f9db5e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9db6a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9db760>,
#         <bem.triangulation.Triangulation at 0x21a3f9db820>,
#         <bem.triangulation.Triangulation at 0x21a3f9db8e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9db9a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9dba60>,
#         <bem.triangulation.Triangulation at 0x21a3f9dbb20>]),
#       ('DC1',
#        [<bem.triangulation.Triangulation at 0x21a3f9dbbe0>,
#         <bem.triangulation.Triangulation at 0x21a3f9dbca0>,
#         <bem.triangulation.Triangulation at 0x21a3f9dbd60>,
#         <bem.triangulation.Triangulation at 0x21a3f9dbe20>,
#         <bem.triangulation.Triangulation at 0x21a3f9dbee0>,
#         <bem.triangulation.Triangulation at 0x21a3f9dbfa0>,
#         <bem.triangulation.Triangulation at 0x21a3f9d20a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9d2160>,
#         <bem.triangulation.Triangulation at 0x21a3f9d2220>,
#         <bem.triangulation.Triangulation at 0x21a3f9d22e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9d23a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9d2460>,
#         <bem.triangulation.Triangulation at 0x21a3f9d2520>,
#         <bem.triangulation.Triangulation at 0x21a3f9d25e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9d26a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9d2760>]),
#       ('DC3',
#        [<bem.triangulation.Triangulation at 0x21a3f9d2820>,
#         <bem.triangulation.Triangulation at 0x21a3f9d28e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9d29a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9d2a60>,
#         <bem.triangulation.Triangulation at 0x21a3f9d2b20>,
#         <bem.triangulation.Triangulation at 0x21a3f9d2be0>,
#         <bem.triangulation.Triangulation at 0x21a3f9d2ca0>,
#         <bem.triangulation.Triangulation at 0x21a3f9d2d60>,
#         <bem.triangulation.Triangulation at 0x21a3f9d2e20>,
#         <bem.triangulation.Triangulation at 0x21a3f9d2ee0>,
#         <bem.triangulation.Triangulation at 0x21a3f9d2fa0>,
#         <bem.triangulation.Triangulation at 0x21a3f9cf0a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9cf160>,
#         <bem.triangulation.Triangulation at 0x21a3f9cf220>]),
#       ('DC4',
#        [<bem.triangulation.Triangulation at 0x21a3f9cf2e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9cf3a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9cf460>,
#         <bem.triangulation.Triangulation at 0x21a3f9cf520>,
#         <bem.triangulation.Triangulation at 0x21a3f9cf5e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9cf6a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9cf760>,
#         <bem.triangulation.Triangulation at 0x21a3f9cf820>,
#         <bem.triangulation.Triangulation at 0x21a3f9cf8e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9cf9a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9cfa60>,
#         <bem.triangulation.Triangulation at 0x21a3f9cfb20>,
#         <bem.triangulation.Triangulation at 0x21a3f9cfbe0>,
#         <bem.triangulation.Triangulation at 0x21a3f9cfca0>,
#         <bem.triangulation.Triangulation at 0x21a3f9cfd60>]),
#       ('DC5',
#        [<bem.triangulation.Triangulation at 0x21a3f9cfe20>,
#         <bem.triangulation.Triangulation at 0x21a3f9cfee0>,
#         <bem.triangulation.Triangulation at 0x21a3f9cffa0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c60a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6160>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6220>,
#         <bem.triangulation.Triangulation at 0x21a3f9c62e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c63a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6460>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6520>,
#         <bem.triangulation.Triangulation at 0x21a3f9c65e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c66a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6760>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6820>]),
#       ('DC6',
#        [<bem.triangulation.Triangulation at 0x21a3f9c68e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c69a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6a60>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6b20>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6be0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6ca0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6d60>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6e20>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6ee0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c6fa0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c40a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c4160>,
#         <bem.triangulation.Triangulation at 0x21a3f9c4220>,
#         <bem.triangulation.Triangulation at 0x21a3f9c42e0>]),
#       ('DC8',
#        [<bem.triangulation.Triangulation at 0x21a3f9c43a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c4460>,
#         <bem.triangulation.Triangulation at 0x21a3f9c4520>,
#         <bem.triangulation.Triangulation at 0x21a3f9c45e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c46a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c4760>,
#         <bem.triangulation.Triangulation at 0x21a3f9c4820>,
#         <bem.triangulation.Triangulation at 0x21a3f9c48e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c49a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c4a60>,
#         <bem.triangulation.Triangulation at 0x21a3f9c4b20>,
#         <bem.triangulation.Triangulation at 0x21a3f9c4be0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c4ca0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c4d60>]),
#       ('DC9',
#        [<bem.triangulation.Triangulation at 0x21a3f9c4e20>,
#         <bem.triangulation.Triangulation at 0x21a3f9c4ee0>,
#         <bem.triangulation.Triangulation at 0x21a3f9c4fa0>,
#         <bem.triangulation.Triangulation at 0x21a3f9b80a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8160>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8280>,
#         <bem.triangulation.Triangulation at 0x21a3f9b82e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9b83a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8460>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8520>,
#         <bem.triangulation.Triangulation at 0x21a3f9b85e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9b86a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8760>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8820>]),
#       ('DC10',
#        [<bem.triangulation.Triangulation at 0x21a3f9b88e0>,
#         <bem.triangulation.Triangulation at 0x21a3f9b89a0>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8a60>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8b20>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8be0>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8ca0>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8d60>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8e20>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8ee0>,
#         <bem.triangulation.Triangulation at 0x21a3f9b8fa0>,
#         <bem.triangulation.Triangulation at 0x21a3f9b70a0>])])

# %%
# save base mesh to a pickle file
with open(fout_name,'wb') as f:
    data = (mesh_unit,
            xl,
            yl,
            zl,
            mesh,
            list(od.values()))
    pickle.dump(data,f)

# %% [markdown]
# ## view mesh
# Uses Pyvista package to generate interactive 3-d plot of the mesh

# %%
# Plot triangle mezshes of the final mesh
mesh.plot()

# %% [markdown]
# Show number of points included in the mesh

# %%
print(len(mesh.points))
# Out:
# 10755
