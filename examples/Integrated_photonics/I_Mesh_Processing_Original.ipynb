# %% [markdown]
# # `Documention & Tutorial`
# This BEM package is used for for numerical simulation of the electric field of ion traps in python. Some external packages are wrapped into it:
#
# * fast triangulation (http://www.cs.cmu.edu/~quake/triangle.research.html)
# * fastlap boundary element method (Nabors K S. Efficient three-dimensional capacitance calculation[D]. Massachusetts Institute of Technology, 1993.)
#
# This document, also as a tutorial, explains how to use these packages to compute the electric field and compute its multipole expansion coefficient starting from scratch with a fusion 360 trap model(take `./f3d/htrap_cutout_overhang_9x5mm.f3d` for example). Our document consists of three .ipynb files:
#
# * `I_Mesh_Processing.ipynb`
# * `II_Field_Simulation.ipynb`
# * `III_Multipole_Expansion.ipynb`
#
# We split the document into three files for two reasons:
# 1. The most time consuming part `II_Field_Simulation.ipynb` could be taken out alone and run on a high peformance computer.
# 2. The intermediate result between files can be checked- 'intermediate files' refer to the inital mesh grid (that corresponds to the charge distribution), the simulation values and the simulation coordinates, all of which are saved in the inter_results folder. So if the voltage solution files for the trap don't make sense, it is possible to go back through saved data to see where things have gone wrong.
# Here are the three jupyter notebooks and what:
# 1. I_Mesh_Processing- this notebook generates a mesh of the trap, saved in inter_results as a .pkl file
#
#
# Going through three files in order and running their python code will help you understand our workflow. Generally our workflow divides into three steps, corresponding to the above three .ipynb files. First, in I_Mesh_Processing, we identify different electrodes of the trap model by different colors. Also, we refine the trap model meshes to prepare for the second step. The result is stored in `mesh_result.pkl`.
#
# Secondly, in II_Field_Simulation, we simulate the electric potential with fastlap boundary element method(FMM), the accuracy of this step depends on the mesh size in the first step. The result is stored in `field_result.pkl`.
#
# Thirdly, in III_Multipole_Expansion, we analyze the electric field and electric potential. This notebook generates the multipole coefficients of the fields and potentials for each electrode and uses that information to generate a solution file with the function call `write_csv`. If your solution don't make sense, a good place to start is to insure that the mesh you are using is fine enough (generate several field results for different meshes)- if the potentials and fields are converging to specific values, this suggests there is something wrong with the multipole expansion. If you start with multipole expansion, you do not know if it is a problem with the expansion or with the field.
#
# Before running codes, you must set up the environment according to instructions in `README`
#
# notes
# * Our workflow, as indicated by this document, abandons mayavi(with its embeded package tvtk). But we reserve mayavi in our Bem source code, if you want to use mayavi related functions, you must set up environment with files in`./backup/setup_with_mayavi`, just replace corresponding files in the root folder with them and set up.
#     * why we abandon mayavi: because its python interface(with its dependence vtk and PyQt5) requires complex package dependencies and version controls especially for new python versions. This makes it difficult to maintain this project.
#     * why we still keep mayavi in the source code? Because it is rooted in our source code deeply. We can just avoid invoking related functions instead of deleting them, because they may make sense in the future.

# %% [markdown]
# # `I. Mesh Processing`
# This .pynb file reads a colored model file `./inter_results/htrap_cutout.stl`, and assigns a name for each color(thus for each electrode). The result is stored in `./inter_results/mesh_result.pkl`.
#
# In this file we name different electrodes and refine the meshes. The size of mesh determines the accuracy in next step. You should set the mesh finer and finer until the result converges. Also, you can set the mesh finer and test the convergence.
#
# ## (1) color your electrodes (in fusion 360) and export stl
# First of all, you have a trap model in fusion 360 project, for example, `./f3d/htrap_cutout_overhang_9x5mm.f3d`. Here we use different color to identify different electrodes(STL file stores color for each mesh). In fusion 360, you can assign different appearance for different electrodes. We recommend to use ../../bemCol_lib/bemCol.adsklib for different electrodes. Same color for two electrodes means they are treated as the same electrode. Then we get `./f3d/htrap_cutout_overhang_9x5mm_my_colored.f3d`
#
# Then export to an stl file in fusion360 file>export tab and move the file in `./inter_results`. We export our stl in mm, so we set the mesh unit to mm.

# %% [markdown]
# Furthurmore, it's our convention to use unit mm in our traps. e.g. [Electric field] = V/mm , [harmonic confining potential] = V/mm^2.so we set

# %%
# this is the unit for our Mesh structure
# in the following code, this is the default unit for python variables
#units 
mesh_unit = 1e-3

# %% [markdown]
# Additional notes (from Wenhao):
# * Why use standard color? We define a set of standard color lib `../../../bemCol_lib/bemCol.adsklib` for two reasons: 1. when exporting to .stl file, fusion 360 will compress 0-256 color(RGBA32) into 0-32 color(RGBA16), which means that some similar colors in fusion 360 will become same color after export to .stl file. Our standard color lib avoid this problem. 2.If you use .stl file exported from fusion 360 DIRECTLY, naming the electrodes would be very convinient. If you use other apps such as Inventor or Meshlab to generate .stl file, you can ignore the second reason because color encoding are quite different in different apps

# %% [markdown]
# ## (2) assign a name for each color

# %%
import pickle
import numpy as np
import matplotlib as mpl
import sys
from utils.helper_functions import *
from bem.bemColors_lib.bemColors import bemColors
from bem import Electrodes, Sphere, Mesh, Grid, Configuration, Result, Box
# load stl geometry file
from bem.formats import stl
# stl_path = "roughness/"+"basic_excitation"+".stl"  


#radius is the radius of the sphere from the ions location to generate a finer
#electrode mesh
radius= 500e-3
#'area' is the area of the triangles inside the sphere
area = 1e-4
# file = 'mit_charge'
# file = 'htrap_cutout_overhang_taper_2'
# file_out = 'htrap_cutout_overhang_taper_el3'
# stl_path = 'inter_results/taper_overhang/'+file+'.stl'
# fout_name = 'inter_results/taper_overhang/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


file_out = 'htrap_cutout_el2'
stl_path = 'inter_results/htrap_cutout/htrap_cutout.stl'
fout_name = 'inter_results/htrap_cutout/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


module_path = os.path.abspath('')


s_nta = stl.read_stl(open(stl_path, "rb"))

# %% [markdown]
# Firstly, we print all the colors appear in the stl file. If a color is of standard colors in `bemCol.adsklib` or named manually by function `bemCol.set_my_color()`, then the color will appear in a straightforward name, such as `bem0`,`bem1` ...... . Otherwise, the color will simply be named as `'_unkCol0'` , `'_unkCol1'`, ...
#
# notes
# * try to comment out the line of `ele_col.set_my_color()` in the following block, name `'_unkCol0'` will appear.

# %%
ele_col = bemColors(np.array(list(set(s_nta[2]))),('fusion360','export_stl'))
ele_col.set_my_color(value = (178,178,178),cl_format = ('fusion360','export_stl','RGBA64'),name = 'self_defined')
ele_col.print_stl_colors()
# Out:
# COLORS in the stl:
# ['bem6']
# ['bem13']
# ['bem19']
# ['bem11']
# ['bem17']
# ['bem15']
# ['bem30']
# ['bem1']
# ['bem12']
# ['bem5']
# ['bem25']
# ['bem18']
# ['bem16']
# ['bem3']
# ['bem7']
# ['bem9']
# ['bem2']
# ['bem4']
# ['bem20']
# ['bem10']
# ['bem14']
# ['bem8']
# ['bem21']
# ['_unkColor0']
# TOTAL COLORS:  24

# %% [markdown]
# Next, you need to assign a name for each color that appeared above. With standard colors defined in `bemCol.adsklib`, the correspondence between color and electrode is clear, which make it easy for this step. You can also comment out some `ele_col.set_color_name()`, run all the codes again and observe the missing part in the printed figure, which corresponds to the electrode you comment out. The second method also serves as a double check. Besides, parameter in `stl.stl_to_mesh()` can be set as `quiet = False` to check whether the program reads planes correctly.

# %%
# assign a name for each color
# taper htrap_cutout 2022
# assign a name for each color

# In od[key] = value, key is the color from the Fusion360 color library we made
# value assigns a specific name to that color in this program. 
# In future version, we may want to consider getting rid of this step for simplification
# then you just assign the color in fusion 360 and be done with it. The only concern there is you
from collections import OrderedDict
od = OrderedDict()
od['bem1']='DC1'
od['bem2']='DC2'
od['bem3']='DC3'
od['bem4']='DC4'
od['bem5']='DC5'
od['bem6']='DC6'
od['bem7']='DC7'
od['bem8']='DC8'
od['bem9']='DC9'
od['bem10']='DC10'
od['bem11']='DC11'
od['bem12']='DC12'
od['bem13']='DC13'
od['bem14']='DC14'
od['bem15']='DC15'
od['bem16']='DC16'
od['bem17']='DC17'
od['bem18']='DC18'
od['bem19']='DC19'
od['bem20']='DC20'
od['bem21'] = 'DC21'
od['bem25'] = 'RF'
od['bem30'] = 'gnd'
for key in list(od.keys()):
    ele_col.color_electrode(color=key,name=od[key])

# print colors still with no name. These meshes will be neglected in the code below. 
ele_col.drop_colors()

# read stl into mesh with electrode names
# unnamed meshes will not be imported at all

mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=1,
    rename=ele_col.electrode_colors, quiet=True))
# Out:
# dropping color ['_unkColor0']
# TOTAL COLORS DROPPED:  1
# dropping 20083

# %% [markdown]
# ## (3) remesh
#
# In this step, we generate triangle mesh with constraints. The meshes are 2-dimensional triangles on the surface of electrodes. The region enclosed by constraint shape can have finer mesh. Triangulation is done by `triangle` C library. Folowing variables are all in unit `mesh_unit` now.
#
# Our remesh strategy consists of two steps of triangulation:
# 1. global triangulation without constraint. This step eliminate some long and sharp triangles by combining and dividing, and obtains a coarse grain triangulated model.
# 2. local triangulation with constraint. This step refines each triangles in step 1, the triangle density is defined by `mesh.areas_from_constraints
#
# parameters in the below code block should be tuned specificly for different trap geometries.`

# %%
# here we define a spherical constriant zone:
# xl = 270*1e-3
# yl = -3.5*1e-3
# zl = 72.5*1e-3

#here is the location that will be the reference point for further meshing
#usually, this is the ion's location, specified in appropriate units (usually millimeters)
zl = -450*1e-3
yl = 75*1e-3
xl = 3.75*1e-3


mesh.triangulate(opts="",new = False)

# for z in np.arange(-400e-3,700e-3,100e-3):
print('first triangulation:')
# for z in np.arange(-200e-3, 200e-3, 50e-3):
rad = radius*3
inside=area*30
outside=1
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="a2Q",new = False)

# # what happened to this feature (Box)? is this on bem savio?
# # mesh.areas_from_constraints(Box(start=-0.5, end= 0.5,inside=inside, outside=outside))



# areas_from_constraints specifies sphere with finer mesh inside it.
#  "inside", "outside" set different mesh densities. 
print('second triangulation:')
rad =radius
inside=area*2
outside=1e4
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="q5Q",new = False)

# save base mesh to a pickle file
# with open(fout_name,'wb') as f:
#     data = (mesh_unit,
#             xl,
#             yl,
#             zl,
#             mesh,
#             list(od.values()))
#     pickle.dump(data,f)
# Out:
# start triangulate RF
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate RF
# start triangulate DC21
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC21
# start triangulate DC2
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC2
# start triangulate DC7
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC7
# start triangulate DC11
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC11
# start triangulate DC12
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC12
# start triangulate DC13
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC13
# start triangulate DC14
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC14
# start triangulate DC15
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC15
# start triangulate DC16
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC16
# start triangulate DC17
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC17
# start triangulate DC18
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC18
# start triangulate DC19
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC19
# start triangulate DC20
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC20
# start triangulate gnd
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate gnd
# start triangulate DC1
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC1
# start triangulate DC3
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC3
# start triangulate DC4
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC4
# start triangulate DC5
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC5
# start triangulate DC6
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC6
# start triangulate DC8
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC8
# start triangulate DC9
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC9
# start triangulate DC10
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC10
# first triangulation:
# start triangulate RF
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate RF
# start triangulate DC21
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC10
# second triangulation:
# start triangulate RF
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate RF
# start triangulate DC21
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC10
# Mesh([('RF',
#        [<bem.triangulation.Triangulation at 0x28f0b25d520>,
#         <bem.triangulation.Triangulation at 0x28f0b2580a0>,
#         <bem.triangulation.Triangulation at 0x28f0b258280>,
#         <bem.triangulation.Triangulation at 0x28f0b258520>,
#         <bem.triangulation.Triangulation at 0x28f6bb23c40>,
#         <bem.triangulation.Triangulation at 0x28f6bb23f70>,
#         <bem.triangulation.Triangulation at 0x28f6bb37670>,
#         <bem.triangulation.Triangulation at 0x28f6bb375b0>,
#         <bem.triangulation.Triangulation at 0x28f6bb374f0>,
#         <bem.triangulation.Triangulation at 0x28f6bb37430>,
#         <bem.triangulation.Triangulation at 0x28f6bb37370>,
#         <bem.triangulation.Triangulation at 0x28f6bb372b0>,
#         <bem.triangulation.Triangulation at 0x28f6bb3b6d0>,
#         <bem.triangulation.Triangulation at 0x28f6bb3b760>,
#         <bem.triangulation.Triangulation at 0x28f6bb3b820>,
#         <bem.triangulation.Triangulation at 0x28f6bb3b8e0>,
#         <bem.triangulation.Triangulation at 0x28f6bb3b9a0>]),
#       ('DC21',
#        [<bem.triangulation.Triangulation at 0x28f6bb3ba60>,
#         <bem.triangulation.Triangulation at 0x28f6bb3bb20>,
#         <bem.triangulation.Triangulation at 0x28f6bb3bbe0>,
#         <bem.triangulation.Triangulation at 0x28f6bb3bca0>,
#         <bem.triangulation.Triangulation at 0x28f6bb3bd60>,
#         <bem.triangulation.Triangulation at 0x28f6bb3be20>,
#         <bem.triangulation.Triangulation at 0x28f6bb3bee0>]),
#       ('DC2',
#        [<bem.triangulation.Triangulation at 0x28f6bb3b130>,
#         <bem.triangulation.Triangulation at 0x28f6bb3b070>,
#         <bem.triangulation.Triangulation at 0x28f6bb3bfa0>,
#         <bem.triangulation.Triangulation at 0x28f6cc930a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc93160>,
#         <bem.triangulation.Triangulation at 0x28f6cc93220>,
#         <bem.triangulation.Triangulation at 0x28f6cc932e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc933a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc93460>,
#         <bem.triangulation.Triangulation at 0x28f6cc93520>,
#         <bem.triangulation.Triangulation at 0x28f6cc935e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc936a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc93760>]),
#       ('DC7',
#        [<bem.triangulation.Triangulation at 0x28f6cc93820>,
#         <bem.triangulation.Triangulation at 0x28f6cc938e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc939a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc93a60>,
#         <bem.triangulation.Triangulation at 0x28f6cc93b20>,
#         <bem.triangulation.Triangulation at 0x28f6cc93be0>,
#         <bem.triangulation.Triangulation at 0x28f6cc93ca0>,
#         <bem.triangulation.Triangulation at 0x28f6cc93d60>,
#         <bem.triangulation.Triangulation at 0x28f6cc93e20>,
#         <bem.triangulation.Triangulation at 0x28f6cc93ee0>,
#         <bem.triangulation.Triangulation at 0x28f6cc93fa0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb40a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb4160>]),
#       ('DC11',
#        [<bem.triangulation.Triangulation at 0x28f6ccb4220>,
#         <bem.triangulation.Triangulation at 0x28f6ccb42e0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb43a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb4460>,
#         <bem.triangulation.Triangulation at 0x28f6ccb4520>,
#         <bem.triangulation.Triangulation at 0x28f6ccb45e0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb46a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb4760>,
#         <bem.triangulation.Triangulation at 0x28f6ccb4820>,
#         <bem.triangulation.Triangulation at 0x28f6ccb48e0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb49a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb4a60>,
#         <bem.triangulation.Triangulation at 0x28f6ccb4b20>,
#         <bem.triangulation.Triangulation at 0x28f6ccb4be0>]),
#       ('DC12',
#        [<bem.triangulation.Triangulation at 0x28f6ccb4ca0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb4d60>,
#         <bem.triangulation.Triangulation at 0x28f6ccb4e20>,
#         <bem.triangulation.Triangulation at 0x28f6ccb4ee0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb4fa0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb60a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb6160>,
#         <bem.triangulation.Triangulation at 0x28f6ccb6220>,
#         <bem.triangulation.Triangulation at 0x28f6ccb62e0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb63a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb6460>,
#         <bem.triangulation.Triangulation at 0x28f6ccb6520>,
#         <bem.triangulation.Triangulation at 0x28f6ccb65e0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb66a0>]),
#       ('DC13',
#        [<bem.triangulation.Triangulation at 0x28f6ccb6760>,
#         <bem.triangulation.Triangulation at 0x28f6ccb6820>,
#         <bem.triangulation.Triangulation at 0x28f6ccb68e0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb69a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb6a60>,
#         <bem.triangulation.Triangulation at 0x28f6ccb6b20>,
#         <bem.triangulation.Triangulation at 0x28f6ccb6be0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb6ca0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb6d60>,
#         <bem.triangulation.Triangulation at 0x28f6ccb6e20>,
#         <bem.triangulation.Triangulation at 0x28f6ccb6ee0>,
#         <bem.triangulation.Triangulation at 0x28f6ccb6fa0>,
#         <bem.triangulation.Triangulation at 0x28f6ccbb0a0>]),
#       ('DC14',
#        [<bem.triangulation.Triangulation at 0x28f6ccbb160>,
#         <bem.triangulation.Triangulation at 0x28f6ccbb220>,
#         <bem.triangulation.Triangulation at 0x28f6ccbb2e0>,
#         <bem.triangulation.Triangulation at 0x28f6ccbb3a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccbb460>,
#         <bem.triangulation.Triangulation at 0x28f6ccbb520>,
#         <bem.triangulation.Triangulation at 0x28f6ccbb5e0>,
#         <bem.triangulation.Triangulation at 0x28f6ccbb6a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccbb760>,
#         <bem.triangulation.Triangulation at 0x28f6ccbb820>,
#         <bem.triangulation.Triangulation at 0x28f6ccbb8e0>,
#         <bem.triangulation.Triangulation at 0x28f6ccbb9a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccbba60>]),
#       ('DC15',
#        [<bem.triangulation.Triangulation at 0x28f6ccbbb20>,
#         <bem.triangulation.Triangulation at 0x28f6ccbbbe0>,
#         <bem.triangulation.Triangulation at 0x28f6ccbbca0>,
#         <bem.triangulation.Triangulation at 0x28f6ccbbd60>,
#         <bem.triangulation.Triangulation at 0x28f6ccbbe20>,
#         <bem.triangulation.Triangulation at 0x28f6ccbbee0>,
#         <bem.triangulation.Triangulation at 0x28f6ccbbfa0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc00a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc0160>,
#         <bem.triangulation.Triangulation at 0x28f6ccc0220>,
#         <bem.triangulation.Triangulation at 0x28f6ccc02e0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc03a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc0460>]),
#       ('DC16',
#        [<bem.triangulation.Triangulation at 0x28f6ccc0520>,
#         <bem.triangulation.Triangulation at 0x28f6ccc0640>,
#         <bem.triangulation.Triangulation at 0x28f6ccc06a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc0760>,
#         <bem.triangulation.Triangulation at 0x28f6ccc0820>,
#         <bem.triangulation.Triangulation at 0x28f6ccc08e0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc09a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc0a60>,
#         <bem.triangulation.Triangulation at 0x28f6ccc0b20>,
#         <bem.triangulation.Triangulation at 0x28f6ccc0be0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc0ca0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc0d60>,
#         <bem.triangulation.Triangulation at 0x28f6ccc0e20>]),
#       ('DC17',
#        [<bem.triangulation.Triangulation at 0x28f6ccc0ee0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc0fa0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc50a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc5160>,
#         <bem.triangulation.Triangulation at 0x28f6ccc5220>,
#         <bem.triangulation.Triangulation at 0x28f6ccc52e0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc53a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc5460>,
#         <bem.triangulation.Triangulation at 0x28f6ccc5520>,
#         <bem.triangulation.Triangulation at 0x28f6ccc55e0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc56a0>,
#         <bem.triangulation.Triangulation at 0x28f6ccc5760>,
#         <bem.triangulation.Triangulation at 0x28f6ccc5820>]),
#       ('DC18',
#        [<bem.triangulation.Triangulation at 0x28f6ccc58e0>,
# ...
#         <bem.triangulation.Triangulation at 0x28f6cb2c5e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb2c6a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb2c760>,
#         <bem.triangulation.Triangulation at 0x28f6cb2c820>,
#         <bem.triangulation.Triangulation at 0x28f6cb2c8e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb2c9a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb2ca60>,
#         <bem.triangulation.Triangulation at 0x28f6cb2cb20>,
#         <bem.triangulation.Triangulation at 0x28f6cb2cbe0>,
#         <bem.triangulation.Triangulation at 0x28f6cb2cca0>,
#         <bem.triangulation.Triangulation at 0x28f6cb2cd60>,
#         <bem.triangulation.Triangulation at 0x28f6cb2ce20>,
#         <bem.triangulation.Triangulation at 0x28f6cb2cee0>,
#         <bem.triangulation.Triangulation at 0x28f6cb2cfa0>,
#         <bem.triangulation.Triangulation at 0x28f6cb310a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb31160>,
#         <bem.triangulation.Triangulation at 0x28f6cb31220>,
#         <bem.triangulation.Triangulation at 0x28f6cb312e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb313a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb31460>,
#         <bem.triangulation.Triangulation at 0x28f6cb31520>,
#         <bem.triangulation.Triangulation at 0x28f6cb315e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb316a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb31760>,
#         <bem.triangulation.Triangulation at 0x28f6cb31820>,
#         <bem.triangulation.Triangulation at 0x28f6cb318e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb319a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb31a60>,
#         <bem.triangulation.Triangulation at 0x28f6cb31b20>,
#         <bem.triangulation.Triangulation at 0x28f6cb31be0>,
#         <bem.triangulation.Triangulation at 0x28f6cb31ca0>,
#         <bem.triangulation.Triangulation at 0x28f6cb31d60>,
#         <bem.triangulation.Triangulation at 0x28f6cb31e20>,
#         <bem.triangulation.Triangulation at 0x28f6cb31ee0>,
#         <bem.triangulation.Triangulation at 0x28f6cb31fa0>,
#         <bem.triangulation.Triangulation at 0x28f6cb360a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb36160>,
#         <bem.triangulation.Triangulation at 0x28f6cb36220>,
#         <bem.triangulation.Triangulation at 0x28f6cb362e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb363a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb36460>,
#         <bem.triangulation.Triangulation at 0x28f6cb36520>,
#         <bem.triangulation.Triangulation at 0x28f6cb365e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb366a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb36760>,
#         <bem.triangulation.Triangulation at 0x28f6cb36820>,
#         <bem.triangulation.Triangulation at 0x28f6cb368e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb369a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb36a60>,
#         <bem.triangulation.Triangulation at 0x28f6cb36b20>,
#         <bem.triangulation.Triangulation at 0x28f6cb36be0>,
#         <bem.triangulation.Triangulation at 0x28f6cb36ca0>,
#         <bem.triangulation.Triangulation at 0x28f6cb36d60>,
#         <bem.triangulation.Triangulation at 0x28f6cb36e20>,
#         <bem.triangulation.Triangulation at 0x28f6cb36ee0>,
#         <bem.triangulation.Triangulation at 0x28f6cb36fa0>,
#         <bem.triangulation.Triangulation at 0x28f6cb3b0a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb3b160>,
#         <bem.triangulation.Triangulation at 0x28f6cb3b220>,
#         <bem.triangulation.Triangulation at 0x28f6cb3b2e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb3b3a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb3b460>,
#         <bem.triangulation.Triangulation at 0x28f6cb3b520>,
#         <bem.triangulation.Triangulation at 0x28f6cb3b5e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb3b6a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb3b760>,
#         <bem.triangulation.Triangulation at 0x28f6cb3b820>,
#         <bem.triangulation.Triangulation at 0x28f6cb3b8e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb3b9a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb3ba60>,
#         <bem.triangulation.Triangulation at 0x28f6cb3bb20>,
#         <bem.triangulation.Triangulation at 0x28f6cb3bbe0>,
#         <bem.triangulation.Triangulation at 0x28f6cb3bca0>,
#         <bem.triangulation.Triangulation at 0x28f6cb3bd60>,
#         <bem.triangulation.Triangulation at 0x28f6cb3be20>,
#         <bem.triangulation.Triangulation at 0x28f6cb3bee0>,
#         <bem.triangulation.Triangulation at 0x28f6cb3bfa0>,
#         <bem.triangulation.Triangulation at 0x28f6cb400a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb40160>,
#         <bem.triangulation.Triangulation at 0x28f6cb40220>,
#         <bem.triangulation.Triangulation at 0x28f6cb402e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb40400>,
#         <bem.triangulation.Triangulation at 0x28f6cb40460>,
#         <bem.triangulation.Triangulation at 0x28f6cb40520>,
#         <bem.triangulation.Triangulation at 0x28f6cb405e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb406a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb40760>,
#         <bem.triangulation.Triangulation at 0x28f6cb40820>,
#         <bem.triangulation.Triangulation at 0x28f6cb408e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb409a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb40a60>,
#         <bem.triangulation.Triangulation at 0x28f6cb40b20>,
#         <bem.triangulation.Triangulation at 0x28f6cb40be0>,
#         <bem.triangulation.Triangulation at 0x28f6cb40ca0>,
#         <bem.triangulation.Triangulation at 0x28f6cb40d60>,
#         <bem.triangulation.Triangulation at 0x28f6cb40e20>,
#         <bem.triangulation.Triangulation at 0x28f6cb40ee0>,
#         <bem.triangulation.Triangulation at 0x28f6cb40fa0>,
#         <bem.triangulation.Triangulation at 0x28f6cb450a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb45160>,
#         <bem.triangulation.Triangulation at 0x28f6cb45220>,
#         <bem.triangulation.Triangulation at 0x28f6cb452e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb453a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb45460>,
#         <bem.triangulation.Triangulation at 0x28f6cb45520>,
#         <bem.triangulation.Triangulation at 0x28f6cb455e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb456a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb45760>,
#         <bem.triangulation.Triangulation at 0x28f6cb45820>,
#         <bem.triangulation.Triangulation at 0x28f6cb458e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb459a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb45a60>,
#         <bem.triangulation.Triangulation at 0x28f6cb45b20>,
#         <bem.triangulation.Triangulation at 0x28f6cb45be0>,
#         <bem.triangulation.Triangulation at 0x28f6cb45ca0>,
#         <bem.triangulation.Triangulation at 0x28f6cb45d60>,
#         <bem.triangulation.Triangulation at 0x28f6cb45e20>,
#         <bem.triangulation.Triangulation at 0x28f6cb45ee0>,
#         <bem.triangulation.Triangulation at 0x28f6cb45fa0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4a0a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4a160>,
#         <bem.triangulation.Triangulation at 0x28f6cb4a220>,
#         <bem.triangulation.Triangulation at 0x28f6cb4a2e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4a3a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4a460>,
#         <bem.triangulation.Triangulation at 0x28f6cb4a520>,
#         <bem.triangulation.Triangulation at 0x28f6cb4a5e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4a6a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4a760>,
#         <bem.triangulation.Triangulation at 0x28f6cb4a820>,
#         <bem.triangulation.Triangulation at 0x28f6cb4a8e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4a9a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4aa60>,
#         <bem.triangulation.Triangulation at 0x28f6cb4ab20>,
#         <bem.triangulation.Triangulation at 0x28f6cb4abe0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4aca0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4ad60>,
#         <bem.triangulation.Triangulation at 0x28f6cb4ae20>,
#         <bem.triangulation.Triangulation at 0x28f6cb4aee0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4afa0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4f0a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4f160>,
#         <bem.triangulation.Triangulation at 0x28f6cb4f220>,
#         <bem.triangulation.Triangulation at 0x28f6cb4f2e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4f3a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4f460>,
#         <bem.triangulation.Triangulation at 0x28f6cb4f520>,
#         <bem.triangulation.Triangulation at 0x28f6cb4f5e0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4f6a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4f760>,
#         <bem.triangulation.Triangulation at 0x28f6cb4f820>,
#         <bem.triangulation.Triangulation at 0x28f6cb4f8e0>]),
#       ('DC1',
#        [<bem.triangulation.Triangulation at 0x28f6cb4f9a0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4fa60>,
#         <bem.triangulation.Triangulation at 0x28f6cb4fb20>,
#         <bem.triangulation.Triangulation at 0x28f6cb4fbe0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4fca0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4fd60>,
#         <bem.triangulation.Triangulation at 0x28f6cb4fe20>,
#         <bem.triangulation.Triangulation at 0x28f6cb4fee0>,
#         <bem.triangulation.Triangulation at 0x28f6cb4ffa0>,
#         <bem.triangulation.Triangulation at 0x28f6cc740a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc74160>,
#         <bem.triangulation.Triangulation at 0x28f6cc74220>,
#         <bem.triangulation.Triangulation at 0x28f6cc742e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc743a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc74460>,
#         <bem.triangulation.Triangulation at 0x28f6cc74520>]),
#       ('DC3',
#        [<bem.triangulation.Triangulation at 0x28f6cc745e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc746a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc74760>,
#         <bem.triangulation.Triangulation at 0x28f6cc74820>,
#         <bem.triangulation.Triangulation at 0x28f6cc748e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc749a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc74a60>,
#         <bem.triangulation.Triangulation at 0x28f6cc74b20>,
#         <bem.triangulation.Triangulation at 0x28f6cc74be0>,
#         <bem.triangulation.Triangulation at 0x28f6cc74ca0>,
#         <bem.triangulation.Triangulation at 0x28f6cc74d60>,
#         <bem.triangulation.Triangulation at 0x28f6cc74e20>,
#         <bem.triangulation.Triangulation at 0x28f6cc74ee0>,
#         <bem.triangulation.Triangulation at 0x28f6cc74fa0>]),
#       ('DC4',
#        [<bem.triangulation.Triangulation at 0x28f6cc6b0a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc6b160>,
#         <bem.triangulation.Triangulation at 0x28f6cc6b220>,
#         <bem.triangulation.Triangulation at 0x28f6cc6b2e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc6b3a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc6b460>,
#         <bem.triangulation.Triangulation at 0x28f6cc6b520>,
#         <bem.triangulation.Triangulation at 0x28f6cc6b5e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc6b6a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc6b760>,
#         <bem.triangulation.Triangulation at 0x28f6cc6b820>,
#         <bem.triangulation.Triangulation at 0x28f6cc6b8e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc6b9a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc6ba60>,
#         <bem.triangulation.Triangulation at 0x28f6cc6bb20>]),
#       ('DC5',
#        [<bem.triangulation.Triangulation at 0x28f6cc6bbe0>,
#         <bem.triangulation.Triangulation at 0x28f6cc6bca0>,
#         <bem.triangulation.Triangulation at 0x28f6cc6bd60>,
#         <bem.triangulation.Triangulation at 0x28f6cc6be20>,
#         <bem.triangulation.Triangulation at 0x28f6cc6bee0>,
#         <bem.triangulation.Triangulation at 0x28f6cc6bfa0>,
#         <bem.triangulation.Triangulation at 0x28f6cc500a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc50160>,
#         <bem.triangulation.Triangulation at 0x28f6cc50220>,
#         <bem.triangulation.Triangulation at 0x28f6cc502e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc503a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc50460>,
#         <bem.triangulation.Triangulation at 0x28f6cc50520>,
#         <bem.triangulation.Triangulation at 0x28f6cc505e0>]),
#       ('DC6',
#        [<bem.triangulation.Triangulation at 0x28f6cc506a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc50760>,
#         <bem.triangulation.Triangulation at 0x28f6cc50820>,
#         <bem.triangulation.Triangulation at 0x28f6cc508e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc509a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc50a60>,
#         <bem.triangulation.Triangulation at 0x28f6cc50b20>,
#         <bem.triangulation.Triangulation at 0x28f6cc50be0>,
#         <bem.triangulation.Triangulation at 0x28f6cc50ca0>,
#         <bem.triangulation.Triangulation at 0x28f6cc50dc0>,
#         <bem.triangulation.Triangulation at 0x28f6cc50e20>,
#         <bem.triangulation.Triangulation at 0x28f6cc50ee0>,
#         <bem.triangulation.Triangulation at 0x28f6cc50fa0>,
#         <bem.triangulation.Triangulation at 0x28f6cc560a0>]),
#       ('DC8',
#        [<bem.triangulation.Triangulation at 0x28f6cc56160>,
#         <bem.triangulation.Triangulation at 0x28f6cc56220>,
#         <bem.triangulation.Triangulation at 0x28f6cc562e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc563a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc56460>,
#         <bem.triangulation.Triangulation at 0x28f6cc56520>,
#         <bem.triangulation.Triangulation at 0x28f6cc565e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc566a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc56760>,
#         <bem.triangulation.Triangulation at 0x28f6cc56820>,
#         <bem.triangulation.Triangulation at 0x28f6cc568e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc569a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc56a60>,
#         <bem.triangulation.Triangulation at 0x28f6cc56b20>]),
#       ('DC9',
#        [<bem.triangulation.Triangulation at 0x28f6cc56be0>,
#         <bem.triangulation.Triangulation at 0x28f6cc56ca0>,
#         <bem.triangulation.Triangulation at 0x28f6cc56d60>,
#         <bem.triangulation.Triangulation at 0x28f6cc56e20>,
#         <bem.triangulation.Triangulation at 0x28f6cc56ee0>,
#         <bem.triangulation.Triangulation at 0x28f6cc56fa0>,
#         <bem.triangulation.Triangulation at 0x28f6cc5d0a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc5d160>,
#         <bem.triangulation.Triangulation at 0x28f6cc5d220>,
#         <bem.triangulation.Triangulation at 0x28f6cc5d2e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc5d3a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc5d460>,
#         <bem.triangulation.Triangulation at 0x28f6cc5d520>,
#         <bem.triangulation.Triangulation at 0x28f6cc5d5e0>]),
#       ('DC10',
#        [<bem.triangulation.Triangulation at 0x28f6cc5d6a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc5d760>,
#         <bem.triangulation.Triangulation at 0x28f6cc5d820>,
#         <bem.triangulation.Triangulation at 0x28f6cc5d8e0>,
#         <bem.triangulation.Triangulation at 0x28f6cc5d9a0>,
#         <bem.triangulation.Triangulation at 0x28f6cc5da60>,
#         <bem.triangulation.Triangulation at 0x28f6cc5db20>,
#         <bem.triangulation.Triangulation at 0x28f6cc5dbe0>,
#         <bem.triangulation.Triangulation at 0x28f6cc5dca0>,
#         <bem.triangulation.Triangulation at 0x28f6cc5dd60>,
#         <bem.triangulation.Triangulation at 0x28f6cc5de20>])])

# %%
# save base mesh to a pickle file
with open(fout_name,'wb') as f:
    data = (mesh_unit,
            xl,
            yl,
            zl,
            mesh,
            list(od.values()))
    pickle.dump(data,f)

# %% [markdown]
# ## view mesh
# Uses Pyvista package to generate interactive 3-d plot of the mesh

# %%
# Plot triangle mezshes of the final mesh
mesh.plot()

# %% [markdown]
# Show number of points included in the mesh

# %%
print(len(mesh.points))
# Out:
# 8692
