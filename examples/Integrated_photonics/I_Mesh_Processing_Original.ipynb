# %% [markdown]
# # `Documention & Tutorial`
# This BEM package is used for for numerical simulation of the electric field of ion traps in python. Some external packages are wrapped into it:
#
# * fast triangulation (http://www.cs.cmu.edu/~quake/triangle.research.html)
# * fastlap boundary element method (Nabors K S. Efficient three-dimensional capacitance calculation[D]. Massachusetts Institute of Technology, 1993.)
#
# This document, also as a tutorial, explains how to use these packages to compute the electric field and compute its multipole expansion coefficient starting from scratch with a fusion 360 trap model(take `./f3d/htrap_cutout_overhang_9x5mm.f3d` for example). Our document consists of three .ipynb files:
#
# * `I_Mesh_Processing.ipynb`
# * `II_Field_Simulation.ipynb`
# * `III_Multipole_Expansion.ipynb`
#
# We split the document into three files for two reasons:
# 1. The most time consuming part `II_Field_Simulation.ipynb` could be taken out alone and run on a high peformance computer.
# 2. The intermediate result between files can be checked- 'intermediate files' refer to the inital mesh grid (that corresponds to the charge distribution), the simulation values and the simulation coordinates, all of which are saved in the inter_results folder. So if the voltage solution files for the trap don't make sense, it is possible to go back through saved data to see where things have gone wrong.
# Here are the three jupyter notebooks and what:
# 1. I_Mesh_Processing- this notebook generates a mesh of the trap, saved in inter_results as a .pkl file
#
#
# Going through three files in order and running their python code will help you understand our workflow. Generally our workflow divides into three steps, corresponding to the above three .ipynb files. First, in I_Mesh_Processing, we identify different electrodes of the trap model by different colors. Also, we refine the trap model meshes to prepare for the second step. The result is stored in `mesh_result.pkl`.
#
# Secondly, in II_Field_Simulation, we simulate the electric potential with fastlap boundary element method(FMM), the accuracy of this step depends on the mesh size in the first step. The result is stored in `field_result.pkl`.
#
# Thirdly, in III_Multipole_Expansion, we analyze the electric field and electric potential. This notebook generates the multipole coefficients of the fields and potentials for each electrode and uses that information to generate a solution file with the function call `write_csv`. If your solution don't make sense, a good place to start is to insure that the mesh you are using is fine enough (generate several field results for different meshes)- if the potentials and fields are converging to specific values, this suggests there is something wrong with the multipole expansion. If you start with multipole expansion, you do not know if it is a problem with the expansion or with the field.
#
# Before running codes, you must set up the environment according to instructions in `README`
#
# notes
# * Our workflow, as indicated by this document, abandons mayavi(with its embeded package tvtk). But we reserve mayavi in our Bem source code, if you want to use mayavi related functions, you must set up environment with files in`./backup/setup_with_mayavi`, just replace corresponding files in the root folder with them and set up.
#     * why we abandon mayavi: because its python interface(with its dependence vtk and PyQt5) requires complex package dependencies and version controls especially for new python versions. This makes it difficult to maintain this project.
#     * why we still keep mayavi in the source code? Because it is rooted in our source code deeply. We can just avoid invoking related functions instead of deleting them, because they may make sense in the future.

# %% [markdown]
# # `I. Mesh Processing`
# This .pynb file reads a colored model file `./inter_results/htrap_cutout.stl`, and assigns a name for each color(thus for each electrode). The result is stored in `./inter_results/mesh_result.pkl`.
#
# In this file we name different electrodes and refine the meshes. The size of mesh determines the accuracy in next step. You should set the mesh finer and finer until the result converges. Also, you can set the mesh finer and test the convergence.
#
# ## (1) color your electrodes (in fusion 360) and export stl
# First of all, you have a trap model in fusion 360 project, for example, `./f3d/htrap_cutout_overhang_9x5mm.f3d`. Here we use different color to identify different electrodes(STL file stores color for each mesh). In fusion 360, you can assign different appearance for different electrodes. We recommend to use ../../bemCol_lib/bemCol.adsklib for different electrodes. Same color for two electrodes means they are treated as the same electrode. Then we get `./f3d/htrap_cutout_overhang_9x5mm_my_colored.f3d`
#
# Then export to an stl file in fusion360 file>export tab and move the file in `./inter_results`. We export our stl in mm, so we set the mesh unit to mm.

# %% [markdown]
# Furthurmore, it's our convention to use unit mm in our traps. e.g. [Electric field] = V/mm , [harmonic confining potential] = V/mm^2.so we set

# %%
# this is the unit for our Mesh structure
# in the following code, this is the default unit for python variables
#units 
mesh_unit = 1e-3

# %% [markdown]
# Additional notes (from Wenhao):
# * Why use standard color? We define a set of standard color lib `../../../bemCol_lib/bemCol.adsklib` for two reasons: 1. when exporting to .stl file, fusion 360 will compress 0-256 color(RGBA32) into 0-32 color(RGBA16), which means that some similar colors in fusion 360 will become same color after export to .stl file. Our standard color lib avoid this problem. 2.If you use .stl file exported from fusion 360 DIRECTLY, naming the electrodes would be very convinient. If you use other apps such as Inventor or Meshlab to generate .stl file, you can ignore the second reason because color encoding are quite different in different apps

# %% [markdown]
# ## (2) assign a name for each color

# %%
import pickle
import numpy as np
import matplotlib as mpl
import sys
from utils.helper_functions import *
from bem.bemColors_lib.bemColors import bemColors
from bem import Electrodes, Sphere, Mesh, Grid, Configuration, Result, Box
# load stl geometry file
from bem.formats import stl
# stl_path = "roughness/"+"basic_excitation"+".stl"  


#radius is the radius of the sphere from the ions location to generate a finer
#electrode mesh
radius= 500e-3
#'area' is the area of the triangles inside the sphere
area = 1e-4
# file = 'mit_charge'
# file = 'htrap_cutout_overhang_taper_2'
# file_out = 'htrap_cutout_overhang_taper_el3'
# stl_path = 'inter_results/taper_overhang/'+file+'.stl'
# fout_name = 'inter_results/taper_overhang/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


file_out = 'htrap_cutout_el2'
stl_path = 'inter_results/htrap_cutout/htrap_cutout.stl'
fout_name = 'inter_results/htrap_cutout/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


module_path = os.path.abspath('')


s_nta = stl.read_stl(open(stl_path, "rb"))

# %% [markdown]
# Firstly, we print all the colors appear in the stl file. If a color is of standard colors in `bemCol.adsklib` or named manually by function `bemCol.set_my_color()`, then the color will appear in a straightforward name, such as `bem0`,`bem1` ...... . Otherwise, the color will simply be named as `'_unkCol0'` , `'_unkCol1'`, ...
#
# notes
# * try to comment out the line of `ele_col.set_my_color()` in the following block, name `'_unkCol0'` will appear.

# %%
ele_col = bemColors(np.array(list(set(s_nta[2]))),('fusion360','export_stl'))
ele_col.set_my_color(value = (178,178,178),cl_format = ('fusion360','export_stl','RGBA64'),name = 'self_defined')
ele_col.print_stl_colors()
# Out:
# COLORS in the stl:
# ['bem6']
# ['bem13']
# ['bem19']
# ['bem11']
# ['bem17']
# ['bem15']
# ['bem30']
# ['bem1']
# ['bem12']
# ['bem5']
# ['bem25']
# ['bem18']
# ['bem16']
# ['bem3']
# ['bem7']
# ['bem9']
# ['bem2']
# ['bem4']
# ['bem20']
# ['bem10']
# ['bem14']
# ['bem8']
# ['bem21']
# ['_unkColor0']
# TOTAL COLORS:  24

# %% [markdown]
# Next, you need to assign a name for each color that appeared above. With standard colors defined in `bemCol.adsklib`, the correspondence between color and electrode is clear, which make it easy for this step. You can also comment out some `ele_col.set_color_name()`, run all the codes again and observe the missing part in the printed figure, which corresponds to the electrode you comment out. The second method also serves as a double check. Besides, parameter in `stl.stl_to_mesh()` can be set as `quiet = False` to check whether the program reads planes correctly.

# %%
# assign a name for each color
# taper htrap_cutout 2022
# assign a name for each color

# In od[key] = value, key is the color from the Fusion360 color library we made
# value assigns a specific name to that color in this program. 
# In future version, we may want to consider getting rid of this step for simplification
# then you just assign the color in fusion 360 and be done with it. The only concern there is you
from collections import OrderedDict
od = OrderedDict()
od['bem1']='DC1'
od['bem2']='DC2'
od['bem3']='DC3'
od['bem4']='DC4'
od['bem5']='DC5'
od['bem6']='DC6'
od['bem7']='DC7'
od['bem8']='DC8'
od['bem9']='DC9'
od['bem10']='DC10'
od['bem11']='DC11'
od['bem12']='DC12'
od['bem13']='DC13'
od['bem14']='DC14'
od['bem15']='DC15'
od['bem16']='DC16'
od['bem17']='DC17'
od['bem18']='DC18'
od['bem19']='DC19'
od['bem20']='DC20'
od['bem21'] = 'DC21'
od['bem25'] = 'RF'
od['bem30'] = 'gnd'
for key in list(od.keys()):
    ele_col.color_electrode(color=key,name=od[key])

# print colors still with no name. These meshes will be neglected in the code below. 
ele_col.drop_colors()

# read stl into mesh with electrode names
# unnamed meshes will not be imported at all

mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=1,
    rename=ele_col.electrode_colors, quiet=True))
# Out:
# dropping color ['_unkColor0']
# TOTAL COLORS DROPPED:  1
# dropping 20083

# %% [markdown]
# ## (3) remesh
#
# In this step, we generate triangle mesh with constraints. The meshes are 2-dimensional triangles on the surface of electrodes. The region enclosed by constraint shape can have finer mesh. Triangulation is done by `triangle` C library. Folowing variables are all in unit `mesh_unit` now.
#
# Our remesh strategy consists of two steps of triangulation:
# 1. global triangulation without constraint. This step eliminate some long and sharp triangles by combining and dividing, and obtains a coarse grain triangulated model.
# 2. local triangulation with constraint. This step refines each triangles in step 1, the triangle density is defined by `mesh.areas_from_constraints
#
# parameters in the below code block should be tuned specificly for different trap geometries.`

# %%
# here we define a spherical constriant zone:
# xl = 270*1e-3
# yl = -3.5*1e-3
# zl = 72.5*1e-3

#here is the location that will be the reference point for further meshing
#usually, this is the ion's location, specified in appropriate units (usually millimeters)
zl = -450*1e-3
yl = 75*1e-3
xl = 3.75*1e-3


mesh.triangulate(opts="",new = False)

# for z in np.arange(-400e-3,700e-3,100e-3):
print('first triangulation:')
# for z in np.arange(-200e-3, 200e-3, 50e-3):
rad = radius*3
inside=area*30
outside=1
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="a2Q",new = False)

# # what happened to this feature (Box)? is this on bem savio?
# # mesh.areas_from_constraints(Box(start=-0.5, end= 0.5,inside=inside, outside=outside))



# areas_from_constraints specifies sphere with finer mesh inside it.
#  "inside", "outside" set different mesh densities. 
print('second triangulation:')
rad =radius
inside=area*2
outside=1e4
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="q5Q",new = False)

# save base mesh to a pickle file
# with open(fout_name,'wb') as f:
#     data = (mesh_unit,
#             xl,
#             yl,
#             zl,
#             mesh,
#             list(od.values()))
#     pickle.dump(data,f)
# Out:
# start triangulate RF
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate RF
# start triangulate DC21
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC21
# start triangulate DC2
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC2
# start triangulate DC7
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC7
# start triangulate DC11
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC11
# start triangulate DC12
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC12
# start triangulate DC13
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC13
# start triangulate DC14
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC14
# start triangulate DC15
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC15
# start triangulate DC16
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC16
# start triangulate DC17
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC17
# start triangulate DC18
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC18
# start triangulate DC19
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC19
# start triangulate DC20
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC20
# start triangulate gnd
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate gnd
# start triangulate DC1
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC1
# start triangulate DC3
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC3
# start triangulate DC4
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC4
# start triangulate DC5
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC5
# start triangulate DC6
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC6
# start triangulate DC8
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC8
# start triangulate DC9
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC9
# start triangulate DC10
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC10
# first triangulation:
# start triangulate RF
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate RF
# start triangulate DC21
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC10
# second triangulation:
# start triangulate RF
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate RF
# start triangulate DC21
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC10
# Mesh([('RF',
#        [<bem.triangulation.Triangulation at 0x1fe44181b20>,
#         <bem.triangulation.Triangulation at 0x1fe4417c970>,
#         <bem.triangulation.Triangulation at 0x1fe4417c310>,
#         <bem.triangulation.Triangulation at 0x1fe4417cb80>,
#         <bem.triangulation.Triangulation at 0x1fe4417cdf0>,
#         <bem.triangulation.Triangulation at 0x1fe25a43fa0>,
#         <bem.triangulation.Triangulation at 0x1fe25a556a0>,
#         <bem.triangulation.Triangulation at 0x1fe25a555e0>,
#         <bem.triangulation.Triangulation at 0x1fe25a55520>,
#         <bem.triangulation.Triangulation at 0x1fe25a55460>,
#         <bem.triangulation.Triangulation at 0x1fe25a553a0>,
#         <bem.triangulation.Triangulation at 0x1fe25a552e0>,
#         <bem.triangulation.Triangulation at 0x1fe25a55220>,
#         <bem.triangulation.Triangulation at 0x1fe25a5a8e0>,
#         <bem.triangulation.Triangulation at 0x1fe25a5a820>,
#         <bem.triangulation.Triangulation at 0x1fe25a5a760>,
#         <bem.triangulation.Triangulation at 0x1fe25a5a6a0>]),
#       ('DC21',
#        [<bem.triangulation.Triangulation at 0x1fe25a5a5e0>,
#         <bem.triangulation.Triangulation at 0x1fe25a5a520>,
#         <bem.triangulation.Triangulation at 0x1fe25a5a460>,
#         <bem.triangulation.Triangulation at 0x1fe25a5a3a0>,
#         <bem.triangulation.Triangulation at 0x1fe25a5a2e0>,
#         <bem.triangulation.Triangulation at 0x1fe25a5a220>,
#         <bem.triangulation.Triangulation at 0x1fe25a5a160>]),
#       ('DC2',
#        [<bem.triangulation.Triangulation at 0x1fe25a5ae80>,
#         <bem.triangulation.Triangulation at 0x1fe25a5af40>,
#         <bem.triangulation.Triangulation at 0x1fe25a5a0a0>,
#         <bem.triangulation.Triangulation at 0x1fe25be3070>,
#         <bem.triangulation.Triangulation at 0x1fe25be3130>,
#         <bem.triangulation.Triangulation at 0x1fe25be31f0>,
#         <bem.triangulation.Triangulation at 0x1fe25be32b0>,
#         <bem.triangulation.Triangulation at 0x1fe25be3370>,
#         <bem.triangulation.Triangulation at 0x1fe25be3430>,
#         <bem.triangulation.Triangulation at 0x1fe25be34f0>,
#         <bem.triangulation.Triangulation at 0x1fe25be35b0>,
#         <bem.triangulation.Triangulation at 0x1fe25be3670>,
#         <bem.triangulation.Triangulation at 0x1fe25be3730>]),
#       ('DC7',
#        [<bem.triangulation.Triangulation at 0x1fe25be37f0>,
#         <bem.triangulation.Triangulation at 0x1fe25be38b0>,
#         <bem.triangulation.Triangulation at 0x1fe25be3970>,
#         <bem.triangulation.Triangulation at 0x1fe25be3a30>,
#         <bem.triangulation.Triangulation at 0x1fe25be3af0>,
#         <bem.triangulation.Triangulation at 0x1fe25be3bb0>,
#         <bem.triangulation.Triangulation at 0x1fe25be3c70>,
#         <bem.triangulation.Triangulation at 0x1fe25be3d30>,
#         <bem.triangulation.Triangulation at 0x1fe25be3df0>,
#         <bem.triangulation.Triangulation at 0x1fe25be3eb0>,
#         <bem.triangulation.Triangulation at 0x1fe25be3f70>,
#         <bem.triangulation.Triangulation at 0x1fe25c00070>,
#         <bem.triangulation.Triangulation at 0x1fe25c00130>]),
#       ('DC11',
#        [<bem.triangulation.Triangulation at 0x1fe25c001f0>,
#         <bem.triangulation.Triangulation at 0x1fe25c002b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c00370>,
#         <bem.triangulation.Triangulation at 0x1fe25c00430>,
#         <bem.triangulation.Triangulation at 0x1fe25c004f0>,
#         <bem.triangulation.Triangulation at 0x1fe25c005b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c00670>,
#         <bem.triangulation.Triangulation at 0x1fe25c00730>,
#         <bem.triangulation.Triangulation at 0x1fe25c007f0>,
#         <bem.triangulation.Triangulation at 0x1fe25c008b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c00970>,
#         <bem.triangulation.Triangulation at 0x1fe25c00a30>,
#         <bem.triangulation.Triangulation at 0x1fe25c00af0>,
#         <bem.triangulation.Triangulation at 0x1fe25c00bb0>]),
#       ('DC12',
#        [<bem.triangulation.Triangulation at 0x1fe25c00c70>,
#         <bem.triangulation.Triangulation at 0x1fe25c00d30>,
#         <bem.triangulation.Triangulation at 0x1fe25c00df0>,
#         <bem.triangulation.Triangulation at 0x1fe25c00eb0>,
#         <bem.triangulation.Triangulation at 0x1fe25c00f70>,
#         <bem.triangulation.Triangulation at 0x1fe25c06070>,
#         <bem.triangulation.Triangulation at 0x1fe25c06130>,
#         <bem.triangulation.Triangulation at 0x1fe25c061f0>,
#         <bem.triangulation.Triangulation at 0x1fe25c062b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c06370>,
#         <bem.triangulation.Triangulation at 0x1fe25c06430>,
#         <bem.triangulation.Triangulation at 0x1fe25c064f0>,
#         <bem.triangulation.Triangulation at 0x1fe25c065b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c06670>]),
#       ('DC13',
#        [<bem.triangulation.Triangulation at 0x1fe25c06730>,
#         <bem.triangulation.Triangulation at 0x1fe25c067f0>,
#         <bem.triangulation.Triangulation at 0x1fe25c068b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c06970>,
#         <bem.triangulation.Triangulation at 0x1fe25c06a30>,
#         <bem.triangulation.Triangulation at 0x1fe25c06af0>,
#         <bem.triangulation.Triangulation at 0x1fe25c06bb0>,
#         <bem.triangulation.Triangulation at 0x1fe25c06c70>,
#         <bem.triangulation.Triangulation at 0x1fe25c06d30>,
#         <bem.triangulation.Triangulation at 0x1fe25c06df0>,
#         <bem.triangulation.Triangulation at 0x1fe25c06eb0>,
#         <bem.triangulation.Triangulation at 0x1fe25c06f70>,
#         <bem.triangulation.Triangulation at 0x1fe25c0b070>]),
#       ('DC14',
#        [<bem.triangulation.Triangulation at 0x1fe25c0b130>,
#         <bem.triangulation.Triangulation at 0x1fe25c0b1f0>,
#         <bem.triangulation.Triangulation at 0x1fe25c0b2b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c0b370>,
#         <bem.triangulation.Triangulation at 0x1fe25c0b430>,
#         <bem.triangulation.Triangulation at 0x1fe25c0b4f0>,
#         <bem.triangulation.Triangulation at 0x1fe25c0b5b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c0b670>,
#         <bem.triangulation.Triangulation at 0x1fe25c0b730>,
#         <bem.triangulation.Triangulation at 0x1fe25c0b7f0>,
#         <bem.triangulation.Triangulation at 0x1fe25c0b8b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c0b970>,
#         <bem.triangulation.Triangulation at 0x1fe25c0ba30>]),
#       ('DC15',
#        [<bem.triangulation.Triangulation at 0x1fe25c0baf0>,
#         <bem.triangulation.Triangulation at 0x1fe25c0bbb0>,
#         <bem.triangulation.Triangulation at 0x1fe25c0bc70>,
#         <bem.triangulation.Triangulation at 0x1fe25c0bd30>,
#         <bem.triangulation.Triangulation at 0x1fe25c0bdf0>,
#         <bem.triangulation.Triangulation at 0x1fe25c0beb0>,
#         <bem.triangulation.Triangulation at 0x1fe25c0bf70>,
#         <bem.triangulation.Triangulation at 0x1fe25c10070>,
#         <bem.triangulation.Triangulation at 0x1fe25c10130>,
#         <bem.triangulation.Triangulation at 0x1fe25c101f0>,
#         <bem.triangulation.Triangulation at 0x1fe25c102b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c10370>,
#         <bem.triangulation.Triangulation at 0x1fe25c10430>]),
#       ('DC16',
#        [<bem.triangulation.Triangulation at 0x1fe25c104f0>,
#         <bem.triangulation.Triangulation at 0x1fe25c105b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c10670>,
#         <bem.triangulation.Triangulation at 0x1fe25c10730>,
#         <bem.triangulation.Triangulation at 0x1fe25c10820>,
#         <bem.triangulation.Triangulation at 0x1fe25c108b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c10970>,
#         <bem.triangulation.Triangulation at 0x1fe25c10a30>,
#         <bem.triangulation.Triangulation at 0x1fe25c10af0>,
#         <bem.triangulation.Triangulation at 0x1fe25c10bb0>,
#         <bem.triangulation.Triangulation at 0x1fe25c10c70>,
#         <bem.triangulation.Triangulation at 0x1fe25c10d30>,
#         <bem.triangulation.Triangulation at 0x1fe25c10df0>]),
#       ('DC17',
#        [<bem.triangulation.Triangulation at 0x1fe25c10eb0>,
#         <bem.triangulation.Triangulation at 0x1fe25c10f70>,
#         <bem.triangulation.Triangulation at 0x1fe25c15070>,
#         <bem.triangulation.Triangulation at 0x1fe25c15130>,
#         <bem.triangulation.Triangulation at 0x1fe25c151f0>,
#         <bem.triangulation.Triangulation at 0x1fe25c152b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c15370>,
#         <bem.triangulation.Triangulation at 0x1fe25c15430>,
#         <bem.triangulation.Triangulation at 0x1fe25c154f0>,
#         <bem.triangulation.Triangulation at 0x1fe25c155b0>,
#         <bem.triangulation.Triangulation at 0x1fe25c15670>,
#         <bem.triangulation.Triangulation at 0x1fe25c15730>,
#         <bem.triangulation.Triangulation at 0x1fe25c157f0>]),
#       ('DC18',
#        [<bem.triangulation.Triangulation at 0x1fe25c158b0>,
# ...
#         <bem.triangulation.Triangulation at 0x1fe25a7c5b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a7c670>,
#         <bem.triangulation.Triangulation at 0x1fe25a7c730>,
#         <bem.triangulation.Triangulation at 0x1fe25a7c7f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a7c8b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a7c970>,
#         <bem.triangulation.Triangulation at 0x1fe25a7ca30>,
#         <bem.triangulation.Triangulation at 0x1fe25a7caf0>,
#         <bem.triangulation.Triangulation at 0x1fe25a7cbb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a7cc70>,
#         <bem.triangulation.Triangulation at 0x1fe25a7cd30>,
#         <bem.triangulation.Triangulation at 0x1fe25a7cdf0>,
#         <bem.triangulation.Triangulation at 0x1fe25a7ceb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a7cf70>,
#         <bem.triangulation.Triangulation at 0x1fe25a81070>,
#         <bem.triangulation.Triangulation at 0x1fe25a81130>,
#         <bem.triangulation.Triangulation at 0x1fe25a811f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a812b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a81370>,
#         <bem.triangulation.Triangulation at 0x1fe25a81430>,
#         <bem.triangulation.Triangulation at 0x1fe25a814f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a815b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a81670>,
#         <bem.triangulation.Triangulation at 0x1fe25a81730>,
#         <bem.triangulation.Triangulation at 0x1fe25a817f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a818b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a81970>,
#         <bem.triangulation.Triangulation at 0x1fe25a81a30>,
#         <bem.triangulation.Triangulation at 0x1fe25a81af0>,
#         <bem.triangulation.Triangulation at 0x1fe25a81bb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a81c70>,
#         <bem.triangulation.Triangulation at 0x1fe25a81d30>,
#         <bem.triangulation.Triangulation at 0x1fe25a81df0>,
#         <bem.triangulation.Triangulation at 0x1fe25a81eb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a81f70>,
#         <bem.triangulation.Triangulation at 0x1fe25a86070>,
#         <bem.triangulation.Triangulation at 0x1fe25a86130>,
#         <bem.triangulation.Triangulation at 0x1fe25a861f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a862b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a86370>,
#         <bem.triangulation.Triangulation at 0x1fe25a86430>,
#         <bem.triangulation.Triangulation at 0x1fe25a864f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a865b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a86670>,
#         <bem.triangulation.Triangulation at 0x1fe25a86730>,
#         <bem.triangulation.Triangulation at 0x1fe25a867f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a868b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a86970>,
#         <bem.triangulation.Triangulation at 0x1fe25a86a30>,
#         <bem.triangulation.Triangulation at 0x1fe25a86af0>,
#         <bem.triangulation.Triangulation at 0x1fe25a86bb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a86c70>,
#         <bem.triangulation.Triangulation at 0x1fe25a86d30>,
#         <bem.triangulation.Triangulation at 0x1fe25a86df0>,
#         <bem.triangulation.Triangulation at 0x1fe25a86eb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a86f70>,
#         <bem.triangulation.Triangulation at 0x1fe25a8b070>,
#         <bem.triangulation.Triangulation at 0x1fe25a8b130>,
#         <bem.triangulation.Triangulation at 0x1fe25a8b1f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a8b2b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a8b370>,
#         <bem.triangulation.Triangulation at 0x1fe25a8b430>,
#         <bem.triangulation.Triangulation at 0x1fe25a8b4f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a8b5b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a8b670>,
#         <bem.triangulation.Triangulation at 0x1fe25a8b730>,
#         <bem.triangulation.Triangulation at 0x1fe25a8b7f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a8b8b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a8b970>,
#         <bem.triangulation.Triangulation at 0x1fe25a8ba30>,
#         <bem.triangulation.Triangulation at 0x1fe25a8baf0>,
#         <bem.triangulation.Triangulation at 0x1fe25a8bbb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a8bc70>,
#         <bem.triangulation.Triangulation at 0x1fe25a8bd30>,
#         <bem.triangulation.Triangulation at 0x1fe25a8bdf0>,
#         <bem.triangulation.Triangulation at 0x1fe25a8beb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a8bf70>,
#         <bem.triangulation.Triangulation at 0x1fe25a90070>,
#         <bem.triangulation.Triangulation at 0x1fe25a90130>,
#         <bem.triangulation.Triangulation at 0x1fe25a901f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a902b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a90370>,
#         <bem.triangulation.Triangulation at 0x1fe25a90430>,
#         <bem.triangulation.Triangulation at 0x1fe25a904f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a90610>,
#         <bem.triangulation.Triangulation at 0x1fe25a90670>,
#         <bem.triangulation.Triangulation at 0x1fe25a90730>,
#         <bem.triangulation.Triangulation at 0x1fe25a907f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a908b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a90970>,
#         <bem.triangulation.Triangulation at 0x1fe25a90a30>,
#         <bem.triangulation.Triangulation at 0x1fe25a90af0>,
#         <bem.triangulation.Triangulation at 0x1fe25a90bb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a90c70>,
#         <bem.triangulation.Triangulation at 0x1fe25a90d30>,
#         <bem.triangulation.Triangulation at 0x1fe25a90df0>,
#         <bem.triangulation.Triangulation at 0x1fe25a90eb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a90f70>,
#         <bem.triangulation.Triangulation at 0x1fe25a95070>,
#         <bem.triangulation.Triangulation at 0x1fe25a95130>,
#         <bem.triangulation.Triangulation at 0x1fe25a951f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a952b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a95370>,
#         <bem.triangulation.Triangulation at 0x1fe25a95430>,
#         <bem.triangulation.Triangulation at 0x1fe25a954f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a955b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a95670>,
#         <bem.triangulation.Triangulation at 0x1fe25a95730>,
#         <bem.triangulation.Triangulation at 0x1fe25a957f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a958b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a95970>,
#         <bem.triangulation.Triangulation at 0x1fe25a95a30>,
#         <bem.triangulation.Triangulation at 0x1fe25a95af0>,
#         <bem.triangulation.Triangulation at 0x1fe25a95bb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a95c70>,
#         <bem.triangulation.Triangulation at 0x1fe25a95d30>,
#         <bem.triangulation.Triangulation at 0x1fe25a95df0>,
#         <bem.triangulation.Triangulation at 0x1fe25a95eb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a95f70>,
#         <bem.triangulation.Triangulation at 0x1fe25a9a070>,
#         <bem.triangulation.Triangulation at 0x1fe25a9a130>,
#         <bem.triangulation.Triangulation at 0x1fe25a9a1f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9a2b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9a370>,
#         <bem.triangulation.Triangulation at 0x1fe25a9a430>,
#         <bem.triangulation.Triangulation at 0x1fe25a9a4f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9a5b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9a670>,
#         <bem.triangulation.Triangulation at 0x1fe25a9a730>,
#         <bem.triangulation.Triangulation at 0x1fe25a9a7f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9a8b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9a970>,
#         <bem.triangulation.Triangulation at 0x1fe25a9aa30>,
#         <bem.triangulation.Triangulation at 0x1fe25a9aaf0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9abb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9ac70>,
#         <bem.triangulation.Triangulation at 0x1fe25a9ad30>,
#         <bem.triangulation.Triangulation at 0x1fe25a9adf0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9aeb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9af70>,
#         <bem.triangulation.Triangulation at 0x1fe25a9f070>,
#         <bem.triangulation.Triangulation at 0x1fe25a9f130>,
#         <bem.triangulation.Triangulation at 0x1fe25a9f1f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9f2b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9f370>,
#         <bem.triangulation.Triangulation at 0x1fe25a9f430>,
#         <bem.triangulation.Triangulation at 0x1fe25a9f4f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9f5b0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9f670>,
#         <bem.triangulation.Triangulation at 0x1fe25a9f730>,
#         <bem.triangulation.Triangulation at 0x1fe25a9f7f0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9f8b0>]),
#       ('DC1',
#        [<bem.triangulation.Triangulation at 0x1fe25a9f970>,
#         <bem.triangulation.Triangulation at 0x1fe25a9fa30>,
#         <bem.triangulation.Triangulation at 0x1fe25a9faf0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9fbb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9fc70>,
#         <bem.triangulation.Triangulation at 0x1fe25a9fd30>,
#         <bem.triangulation.Triangulation at 0x1fe25a9fdf0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9feb0>,
#         <bem.triangulation.Triangulation at 0x1fe25a9ff70>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8070>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8130>,
#         <bem.triangulation.Triangulation at 0x1fe25ba81f0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba82b0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8370>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8430>,
#         <bem.triangulation.Triangulation at 0x1fe25ba84f0>]),
#       ('DC3',
#        [<bem.triangulation.Triangulation at 0x1fe25ba85b0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8670>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8730>,
#         <bem.triangulation.Triangulation at 0x1fe25ba87f0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba88b0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8970>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8a30>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8af0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8bb0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8c70>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8d30>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8df0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8eb0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba8f70>]),
#       ('DC4',
#        [<bem.triangulation.Triangulation at 0x1fe25bc0070>,
#         <bem.triangulation.Triangulation at 0x1fe25bc0130>,
#         <bem.triangulation.Triangulation at 0x1fe25bc01f0>,
#         <bem.triangulation.Triangulation at 0x1fe25bc02b0>,
#         <bem.triangulation.Triangulation at 0x1fe25bc0370>,
#         <bem.triangulation.Triangulation at 0x1fe25bc0430>,
#         <bem.triangulation.Triangulation at 0x1fe25bc04f0>,
#         <bem.triangulation.Triangulation at 0x1fe25bc05b0>,
#         <bem.triangulation.Triangulation at 0x1fe25bc0670>,
#         <bem.triangulation.Triangulation at 0x1fe25bc0730>,
#         <bem.triangulation.Triangulation at 0x1fe25bc07f0>,
#         <bem.triangulation.Triangulation at 0x1fe25bc08b0>,
#         <bem.triangulation.Triangulation at 0x1fe25bc0970>,
#         <bem.triangulation.Triangulation at 0x1fe25bc0a30>,
#         <bem.triangulation.Triangulation at 0x1fe25bc0af0>]),
#       ('DC5',
#        [<bem.triangulation.Triangulation at 0x1fe25bc0bb0>,
#         <bem.triangulation.Triangulation at 0x1fe25bc0c70>,
#         <bem.triangulation.Triangulation at 0x1fe25bc0d30>,
#         <bem.triangulation.Triangulation at 0x1fe25bc0df0>,
#         <bem.triangulation.Triangulation at 0x1fe25bc0eb0>,
#         <bem.triangulation.Triangulation at 0x1fe25bc0f70>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0070>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0130>,
#         <bem.triangulation.Triangulation at 0x1fe25ba01f0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba02b0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0370>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0430>,
#         <bem.triangulation.Triangulation at 0x1fe25ba04f0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba05b0>]),
#       ('DC6',
#        [<bem.triangulation.Triangulation at 0x1fe25ba0670>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0730>,
#         <bem.triangulation.Triangulation at 0x1fe25ba07f0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba08b0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0970>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0a30>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0af0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0bb0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0c70>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0d30>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0df0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0eb0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba0fd0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba5070>]),
#       ('DC8',
#        [<bem.triangulation.Triangulation at 0x1fe25ba5130>,
#         <bem.triangulation.Triangulation at 0x1fe25ba51f0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba52b0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba5370>,
#         <bem.triangulation.Triangulation at 0x1fe25ba5430>,
#         <bem.triangulation.Triangulation at 0x1fe25ba54f0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba55b0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba5670>,
#         <bem.triangulation.Triangulation at 0x1fe25ba5730>,
#         <bem.triangulation.Triangulation at 0x1fe25ba57f0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba58b0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba5970>,
#         <bem.triangulation.Triangulation at 0x1fe25ba5a30>,
#         <bem.triangulation.Triangulation at 0x1fe25ba5af0>]),
#       ('DC9',
#        [<bem.triangulation.Triangulation at 0x1fe25ba5bb0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba5c70>,
#         <bem.triangulation.Triangulation at 0x1fe25ba5d30>,
#         <bem.triangulation.Triangulation at 0x1fe25ba5df0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba5eb0>,
#         <bem.triangulation.Triangulation at 0x1fe25ba5f70>,
#         <bem.triangulation.Triangulation at 0x1fe25bac070>,
#         <bem.triangulation.Triangulation at 0x1fe25bac130>,
#         <bem.triangulation.Triangulation at 0x1fe25bac1f0>,
#         <bem.triangulation.Triangulation at 0x1fe25bac2b0>,
#         <bem.triangulation.Triangulation at 0x1fe25bac370>,
#         <bem.triangulation.Triangulation at 0x1fe25bac430>,
#         <bem.triangulation.Triangulation at 0x1fe25bac4f0>,
#         <bem.triangulation.Triangulation at 0x1fe25bac5b0>]),
#       ('DC10',
#        [<bem.triangulation.Triangulation at 0x1fe25bac670>,
#         <bem.triangulation.Triangulation at 0x1fe25bac730>,
#         <bem.triangulation.Triangulation at 0x1fe25bac7f0>,
#         <bem.triangulation.Triangulation at 0x1fe25bac8b0>,
#         <bem.triangulation.Triangulation at 0x1fe25bac970>,
#         <bem.triangulation.Triangulation at 0x1fe25baca30>,
#         <bem.triangulation.Triangulation at 0x1fe25bacaf0>,
#         <bem.triangulation.Triangulation at 0x1fe25bacbb0>,
#         <bem.triangulation.Triangulation at 0x1fe25bacc70>,
#         <bem.triangulation.Triangulation at 0x1fe25bacd30>,
#         <bem.triangulation.Triangulation at 0x1fe25bacdf0>])])

# %%
# save base mesh to a pickle file
with open(fout_name,'wb') as f:
    data = (mesh_unit,
            xl,
            yl,
            zl,
            mesh,
            list(od.values()))
    pickle.dump(data,f)

# %% [markdown]
# ## view mesh
# Uses Pyvista package to generate interactive 3-d plot of the mesh

# %%
# Plot triangle mezshes of the final mesh
mesh.plot()

# %% [markdown]
# Show number of points included in the mesh

# %%
print(len(mesh.points))
# Out:
# 8692
