# %% [markdown]
# # `Documention & Tutorial`
# This BEM package is used for for numerical simulation of the electric field of ion traps in python. Some external packages are wrapped into it:
#
# * fast triangulation (http://www.cs.cmu.edu/~quake/triangle.research.html)
# * fastlap boundary element method (Nabors K S. Efficient three-dimensional capacitance calculation[D]. Massachusetts Institute of Technology, 1993.)
#
# This document, also as a tutorial, explains how to use these packages to compute the electric field and compute its multipole expansion coefficient starting from scratch with a fusion 360 trap model(take `./f3d/htrap_cutout_overhang_9x5mm.f3d` for example). Our document consists of three .ipynb files:
#
# * `I_Mesh_Processing.ipynb`
# * `II_Field_Simulation.ipynb`
# * `III_Multipole_Expansion.ipynb`
#
# We split the document into three files for two reasons:
# 1. The most time consuming part `II_Field_Simulation.ipynb` could be taken out alone and run on a high peformance computer.
# 2. The intermediate result between files can be checked- 'intermediate files' refer to the inital mesh grid (that corresponds to the charge distribution), the simulation values and the simulation coordinates, all of which are saved in the inter_results folder. So if the voltage solution files for the trap don't make sense, it is possible to go back through saved data to see where things have gone wrong.
# Here are the three jupyter notebooks and what:
# 1. I_Mesh_Processing- this notebook generates a mesh of the trap, saved in inter_results as a .pkl file
#
#
# Going through three files in order and running their python code will help you understand our workflow. Generally our workflow divides into three steps, corresponding to the above three .ipynb files. First, in I_Mesh_Processing, we identify different electrodes of the trap model by different colors. Also, we refine the trap model meshes to prepare for the second step. The result is stored in `mesh_result.pkl`.
#
# Secondly, in II_Field_Simulation, we simulate the electric potential with fastlap boundary element method(FMM), the accuracy of this step depends on the mesh size in the first step. The result is stored in `field_result.pkl`.
#
# Thirdly, in III_Multipole_Expansion, we analyze the electric field and electric potential. This notebook generates the multipole coefficients of the fields and potentials for each electrode and uses that information to generate a solution file with the function call `write_csv`. If your solution don't make sense, a good place to start is to insure that the mesh you are using is fine enough (generate several field results for different meshes)- if the potentials and fields are converging to specific values, this suggests there is something wrong with the multipole expansion. If you start with multipole expansion, you do not know if it is a problem with the expansion or with the field.
#
# Before running codes, you must set up the environment according to instructions in `README`
#
# notes
# * Our workflow, as indicated by this document, abandons mayavi(with its embeded package tvtk). But we reserve mayavi in our Bem source code, if you want to use mayavi related functions, you must set up environment with files in`./backup/setup_with_mayavi`, just replace corresponding files in the root folder with them and set up.
#     * why we abandon mayavi: because its python interface(with its dependence vtk and PyQt5) requires complex package dependencies and version controls especially for new python versions. This makes it difficult to maintain this project.
#     * why we still keep mayavi in the source code? Because it is rooted in our source code deeply. We can just avoid invoking related functions instead of deleting them, because they may make sense in the future.

# %% [markdown]
# # `I. Mesh Processing`
# This .pynb file reads a colored model file `./inter_results/htrap_cutout.stl`, and assigns a name for each color(thus for each electrode). The result is stored in `./inter_results/mesh_result.pkl`.
#
# In this file we name different electrodes and refine the meshes. The size of mesh determines the accuracy in next step. You should set the mesh finer and finer until the result converges. Also, you can set the mesh finer and test the convergence.
#
# ## (1) color your electrodes (in fusion 360) and export stl
# First of all, you have a trap model in fusion 360 project, for example, `./f3d/htrap_cutout_overhang_9x5mm.f3d`. Here we use different color to identify different electrodes(STL file stores color for each mesh). In fusion 360, you can assign different appearance for different electrodes. We recommend to use ../../bemCol_lib/bemCol.adsklib for different electrodes. Same color for two electrodes means they are treated as the same electrode. Then we get `./f3d/htrap_cutout_overhang_9x5mm_my_colored.f3d`
#
# Then export to an stl file in fusion360 file>export tab and move the file in `./inter_results`. We export our stl in mm, so we set the mesh unit to mm.

# %% [markdown]
# Furthurmore, it's our convention to use unit mm in our traps. e.g. [Electric field] = V/mm , [harmonic confining potential] = V/mm^2.so we set

# %%
# this is the unit for our Mesh structure
# in the following code, this is the default unit for python variables
#units 
mesh_unit = 1e-3

# %% [markdown]
# Additional notes (from Wenhao):
# * Why use standard color? We define a set of standard color lib `../../../bemCol_lib/bemCol.adsklib` for two reasons: 1. when exporting to .stl file, fusion 360 will compress 0-256 color(RGBA32) into 0-32 color(RGBA16), which means that some similar colors in fusion 360 will become same color after export to .stl file. Our standard color lib avoid this problem. 2.If you use .stl file exported from fusion 360 DIRECTLY, naming the electrodes would be very convinient. If you use other apps such as Inventor or Meshlab to generate .stl file, you can ignore the second reason because color encoding are quite different in different apps

# %% [markdown]
# ## (2) assign a name for each color

# %%
import pickle
import numpy as np
import matplotlib as mpl
import sys
from utils.helper_functions import *
from bem.bemColors_lib.bemColors import bemColors
from bem import Electrodes, Sphere, Mesh, Grid, Configuration, Result, Box
# load stl geometry file
from bem.formats import stl
# stl_path = "roughness/"+"basic_excitation"+".stl"  


#radius is the radius of the sphere from the ions location to generate a finer
#electrode mesh
radius= 500e-3
#'area' is the area of the triangles inside the sphere
area = 1e-4
# file = 'mit_charge'
# file = 'htrap_cutout_overhang_taper_2'
# file_out = 'htrap_cutout_overhang_taper_el3'
# stl_path = 'inter_results/taper_overhang/'+file+'.stl'
# fout_name = 'inter_results/taper_overhang/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


file_out = 'htrap_cutout_el2'
stl_path = 'inter_results/htrap_cutout/htrap_cutout.stl'
fout_name = 'inter_results/htrap_cutout/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


module_path = os.path.abspath('')


s_nta = stl.read_stl(open(stl_path, "rb"))

# %% [markdown]
# Firstly, we print all the colors appear in the stl file. If a color is of standard colors in `bemCol.adsklib` or named manually by function `bemCol.set_my_color()`, then the color will appear in a straightforward name, such as `bem0`,`bem1` ...... . Otherwise, the color will simply be named as `'_unkCol0'` , `'_unkCol1'`, ...
#
# notes
# * try to comment out the line of `ele_col.set_my_color()` in the following block, name `'_unkCol0'` will appear.

# %%
ele_col = bemColors(np.array(list(set(s_nta[2]))),('fusion360','export_stl'))
ele_col.set_my_color(value = (178,178,178),cl_format = ('fusion360','export_stl','RGBA64'),name = 'self_defined')
ele_col.print_stl_colors()
# Out:
# COLORS in the stl:
# ['bem6']
# ['bem13']
# ['bem19']
# ['bem11']
# ['bem17']
# ['bem15']
# ['bem30']
# ['bem1']
# ['bem12']
# ['bem5']
# ['bem25']
# ['bem18']
# ['bem16']
# ['bem3']
# ['bem7']
# ['bem9']
# ['bem2']
# ['bem4']
# ['bem20']
# ['bem10']
# ['bem14']
# ['bem8']
# ['bem21']
# ['_unkColor0']
# TOTAL COLORS:  24

# %% [markdown]
# Next, you need to assign a name for each color that appeared above. With standard colors defined in `bemCol.adsklib`, the correspondence between color and electrode is clear, which make it easy for this step. You can also comment out some `ele_col.set_color_name()`, run all the codes again and observe the missing part in the printed figure, which corresponds to the electrode you comment out. The second method also serves as a double check. Besides, parameter in `stl.stl_to_mesh()` can be set as `quiet = False` to check whether the program reads planes correctly.

# %%
# assign a name for each color
# taper htrap_cutout 2022
# assign a name for each color

# In od[key] = value, key is the color from the Fusion360 color library we made
# value assigns a specific name to that color in this program. 
# In future version, we may want to consider getting rid of this step for simplification
# then you just assign the color in fusion 360 and be done with it. The only concern there is you
from collections import OrderedDict
od = OrderedDict()
od['bem1']='DC1'
od['bem2']='DC2'
od['bem3']='DC3'
od['bem4']='DC4'
od['bem5']='DC5'
od['bem6']='DC6'
od['bem7']='DC7'
od['bem8']='DC8'
od['bem9']='DC9'
od['bem10']='DC10'
od['bem11']='DC11'
od['bem12']='DC12'
od['bem13']='DC13'
od['bem14']='DC14'
od['bem15']='DC15'
od['bem16']='DC16'
od['bem17']='DC17'
od['bem18']='DC18'
od['bem19']='DC19'
od['bem20']='DC20'
od['bem21'] = 'DC21'
od['bem25'] = 'RF'
od['bem30'] = 'gnd'
for key in list(od.keys()):
    ele_col.color_electrode(color=key,name=od[key])

# print colors still with no name. These meshes will be neglected in the code below. 
ele_col.drop_colors()

# read stl into mesh with electrode names
# unnamed meshes will not be imported at all

mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=1,
    rename=ele_col.electrode_colors, quiet=True))
# Out:
# dropping color ['_unkColor0']
# TOTAL COLORS DROPPED:  1
# dropping 20083

# %% [markdown]
# ## (3) remesh
#
# In this step, we generate triangle mesh with constraints. The meshes are 2-dimensional triangles on the surface of electrodes. The region enclosed by constraint shape can have finer mesh. Triangulation is done by `triangle` C library. Folowing variables are all in unit `mesh_unit` now.
#
# Our remesh strategy consists of two steps of triangulation:
# 1. global triangulation without constraint. This step eliminate some long and sharp triangles by combining and dividing, and obtains a coarse grain triangulated model.
# 2. local triangulation with constraint. This step refines each triangles in step 1, the triangle density is defined by `mesh.areas_from_constraints
#
# parameters in the below code block should be tuned specificly for different trap geometries.`

# %%
# here we define a spherical constriant zone:
# xl = 270*1e-3
# yl = -3.5*1e-3
# zl = 72.5*1e-3

#here is the location that will be the reference point for further meshing
#usually, this is the ion's location, specified in appropriate units (usually millimeters)
zl = -450*1e-3
yl = 75*1e-3
xl = 3.75*1e-3


mesh.triangulate(opts="",new = False)

# for z in np.arange(-400e-3,700e-3,100e-3):
print('first triangulation:')
# for z in np.arange(-200e-3, 200e-3, 50e-3):
rad = radius*3
inside=area*30
outside=1
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="a2Q",new = False)

# # what happened to this feature (Box)? is this on bem savio?
# # mesh.areas_from_constraints(Box(start=-0.5, end= 0.5,inside=inside, outside=outside))



# areas_from_constraints specifies sphere with finer mesh inside it.
#  "inside", "outside" set different mesh densities. 
print('second triangulation:')
rad =radius
inside=area*2
outside=1e4
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="q5Q",new = False)

# save base mesh to a pickle file
# with open(fout_name,'wb') as f:
#     data = (mesh_unit,
#             xl,
#             yl,
#             zl,
#             mesh,
#             list(od.values()))
#     pickle.dump(data,f)
# Out:
# start triangulate RF
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate RF
# start triangulate DC21
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC21
# start triangulate DC2
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC2
# start triangulate DC7
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC7
# start triangulate DC11
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC11
# start triangulate DC12
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC12
# start triangulate DC13
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC13
# start triangulate DC14
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC14
# start triangulate DC15
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC15
# start triangulate DC16
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC16
# start triangulate DC17
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC17
# start triangulate DC18
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC18
# start triangulate DC19
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC19
# start triangulate DC20
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC20
# start triangulate gnd
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate gnd
# start triangulate DC1
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC1
# start triangulate DC3
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC3
# start triangulate DC4
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC4
# start triangulate DC5
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC5
# start triangulate DC6
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC6
# start triangulate DC8
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC8
# start triangulate DC9
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC9
# start triangulate DC10
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC10
# first triangulation:
# start triangulate RF
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate RF
# start triangulate DC21
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC10
# second triangulation:
# start triangulate RF
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate RF
# start triangulate DC21
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC10
# Mesh([('RF',
#        [<bem.triangulation.Triangulation at 0x217cf2036d0>,
#         <bem.triangulation.Triangulation at 0x217cf1fe880>,
#         <bem.triangulation.Triangulation at 0x217cf1fe220>,
#         <bem.triangulation.Triangulation at 0x217cf1fedf0>,
#         <bem.triangulation.Triangulation at 0x217cf1fef70>,
#         <bem.triangulation.Triangulation at 0x217b0a92c40>,
#         <bem.triangulation.Triangulation at 0x217b0a92ee0>,
#         <bem.triangulation.Triangulation at 0x217b0aa5640>,
#         <bem.triangulation.Triangulation at 0x217b0aa5580>,
#         <bem.triangulation.Triangulation at 0x217b0aa54c0>,
#         <bem.triangulation.Triangulation at 0x217b0aa5400>,
#         <bem.triangulation.Triangulation at 0x217b0aa5340>,
#         <bem.triangulation.Triangulation at 0x217b0aa5280>,
#         <bem.triangulation.Triangulation at 0x217b0aac700>,
#         <bem.triangulation.Triangulation at 0x217b0aac790>,
#         <bem.triangulation.Triangulation at 0x217b0aac850>,
#         <bem.triangulation.Triangulation at 0x217b0aac910>]),
#       ('DC21',
#        [<bem.triangulation.Triangulation at 0x217b0aac9d0>,
#         <bem.triangulation.Triangulation at 0x217b0aaca90>,
#         <bem.triangulation.Triangulation at 0x217b0aacb50>,
#         <bem.triangulation.Triangulation at 0x217b0aacc10>,
#         <bem.triangulation.Triangulation at 0x217b0aaccd0>,
#         <bem.triangulation.Triangulation at 0x217b0aacd90>,
#         <bem.triangulation.Triangulation at 0x217b0aace50>]),
#       ('DC2',
#        [<bem.triangulation.Triangulation at 0x217b0aacf10>,
#         <bem.triangulation.Triangulation at 0x217b0aac130>,
#         <bem.triangulation.Triangulation at 0x217b0aac070>,
#         <bem.triangulation.Triangulation at 0x217b0c31040>,
#         <bem.triangulation.Triangulation at 0x217b0c310d0>,
#         <bem.triangulation.Triangulation at 0x217b0c31190>,
#         <bem.triangulation.Triangulation at 0x217b0c31250>,
#         <bem.triangulation.Triangulation at 0x217b0c31310>,
#         <bem.triangulation.Triangulation at 0x217b0c313d0>,
#         <bem.triangulation.Triangulation at 0x217b0c31490>,
#         <bem.triangulation.Triangulation at 0x217b0c31550>,
#         <bem.triangulation.Triangulation at 0x217b0c31610>,
#         <bem.triangulation.Triangulation at 0x217b0c316d0>]),
#       ('DC7',
#        [<bem.triangulation.Triangulation at 0x217b0c31790>,
#         <bem.triangulation.Triangulation at 0x217b0c31850>,
#         <bem.triangulation.Triangulation at 0x217b0c31910>,
#         <bem.triangulation.Triangulation at 0x217b0c319d0>,
#         <bem.triangulation.Triangulation at 0x217b0c31a90>,
#         <bem.triangulation.Triangulation at 0x217b0c31b50>,
#         <bem.triangulation.Triangulation at 0x217b0c31c10>,
#         <bem.triangulation.Triangulation at 0x217b0c31cd0>,
#         <bem.triangulation.Triangulation at 0x217b0c31d90>,
#         <bem.triangulation.Triangulation at 0x217b0c31e50>,
#         <bem.triangulation.Triangulation at 0x217b0c31f10>,
#         <bem.triangulation.Triangulation at 0x217b0c51040>,
#         <bem.triangulation.Triangulation at 0x217b0c510d0>]),
#       ('DC11',
#        [<bem.triangulation.Triangulation at 0x217b0c51190>,
#         <bem.triangulation.Triangulation at 0x217b0c51250>,
#         <bem.triangulation.Triangulation at 0x217b0c51310>,
#         <bem.triangulation.Triangulation at 0x217b0c513d0>,
#         <bem.triangulation.Triangulation at 0x217b0c51490>,
#         <bem.triangulation.Triangulation at 0x217b0c51550>,
#         <bem.triangulation.Triangulation at 0x217b0c51610>,
#         <bem.triangulation.Triangulation at 0x217b0c516d0>,
#         <bem.triangulation.Triangulation at 0x217b0c51790>,
#         <bem.triangulation.Triangulation at 0x217b0c51850>,
#         <bem.triangulation.Triangulation at 0x217b0c51910>,
#         <bem.triangulation.Triangulation at 0x217b0c519d0>,
#         <bem.triangulation.Triangulation at 0x217b0c51a90>,
#         <bem.triangulation.Triangulation at 0x217b0c51b50>]),
#       ('DC12',
#        [<bem.triangulation.Triangulation at 0x217b0c51c10>,
#         <bem.triangulation.Triangulation at 0x217b0c51cd0>,
#         <bem.triangulation.Triangulation at 0x217b0c51d90>,
#         <bem.triangulation.Triangulation at 0x217b0c51e50>,
#         <bem.triangulation.Triangulation at 0x217b0c51f10>,
#         <bem.triangulation.Triangulation at 0x217b0c56040>,
#         <bem.triangulation.Triangulation at 0x217b0c560d0>,
#         <bem.triangulation.Triangulation at 0x217b0c56190>,
#         <bem.triangulation.Triangulation at 0x217b0c56250>,
#         <bem.triangulation.Triangulation at 0x217b0c56310>,
#         <bem.triangulation.Triangulation at 0x217b0c563d0>,
#         <bem.triangulation.Triangulation at 0x217b0c56490>,
#         <bem.triangulation.Triangulation at 0x217b0c56550>,
#         <bem.triangulation.Triangulation at 0x217b0c56610>]),
#       ('DC13',
#        [<bem.triangulation.Triangulation at 0x217b0c566d0>,
#         <bem.triangulation.Triangulation at 0x217b0c56790>,
#         <bem.triangulation.Triangulation at 0x217b0c56850>,
#         <bem.triangulation.Triangulation at 0x217b0c56910>,
#         <bem.triangulation.Triangulation at 0x217b0c569d0>,
#         <bem.triangulation.Triangulation at 0x217b0c56a90>,
#         <bem.triangulation.Triangulation at 0x217b0c56b50>,
#         <bem.triangulation.Triangulation at 0x217b0c56c10>,
#         <bem.triangulation.Triangulation at 0x217b0c56cd0>,
#         <bem.triangulation.Triangulation at 0x217b0c56d90>,
#         <bem.triangulation.Triangulation at 0x217b0c56e50>,
#         <bem.triangulation.Triangulation at 0x217b0c56f10>,
#         <bem.triangulation.Triangulation at 0x217b0c5b040>]),
#       ('DC14',
#        [<bem.triangulation.Triangulation at 0x217b0c5b0d0>,
#         <bem.triangulation.Triangulation at 0x217b0c5b190>,
#         <bem.triangulation.Triangulation at 0x217b0c5b250>,
#         <bem.triangulation.Triangulation at 0x217b0c5b310>,
#         <bem.triangulation.Triangulation at 0x217b0c5b3d0>,
#         <bem.triangulation.Triangulation at 0x217b0c5b490>,
#         <bem.triangulation.Triangulation at 0x217b0c5b550>,
#         <bem.triangulation.Triangulation at 0x217b0c5b610>,
#         <bem.triangulation.Triangulation at 0x217b0c5b6d0>,
#         <bem.triangulation.Triangulation at 0x217b0c5b790>,
#         <bem.triangulation.Triangulation at 0x217b0c5b850>,
#         <bem.triangulation.Triangulation at 0x217b0c5b910>,
#         <bem.triangulation.Triangulation at 0x217b0c5b9d0>]),
#       ('DC15',
#        [<bem.triangulation.Triangulation at 0x217b0c5ba90>,
#         <bem.triangulation.Triangulation at 0x217b0c5bb50>,
#         <bem.triangulation.Triangulation at 0x217b0c5bc10>,
#         <bem.triangulation.Triangulation at 0x217b0c5bcd0>,
#         <bem.triangulation.Triangulation at 0x217b0c5bd90>,
#         <bem.triangulation.Triangulation at 0x217b0c5be50>,
#         <bem.triangulation.Triangulation at 0x217b0c5bf10>,
#         <bem.triangulation.Triangulation at 0x217b0c60040>,
#         <bem.triangulation.Triangulation at 0x217b0c600d0>,
#         <bem.triangulation.Triangulation at 0x217b0c60190>,
#         <bem.triangulation.Triangulation at 0x217b0c60250>,
#         <bem.triangulation.Triangulation at 0x217b0c60310>,
#         <bem.triangulation.Triangulation at 0x217b0c603d0>]),
#       ('DC16',
#        [<bem.triangulation.Triangulation at 0x217b0c60490>,
#         <bem.triangulation.Triangulation at 0x217b0c60550>,
#         <bem.triangulation.Triangulation at 0x217b0c60610>,
#         <bem.triangulation.Triangulation at 0x217b0c606d0>,
#         <bem.triangulation.Triangulation at 0x217b0c60790>,
#         <bem.triangulation.Triangulation at 0x217b0c60850>,
#         <bem.triangulation.Triangulation at 0x217b0c60910>,
#         <bem.triangulation.Triangulation at 0x217b0c609d0>,
#         <bem.triangulation.Triangulation at 0x217b0c60a90>,
#         <bem.triangulation.Triangulation at 0x217b0c60b50>,
#         <bem.triangulation.Triangulation at 0x217b0c60c10>,
#         <bem.triangulation.Triangulation at 0x217b0c60cd0>,
#         <bem.triangulation.Triangulation at 0x217b0c60d90>]),
#       ('DC17',
#        [<bem.triangulation.Triangulation at 0x217b0c60e50>,
#         <bem.triangulation.Triangulation at 0x217b0c60f10>,
#         <bem.triangulation.Triangulation at 0x217b0c65040>,
#         <bem.triangulation.Triangulation at 0x217b0c650d0>,
#         <bem.triangulation.Triangulation at 0x217b0c65190>,
#         <bem.triangulation.Triangulation at 0x217b0c65250>,
#         <bem.triangulation.Triangulation at 0x217b0c65310>,
#         <bem.triangulation.Triangulation at 0x217b0c653d0>,
#         <bem.triangulation.Triangulation at 0x217b0c65490>,
#         <bem.triangulation.Triangulation at 0x217b0c65550>,
#         <bem.triangulation.Triangulation at 0x217b0c65610>,
#         <bem.triangulation.Triangulation at 0x217b0c656d0>,
#         <bem.triangulation.Triangulation at 0x217b0c65790>]),
#       ('DC18',
#        [<bem.triangulation.Triangulation at 0x217b0c65850>,
# ...
#         <bem.triangulation.Triangulation at 0x217b0aca550>,
#         <bem.triangulation.Triangulation at 0x217b0aca610>,
#         <bem.triangulation.Triangulation at 0x217b0aca6d0>,
#         <bem.triangulation.Triangulation at 0x217b0aca790>,
#         <bem.triangulation.Triangulation at 0x217b0aca850>,
#         <bem.triangulation.Triangulation at 0x217b0aca910>,
#         <bem.triangulation.Triangulation at 0x217b0aca9d0>,
#         <bem.triangulation.Triangulation at 0x217b0acaa90>,
#         <bem.triangulation.Triangulation at 0x217b0acab50>,
#         <bem.triangulation.Triangulation at 0x217b0acac10>,
#         <bem.triangulation.Triangulation at 0x217b0acacd0>,
#         <bem.triangulation.Triangulation at 0x217b0acad90>,
#         <bem.triangulation.Triangulation at 0x217b0acae50>,
#         <bem.triangulation.Triangulation at 0x217b0acaf10>,
#         <bem.triangulation.Triangulation at 0x217b0acf040>,
#         <bem.triangulation.Triangulation at 0x217b0acf0d0>,
#         <bem.triangulation.Triangulation at 0x217b0acf190>,
#         <bem.triangulation.Triangulation at 0x217b0acf250>,
#         <bem.triangulation.Triangulation at 0x217b0acf310>,
#         <bem.triangulation.Triangulation at 0x217b0acf3d0>,
#         <bem.triangulation.Triangulation at 0x217b0acf490>,
#         <bem.triangulation.Triangulation at 0x217b0acf550>,
#         <bem.triangulation.Triangulation at 0x217b0acf610>,
#         <bem.triangulation.Triangulation at 0x217b0acf6d0>,
#         <bem.triangulation.Triangulation at 0x217b0acf790>,
#         <bem.triangulation.Triangulation at 0x217b0acf850>,
#         <bem.triangulation.Triangulation at 0x217b0acf910>,
#         <bem.triangulation.Triangulation at 0x217b0acf9d0>,
#         <bem.triangulation.Triangulation at 0x217b0acfa90>,
#         <bem.triangulation.Triangulation at 0x217b0acfb50>,
#         <bem.triangulation.Triangulation at 0x217b0acfc10>,
#         <bem.triangulation.Triangulation at 0x217b0acfcd0>,
#         <bem.triangulation.Triangulation at 0x217b0acfd90>,
#         <bem.triangulation.Triangulation at 0x217b0acfe50>,
#         <bem.triangulation.Triangulation at 0x217b0acff10>,
#         <bem.triangulation.Triangulation at 0x217b0ad4040>,
#         <bem.triangulation.Triangulation at 0x217b0ad40d0>,
#         <bem.triangulation.Triangulation at 0x217b0ad4190>,
#         <bem.triangulation.Triangulation at 0x217b0ad4250>,
#         <bem.triangulation.Triangulation at 0x217b0ad4310>,
#         <bem.triangulation.Triangulation at 0x217b0ad43d0>,
#         <bem.triangulation.Triangulation at 0x217b0ad4490>,
#         <bem.triangulation.Triangulation at 0x217b0ad4550>,
#         <bem.triangulation.Triangulation at 0x217b0ad4610>,
#         <bem.triangulation.Triangulation at 0x217b0ad46d0>,
#         <bem.triangulation.Triangulation at 0x217b0ad4790>,
#         <bem.triangulation.Triangulation at 0x217b0ad4850>,
#         <bem.triangulation.Triangulation at 0x217b0ad4910>,
#         <bem.triangulation.Triangulation at 0x217b0ad49d0>,
#         <bem.triangulation.Triangulation at 0x217b0ad4a90>,
#         <bem.triangulation.Triangulation at 0x217b0ad4b50>,
#         <bem.triangulation.Triangulation at 0x217b0ad4c10>,
#         <bem.triangulation.Triangulation at 0x217b0ad4cd0>,
#         <bem.triangulation.Triangulation at 0x217b0ad4d90>,
#         <bem.triangulation.Triangulation at 0x217b0ad4e50>,
#         <bem.triangulation.Triangulation at 0x217b0ad4f10>,
#         <bem.triangulation.Triangulation at 0x217b0ad9040>,
#         <bem.triangulation.Triangulation at 0x217b0ad90d0>,
#         <bem.triangulation.Triangulation at 0x217b0ad9190>,
#         <bem.triangulation.Triangulation at 0x217b0ad9250>,
#         <bem.triangulation.Triangulation at 0x217b0ad9310>,
#         <bem.triangulation.Triangulation at 0x217b0ad93d0>,
#         <bem.triangulation.Triangulation at 0x217b0ad9490>,
#         <bem.triangulation.Triangulation at 0x217b0ad9550>,
#         <bem.triangulation.Triangulation at 0x217b0ad9610>,
#         <bem.triangulation.Triangulation at 0x217b0ad96d0>,
#         <bem.triangulation.Triangulation at 0x217b0ad9790>,
#         <bem.triangulation.Triangulation at 0x217b0ad9850>,
#         <bem.triangulation.Triangulation at 0x217b0ad9910>,
#         <bem.triangulation.Triangulation at 0x217b0ad99d0>,
#         <bem.triangulation.Triangulation at 0x217b0ad9a90>,
#         <bem.triangulation.Triangulation at 0x217b0ad9b50>,
#         <bem.triangulation.Triangulation at 0x217b0ad9c10>,
#         <bem.triangulation.Triangulation at 0x217b0ad9cd0>,
#         <bem.triangulation.Triangulation at 0x217b0ad9d90>,
#         <bem.triangulation.Triangulation at 0x217b0ad9e50>,
#         <bem.triangulation.Triangulation at 0x217b0ad9f10>,
#         <bem.triangulation.Triangulation at 0x217b0ade040>,
#         <bem.triangulation.Triangulation at 0x217b0ade0d0>,
#         <bem.triangulation.Triangulation at 0x217b0ade190>,
#         <bem.triangulation.Triangulation at 0x217b0ade2b0>,
#         <bem.triangulation.Triangulation at 0x217b0ade310>,
#         <bem.triangulation.Triangulation at 0x217b0ade3d0>,
#         <bem.triangulation.Triangulation at 0x217b0ade490>,
#         <bem.triangulation.Triangulation at 0x217b0ade550>,
#         <bem.triangulation.Triangulation at 0x217b0ade610>,
#         <bem.triangulation.Triangulation at 0x217b0ade6d0>,
#         <bem.triangulation.Triangulation at 0x217b0ade790>,
#         <bem.triangulation.Triangulation at 0x217b0ade850>,
#         <bem.triangulation.Triangulation at 0x217b0ade910>,
#         <bem.triangulation.Triangulation at 0x217b0ade9d0>,
#         <bem.triangulation.Triangulation at 0x217b0adea90>,
#         <bem.triangulation.Triangulation at 0x217b0adeb50>,
#         <bem.triangulation.Triangulation at 0x217b0adec10>,
#         <bem.triangulation.Triangulation at 0x217b0adecd0>,
#         <bem.triangulation.Triangulation at 0x217b0aded90>,
#         <bem.triangulation.Triangulation at 0x217b0adee50>,
#         <bem.triangulation.Triangulation at 0x217b0adef10>,
#         <bem.triangulation.Triangulation at 0x217b0ae3040>,
#         <bem.triangulation.Triangulation at 0x217b0ae30d0>,
#         <bem.triangulation.Triangulation at 0x217b0ae3190>,
#         <bem.triangulation.Triangulation at 0x217b0ae3250>,
#         <bem.triangulation.Triangulation at 0x217b0ae3310>,
#         <bem.triangulation.Triangulation at 0x217b0ae33d0>,
#         <bem.triangulation.Triangulation at 0x217b0ae3490>,
#         <bem.triangulation.Triangulation at 0x217b0ae3550>,
#         <bem.triangulation.Triangulation at 0x217b0ae3610>,
#         <bem.triangulation.Triangulation at 0x217b0ae36d0>,
#         <bem.triangulation.Triangulation at 0x217b0ae3790>,
#         <bem.triangulation.Triangulation at 0x217b0ae3850>,
#         <bem.triangulation.Triangulation at 0x217b0ae3910>,
#         <bem.triangulation.Triangulation at 0x217b0ae39d0>,
#         <bem.triangulation.Triangulation at 0x217b0ae3a90>,
#         <bem.triangulation.Triangulation at 0x217b0ae3b50>,
#         <bem.triangulation.Triangulation at 0x217b0ae3c10>,
#         <bem.triangulation.Triangulation at 0x217b0ae3cd0>,
#         <bem.triangulation.Triangulation at 0x217b0ae3d90>,
#         <bem.triangulation.Triangulation at 0x217b0ae3e50>,
#         <bem.triangulation.Triangulation at 0x217b0ae3f10>,
#         <bem.triangulation.Triangulation at 0x217b0ae8040>,
#         <bem.triangulation.Triangulation at 0x217b0ae80d0>,
#         <bem.triangulation.Triangulation at 0x217b0ae8190>,
#         <bem.triangulation.Triangulation at 0x217b0ae8250>,
#         <bem.triangulation.Triangulation at 0x217b0ae8310>,
#         <bem.triangulation.Triangulation at 0x217b0ae83d0>,
#         <bem.triangulation.Triangulation at 0x217b0ae8490>,
#         <bem.triangulation.Triangulation at 0x217b0ae8550>,
#         <bem.triangulation.Triangulation at 0x217b0ae8610>,
#         <bem.triangulation.Triangulation at 0x217b0ae86d0>,
#         <bem.triangulation.Triangulation at 0x217b0ae8790>,
#         <bem.triangulation.Triangulation at 0x217b0ae8850>,
#         <bem.triangulation.Triangulation at 0x217b0ae8910>,
#         <bem.triangulation.Triangulation at 0x217b0ae89d0>,
#         <bem.triangulation.Triangulation at 0x217b0ae8a90>,
#         <bem.triangulation.Triangulation at 0x217b0ae8b50>,
#         <bem.triangulation.Triangulation at 0x217b0ae8c10>,
#         <bem.triangulation.Triangulation at 0x217b0ae8cd0>,
#         <bem.triangulation.Triangulation at 0x217b0ae8d90>,
#         <bem.triangulation.Triangulation at 0x217b0ae8e50>,
#         <bem.triangulation.Triangulation at 0x217b0ae8f10>,
#         <bem.triangulation.Triangulation at 0x217b0aed040>,
#         <bem.triangulation.Triangulation at 0x217b0aed0d0>,
#         <bem.triangulation.Triangulation at 0x217b0aed190>,
#         <bem.triangulation.Triangulation at 0x217b0aed250>,
#         <bem.triangulation.Triangulation at 0x217b0aed310>,
#         <bem.triangulation.Triangulation at 0x217b0aed3d0>,
#         <bem.triangulation.Triangulation at 0x217b0aed490>,
#         <bem.triangulation.Triangulation at 0x217b0aed550>,
#         <bem.triangulation.Triangulation at 0x217b0aed610>,
#         <bem.triangulation.Triangulation at 0x217b0aed6d0>,
#         <bem.triangulation.Triangulation at 0x217b0aed790>,
#         <bem.triangulation.Triangulation at 0x217b0aed850>]),
#       ('DC1',
#        [<bem.triangulation.Triangulation at 0x217b0aed910>,
#         <bem.triangulation.Triangulation at 0x217b0aed9d0>,
#         <bem.triangulation.Triangulation at 0x217b0aeda90>,
#         <bem.triangulation.Triangulation at 0x217b0aedb50>,
#         <bem.triangulation.Triangulation at 0x217b0aedc10>,
#         <bem.triangulation.Triangulation at 0x217b0aedcd0>,
#         <bem.triangulation.Triangulation at 0x217b0aedd90>,
#         <bem.triangulation.Triangulation at 0x217b0aede50>,
#         <bem.triangulation.Triangulation at 0x217b0aedf10>,
#         <bem.triangulation.Triangulation at 0x217b0bf6040>,
#         <bem.triangulation.Triangulation at 0x217b0bf60d0>,
#         <bem.triangulation.Triangulation at 0x217b0bf6190>,
#         <bem.triangulation.Triangulation at 0x217b0bf6250>,
#         <bem.triangulation.Triangulation at 0x217b0bf6310>,
#         <bem.triangulation.Triangulation at 0x217b0bf63d0>,
#         <bem.triangulation.Triangulation at 0x217b0bf6490>]),
#       ('DC3',
#        [<bem.triangulation.Triangulation at 0x217b0bf6550>,
#         <bem.triangulation.Triangulation at 0x217b0bf6610>,
#         <bem.triangulation.Triangulation at 0x217b0bf66d0>,
#         <bem.triangulation.Triangulation at 0x217b0bf6790>,
#         <bem.triangulation.Triangulation at 0x217b0bf6850>,
#         <bem.triangulation.Triangulation at 0x217b0bf6910>,
#         <bem.triangulation.Triangulation at 0x217b0bf69d0>,
#         <bem.triangulation.Triangulation at 0x217b0bf6a90>,
#         <bem.triangulation.Triangulation at 0x217b0bf6b50>,
#         <bem.triangulation.Triangulation at 0x217b0bf6c10>,
#         <bem.triangulation.Triangulation at 0x217b0bf6cd0>,
#         <bem.triangulation.Triangulation at 0x217b0bf6d90>,
#         <bem.triangulation.Triangulation at 0x217b0bf6e50>,
#         <bem.triangulation.Triangulation at 0x217b0bf6f10>]),
#       ('DC4',
#        [<bem.triangulation.Triangulation at 0x217b0c17040>,
#         <bem.triangulation.Triangulation at 0x217b0c170d0>,
#         <bem.triangulation.Triangulation at 0x217b0c17190>,
#         <bem.triangulation.Triangulation at 0x217b0c17250>,
#         <bem.triangulation.Triangulation at 0x217b0c17310>,
#         <bem.triangulation.Triangulation at 0x217b0c173d0>,
#         <bem.triangulation.Triangulation at 0x217b0c17490>,
#         <bem.triangulation.Triangulation at 0x217b0c17550>,
#         <bem.triangulation.Triangulation at 0x217b0c17610>,
#         <bem.triangulation.Triangulation at 0x217b0c176d0>,
#         <bem.triangulation.Triangulation at 0x217b0c17790>,
#         <bem.triangulation.Triangulation at 0x217b0c17850>,
#         <bem.triangulation.Triangulation at 0x217b0c17910>,
#         <bem.triangulation.Triangulation at 0x217b0c179d0>,
#         <bem.triangulation.Triangulation at 0x217b0c17a90>]),
#       ('DC5',
#        [<bem.triangulation.Triangulation at 0x217b0c17b50>,
#         <bem.triangulation.Triangulation at 0x217b0c17c10>,
#         <bem.triangulation.Triangulation at 0x217b0c17cd0>,
#         <bem.triangulation.Triangulation at 0x217b0c17d90>,
#         <bem.triangulation.Triangulation at 0x217b0c17e50>,
#         <bem.triangulation.Triangulation at 0x217b0c17f10>,
#         <bem.triangulation.Triangulation at 0x217b0c05040>,
#         <bem.triangulation.Triangulation at 0x217b0c050d0>,
#         <bem.triangulation.Triangulation at 0x217b0c05190>,
#         <bem.triangulation.Triangulation at 0x217b0c05250>,
#         <bem.triangulation.Triangulation at 0x217b0c05310>,
#         <bem.triangulation.Triangulation at 0x217b0c053d0>,
#         <bem.triangulation.Triangulation at 0x217b0c05490>,
#         <bem.triangulation.Triangulation at 0x217b0c05550>]),
#       ('DC6',
#        [<bem.triangulation.Triangulation at 0x217b0c05610>,
#         <bem.triangulation.Triangulation at 0x217b0c056d0>,
#         <bem.triangulation.Triangulation at 0x217b0c05790>,
#         <bem.triangulation.Triangulation at 0x217b0c05850>,
#         <bem.triangulation.Triangulation at 0x217b0c05910>,
#         <bem.triangulation.Triangulation at 0x217b0c059d0>,
#         <bem.triangulation.Triangulation at 0x217b0c05a90>,
#         <bem.triangulation.Triangulation at 0x217b0c05b50>,
#         <bem.triangulation.Triangulation at 0x217b0c05c70>,
#         <bem.triangulation.Triangulation at 0x217b0c05cd0>,
#         <bem.triangulation.Triangulation at 0x217b0c05d90>,
#         <bem.triangulation.Triangulation at 0x217b0c05e50>,
#         <bem.triangulation.Triangulation at 0x217b0c05f10>,
#         <bem.triangulation.Triangulation at 0x217b0c2d040>]),
#       ('DC8',
#        [<bem.triangulation.Triangulation at 0x217b0c2d0d0>,
#         <bem.triangulation.Triangulation at 0x217b0c2d190>,
#         <bem.triangulation.Triangulation at 0x217b0c2d250>,
#         <bem.triangulation.Triangulation at 0x217b0c2d310>,
#         <bem.triangulation.Triangulation at 0x217b0c2d3d0>,
#         <bem.triangulation.Triangulation at 0x217b0c2d490>,
#         <bem.triangulation.Triangulation at 0x217b0c2d550>,
#         <bem.triangulation.Triangulation at 0x217b0c2d610>,
#         <bem.triangulation.Triangulation at 0x217b0c2d6d0>,
#         <bem.triangulation.Triangulation at 0x217b0c2d790>,
#         <bem.triangulation.Triangulation at 0x217b0c2d850>,
#         <bem.triangulation.Triangulation at 0x217b0c2d910>,
#         <bem.triangulation.Triangulation at 0x217b0c2d9d0>,
#         <bem.triangulation.Triangulation at 0x217b0c2da90>]),
#       ('DC9',
#        [<bem.triangulation.Triangulation at 0x217b0c2db50>,
#         <bem.triangulation.Triangulation at 0x217b0c2dc10>,
#         <bem.triangulation.Triangulation at 0x217b0c2dcd0>,
#         <bem.triangulation.Triangulation at 0x217b0c2dd90>,
#         <bem.triangulation.Triangulation at 0x217b0c2de50>,
#         <bem.triangulation.Triangulation at 0x217b0c2df10>,
#         <bem.triangulation.Triangulation at 0x217b0bfb040>,
#         <bem.triangulation.Triangulation at 0x217b0bfb0d0>,
#         <bem.triangulation.Triangulation at 0x217b0bfb190>,
#         <bem.triangulation.Triangulation at 0x217b0bfb250>,
#         <bem.triangulation.Triangulation at 0x217b0bfb310>,
#         <bem.triangulation.Triangulation at 0x217b0bfb3d0>,
#         <bem.triangulation.Triangulation at 0x217b0bfb490>,
#         <bem.triangulation.Triangulation at 0x217b0bfb550>]),
#       ('DC10',
#        [<bem.triangulation.Triangulation at 0x217b0bfb610>,
#         <bem.triangulation.Triangulation at 0x217b0bfb6d0>,
#         <bem.triangulation.Triangulation at 0x217b0bfb790>,
#         <bem.triangulation.Triangulation at 0x217b0bfb850>,
#         <bem.triangulation.Triangulation at 0x217b0bfb910>,
#         <bem.triangulation.Triangulation at 0x217b0bfb9d0>,
#         <bem.triangulation.Triangulation at 0x217b0bfba90>,
#         <bem.triangulation.Triangulation at 0x217b0bfbb50>,
#         <bem.triangulation.Triangulation at 0x217b0bfbc10>,
#         <bem.triangulation.Triangulation at 0x217b0bfbcd0>,
#         <bem.triangulation.Triangulation at 0x217b0bfbd90>])])

# %%
# save base mesh to a pickle file
with open(fout_name,'wb') as f:
    data = (mesh_unit,
            xl,
            yl,
            zl,
            mesh,
            list(od.values()))
    pickle.dump(data,f)

# %% [markdown]
# ## view mesh
# Uses Pyvista package to generate interactive 3-d plot of the mesh

# %%
# Plot triangle mezshes of the final mesh
mesh.plot()

# %% [markdown]
# Show number of points included in the mesh

# %%
print(len(mesh.points))
# Out:
# 8692
