# %% [markdown]
# # `Documention & Tutorial`
# This BEM package is used for for numerical simulation of the electric field of ion traps in python. Some external packages are wrapped into it:
#
# * fast triangulation (http://www.cs.cmu.edu/~quake/triangle.research.html)
# * fastlap boundary element method (Nabors K S. Efficient three-dimensional capacitance calculation[D]. Massachusetts Institute of Technology, 1993.)
#
# This document, also as a tutorial, explains how to use these packages to compute the electric field and compute its multipole expansion coefficient starting from scratch with a fusion 360 trap model(take `./f3d/htrap_overhang_9x5mm.f3d` for example). Our document consists of three .ipynb files:
#
# * `I_Mesh_Processing.ipynb`
# * `II_Field_Simulation.ipynb`
# * `III_Multipole_Expansion.ipynb`
#
# We split the document into three files for two reasons:
# 1. The most time consuming part `II_Field_Simulation.ipynb` could be taken out alone and run on a high peformance computer.
# 2. The intermediate result between files can be checked- 'intermediate files' refer to the inital mesh grid (that corresponds to the charge distribution), the simulation values and the simulation coordinates, all of which are saved in the inter_results folder. So if the voltage solution files for the trap don't make sense, it is possible to go back through saved data to see where things have gone wrong.
# Here are the three jupyter notebooks and what:
# 1. I_Mesh_Processing- this notebook generates a mesh of the trap, saved in inter_results as a .pkl file
#
#
# Going through three files in order and running their python code will help you understand our workflow. Generally our workflow divides into three steps, corresponding to the above three .ipynb files. First, in I_Mesh_Processing, we identify different electrodes of the trap model by different colors. Also, we refine the trap model meshes to prepare for the second step. The result is stored in `mesh_result.pkl`.
#
# Secondly, in II_Field_Simulation, we simulate the electric potential with fastlap boundary element method(FMM), the accuracy of this step depends on the mesh size in the first step. The result is stored in `field_result.pkl`.
#
# Thirdly, in III_Multipole_Expansion, we analyze the electric field and electric potential. This notebook generates the multipole coefficients of the fields and potentials for each electrode and uses that information to generate a solution file with the function call `write_csv`. If your solution don't make sense, a good place to start is to insure that the mesh you are using is fine enough (generate several field results for different meshes)- if the potentials and fields are converging to specific values, this suggests there is something wrong with the multipole expansion. If you start with multipole expansion, you do not know if it is a problem with the expansion or with the field.
#
# Before running codes, you must set up the environment according to instructions in `README`
#
# notes
# * Our workflow, as indicated by this document, abandons mayavi(with its embeded package tvtk). But we reserve mayavi in our Bem source code, if you want to use mayavi related functions, you must set up environment with files in`./backup/setup_with_mayavi`, just replace corresponding files in the root folder with them and set up.
#     * why we abandon mayavi: because its python interface(with its dependence vtk and PyQt5) requires complex package dependencies and version controls especially for new python versions. This makes it difficult to maintain this project.
#     * why we still keep mayavi in the source code? Because it is rooted in our source code deeply. We can just avoid invoking related functions instead of deleting them, because they may make sense in the future.

# %% [markdown]
# # `I. Mesh Processing`
# This .pynb file reads a colored model file `./inter_results/htrap.stl`, and assigns a name for each color(thus for each electrode). The result is stored in `./inter_results/mesh_result.pkl`.
#
# In this file we name different electrodes and refine the meshes. The size of mesh determines the accuracy in next step. You should set the mesh finer and finer until the result converges. Also, you can set the mesh finer and test the convergence.
#
# ## (1) color your electrodes (in fusion 360) and export stl
# First of all, you have a trap model in fusion 360 project, for example, `./f3d/htrap_overhang_9x5mm.f3d`. Here we use different color to identify different electrodes(STL file stores color for each mesh). In fusion 360, you can assign different appearance for different electrodes. We recommend to use ../../bemCol_lib/bemCol.adsklib for different electrodes. Same color for two electrodes means they are treated as the same electrode. Then we get `./f3d/htrap_overhang_9x5mm_my_colored.f3d`
#
# Then export to an stl file in fusion360 file>export tab and move the file in `./inter_results`. We export our stl in mm, so we set the mesh unit to mm.

# %% [markdown]
# Furthurmore, it's our convention to use unit mm in our traps. e.g. [Electric field] = V/mm , [harmonic confining potential] = V/mm^2.so we set

# %%
# this is the unit for our Mesh structure
# in the following code, this is the default unit for python variables
#units 
mesh_unit = 1e-3

# %% [markdown]
# Additional notes (from Wenhao):
# * Why use standard color? We define a set of standard color lib `../../../bemCol_lib/bemCol.adsklib` for two reasons: 1. when exporting to .stl file, fusion 360 will compress 0-256 color(RGBA32) into 0-32 color(RGBA16), which means that some similar colors in fusion 360 will become same color after export to .stl file. Our standard color lib avoid this problem. 2.If you use .stl file exported from fusion 360 DIRECTLY, naming the electrodes would be very convinient. If you use other apps such as Inventor or Meshlab to generate .stl file, you can ignore the second reason because color encoding are quite different in different apps

# %% [markdown]
# ## (2) assign a name for each color

# %%
import pickle
import numpy as np
import matplotlib as mpl
import sys
from utils.helper_functions import *
from bem.bemColors_lib.bemColors import bemColors
from bem import Electrodes, Sphere, Mesh, Grid, Configuration, Result, Box
# load stl geometry file
from bem.formats import stl
# stl_path = "roughness/"+"basic_excitation"+".stl"  


#radius is the radius of the sphere from the ions location to generate a finer
#electrode mesh
radius= 500e-3
#'area' is the area of the triangles inside the sphere
area = 1e-4
# file = 'mit_charge'
# file = 'htrap_overhang_taper_2'
# file_out = 'htrap_overhang_taper_el3'
# stl_path = 'inter_results/taper_overhang/'+file+'.stl'
# fout_name = 'inter_results/taper_overhang/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


file_out = 'trap_noyce'
stl_path = 'inter_results/trap_noyce/trap_noyce.stl'
fout_name = 'inter_results/trap_noyce/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


module_path = os.path.abspath('')


s_nta = stl.read_stl(open(stl_path, "rb"))

# %% [markdown]
# Firstly, we print all the colors appear in the stl file. If a color is of standard colors in `bemCol.adsklib` or named manually by function `bemCol.set_my_color()`, then the color will appear in a straightforward name, such as `bem0`,`bem1` ...... . Otherwise, the color will simply be named as `'_unkCol0'` , `'_unkCol1'`, ...
#
# notes
# * try to comment out the line of `ele_col.set_my_color()` in the following block, name `'_unkCol0'` will appear.

# %%
ele_col = bemColors(np.array(list(set(s_nta[2]))),('fusion360','export_stl'))
ele_col.set_my_color(value = (178,178,178),cl_format = ('fusion360','export_stl','RGBA64'),name = 'self_defined')
ele_col.print_stl_colors()
# Out:
# COLORS in the stl:
# ['bem6']
# ['bem13']
# ['bem19']
# ['bem11']
# ['bem17']
# ['bem15']
# ['bem30']
# ['bem1']
# ['bem12']
# ['bem5']
# ['bem25']
# ['bem18']
# ['bem16']
# ['bem3']
# ['bem7']
# ['bem9']
# ['bem2']
# ['bem4']
# ['bem20']
# ['bem10']
# ['bem14']
# ['bem8']
# ['bem21']
# ['_unkColor0']
# TOTAL COLORS:  24

# %% [markdown]
# Next, you need to assign a name for each color that appeared above. With standard colors defined in `bemCol.adsklib`, the correspondence between color and electrode is clear, which make it easy for this step. You can also comment out some `ele_col.set_color_name()`, run all the codes again and observe the missing part in the printed figure, which corresponds to the electrode you comment out. The second method also serves as a double check. Besides, parameter in `stl.stl_to_mesh()` can be set as `quiet = False` to check whether the program reads planes correctly.

# %%
# assign a name for each color
# taper htrap 2022
# assign a name for each color

# In od[key] = value, key is the color from the Fusion360 color library we made
# value assigns a specific name to that color in this program. 
# In future version, we may want to consider getting rid of this step for simplification
# then you just assign the color in fusion 360 and be done with it. The only concern there is you
from collections import OrderedDict
od = OrderedDict()
od['bem1']='DC1'
od['bem2']='DC2'
od['bem3']='DC3'
od['bem4']='DC4'
od['bem5']='DC5'
od['bem6']='DC6'
od['bem7']='DC7'
od['bem8']='DC8'
od['bem9']='DC9'
od['bem10']='DC10'
od['bem11']='DC11'
od['bem12']='DC12'
od['bem13']='DC13'
od['bem14']='DC14'
od['bem15']='DC15'
od['bem16']='DC16'
od['bem17']='DC17'
od['bem18']='DC18'
od['bem19']='DC19'
od['bem20']='DC20'
od['bem21'] = 'DC21'
od['bem25'] = 'RF'
od['bem30'] = 'gnd'
for key in list(od.keys()):
    ele_col.color_electrode(color=key,name=od[key])

# print colors still with no name. These meshes will be neglected in the code below. 
ele_col.drop_colors()

# read stl into mesh with electrode names
# unnamed meshes will not be imported at all

mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=1,
    rename=ele_col.electrode_colors, quiet=True))
# Out:
# dropping color ['_unkColor0']
# TOTAL COLORS DROPPED:  1
# dropping 20083

# %% [markdown]
# ## (3) remesh
#
# In this step, we generate triangle mesh with constraints. The meshes are 2-dimensional triangles on the surface of electrodes. The region enclosed by constraint shape can have finer mesh. Triangulation is done by `triangle` C library. Folowing variables are all in unit `mesh_unit` now.
#
# Our remesh strategy consists of two steps of triangulation:
# 1. global triangulation without constraint. This step eliminate some long and sharp triangles by combining and dividing, and obtains a coarse grain triangulated model.
# 2. local triangulation with constraint. This step refines each triangles in step 1, the triangle density is defined by `mesh.areas_from_constraints
#
# parameters in the below code block should be tuned specificly for different trap geometries.`

# %%
# here we define a spherical constriant zone:
# xl = 270*1e-3
# yl = -3.5*1e-3
# zl = 72.5*1e-3

#here is the location that will be the reference point for further meshing
#usually, this is the ion's location, specified in appropriate units (usually millimeters)
zl = -450*1e-3
yl = 75*1e-3
xl = 3.75*1e-3


mesh.triangulate(opts="",new = False)

# for z in np.arange(-400e-3,700e-3,100e-3):
print('first triangulation:')
# for z in np.arange(-200e-3, 200e-3, 50e-3):
rad = radius*3
inside=area*30
outside=1
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="a2Q",new = False)

# # what happened to this feature (Box)? is this on bem savio?
# # mesh.areas_from_constraints(Box(start=-0.5, end= 0.5,inside=inside, outside=outside))



# areas_from_constraints specifies sphere with finer mesh inside it.
#  "inside", "outside" set different mesh densities. 
print('second triangulation:')
rad =radius
inside=area*2
outside=1e4
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="q5Q",new = False)

# save base mesh to a pickle file
# with open(fout_name,'wb') as f:
#     data = (mesh_unit,
#             xl,
#             yl,
#             zl,
#             mesh,
#             list(od.values()))
#     pickle.dump(data,f)
# Out:
# start triangulate RF
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate RF
# start triangulate DC21
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC21
# start triangulate DC2
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC2
# start triangulate DC7
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC7
# start triangulate DC11
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC11
# start triangulate DC12
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC12
# start triangulate DC13
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC13
# start triangulate DC14
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC14
# start triangulate DC15
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC15
# start triangulate DC16
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC16
# start triangulate DC17
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC17
# start triangulate DC18
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC18
# start triangulate DC19
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC19
# start triangulate DC20
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC20
# start triangulate gnd
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate gnd
# start triangulate DC1
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC1
# start triangulate DC3
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC3
# start triangulate DC4
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC4
# start triangulate DC5
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC5
# start triangulate DC6
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC6
# start triangulate DC8
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC8
# start triangulate DC9
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC9
# start triangulate DC10
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC10
# first triangulation:
# start triangulate RF
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate RF
# start triangulate DC21
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC10
# second triangulation:
# start triangulate RF
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate RF
# start triangulate DC21
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC21
# start triangulate DC2
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC2
# start triangulate DC7
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC7
# start triangulate DC11
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC11
# start triangulate DC12
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC12
# start triangulate DC13
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC13
# start triangulate DC14
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC14
# start triangulate DC15
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC15
# start triangulate DC16
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC16
# start triangulate DC17
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC17
# start triangulate DC18
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC18
# start triangulate DC19
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC19
# start triangulate DC20
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC20
# start triangulate gnd
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate gnd
# start triangulate DC1
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC3
# start triangulate DC4
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC4
# start triangulate DC5
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC5
# start triangulate DC6
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC8
# start triangulate DC9
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC9
# start triangulate DC10
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC10
# Mesh([('RF',
#        [<bem.triangulation.Triangulation at 0x1a5f3aa2c10>,
#         <bem.triangulation.Triangulation at 0x1a5f5f528e0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f520a0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f52130>,
#         <bem.triangulation.Triangulation at 0x1a5f5f52ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f52f10>,
#         <bem.triangulation.Triangulation at 0x1a5f5f52e20>,
#         <bem.triangulation.Triangulation at 0x1a5f5f52be0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f52b20>,
#         <bem.triangulation.Triangulation at 0x1a5f5f529d0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f52820>,
#         <bem.triangulation.Triangulation at 0x1a5f5f2a850>,
#         <bem.triangulation.Triangulation at 0x1a5f5f2aca0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f2adf0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f2af70>,
#         <bem.triangulation.Triangulation at 0x1a5f5f2a6a0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f2a5b0>]),
#       ('DC21',
#        [<bem.triangulation.Triangulation at 0x1a5f5f2a2e0>,
#         <bem.triangulation.Triangulation at 0x1a5922083a0>,
#         <bem.triangulation.Triangulation at 0x1a592208700>,
#         <bem.triangulation.Triangulation at 0x1a592208580>,
#         <bem.triangulation.Triangulation at 0x1a592208430>,
#         <bem.triangulation.Triangulation at 0x1a5922080d0>,
#         <bem.triangulation.Triangulation at 0x1a5922083d0>]),
#       ('DC2',
#        [<bem.triangulation.Triangulation at 0x1a592208d90>,
#         <bem.triangulation.Triangulation at 0x1a592208fd0>,
#         <bem.triangulation.Triangulation at 0x1a592208940>,
#         <bem.triangulation.Triangulation at 0x1a592208ac0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16d90>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16ca0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16370>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16460>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16d00>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16a30>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16880>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16cd0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16e50>]),
#       ('DC7',
#        [<bem.triangulation.Triangulation at 0x1a5f5f16a90>,
#         <bem.triangulation.Triangulation at 0x1a5f5f167f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f166a0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16df0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f165e0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16040>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16dc0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16610>,
#         <bem.triangulation.Triangulation at 0x1a5f5f162e0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16100>,
#         <bem.triangulation.Triangulation at 0x1a5f5f16fa0>,
#         <bem.triangulation.Triangulation at 0x1a5921feac0>,
#         <bem.triangulation.Triangulation at 0x1a5921fed30>]),
#       ('DC11',
#        [<bem.triangulation.Triangulation at 0x1a5921febe0>,
#         <bem.triangulation.Triangulation at 0x1a5921fe880>,
#         <bem.triangulation.Triangulation at 0x1a5921feca0>,
#         <bem.triangulation.Triangulation at 0x1a5921fed00>,
#         <bem.triangulation.Triangulation at 0x1a5921fea60>,
#         <bem.triangulation.Triangulation at 0x1a5921feeb0>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75220>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75100>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75250>,
#         <bem.triangulation.Triangulation at 0x1a5f3b753d0>,
#         <bem.triangulation.Triangulation at 0x1a5f3b754f0>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75310>,
#         <bem.triangulation.Triangulation at 0x1a5f3b755e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3b756a0>]),
#       ('DC12',
#        [<bem.triangulation.Triangulation at 0x1a5f3b75760>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75820>,
#         <bem.triangulation.Triangulation at 0x1a5f3b758e0>,
#         <bem.triangulation.Triangulation at 0x1a5f3b759d0>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75a90>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75b50>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75c10>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75cd0>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75d90>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75e50>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75f10>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75fd0>,
#         <bem.triangulation.Triangulation at 0x1a5f3b75460>,
#         <bem.triangulation.Triangulation at 0x1a5910addf0>]),
#       ('DC13',
#        [<bem.triangulation.Triangulation at 0x1a5f3ab2640>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab26d0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab28b0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2eb0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2820>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2730>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2250>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab24f0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2310>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab24c0>,
#         <bem.triangulation.Triangulation at 0x1a5f3ab2940>]),
#       ('DC14',
#        [<bem.triangulation.Triangulation at 0x1a5f5f70100>,
#         <bem.triangulation.Triangulation at 0x1a5f5f704f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70340>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70b80>,
#         <bem.triangulation.Triangulation at 0x1a5f5f704c0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70070>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70370>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70460>,
#         <bem.triangulation.Triangulation at 0x1a5f5f706a0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70910>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70160>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70730>,
#         <bem.triangulation.Triangulation at 0x1a5f5f709d0>]),
#       ('DC15',
#        [<bem.triangulation.Triangulation at 0x1a5f5f70c10>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70d90>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70eb0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70220>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70700>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70d00>,
#         <bem.triangulation.Triangulation at 0x1a5f5f70b20>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73880>,
#         <bem.triangulation.Triangulation at 0x1a5f5f735e0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f730d0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73040>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73190>,
#         <bem.triangulation.Triangulation at 0x1a5f5f733a0>]),
#       ('DC16',
#        [<bem.triangulation.Triangulation at 0x1a5f5f73340>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73820>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73be0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73430>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73700>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73ac0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73d90>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73fa0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f738e0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73a60>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73e20>,
#         <bem.triangulation.Triangulation at 0x1a5f5f73940>,
#         <bem.triangulation.Triangulation at 0x1a5f5f32c70>]),
#       ('DC17',
#        [<bem.triangulation.Triangulation at 0x1a5f5f32250>,
#         <bem.triangulation.Triangulation at 0x1a5f5f322e0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f32700>,
#         <bem.triangulation.Triangulation at 0x1a5f5f32910>,
#         <bem.triangulation.Triangulation at 0x1a5f5f32b50>,
#         <bem.triangulation.Triangulation at 0x1a5f5f32040>,
#         <bem.triangulation.Triangulation at 0x1a5f5f322b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f32d30>,
#         <bem.triangulation.Triangulation at 0x1a5f5f320a0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f32310>,
#         <bem.triangulation.Triangulation at 0x1a5f5f32550>,
#         <bem.triangulation.Triangulation at 0x1a5f5f326a0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f32790>]),
#       ('DC18',
#        [<bem.triangulation.Triangulation at 0x1a5f5f32a00>,
# ...
#         <bem.triangulation.Triangulation at 0x1a5f5ce7970>,
#         <bem.triangulation.Triangulation at 0x1a5f5ce7280>,
#         <bem.triangulation.Triangulation at 0x1a5f5ce7580>,
#         <bem.triangulation.Triangulation at 0x1a5f5ce77c0>,
#         <bem.triangulation.Triangulation at 0x1a5f5ce7b80>,
#         <bem.triangulation.Triangulation at 0x1a5f5ce7e80>,
#         <bem.triangulation.Triangulation at 0x1a5f5ce7880>,
#         <bem.triangulation.Triangulation at 0x1a5f3ba7820>,
#         <bem.triangulation.Triangulation at 0x1a5f3ba7f10>,
#         <bem.triangulation.Triangulation at 0x1a5f5cec790>,
#         <bem.triangulation.Triangulation at 0x1a5f5cecd00>,
#         <bem.triangulation.Triangulation at 0x1a5f5cec550>,
#         <bem.triangulation.Triangulation at 0x1a5f5cf0c40>,
#         <bem.triangulation.Triangulation at 0x1a5f5cf04f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5cf0b80>,
#         <bem.triangulation.Triangulation at 0x1a5f5cf0610>,
#         <bem.triangulation.Triangulation at 0x1a5f5cd4040>,
#         <bem.triangulation.Triangulation at 0x1a5f5cd4790>,
#         <bem.triangulation.Triangulation at 0x1a5f5cd4ee0>,
#         <bem.triangulation.Triangulation at 0x1a5f5cd4fd0>,
#         <bem.triangulation.Triangulation at 0x1a5f5cf41f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5cf4940>,
#         <bem.triangulation.Triangulation at 0x1a5f5cf41c0>,
#         <bem.triangulation.Triangulation at 0x1a5f5cf4820>,
#         <bem.triangulation.Triangulation at 0x1a5f5cf4a90>,
#         <bem.triangulation.Triangulation at 0x1a5f5cf7cd0>,
#         <bem.triangulation.Triangulation at 0x1a5f5cf71c0>,
#         <bem.triangulation.Triangulation at 0x1a5f5cf7730>,
#         <bem.triangulation.Triangulation at 0x1a5f5cfad90>,
#         <bem.triangulation.Triangulation at 0x1a5f5cfadc0>,
#         <bem.triangulation.Triangulation at 0x1a5f5cfad60>,
#         <bem.triangulation.Triangulation at 0x1a5f5cfe220>,
#         <bem.triangulation.Triangulation at 0x1a5f5cfe970>,
#         <bem.triangulation.Triangulation at 0x1a5f5cfe310>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78100>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78340>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78070>,
#         <bem.triangulation.Triangulation at 0x1a5f5f782b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f784f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f785b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78670>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78730>,
#         <bem.triangulation.Triangulation at 0x1a5f5f787f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f788b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78970>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78a30>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78af0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78bb0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78c70>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78d30>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78df0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78eb0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f78f70>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81070>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81130>,
#         <bem.triangulation.Triangulation at 0x1a5f5f811f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f812b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81370>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81430>,
#         <bem.triangulation.Triangulation at 0x1a5f5f814f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f815b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81670>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81730>,
#         <bem.triangulation.Triangulation at 0x1a5f5f817f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f818b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81970>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81a30>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81af0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81bb0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81c70>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81d30>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81df0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81eb0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f81f70>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84070>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84130>,
#         <bem.triangulation.Triangulation at 0x1a5f5f841f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f842b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84370>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84430>,
#         <bem.triangulation.Triangulation at 0x1a5f5f844f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f845b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84670>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84730>,
#         <bem.triangulation.Triangulation at 0x1a5f5f847f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f848b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84970>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84a30>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84af0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84bb0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84c70>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84d30>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84df0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84eb0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f84f70>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88070>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88130>,
#         <bem.triangulation.Triangulation at 0x1a5f5f881f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f882b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88370>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88430>,
#         <bem.triangulation.Triangulation at 0x1a5f5f884f0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f885b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88670>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88730>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88850>,
#         <bem.triangulation.Triangulation at 0x1a5f5f888b0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88970>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88a30>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88af0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88bb0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88c70>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88d30>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88df0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88eb0>,
#         <bem.triangulation.Triangulation at 0x1a5f5f88f70>,
#         <bem.triangulation.Triangulation at 0x1a58105b070>,
#         <bem.triangulation.Triangulation at 0x1a58105b130>,
#         <bem.triangulation.Triangulation at 0x1a58105b1f0>,
#         <bem.triangulation.Triangulation at 0x1a58105b2b0>,
#         <bem.triangulation.Triangulation at 0x1a58105b370>,
#         <bem.triangulation.Triangulation at 0x1a58105b430>,
#         <bem.triangulation.Triangulation at 0x1a58105b4f0>,
#         <bem.triangulation.Triangulation at 0x1a58105b5b0>,
#         <bem.triangulation.Triangulation at 0x1a58105b670>,
#         <bem.triangulation.Triangulation at 0x1a58105b730>,
#         <bem.triangulation.Triangulation at 0x1a58105b7f0>,
#         <bem.triangulation.Triangulation at 0x1a58105b8b0>,
#         <bem.triangulation.Triangulation at 0x1a58105b970>,
#         <bem.triangulation.Triangulation at 0x1a58105ba30>,
#         <bem.triangulation.Triangulation at 0x1a58105baf0>,
#         <bem.triangulation.Triangulation at 0x1a58105bbb0>,
#         <bem.triangulation.Triangulation at 0x1a58105bc70>,
#         <bem.triangulation.Triangulation at 0x1a58105bd30>,
#         <bem.triangulation.Triangulation at 0x1a58105bdf0>,
#         <bem.triangulation.Triangulation at 0x1a58105beb0>,
#         <bem.triangulation.Triangulation at 0x1a58105bf70>,
#         <bem.triangulation.Triangulation at 0x1a581062070>,
#         <bem.triangulation.Triangulation at 0x1a581062130>,
#         <bem.triangulation.Triangulation at 0x1a5810621f0>,
#         <bem.triangulation.Triangulation at 0x1a5810622b0>,
#         <bem.triangulation.Triangulation at 0x1a581062370>,
#         <bem.triangulation.Triangulation at 0x1a581062430>,
#         <bem.triangulation.Triangulation at 0x1a5810624f0>,
#         <bem.triangulation.Triangulation at 0x1a5810625b0>,
#         <bem.triangulation.Triangulation at 0x1a581062670>,
#         <bem.triangulation.Triangulation at 0x1a581062730>,
#         <bem.triangulation.Triangulation at 0x1a5810627f0>,
#         <bem.triangulation.Triangulation at 0x1a5810628b0>,
#         <bem.triangulation.Triangulation at 0x1a581062970>,
#         <bem.triangulation.Triangulation at 0x1a581062a30>,
#         <bem.triangulation.Triangulation at 0x1a581062af0>]),
#       ('DC1',
#        [<bem.triangulation.Triangulation at 0x1a581062bb0>,
#         <bem.triangulation.Triangulation at 0x1a581062c70>,
#         <bem.triangulation.Triangulation at 0x1a581062d30>,
#         <bem.triangulation.Triangulation at 0x1a581062df0>,
#         <bem.triangulation.Triangulation at 0x1a581062eb0>,
#         <bem.triangulation.Triangulation at 0x1a581062f70>,
#         <bem.triangulation.Triangulation at 0x1a581058070>,
#         <bem.triangulation.Triangulation at 0x1a581058130>,
#         <bem.triangulation.Triangulation at 0x1a5810581f0>,
#         <bem.triangulation.Triangulation at 0x1a5810582b0>,
#         <bem.triangulation.Triangulation at 0x1a581058370>,
#         <bem.triangulation.Triangulation at 0x1a581058430>,
#         <bem.triangulation.Triangulation at 0x1a5810584f0>,
#         <bem.triangulation.Triangulation at 0x1a5810585b0>,
#         <bem.triangulation.Triangulation at 0x1a581058670>,
#         <bem.triangulation.Triangulation at 0x1a581058730>]),
#       ('DC3',
#        [<bem.triangulation.Triangulation at 0x1a5810587f0>,
#         <bem.triangulation.Triangulation at 0x1a5810588b0>,
#         <bem.triangulation.Triangulation at 0x1a581058970>,
#         <bem.triangulation.Triangulation at 0x1a581058a30>,
#         <bem.triangulation.Triangulation at 0x1a581058af0>,
#         <bem.triangulation.Triangulation at 0x1a581058bb0>,
#         <bem.triangulation.Triangulation at 0x1a581058c70>,
#         <bem.triangulation.Triangulation at 0x1a581058d30>,
#         <bem.triangulation.Triangulation at 0x1a581058df0>,
#         <bem.triangulation.Triangulation at 0x1a581058eb0>,
#         <bem.triangulation.Triangulation at 0x1a581058f70>,
#         <bem.triangulation.Triangulation at 0x1a581055070>,
#         <bem.triangulation.Triangulation at 0x1a581055130>,
#         <bem.triangulation.Triangulation at 0x1a5810551f0>]),
#       ('DC4',
#        [<bem.triangulation.Triangulation at 0x1a5810552b0>,
#         <bem.triangulation.Triangulation at 0x1a581055370>,
#         <bem.triangulation.Triangulation at 0x1a581055430>,
#         <bem.triangulation.Triangulation at 0x1a5810554f0>,
#         <bem.triangulation.Triangulation at 0x1a5810555b0>,
#         <bem.triangulation.Triangulation at 0x1a581055670>,
#         <bem.triangulation.Triangulation at 0x1a581055730>,
#         <bem.triangulation.Triangulation at 0x1a5810557f0>,
#         <bem.triangulation.Triangulation at 0x1a5810558b0>,
#         <bem.triangulation.Triangulation at 0x1a581055970>,
#         <bem.triangulation.Triangulation at 0x1a581055a30>,
#         <bem.triangulation.Triangulation at 0x1a581055af0>,
#         <bem.triangulation.Triangulation at 0x1a581055bb0>,
#         <bem.triangulation.Triangulation at 0x1a581055c70>,
#         <bem.triangulation.Triangulation at 0x1a581055d30>]),
#       ('DC5',
#        [<bem.triangulation.Triangulation at 0x1a581055df0>,
#         <bem.triangulation.Triangulation at 0x1a581055eb0>,
#         <bem.triangulation.Triangulation at 0x1a581055f70>,
#         <bem.triangulation.Triangulation at 0x1a581052070>,
#         <bem.triangulation.Triangulation at 0x1a581052130>,
#         <bem.triangulation.Triangulation at 0x1a5810521f0>,
#         <bem.triangulation.Triangulation at 0x1a5810522b0>,
#         <bem.triangulation.Triangulation at 0x1a581052370>,
#         <bem.triangulation.Triangulation at 0x1a581052430>,
#         <bem.triangulation.Triangulation at 0x1a5810524f0>,
#         <bem.triangulation.Triangulation at 0x1a5810525b0>,
#         <bem.triangulation.Triangulation at 0x1a581052670>,
#         <bem.triangulation.Triangulation at 0x1a581052730>,
#         <bem.triangulation.Triangulation at 0x1a5810527f0>]),
#       ('DC6',
#        [<bem.triangulation.Triangulation at 0x1a5810528b0>,
#         <bem.triangulation.Triangulation at 0x1a581052970>,
#         <bem.triangulation.Triangulation at 0x1a581052a30>,
#         <bem.triangulation.Triangulation at 0x1a581052af0>,
#         <bem.triangulation.Triangulation at 0x1a581052bb0>,
#         <bem.triangulation.Triangulation at 0x1a581052c70>,
#         <bem.triangulation.Triangulation at 0x1a581052d30>,
#         <bem.triangulation.Triangulation at 0x1a581052df0>,
#         <bem.triangulation.Triangulation at 0x1a581052eb0>,
#         <bem.triangulation.Triangulation at 0x1a581052f70>,
#         <bem.triangulation.Triangulation at 0x1a581060070>,
#         <bem.triangulation.Triangulation at 0x1a581060130>,
#         <bem.triangulation.Triangulation at 0x1a5810601f0>,
#         <bem.triangulation.Triangulation at 0x1a5810602b0>]),
#       ('DC8',
#        [<bem.triangulation.Triangulation at 0x1a581060370>,
#         <bem.triangulation.Triangulation at 0x1a581060430>,
#         <bem.triangulation.Triangulation at 0x1a5810604f0>,
#         <bem.triangulation.Triangulation at 0x1a5810605b0>,
#         <bem.triangulation.Triangulation at 0x1a581060670>,
#         <bem.triangulation.Triangulation at 0x1a581060730>,
#         <bem.triangulation.Triangulation at 0x1a5810607f0>,
#         <bem.triangulation.Triangulation at 0x1a5810608b0>,
#         <bem.triangulation.Triangulation at 0x1a581060970>,
#         <bem.triangulation.Triangulation at 0x1a581060a30>,
#         <bem.triangulation.Triangulation at 0x1a581060af0>,
#         <bem.triangulation.Triangulation at 0x1a581060bb0>,
#         <bem.triangulation.Triangulation at 0x1a581060c70>,
#         <bem.triangulation.Triangulation at 0x1a581060d30>]),
#       ('DC9',
#        [<bem.triangulation.Triangulation at 0x1a581060df0>,
#         <bem.triangulation.Triangulation at 0x1a581060eb0>,
#         <bem.triangulation.Triangulation at 0x1a581060f70>,
#         <bem.triangulation.Triangulation at 0x1a581068070>,
#         <bem.triangulation.Triangulation at 0x1a581068130>,
#         <bem.triangulation.Triangulation at 0x1a581068250>,
#         <bem.triangulation.Triangulation at 0x1a5810682b0>,
#         <bem.triangulation.Triangulation at 0x1a581068370>,
#         <bem.triangulation.Triangulation at 0x1a581068430>,
#         <bem.triangulation.Triangulation at 0x1a5810684f0>,
#         <bem.triangulation.Triangulation at 0x1a5810685b0>,
#         <bem.triangulation.Triangulation at 0x1a581068670>,
#         <bem.triangulation.Triangulation at 0x1a581068730>,
#         <bem.triangulation.Triangulation at 0x1a5810687f0>]),
#       ('DC10',
#        [<bem.triangulation.Triangulation at 0x1a5810688b0>,
#         <bem.triangulation.Triangulation at 0x1a581068970>,
#         <bem.triangulation.Triangulation at 0x1a581068a30>,
#         <bem.triangulation.Triangulation at 0x1a581068af0>,
#         <bem.triangulation.Triangulation at 0x1a581068bb0>,
#         <bem.triangulation.Triangulation at 0x1a581068c70>,
#         <bem.triangulation.Triangulation at 0x1a581068d30>,
#         <bem.triangulation.Triangulation at 0x1a581068df0>,
#         <bem.triangulation.Triangulation at 0x1a581068eb0>,
#         <bem.triangulation.Triangulation at 0x1a581068f70>,
#         <bem.triangulation.Triangulation at 0x1a58108e070>])])

# %%
# save base mesh to a pickle file
with open(fout_name,'wb') as f:
    data = (mesh_unit,
            xl,
            yl,
            zl,
            mesh,
            list(od.values()))
    pickle.dump(data,f)

# %% [markdown]
# ## view mesh
# Uses Pyvista package to generate interactive 3-d plot of the mesh

# %%
# Plot triangle mezshes of the final mesh
mesh.plot()

# %% [markdown]
# Show number of points included in the mesh

# %%
print(len(mesh.points))
# Out:
# 8692
