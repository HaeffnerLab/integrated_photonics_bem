# %% [markdown]
# # Package import

# %%
## General
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import warnings
import os 

## Constants and parameters
# from scipy.constants import m, e

## PaulTrapAnalysis
from PaulTrapAnalysis.functions import plotting
from PaulTrapAnalysis.extensions.Electron import big_plt_font, small_plt_font  # plot configuration
from PaulTrapAnalysis.extensions.Electron import import_trap_data, view_result, assign_trap_rf_single_pair  # import data
from PaulTrapAnalysis.extensions.Electron import analyze_trap_height, FindRFNull, analyze_d_eff  # analyze RF null and deff
from PaulTrapAnalysis.extensions.Electron import analyze_radial_frequency, plot_pseudo_contour  # analyze radial frequency
from PaulTrapAnalysis.extensions.Electron import analyze_trap_depth, analyze_trap_frequencies # analyze trap depth, drive frequency, RF amplitude
from PaulTrapAnalysis.extensions.Electron import config_multipoles  # multipole control
from PaulTrapAnalysis.extensions.Electron import display_harmonics_term, display_harmonics_terms  # display spherical harmonics terms
from PaulTrapAnalysis.extensions.Electron import analyze_anharm_DC, analyze_anharm_RF  # analyze DC and RF anharmonicities
from PaulTrapAnalysis.extensions.Electron import get_shift, plot_frequency_shift  # plot the frequency shifts caused by leading order terms

big_plt_font()  # default to a big font size
warnings.filterwarnings('ignore')

# %%
from PaulTrapAnalysis.extensions.Electron import *
m_Ca = 6.6551079e-26
def assign_trap_rf_single_pair(trap, prefix, suffix, 
                   V0_rf, electrodes='RF1',
                   l0=11e-6, Ω_e=2*np.pi*35.53e6):
    """
    Assign the imported RF data to the trap, and 
    calculate the pseudopoential. This assumes that the 
    trap only has one pair of RF electrodes.
    
    Parameters
    ----------
    trap : Trap object
        The trap to assign info to
    rf_data : [result_rf0, result_rf1, result_rf2]
        The imported RF result data from .vtk files
    V0_rf : float
        The amplitude for the RF drive
    l0 : [m]  #FIXME
        The length scale of the simulation grid, 
        default is 100e-6 (100 um)

    Returns
    -------
    trap : Trap object
        The updated trap 
    """
    scale = l0 
    trap.l0 = l0
    
    if trap.file_type == 'vtk':
        result_rf1 = Result.from_vtk(prefix+suffix, electrodes)
        rf1_field = result_rf1.field / scale
        rf_potential = V0_rf*result_rf1.potential 
        pp_rf = np.square(rf1_field).sum(axis=0).reshape(result_rf1.grid.shape)
    else:
        result_rf1 = trap.electrodes[electrodes].potential()
        rf1_field = trap.electrodes[electrodes].potential(derivative=1) / scale
        rf_potential = V0_rf*np.array(result_rf1)[:,:,:,0]
        pp_rf = np.array(np.square(rf1_field).sum(axis=-1)).reshape(np.shape(rf_potential))

    trap.result_rf1 = result_rf1
    trap.rf_field = rf1_field 
    
    trap.V0_rf = V0_rf
    trap.rf_potential_data = rf_potential
    
    trap.rf_field_square = pp_rf
    pp_rf = PseudoPotential(pp_rf,m_Ca,Ω_e,V0_rf)
    trap.pp_rf = pp_rf 

    return trap

# %% [markdown]
# # Data import and parameter define

# %%
prefix = "htrap"
suffix = ""

scale = 10 # conversion scale from BEM units to trap r0 (100um to 1mm)
electrodes = ['RF',
              'DC1', 'DC2', 'DC3','DC4','DC5','DC6','DC7','DC8', 'DC9',
              'DC10', 'DC11', 'DC12', 'DC13', 'DC14', 'DC15','DC16','DC17','DC18','DC19',
              'DC20', 'DC21',
              ]  # all electrode names
# elec_file_lookup = {'DC01': 'RF01', 'DC02': 'RF02'}  # look-up table for electrode names if assigned differently in BEM

# %%
etrap = import_trap_data(prefix, electrodes, elec_file_lookup={}, scale=scale)

# %%
#etrap.x

# %% [markdown]
# # Sanity check

# %%
view_result(prefix, suffix, electrode_name='RF')  # display the BEM simulation result (charge distribution of an electrode)

# %% [markdown]
# # Trap height, d_eff, radial frequency, trap depth

# %%
V0_rf = (2.877/2)*26  # voltage applied to RF electrode
omega_rf = 2*np.pi * 44.0e6  # the RF drive frequency

electrode_name = 'RF'
etrap = assign_trap_rf_single_pair(etrap, prefix, suffix, V0_rf, electrode_name, Ω_e=omega_rf, l0=1e-3)

# %%
rf_null_z, rf_null_index = analyze_trap_height(etrap, find_saddle=1)  # if find_saddle is True, then use interpolation method to find exact RF null
# Out:
# exact_saddle.py: Saddle point out of bounds in axial direction.
# Approximated RF Null is at (0.00, 0.08, 105.00) um, exact RF null is at (3.75, 75.00, 105.00) um
# z index of rf null is 0

# %%
# analyze_d_eff(etrap, dc_electrode='DC1', direction='z', force_center=False)  # if force_center is True, then RF null is manually set to z=0

# %%
# etrap.x = -51.4
# gap_top = -7.929
# middle_electrode = -77
# etrap.y = (gap_top+middle_electrode/2)/(a0*1e6) + 43.69;

# %%
# coord_x, coord_y, coord_z = etrap.result_rf1.grid.to_xyz()
# # etrap.x, etrap.y, etrap.z = coord_y, coord_z, coord_x
# etrap.pp_rf = np.transpose(etrap.pp_rf, axes=(1,2,0))

# %%
def parabola(x, x0, amp, b):
    return amp * (x - x0)**2 + b

# def analyze_radial_frequency(trap, fit_range=10e-6, 
#                              debug=False):
#     '''
#     Analyze the radial frequency and plot
    
#     Parameters
#     ----------
#     trap : Trap object
#         The trap being analyzed
#     fit_range : [m]
#         Fit range of the pseudo potential, default 10um.
#         Note the unit, in SI!
    
#     Returns
#     -------
#     omega_x : [MHz]
#         Frequency in x direction
#     omega_y : [MHz]
#         Frequency in y direction

#     Plots
#     -----
#     plot 1: x&y (um) line cut of pseudop, fit, and deviation
#     plot 2: 2D color map (um) of pseudopotential (eV)
#     '''
#     c = trap.rf_null_index
#     x, y = trap.x, trap.y 

#     ### Setup axes ###
#     scale = trap.l0
#     pp_rf = trap.pp_rf 
#     a = int(np.floor(pp_rf.shape[0]/2))
#     b = int(np.floor(pp_rf.shape[1]/2))
#     x_SI = x*scale
#     y_SI = y*scale
#     px = pp_rf[:, b, c]*e # in J, SI units
#     py = pp_rf[a,:,c]*e # in J
    
#     fit_xlim1 = x_SI[np.argmin(px)]-fit_range
#     fit_xlim2 = x_SI[np.argmin(px)]+fit_range
#     argx1 = np.argmin(np.abs(x_SI - fit_xlim1))
#     argx2 = np.argmin(np.abs(x_SI - fit_xlim2))
#     if debug: 
#         print(argx1,argx2)
#     fit_ylim1 = y_SI[np.argmin(py)]-fit_range
#     fit_ylim2 = y_SI[np.argmin(py)]+fit_range
#     argy1 = np.argmin(np.abs(y_SI - fit_ylim1))
#     argy2 = np.argmin(np.abs(y_SI - fit_ylim2))
#     if debug: 
#         print(argy1,argy2)
    
#     ### fit the data ###
#     poptx, pcovx = curve_fit(parabola, x_SI[argx1:argx2], px[argx1:argx2], p0 = [x_SI[np.argmin(px)], 1E7, 0], xtol=1e-10)
#     x0 = poptx[0]
#     x_amp = poptx[1]
#     x_coordinates = x_SI #- x0
    
#     popty, pcovy = curve_fit(parabola, y_SI[argy1:argy2],py[argy1:argy2], p0 = [y_SI[np.argmin(py)], 1E7, 0], xtol=1e-10)
#     y0 = popty[0]
#     print(y0)
#     y_amp = popty[1]
#     y_coordinates = y_SI #- y0
#     trap.rf_null_x = x0 * 1e6
#     trap.rf_null_y = y0 * 1e6  # in um
    
#     ### Find trap frequencies ###
#     k = 1
#     x_range = np.linspace(k*x_coordinates[0],k*x_coordinates[-1], 1000)
#     y_range = np.linspace(k*y_coordinates[0],k*y_coordinates[-1], 1000)
#     fit_x = parabola(x_range, *poptx) #parabola0(x_range, x_amp)
#     fit_y = parabola(y_range, *popty) #parabola0(y_range, y_amp)
#     fit_x_match = parabola(x_coordinates, *poptx) #parabola0(x_coordinates, x_amp)
#     fit_y_match = parabola(y_coordinates, *popty) #parabola0(y_coordinates, y_amp)
    
#     d2Udx2 = 2*x_amp
#     trapf_x = TrapFrequency(d2Udx2,m)
#     print(f'x trap frequency is about {trapf_x/1E6:.3f} MHz')
#     d2Udy2 = 2*y_amp
#     trapf_y = TrapFrequency(d2Udy2,m)
#     print(f'y trap frequency is about {trapf_y/1E6:.3f} MHz')
    
#     ### Plot pseudo-potential fit ###
#     small_plt_font()
    
#     fig, (ax1, ax2) = plt.subplots(2,1,sharex = True, 
#                                    gridspec_kw={'height_ratios': [3, 1]},
#                                    figsize=(3.4,3.5), dpi = 200)
#     ax1.plot(x*scale*1e6, pp_rf[:, b, c],label = "Pseudo potential along x")
#     ax1.plot(x_range*1E6, fit_x/e, '--', label = f"Fit, $f_x$ = {trapf_x/1E6:.2f} MHz")
#     ax1.plot(y*scale*1e6,pp_rf[a,:,c],label = "Pseudo potential along y")
#     ax1.plot(y_range*1E6, fit_y/e, '--', label = f"Fit, $f_y$ = {trapf_y/1E6:.2f} MHz")
#     ax1.grid()
#     ax1.legend()
#     ax1.set_ylim(-1E-3, k**2*np.max(px)*1.1/e)
#     ax1.set_ylabel('Pseudopotential (eV)', size = 8)
    
#     ax2.plot(x_coordinates*1E6,(px-fit_x_match)/e, '-', color = 'C1', label='$x$')
#     ax2.plot(y_coordinates*1E6,(py-fit_y_match)/e, '-', color = 'C3', label='$y$')
#     ax2.set_xlabel('Distance (um)', size = 8)
#     ax2.set_ylabel('$\Delta$ (eV)', size = 8)
#     ax2.set_ylim(-0.05, 0.05)
#     ax2.set_xlim(k*x_coordinates[0]*1E6, k*x_coordinates[-1]*1E6)
#     ax2.axhline(y = 0, color = 'grey', linestyle = '-.')
#     ax2.grid()
#     ax2.legend()
#     fig.align_ylabels()
#     fig.tight_layout()
#     # plt.savefig('Electron_3layer_pseudo_y_1p6GHz_90V.png', bbox_inches = 'tight')
    
#     plt.show()
    
    

#     return trapf_x, trapf_y

def analyze_radial_frequency(trap,
                             fit_range=10e-6,
                             rf_null_index=None,
                             debug=False):
    """
    Analyze the radial frequency and plot x/y potentials with fits.

    Parameters
    ----------
    trap : Trap object
        Needs attributes .x, .y, .l0, .pp_rf (shape [Nx, Ny, Nz])
    fit_range : float
        Half‐width around the null to fit (in meters)
    rf_null_index : int, optional
        Which slice of the 3rd dimension to use as the RF null.
        Defaults to trap.rf_null_index (if present) or center slice.
    debug : bool
        If True, prints out the fitting‐window indices.

    Returns
    -------
    trapf_x, trapf_y : float
        Trap frequencies in x and y (Hz).
    """
    # --- pick the RF‐null slice ---
    if rf_null_index is not None:
        c = rf_null_index
    else:
        c = getattr(trap, 'rf_null_index',
                    trap.pp_rf.shape[2] // 2)

    # --- mid‐points in x and y ---
    a = trap.pp_rf.shape[0] // 2
    b = trap.pp_rf.shape[1] // 2

    # --- axes in SI ---
    x_SI = trap.x * trap.l0
    y_SI = trap.y * trap.l0

    # --- raw pseudopotential cuts, converted to Joules ---
    px = trap.pp_rf[:, b, c] * e
    py = trap.pp_rf[a, :, c] * e

    # --- locate the minima and build fit windows ---
    ix0 = np.argmin(px)
    iy0 = np.argmin(py)
    argx = np.where(np.abs(x_SI - x_SI[ix0]) < fit_range)[0]
    argy = np.where(np.abs(y_SI - y_SI[iy0]) < fit_range)[0]
    if debug:
        print("x‐fit indices:", argx[0], "→", argx[-1])
        print("y‐fit indices:", argy[0], "→", argy[-1])

    # --- parabola fits: parabola(z; z0, A, offset) = A*(z-z0)**2 + offset ---
    poptx, _ = curve_fit(
        parabola,
        x_SI[argx],
        px[argx],
        p0=[x_SI[ix0], 1e7, 0],
        xtol=1e-10
    )
    popty, _ = curve_fit(
        parabola,
        y_SI[argy],
        py[argy],
        p0=[y_SI[iy0], 1e7, 0],
        xtol=1e-10
    )

    # --- extract null positions & curvature ---
    x0, x_amp = poptx[0], poptx[1]
    y0, y_amp = popty[0], popty[1]
    trap.rf_null_x = x0 * 1e6
    trap.rf_null_y = y0 * 1e6

    # --- trap frequencies (Hz) ---
    trapf_x = TrapFrequency(2 * x_amp, m)
    trapf_y = TrapFrequency(2 * y_amp, m)

    # --- smooth curves for plotting ---
    x_fit = np.linspace(x_SI[argx][0], x_SI[argx][-1], 500)
    y_fit = np.linspace(y_SI[argy][0], y_SI[argy][-1], 500)
    fx = parabola(x_fit, *poptx)
    fy = parabola(y_fit, *popty)
    fx_data = parabola(x_SI[argx], *poptx)
    fy_data = parabola(y_SI[argy], *popty)

    # --- now plot in a 2×2 grid ---
    small_plt_font()
    fig, ((ax_x_raw, ax_y_raw), (ax_x_res, ax_y_res)) = plt.subplots(
        2, 2,
        figsize=(7, 7), dpi=200,
        gridspec_kw={'height_ratios': [3, 1], 'width_ratios': [1, 1]}
    )

    # Raw + fit for X
    ax_x_raw.plot(x_SI * 1e6, trap.pp_rf[:, b, c], label="Raw X")
    ax_x_raw.plot(x_fit * 1e6, fx / e, '--',
                  label=f"Fit X ({trapf_x/1e6:.2f} MHz)")
    ax_x_raw.set_title("X-cut Pseudopotential")
    ax_x_raw.set_ylabel("Energy (eV)")
    ax_x_raw.legend()
    ax_x_raw.grid(True)

    # Residual for X
    ax_x_res.plot((x_SI[argx] - x0) * 1e6,
                  (px[argx] - fx_data) / e, '-')
    ax_x_res.axhline(0, color='grey', linestyle='-.')
    ax_x_res.set_xlabel("Δx (µm)")
    ax_x_res.set_ylabel("ΔE (eV)")
    ax_x_res.grid(True)

    # Raw + fit for Y
    ax_y_raw.plot(y_SI * 1e6, trap.pp_rf[a, :, c], label="Raw Y")
    ax_y_raw.plot(y_fit * 1e6, fy / e, '--',
                  label=f"Fit Y ({trapf_y/1e6:.2f} MHz)")
    ax_y_raw.set_title("Y-cut Pseudopotential")
    ax_y_raw.legend()
    ax_y_raw.grid(True)

    # Residual for Y
    ax_y_res.plot((y_SI[argy] - y0) * 1e6,
                  (py[argy] - fy_data) / e, '-')
    ax_y_res.axhline(0, color='grey', linestyle='-.')
    ax_y_res.set_xlabel("Δy (µm)")
    ax_y_res.set_ylabel("ΔE (eV)")
    ax_y_res.grid(True)

    fig.tight_layout()
    plt.show()

    return trapf_x, trapf_y

# %%
trapf_x, trapf_y = analyze_radial_frequency(etrap, fit_range=5e-5)

# %%
trap_depth = analyze_trap_depth(etrap)

# %%
plot_pseudo_contour(etrap, clim=(-9, 3))  # set the color limits in logscale using clim

# %%
plot_pseudo_contour(etrap, clim=(-4, 3))  # set the color limits in logscale using clim

# %%
Vs, depths = analyze_trap_frequencies(etrap, beta=1/2*(min(trapf_x, trapf_y)/(omega_rf/2/np.pi)), drive_range=(10e-3, 30e-3))

# %%
etrap.rf_null_y
# Out:
# np.float64(75.23718291113909)

# %% [markdown]
# # Multipole control

# %%
etrap.z, etrap.rf_null_x
# Out:
# (array([0.105, 0.106, 0.107, 0.108, 0.109, 0.11 , 0.111, 0.112, 0.113,
#         0.114, 0.115]),
#  np.float64(3.7183033725827928))

# %%
etrap.rf_null_x/1000
# Out:
# np.float64(0.003718303372582793)

# %%
# create MultipoleControl object, print the multipole_expansion and inverse matrix
controlled_electrodes = [f"DC{i}" for i in range(1, 21)]

rf_electrodes = ['RF']
used_order1multipoles = ['Ey', 'Ez', 'Ex']
used_order2multipoles = ['U3', 'U4', 'U2', 'U5', 'U1']
used_multipoles = used_order1multipoles + used_order2multipoles
# position = [etrap.rf_null_x/1000,etrap.rf_null_y/1000, etrap.z[len(etrap.z)//2]/1000] # trap location, in mm unit
print("etrap.rf_null_x/1000", etrap.rf_null_x/1000)
print("etrap.rf_null_y/1000", etrap.rf_null_y/1000)
print("etrap.z[len(etrap.z)//2]/1000", etrap.z[len(etrap.z)//2]/1000)
position = [etrap.rf_null_x/1000,etrap.rf_null_y/1000,etrap.z[len(etrap.z)//2]/1000] # trap location, in mm unit

nROI = 0.01 # expand the field in a 2*10 um cube
roi = [nROI,nROI,nROI]
order = 4 # expansion order

s = config_multipoles(etrap, position, roi, controlled_electrodes, used_multipoles, order, plot_multipoles=0)
s.rf_elecs = rf_electrodes
print('Multipole names:', s.multipole_names)
print('Normalization factors:', s.normalization_factors)

# s.pinv_matrix
s.multipole_expansion
# Out:
# etrap.rf_null_x/1000 0.003718303372582793
# etrap.rf_null_y/1000 0.07523718291113908
# etrap.z[len(etrap.z)//2]/1000 0.00011
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[252], line 18
#      15 roi = [nROI,nROI,nROI]
#      16 order = 4 # expansion order
# ---> 18 s = config_multipoles(etrap, position, roi, controlled_electrodes, used_multipoles, order, plot_multipoles=0)
#      19 s.rf_elecs = rf_electrodes
#      20 print('Multipole names:', s.multipole_names)
#
# File c:\users\photonics\documents\working\paultrapanalysis\PaulTrapAnalysis\extensions\Electron.py:1166, in config_multipoles(trap, position, nROI, controlled_electrodes, used_multipoles, order, plot_multipoles, debug)
#    1163 if debug:
#    1164     print(used_multipoles)
# -> 1166 s = MultipoleControl(trap, position, roi, controlled_electrodes, used_multipoles, order)
#    1167 v1 = pd.Series(np.zeros(len(controlled_electrodes)), index = controlled_electrodes)
#    1168 vs = []
#
# File c:\users\photonics\documents\working\paultrapanalysis\PaulTrapAnalysis\components\Multipoles.py:66, in MultipoleControl.__init__(self, trap, origin, roi, controlled_electrodes, used_multipoles, order)
#      63 self.order = order
#      65 # Below setting up origin and region of interest and so on
# ---> 66 self.update_origin_roi(origin, roi)
#
# File c:\users\photonics\documents\working\paultrapanalysis\PaulTrapAnalysis\components\Multipoles.py:84, in MultipoleControl.update_origin_roi(self, origin, roi)
#      80 z_slice = slice(self.origin[2] - self.roi[2], self.origin[2] + self.roi[2])
#      82 self.electrode_potential_roi = self.trap.individual_potential_contribution(x = x_slice, y = y_slice, z = z_slice)
# ---> 84 self.update_expansion_order(self.order)
#
# File c:\users\photonics\documents\working\paultrapanalysis\PaulTrapAnalysis\components\Multipoles.py:94, in MultipoleControl.update_expansion_order(self, order)
#      89 '''
#      90 This function updates expansion order, and also update everything related to them.
#      91 Can be called from object to update all related stuff.
#      92 '''
#      93 self.order = order
# ---> 94 self.multipole_expansion, self.electrode_potential_regenerated = self.expand_potentials_spherHarm(self.electrode_potential_roi, self.origin, order, self.multipole_names)
#      95 self.update_control(self.controlled_elecs, self.used_multipoles)
#
# File c:\users\photonics\documents\working\paultrapanalysis\PaulTrapAnalysis\components\Multipoles.py:134, in MultipoleControl.expand_potentials_spherHarm(potential_roi, r0, order, multipole_names)
#     132 Y_roi = potential_roi[ele].y
#     133 Z_roi = potential_roi[ele].z
# --> 134 Mj,Yj,scale = spher_harm_expansion(potential_roi[ele].values, r0, X_roi, Y_roi, Z_roi, order)
#     135 multipoles[ele] = pd.Series(Mj[0:N].T[0], index = multipoles_index_names)
#     137 Vregen = spher_harm_cmp(Mj,Yj,scale,order)
#
# File c:\users\photonics\documents\working\paultrapanalysis\PaulTrapAnalysis\functions\expansion.py:110, in spher_harm_expansion(potential_grid, r0, X, Y, Z, order, scale)
#     107 W=np.reshape(potential_grid,npts) # 1D array of all potential values
#     108 W=np.array([W]).T # make into column array
# --> 110 Yj, scale = spher_harm_basis(r0,X,Y,Z,order)
#     111 n_norm_rows = np.min([Yj.shape[1], len(NormsUptoOrder2)])
#     112 for row_ind in range(n_norm_rows):
#
# File c:\users\photonics\documents\working\paultrapanalysis\PaulTrapAnalysis\functions\expansion.py:66, in spher_harm_basis(r0, X, Y, Z, order, scale)
#      63 theta = np.arctan2(y,x)
#      65 # for now normalizing as in matlab code
# ---> 66 dl = Z[1]-Z[0]
#      67 scale = 1#np.sqrt(np.amax(r)*dl)
#      68 rs = r/(scale)
#
# File c:\Users\Photonics\.conda\envs\bem39\lib\site-packages\xarray\core\dataarray.py:891, in DataArray.__getitem__(self, key)
#     888     return self._getitem_coord(key)
#     889 else:
#     890     # xarray-style array indexing
# --> 891     return self.isel(indexers=self._item_key_to_dict(key))
#
# File c:\Users\Photonics\.conda\envs\bem39\lib\site-packages\xarray\core\dataarray.py:1527, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1522     return self._from_temp_dataset(ds)
#    1524 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    1525 # lists, or zero or one-dimensional np.ndarray's
# -> 1527 variable = self._variable.isel(indexers, missing_dims=missing_dims)
#    1528 indexes, index_variables = isel_indexes(self.xindexes, indexers)
#    1530 coords = {}
#
# File c:\Users\Photonics\.conda\envs\bem39\lib\site-packages\xarray\core\variable.py:1034, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1031 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1033 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1034 return self[key]
#
# File c:\Users\Photonics\.conda\envs\bem39\lib\site-packages\xarray\core\variable.py:801, in Variable.__getitem__(self, key)
#     798 dims, indexer, new_order = self._broadcast_indexes(key)
#     799 indexable = as_indexable(self._data)
# --> 801 data = indexing.apply_indexer(indexable, indexer)
#     803 if new_order:
#     804     data = np.moveaxis(data, range(len(new_order)), new_order)
#
# File c:\Users\Photonics\.conda\envs\bem39\lib\site-packages\xarray\core\indexing.py:1030, in apply_indexer(indexable, indexer)
#    1028     return indexable.oindex[indexer]
#    1029 else:
# -> 1030     return indexable[indexer]
#
# File c:\Users\Photonics\.conda\envs\bem39\lib\site-packages\xarray\core\indexing.py:1789, in PandasIndexingAdapter.__getitem__(self, indexer)
#    1786     indexable = NumpyIndexingAdapter(np.asarray(self))
#    1787     return indexable[indexer]
# -> 1789 result = self.array[key]
#    1791 return self._handle_result(result)
#
# File c:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pandas\core\indexes\base.py:5389, in Index.__getitem__(self, key)
#    5386 if is_integer(key) or is_float(key):
#    5387     # GH#44051 exclude bool, which would return a 2d ndarray
#    5388     key = com.cast_scalar_indexer(key)
# -> 5389     return getitem(key)
#    5391 if isinstance(key, slice):
#    5392     # This case is separated from the conditional above to avoid
#    5393     # pessimization com.is_bool_indexer and ndim checks.
#    5394     return self._getitem_slice(key)
#
# IndexError: index 1 is out of bounds for axis 0 with size 0

# %%
# plot voltage solution of a group of multipole coefficients
def plot_muls(height, position=None, ey=0, ez=0, ex=0, u3=0, u4=0, u2=-2, u5=0, u1=0):
    if position is not None: 
        position1 = position
    else:
        position1 = [0,0,height*1e-3]
    s.update_origin_roi(position1, roi)
    multipole_coeffs = {'Ey': ey, 'Ez':ez, 'Ex': ex, 'U3':u3, 'U4':u4, 'U2':u2, 'U5':u5, 'U1':u1}
    voltages = s.setMultipoles(multipole_coeffs)
    # fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20,12))
    fig, ax1 = plt.subplots(figsize = (10,8))
    ax1.bar(s.controlled_elecs, voltages)
    ax1.set_xticklabels(s.controlled_elecs, rotation = 45, fontsize = 12)
    plotting.add_value_labels(ax1)
#     ax1.set_ylim(-25, 40)
    ax1.set_ylabel('V')
    return voltages

# %%
def MHz_to_U2(f_MHz): 
    return 1/2*m*(2*np.pi*f_MHz*1e6)**2/1e6/e

# %%
MHz_to_U2(1)
# Out:
# 8.19925604027559

# %% [markdown]
# # Anharm analysis

# %%
DC_voltages = plot_muls(etrap.rf_null_z, position, u2=MHz_to_U2(1))  # compensating by changing m21 values
#Mj_DC0 = analyze_anharm_DC(s, np.around(DC_voltages, decimals=3), position, nROI, order=4, Mj_threshold=0.05)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[238], line 1
# ----> 1 DC_voltages = plot_muls(etrap.rf_null_z, position, u2=MHz_to_U2(1))  # compensating by changing m21 values
#       2 #Mj_DC0 = analyze_anharm_DC(s, np.around(DC_voltages, decimals=3), position, nROI, order=4, Mj_threshold=0.05)
#
# Cell In[235], line 7, in plot_muls(height, position, ey, ez, ex, u3, u4, u2, u5, u1)
#       5 else:
#       6     position1 = [0,0,height*1e-3]
# ----> 7 s.update_origin_roi(position1, roi)
#       8 multipole_coeffs = {'Ey': ey, 'Ez':ez, 'Ex': ex, 'U3':u3, 'U4':u4, 'U2':u2, 'U5':u5, 'U1':u1}
#       9 voltages = s.setMultipoles(multipole_coeffs)
#
# NameError: name 's' is not defined

# %%
Mj_DC0 = analyze_anharm_DC(s, DC_voltages, position, nROI, order=4, Mj_threshold=0.05)
# Out:
# >>> Fitting using ROI only
# >>> Using manual Harmonic Basis
# >>> Using Least Square
#             Mj
# C    1.140e-02
# Ey  -3.178e-15
# Ez   2.665e-15
# Ex   7.609e-15
# U3  -6.888e-17
# U4  -1.470e-13
# U2   8.199e+00
# U5   6.428e-14
# U1   1.009e-14
# 10  -2.192e+00
# 11  -6.722e-01
# 12   1.922e+00
# 13  -4.652e+00
# 14  -3.203e+00
# 15   1.162e-01
# 16  -2.262e-01
# 17   4.227e-01
# 18   1.342e+00
# 19  -2.848e+00
# 20  -1.858e+00
# 21  -1.847e+02
# 22   4.240e+01
# 23   4.450e+01
# 24  -1.675e+00
# 25  -7.433e-01

# %%
plot_frequency_shift(Mj_DC0, A=10)  # plot the projected frequency shifts at a given motional amplitude set by A

# %%
get_shift(j=31, Mj=13, M2=0.55, A=10)  # get the frequency shift of a term j with fitting coefficient Mj, with some M2 value and amplitude A
# Out:
# np.float64(6.777482898090263e-10)

# %%
display_harmonics_terms(21, 29, 31, 41, 42, 43, 45)
# Out:
# 21:
# 0.375*x**4 + 0.75*x**2*y**2 + 0.375*y**4 + z**4 - z**2*(3*x**2 + 3*y**2)
# 29:
# 210*x*y*z**3 - z*(105*x**3*y + 105*x*y**3)
# 31:
# z**5 - z**3*(5*x**2 + 5*y**2) + z*(1.875*x**4 + 3.75*x**2*y**2 + 1.875*y**4)
# 41:
# 26.25*x**5*y + 52.5*x**3*y**3 + 26.25*x*y**5 + 420*x*y*z**4 - z**2*(420*x**3*y + 420*x*y**3)
# 42:
# -21*y*z**5 + z**3*(52.5*x**2*y + 52.5*y**3) - z*(13.125*x**4*y + 26.25*x**2*y**3 + 13.125*y**5)
# 43:
# -0.3125*x**6 - 0.9375*x**4*y**2 - 0.9375*x**2*y**4 - 0.3125*y**6 + z**6 - z**4*(7.5*x**2 + 7.5*y**2) + z**2*(5.625*x**4 + 11.25*x**2*y**2 + 5.625*y**4)
# 45:
# 13.125*x**6 + 13.125*x**4*y**2 - 13.125*x**2*y**4 - 13.125*y**6 + z**4*(210*x**2 - 210*y**2) - z**2*(210*x**4 - 210*y**4)

# %%
Mj_RF0 = analyze_anharm_RF(s, [1], [0,0,0], nROI, order=6)
# Out:
# >>> Fitting using ROI only
# >>> Using manual Harmonic Basis
# >>> Using Least Square
#             Mj
# C    3.626e-01
# Ey  -9.643e-02
# Ez   3.285e-02
# Ex   7.495e-01
# U3   3.912e+00
# U4  -8.767e-02
# U2   6.758e-02
# U5   4.000e-03
# U1   7.684e+00
# 10   2.036e+01
# 11   4.296e-02
# 12  -2.930e-01
# 13  -2.197e-01
# 14   1.610e-02
# 15  -1.307e-02
# 16  -8.258e+00
# 17  -8.438e+00
# 18   5.686e-02
# 19  -1.725e-02
# 20  -2.684e+00
# 21  -2.308e+00
# 22  -3.025e-01
# 23   2.510e-01
# 24  -1.076e-01
# 25  -2.509e+01
# 26  -1.816e+01
# 27  -1.383e-01
# 28   1.600e+00
# 29   5.749e+00
# 30   5.421e+01
# 31  -6.806e+02
# 32   4.411e+01
# 33  -1.302e+00
# 34  -1.347e+00
# 35  -8.767e-01
# 36   2.039e+00
# 37  -6.699e+00
# 38  -1.624e-01
# 39  -9.405e+00
# 40   4.556e+01
# 41  -9.235e+01
# 42  -5.195e-01
# 43  -1.243e-03
# 44  -2.317e-01
# 45   3.287e-03
# 46  -2.032e+01
# 47   4.382e+00
# 48   6.243e-01
# 49   7.319e+00

# %% [markdown]
# # Trajectory stability

# %%
''' uncomment if needing to save Mj
import esim
scale = 1e3
order = 4
Mj_DC = data.rescale_Mj(Mj_DC0, scale, order).flatten()
Mj_RF = data.rescale_Mj(Mj_RF0, scale, order).flatten()
np.savez(os.path.join(esim.data_dir, f'3layer_v2_0_4.npz'), DC=Mj_DC[1:], RF=Mj_RF[1:], 
                                                                DC0=Mj_DC, RF0=Mj_RF)
'''
# Out:
# " uncomment if needing to save Mj\nimport esim\nscale = 1e3\norder = 4\nMj_DC = data.rescale_Mj(Mj_DC0, scale, order).flatten()\nMj_RF = data.rescale_Mj(Mj_RF0, scale, order).flatten()\nnp.savez(os.path.join(esim.data_dir, f'3layer_v2_0_4.npz'), DC=Mj_DC[1:], RF=Mj_RF[1:], \n                                                                DC0=Mj_DC, RF0=Mj_RF)\n"

# %%
def plot_trajectory():
    '''For a given set of voltages, simulate the trajectory of the particle to make sure it's stable
    do fft to extract the trap frequencies and compare with our expectation from the multipole values
    '''
