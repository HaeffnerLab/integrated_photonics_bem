# %%
import sys
import logging, os
from time import time
import numpy as np
import pyvista as pv
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
# %matplotlib notebook

import ipyparallel as ipp

from bem import Electrodes, Sphere, Cylinder, Mesh, Grid, Configuration, Result
from bem.formats import stl
from bem.bemColors_lib.bemColors import bemColors
from helper_functions import helper_functions
from collections import OrderedDict

# %%
prefix = "Trap_RF_cut_NOYCE_ww1cm2"

# %%
scale = 1e-8    # rescale factor 1 um.
use_stl = True

# load electrode faces from colored stl
# s_nta is intermediate processed stl file.
s_nta = stl.read_stl(open("%s.stl" % prefix, "rb"))
print("Import stl:",os.path.abspath("./"+prefix+".stl"),"\n")
print("Electrode colors (numbers):\n")
mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=scale/1e-6,rename={1:"1"})) # unit inside is um
# Out:
# Import stl: C:\Users\Photonics\Documents\Working\Photonics\noyce\Trap_RF_cut_NOYCE_ww1cm2.stl
#
# Electrode colors (numbers):
#
# dropping 3565
# dropping 15669
# dropping 1399
# dropping 11517
# dropping 20083
# dropping 19501
# dropping 7275
# dropping 1647
# dropping 19943
# dropping 9893
# dropping 28135
# dropping 5941
# dropping 5345
# dropping 5493
# dropping 27949
# dropping 10095
# dropping 10151
# dropping 28463
# dropping 15925
# dropping 13683
# dropping 15905
# dropping 25969
# dropping 5997
# dropping 13363
# mesh.gather() not working properly, be sure to have valid input

# %%
ele_col = bemColors(np.array(list(set(s_nta[2]))),('fusion360','export_stl'))
ele_col.set_my_color(value = (178,178,178),cl_format = ('fusion360','export_stl','RGBA64'),name = 'self_defined')
ele_col.print_stl_colors()
# Out:
# COLORS in the stl:
# ['bem6']
# ['bem13']
# ['bem19']
# ['bem17']
# ['bem11']
# ['bem15']
# ['bem1']
# ['bem12']
# ['bem5']
# ['bem22']
# ['bem18']
# ['bem16']
# ['bem3']
# ['bem7']
# ['bem23']
# ['bem9']
# ['bem2']
# ['bem4']
# ['bem20']
# ['bem10']
# ['bem14']
# ['bem8']
# ['bem21']
# ['_unkColor0']
# TOTAL COLORS:  24

# %%
# # assign a name for each color
# ele_col.color_electrode(color = '_unkColor0', name = 'DC11')
# ele_col.color_electrode(color = '_unkColor1', name = 'DC16')
# ele_col.color_electrode(color = '_unkColor2', name = 'DC7')
# ele_col.color_electrode(color = '_unkColor3', name = 'DC1')
# ele_col.color_electrode(color = '_unkColor4', name = 'DC2')
# ele_col.color_electrode(color = '_unkColor5', name = 'DC3')
# ele_col.color_electrode(color = '_unkColor6', name = 'DC4')
# ele_col.color_electrode(color = '_unkColor7', name = 'DC5')
# ele_col.color_electrode(color = '_unkColor8', name = 'DC6')
# ele_col.color_electrode(color = '_unkColor9', name = 'GND')
# ele_col.color_electrode(color = '_unkColor10', name = 'DC8')
# ele_col.color_electrode(color = '_unkColor11', name = 'DC9')
# ele_col.color_electrode(color = '_unkColor12', name = 'DC10')
# ele_col.color_electrode(color = '_unkColor13', name = 'DC20')
# ## ele_col.color_electrode(color = '_unkColor14', name = 'DC11')
# ele_col.color_electrode(color = '_unkColor15', name = 'DC12')
# ele_col.color_electrode(color = '_unkColor16', name = 'DC13')
# ele_col.color_electrode(color = '_unkColor17', name = 'DC14')
# ele_col.color_electrode(color = '_unkColor18', name = 'DC15')
# ## ele_col.color_electrode(color = '_unkColor19', name = 'DC16')
# ele_col.color_electrode(color = '_unkColor20', name = 'DC17')
# ele_col.color_electrode(color = '_unkColor21', name = 'DC18')
# ele_col.color_electrode(color = '_unkColor22', name = 'DC19')
# ele_col.color_electrode(color = '_unkColor23', name = 'RF')

ele_col.color_electrode(color = 'bem1',name = 'DC19')
ele_col.color_electrode(color = 'bem2',name = 'DC20')
ele_col.color_electrode(color = 'bem3',name = 'DC18')
ele_col.color_electrode(color = 'bem4',name = 'DC1')
ele_col.color_electrode(color = 'bem5',name = 'DC2')
ele_col.color_electrode(color = 'bem6',name = 'DC3')
ele_col.color_electrode(color = 'bem7',name = 'DC4')
ele_col.color_electrode(color = 'bem8',name = 'DC5')
ele_col.color_electrode(color = 'bem9',name = 'DC6')
ele_col.color_electrode(color = 'bem10',name = 'DC7')
ele_col.color_electrode(color = 'bem11',name = 'DC8')
ele_col.color_electrode(color = 'bem12',name = 'DC9')
ele_col.color_electrode(color = 'bem13',name = 'DC10')
ele_col.color_electrode(color = 'bem14',name = 'DC17')
ele_col.color_electrode(color = 'bem15',name = 'DC11')
ele_col.color_electrode(color = 'bem16',name = 'DC12')
ele_col.color_electrode(color = 'bem17',name = 'DC13')
ele_col.color_electrode(color = 'bem18',name = 'DC14')
ele_col.color_electrode(color = 'bem19',name = 'DC15')
ele_col.color_electrode(color = 'bem20',name = 'DC16')
ele_col.color_electrode(color = 'bem21',name = 'RF')
ele_col.color_electrode(color = 'bem22',name = 'GND')
# ele_col.color_electrode(color = 'bem23',name = 'DC19') 
# ele_col.color_electrode(color = '_unkColor0',name = 'DC20')


# # print colors still with no name. These meshes will be neglected in the following codes
ele_col.drop_colors()

# # read stl into mesh with electrode names
# # unnamed meshes will not be imported at all
mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=scale/1e-6,
    rename=ele_col.electrode_colors, quiet=False))
# Out:
# dropping color ['bem23']
# dropping color ['_unkColor0']
# TOTAL COLORS DROPPED:  2
# dropping 3565
# 13 planes in electrode DC9
# normals vectors:
#  [[ 2.35849235e-04  9.99999762e-01  6.66667183e-04]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00]
#  [ 1.52411885e-04  9.99999940e-01  2.35849046e-04]
#  [-2.35849118e-10  9.99999762e-01  6.66667183e-04]
#  [ 1.73611275e-04  1.00000000e+00  0.00000000e+00]
#  [ 6.40397688e-18  9.99999702e-01 -8.06452183e-04]
#  [-8.06452183e-04  9.99999702e-01 -9.99691975e-17]
#  [-8.28712396e-19  9.99999702e-01  8.06451368e-04]
#  [-3.53982286e-05  1.00000000e+00  3.53982286e-05]
#  [-2.80899148e-05  1.00000000e+00  2.80899148e-05]
#  [-9.96492236e-05  9.99999881e-01  4.46428516e-04]
#  [ 1.80011455e-04  9.99999642e-01  8.06451309e-04]
#  [-1.54886023e-16  1.00000000e+00  0.00000000e+00]]
# 12 planes in electrode DC5
# normals vectors:
#  [[-8.72817490e-18  9.99999762e-01  6.66667183e-04]
#  [ 1.52412118e-04  9.99999940e-01  2.35849046e-04]
#  [-1.04229955e-03  9.99998152e-01 -1.61290192e-03]
#  [-2.35849002e-04  9.99999762e-01  6.66667183e-04]
#  [-1.19617187e-04  9.99998689e-01 -1.61290274e-03]
#  [ 2.08333498e-04  9.99999821e-01  5.98118757e-04]
#  [ 8.06452183e-04  9.99999702e-01 -9.63739198e-17]
#  [-4.14766073e-05  1.00000000e+00  0.00000000e+00]
#  [ 8.84178216e-19  9.99999702e-01  8.06452183e-04]
#  [-4.46427562e-10  9.99997973e-01  1.99999800e-03]
#  [ 4.46428516e-04  9.99999881e-01  0.00000000e+00]
#  [-4.46427562e-10  9.99997973e-01 -1.99999800e-03]]
# 15 planes in electrode RF
# normals vectors:
#  [[ 0.00000000e+00  1.00000000e+00 -1.20347759e-05]
#  [ 3.01851287e-05  1.00000000e+00 -1.14753384e-05]
#  [-3.33331479e-03  9.99994457e-01 -1.04072060e-16]
#  [ 1.85184868e-03  9.99998271e-01 -9.85875015e-17]
#  [-4.16663056e-03  9.99991298e-01 -1.01383756e-16]
#  [ 3.33331479e-03  9.99994457e-01  0.00000000e+00]
#  [ 1.69145048e-03  9.99998569e-01  5.98443194e-06]
#  [-6.51896582e-04  9.99999762e-01 -2.30644105e-06]
#  [-1.32245733e-03  9.99998927e-01 -6.09756040e-04]
#  [ 2.09523821e-09  1.00000000e+00  6.66666500e-10]
#  [-9.08265938e-05  9.99999821e-01 -6.09756564e-04]
#  [ 6.29889721e-04  9.99999642e-01 -6.09756447e-04]
#  [-2.35848674e-10  9.99998331e-01  1.81818067e-03]
#  [ 2.35849046e-04  1.00000000e+00 -8.18265789e-17]
#  [-2.35848951e-10  9.99999762e-01 -6.66667183e-04]]
# dropping 20083
# 9 planes in electrode DC13
# normals vectors:
#  [[-5.00000497e-05  1.00000000e+00  4.99992420e-05]
#  [ 5.33049091e-11  9.99999702e-01  8.06452183e-04]
#  [ 5.21150359e-04  9.99999523e-01  8.06452066e-04]
#  [-2.35849063e-10  1.00000000e+00 -2.45479730e-16]
#  [ 7.13775662e-05  9.99999702e-01  8.06451368e-04]
#  [ 5.40034322e-04  9.99999523e-01  8.06451251e-04]
#  [-4.46428807e-04  9.99999881e-01 -2.35849146e-10]
#  [-8.92857497e-04  9.99999404e-01  6.66666892e-04]
#  [-2.35848868e-10  9.99999762e-01 -6.66667183e-04]]
# 11 planes in electrode DC4
# normals vectors:
#  [[-8.19672932e-05  1.00000000e+00  8.19672932e-05]
#  [ 2.53807357e-05  1.00000000e+00 -2.53807357e-05]
#  [ 4.39560426e-05  1.00000000e+00 -4.39560426e-05]
#  [ 4.64900040e-05  1.00000000e+00 -0.00000000e+00]
#  [-8.92857206e-04  9.99999583e-01  0.00000000e+00]
#  [-6.04363217e-04  9.99999762e-01  2.35849249e-04]
#  [-4.46428516e-04  9.99999881e-01  3.30084405e-17]
#  [-1.82481876e-04  9.99999642e-01 -8.06452124e-04]
#  [-5.21150592e-04  9.99999523e-01 -8.06452066e-04]
#  [ 0.00000000e+00  9.99999762e-01  6.66667183e-04]
#  [-2.35849063e-10  1.00000000e+00  6.66666278e-10]]
# 11 planes in electrode DC20
# normals vectors:
#  [[-1.54885718e-16  9.99997973e-01  1.99999590e-03]
#  [ 3.46779183e-04  9.99999821e-01  4.46428952e-04]
#  [-6.26440218e-04  9.99999464e-01 -8.06451193e-04]
#  [-4.46428981e-04  9.99999881e-01  0.00000000e+00]
#  [-1.17508775e-04  9.99999642e-01 -8.06451368e-04]
#  [-1.02564176e-04  9.99999762e-01 -7.03888014e-04]
#  [-8.06452124e-04  9.99999702e-01 -1.71233860e-11]
#  [ 0.00000000e+00  9.99999702e-01 -8.06451368e-04]
#  [-2.35848924e-10  1.00000000e+00  0.00000000e+00]
#  [-5.21150359e-04  9.99999523e-01 -8.06451251e-04]
#  [-8.18232305e-17  9.99999762e-01  6.66667183e-04]]
# 9 planes in electrode DC12
# normals vectors:
#  [[ 4.46428865e-04  9.99999702e-01  6.66666427e-04]
#  [ 7.34922593e-04  9.99999702e-01  2.35849220e-04]
#  [ 4.46428516e-04  9.99999881e-01 -0.00000000e+00]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00]
#  [-1.91563013e-05  1.00000000e+00  1.91571071e-05]
#  [-2.21619016e-18  9.99999702e-01 -8.06451368e-04]
#  [-8.06451368e-04  9.99999702e-01 -9.96951161e-17]
#  [ 2.35849293e-04  1.00000000e+00  0.00000000e+00]
#  [-2.85301183e-04  9.99999642e-01 -8.06451309e-04]]
# 9 planes in electrode DC10
# normals vectors:
#  [[-2.35849235e-04  9.99999762e-01  6.66667183e-04]
#  [-4.71698819e-04  9.99999881e-01 -8.06451295e-10]
#  [-3.19286279e-04  9.99999940e-01  2.35849278e-04]
#  [-2.35849046e-04  1.00000000e+00 -2.31319219e-16]
#  [ 0.00000000e+00  1.00000000e+00 -8.06451406e-10]
#  [ 0.00000000e+00  9.99999702e-01 -8.06451368e-04]
#  [-7.81451352e-04  9.99999702e-01 -2.49999921e-05]
#  [-6.26439753e-04  9.99999464e-01 -8.06451193e-04]
#  [ 4.46427395e-10  9.99997973e-01  1.99999800e-03]]
# 10 planes in electrode DC18
# normals vectors:
#  [[-8.09716294e-05  9.99999583e-01  8.87423754e-04]
#  [ 0.00000000e+00  9.99998689e-01  1.61290192e-03]
#  [ 1.25287776e-03  9.99997914e-01  1.61290064e-03]
#  [-4.46428311e-10  1.00000000e+00  0.00000000e+00]
#  [ 7.87933648e-04  9.99999702e-01  1.85185127e-05]
#  [ 8.84956607e-05  1.00000000e+00 -8.84948531e-05]
#  [ 0.00000000e+00  9.99998689e-01 -1.61290192e-03]
#  [-1.04229932e-03  9.99998152e-01 -1.61290111e-03]
#  [-2.35849002e-04  9.99999762e-01  6.66667183e-04]
#  [ 4.46427643e-04  9.99997914e-01 -1.99999590e-03]]
# 5 planes in electrode DC2
# normals vectors:
#  [[-4.46428981e-04  9.99999881e-01  9.91271475e-17]
#  [-5.46078198e-04  9.99999762e-01  4.46428894e-04]
#  [-8.92857672e-04  9.99999583e-01  0.00000000e+00]
#  [-4.46428079e-04  9.99997914e-01  1.99999777e-03]
#  [ 6.13120596e-11  1.00000000e+00  0.00000000e+00]]
# 7 planes in electrode DC14
# normals vectors:
#  [[-2.35849046e-04  1.00000000e+00 -2.31296455e-16]
#  [ 1.62427286e-17  1.00000000e+00 -8.06451406e-10]
#  [ 1.72405908e-05  1.00000000e+00 -1.72413966e-05]
#  [-8.76424747e-05  9.99999642e-01 -8.06452183e-04]
#  [ 0.00000000e+00  1.00000000e+00 -0.00000000e+00]
#  [-6.26439927e-04  9.99999464e-01 -8.06452008e-04]
#  [ 4.46427950e-10  9.99997973e-01  1.99999800e-03]]
# 5 planes in electrode DC17
# normals vectors:
#  [[-2.35849002e-04  9.99999762e-01  6.66666485e-04]
#  [-4.71698062e-04  9.99999881e-01  0.00000000e+00]
#  [-3.19286191e-04  9.99999940e-01  2.35849031e-04]
#  [-2.35849046e-04  1.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00]]
# 6 planes in electrode DC8
# normals vectors:
#  [[-0.00000000e+00  9.99999702e-01  8.06451368e-04]
#  [ 5.21150359e-04  9.99999523e-01  8.06452066e-04]
#  [-8.34371461e-11  1.00000000e+00  2.35849007e-10]
#  [ 2.35849235e-04  9.99999762e-01 -6.66667183e-04]
#  [ 7.74400076e-04  9.99999702e-01  3.20512736e-05]
#  [ 0.00000000e+00  9.99999762e-01 -6.66666543e-04]]
# 5 planes in electrode DC1
# normals vectors:
#  [[-4.46427643e-04  9.99997914e-01 -1.99999590e-03]
#  [-7.93207553e-04  9.99999583e-01 -4.46428399e-04]
#  [-4.46428516e-04  9.99999881e-01  0.00000000e+00]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00]
#  [-2.35849235e-04  9.99999762e-01  6.66667183e-04]]
# 8 planes in electrode DC15
# normals vectors:
#  [[ 2.35849002e-04  9.99999762e-01  6.66666485e-04]
#  [ 4.71698062e-04  9.99999881e-01  0.00000000e+00]
#  [-5.70601725e-04  9.99998510e-01 -1.61290087e-03]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00]
#  [-4.17361734e-05  9.99998689e-01 -1.61290111e-03]
#  [ 0.00000000e+00  9.99999702e-01 -8.06451368e-04]
#  [-8.06451368e-04  9.99999702e-01 -1.01709195e-16]
#  [-1.62866454e-05  1.00000000e+00  1.62866454e-05]]
# 6 planes in electrode DC11
# normals vectors:
#  [[ 2.45479677e-16  9.99999762e-01  6.66666543e-04]
#  [-2.35849046e-04  1.00000000e+00  0.00000000e+00]
#  [-8.34371604e-05  9.99999940e-01  2.35849046e-04]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00]
#  [-8.36383659e-18  9.99997973e-01  1.99999800e-03]
#  [ 3.46779736e-04  9.99999821e-01  4.46428487e-04]]
# 3 planes in electrode GND
# normals vectors:
#  [[ 0.00000000e+00  9.99999940e-01  3.33333301e-04]
#  [ 6.89747249e-05  9.99999940e-01  2.35849046e-04]
#  [ 0.00000000e+00  1.00000000e+00 -0.00000000e+00]]
# 9 planes in electrode DC7
# normals vectors:
#  [[ 0.00000000e+00  9.99999762e-01 -6.66666543e-04]
#  [ 2.35849046e-04  1.00000000e+00  0.00000000e+00]
#  [ 8.34371604e-05  9.99999940e-01 -2.35849046e-04]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00]
#  [-3.41180821e-05  1.00000000e+00  0.00000000e+00]
#  [-3.27332564e-05  1.00000000e+00  3.27332564e-05]
#  [-4.46428366e-10  9.99999762e-01  6.66667183e-04]
#  [ 4.46428516e-04  9.99999881e-01  0.00000000e+00]
#  [-4.46428366e-10  9.99999762e-01 -6.66667183e-04]]
# 11 planes in electrode DC3
# normals vectors:
#  [[-7.37462906e-05  9.99999642e-01  8.06451368e-04]
#  [ 1.51445256e-17  9.99998689e-01  1.61290111e-03]
#  [ 1.61290111e-03  9.99998689e-01 -9.96037028e-17]
#  [-2.35848951e-10  9.99999762e-01 -6.66666543e-04]
#  [-1.52412031e-04  9.99999940e-01 -2.35849278e-04]
#  [ 5.21150068e-04  9.99999523e-01  8.06451251e-04]
#  [ 2.35849293e-04  1.00000000e+00  6.66666222e-10]
#  [ 5.28820390e-11  1.00000000e+00  8.06451128e-10]
#  [ 4.96277789e-05  9.99999702e-01  7.56823632e-04]
#  [ 8.30374775e-04  9.99999642e-01 -2.39234359e-05]
#  [ 4.46428865e-04  9.99999702e-01 -6.66667125e-04]]
# 12 planes in electrode DC16
# normals vectors:
#  [[-3.76505923e-05  9.99998689e-01 -1.61290192e-03]
#  [ 3.59712212e-05  1.00000000e+00 -3.59712212e-05]
#  [ 9.24460758e-17  1.00000000e+00 -9.24460758e-17]
#  [ 2.35849235e-04  9.99999762e-01  6.66667183e-04]
#  [ 4.71698440e-04  9.99999881e-01  2.35848813e-10]
#  [-5.70602017e-04  9.99998510e-01 -1.61290169e-03]
#  [ 1.63653158e-16  1.00000000e+00  0.00000000e+00]
#  [-1.61030708e-04  9.99999642e-01 -8.06452124e-04]
#  [ 1.34228292e-04  9.99999762e-01  6.72223920e-04]
#  [ 7.90778198e-04  9.99999702e-01  1.56739916e-05]
#  [-9.86462925e-04  9.99999166e-01 -8.06451775e-04]
#  [ 4.46428505e-10  9.99999762e-01  6.66667183e-04]]
# 8 planes in electrode DC6
# normals vectors:
#  [[-3.57781610e-05  9.99999642e-01  8.42229463e-04]
#  [ 0.00000000e+00  9.99998689e-01  1.61290111e-03]
#  [ 1.97291980e-03  9.99996781e-01  1.61289796e-03]
#  [ 1.09589169e-16  1.00000000e+00 -1.63653158e-16]
#  [ 7.75776512e-04  9.99999702e-01  3.06748370e-05]
#  [ 1.52412031e-04  9.99999940e-01  2.35849278e-04]
#  [-6.54613159e-18  9.99999762e-01  6.66667183e-04]
#  [ 4.46428428e-04  9.99999702e-01 -6.66666427e-04]]
# 4 planes in electrode DC19
# normals vectors:
#  [[ 2.35849002e-04  9.99999762e-01  6.66666485e-04]
#  [ 3.88260902e-04  9.99999881e-01  2.35849031e-04]
#  [ 2.35849046e-04  1.00000000e+00 -0.00000000e+00]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00]]

# %%
mesh.plot()

# %%
print(len(mesh.points))
# Out:
# 719

# %%
mesh.triangulate(opts="q20Q",new = False);
# Out:
# start triangulate DC9
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC9
# start triangulate DC5
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC5
# start triangulate RF
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate RF
# start triangulate DC13
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC13
# start triangulate DC4
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC4
# start triangulate DC20
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC20
# start triangulate DC12
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC12
# start triangulate DC10
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC10
# start triangulate DC18
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC18
# start triangulate DC2
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC2
# start triangulate DC14
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC14
# start triangulate DC17
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC17
# start triangulate DC8
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC8
# start triangulate DC1
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC1
# start triangulate DC15
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC15
# start triangulate DC11
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC11
# start triangulate GND
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate GND
# start triangulate DC7
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC7
# start triangulate DC3
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC3
# start triangulate DC16
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC16
# start triangulate DC6
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC6
# start triangulate DC19
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# final opts q20Qzr
# finish triangulate DC19

# %%
mesh.plot()

# %%
print(len(mesh.points))
# Out:
# 27205

# %%
mesh.areas_from_constraints(Sphere(center=np.array([0., 0., 0]),
           radius=5, inside=0.1, outside=1.))    # "inside", "outside" set different mesh densities.
# mesh.areas_from_constraints(Sphere(center=np.array([0., 0., 1]),
#            radius=3.5, inside=0.1, outside=5))    # "inside", "outside" set different mesh densities.
# retriangulate quality and quiet with areas
mesh.triangulate(opts="q20Q", new=False)
# save base mesh to vtk
mesh.to_vtk(prefix)
print("Output vtk:",os.path.abspath("./"+prefix+".vtk"))    # output path
# Out:
# start triangulate DC9
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC9
# start triangulate DC5
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC5
# start triangulate RF
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate RF
# start triangulate DC13
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC13
# start triangulate DC4
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC4
# start triangulate DC20
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC20
# start triangulate DC12
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC12
# start triangulate DC10
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC10
# start triangulate DC18
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC18
# start triangulate DC2
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC2
# start triangulate DC14
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC14
# start triangulate DC17
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC17
# start triangulate DC8
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC8
# start triangulate DC1
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC1
# start triangulate DC15
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC15
# start triangulate DC11
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC11
# start triangulate GND
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate GND
# start triangulate DC7
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC7
# start triangulate DC3
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC3
# start triangulate DC16
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC16
# start triangulate DC6
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC6
# start triangulate DC19
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC19
# Output vtk: C:\Users\Photonics\Documents\Working\Photonics\noyce\Trap_RF_cut_NOYCE_ww1cm2.vtk

# %%
mesh.plot()

# %%
print(len(mesh.points))
# Out:
# 45193

# %%
def run_job(args):
    # job is Configuration instance.
    job, grid, prefix = args
    # refine twice adaptively with increasing number of triangles, min angle 15 deg.
#     job.adapt_mesh(triangles=4e2, opts="q0.1Q")
#     job.adapt_mesh(triangles=1e3, opts="q0.1Q")
    # solve for surface charges
    job.solve_singularities(num_mom=4, num_lev=3, max_iter=400)
    # get potentials and fields
    # RF_field = (job.name=="RF1") or (job.name=="RF2") or (job.name=="RF0")
    RF_field = "RF" in job.name
    result = job.simulate(grid, field=RF_field, num_lev=2)    # For "RF", field=True computes the field.
    result.to_vtk(prefix)
    print("finished job %s" % job.name)
    return job.collect_charges()

# %%
# grid to evalute potential and fields atCreate a grid in unit of scaled length l. Only choose the interested region (trap center) to save time.
s = 0.005 # step 0.01*100 (scale) = 1 um
Lx, Ly, Lz = 0.6, 0.3, 0.2   # in the unit of scaled length l, z=0 is the bottom of substrate, z = 30um is the top of metal
sx, sy, sz = s, s, s
# ni is grid point number, si is step size. Thus to fix size on i direction you need to fix ni*si.
# nx, ny, nz = [2*np.ceil(L/2.0/s).astype('int')+1 for L in (Lx, Ly, Lz)]
nx = 2*np.ceil(Lx/2.0/sx).astype('int')+1 
ny = 2*np.ceil(Ly/2.0/sy).astype('int')+1 
nz = 2*np.ceil(Lz/2.0/sz).astype('int')+1 
print("Size/l:", Lx, Ly, Lz)
print("Step/l:", sx, sy, sz)
print("Shape (grid point numbers):", nx, ny, nz)
grid = Grid(center=(0, 0, 0), step=(sx, sy, sz), shape=(nx, ny, nz))
# Grid center (nx, ny ,nz)/2 is shifted to origin
print("Grid origin/l:", grid.get_origin()[0])
x, y, z = grid.to_xyz()
# Out:
# Size/l: 0.6 0.3 0.2
# Step/l: 0.005 0.005 0.005
# Shape (grid point numbers): 121 61 41
# Grid origin/l: -0.3

# %%
pv.global_theme.notebook = False
def plot_grid_mesh_stl(grid, mesh):
    plotter = pv.Plotter()
    
    # Convert the mesh to PolyData and add it to the plotter
    pd = mesh.to_polydata()
    plotter.add_mesh(pd, scalars='electrode_name', show_edges=True)
    
    # Add the grid points
    x, y, z = np.meshgrid(grid.to_xyz()[0], grid.to_xyz()[1], grid.to_xyz()[2])
    grid_points = np.vstack([x.ravel(), y.ravel(), z.ravel()]).T
    plotter.add_points(grid_points, color='red', point_size=5)
    
    plotter.show_bounds()
    plotter.add_camera_orientation_widget()
    plotter.show()

# Call the function to plot everything together
plot_grid_mesh_stl(grid, mesh)

# %%
jobs = list(Configuration.select(mesh, "RF"))    # select() picks one electrode each time.
# jobs = list(Configuration.select(mesh, "RF"))    # select() picks one electrode each time.
# jobs = list(Configuration.select(mesh, "DC.*")) 



# parallel computation
mycluster = ipp.Cluster()
mycluster.start_cluster_sync()
c = mycluster.connect_client_sync()
c.wait_for_engines()

t0 = time()
# Run a parallel map, executing the wrapper function on indices 0,...,n-1
lview = c.load_balanced_view()
# Cause execution on main process to wait while tasks sent to workers finish
lview.block = True 
asyncresult = lview.map_async(run_job, ((job, grid, prefix) for job in jobs))   # Run calculation in parallel
asyncresult.wait_interactive()
print("Computing time: %f s"%(time()-t0))
# Out:
# Starting 32 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/32 [00:00<?, ?engine/s]
# run_job:   0%|          | 0/1 [00:00<?, ?tasks/s]
# Computing time: 1904.500763 s

# %%
print(len(mesh.points))
# Out:
# 10644898

# %%
import ipyparallel as ipp
from time import time
import psutil

# Select jobs
jobs = list(Configuration.select(mesh, "DC"))    

# Parallel computation setup
mycluster = ipp.Cluster()
mycluster.start_cluster_sync()
c = mycluster.connect_client_sync()
c.wait_for_engines()

# Limit engines to 30
selected_engines = c.ids[:30] if len(c.ids) > 30 else c.ids

# Track memory usage function
def check_memory():
    mem = psutil.virtual_memory()
    print(f"Memory Usage: {mem.percent}% - Available: {mem.available / 1e9:.2f} GB")

# Create a direct view on selected engines
lview = c.direct_view(targets=selected_engines)
lview.block = True

# Run calculation in parallel
t0 = time()
check_memory()

# Run in smaller batches to avoid memory overload
batch_size = min(100, len(jobs))  # Adjust batch size as needed
for i in range(0, len(jobs), batch_size):
    asyncresult = lview.map_async(run_job, ((job, grid, prefix) for job in jobs[i:i + batch_size]))
    asyncresult.wait_interactive()
    check_memory()

print("Computing time: %f s" % (time() - t0))
# Out:
# Starting 32 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/32 [00:00<?, ?engine/s]
# Memory Usage: 35.9% - Available: 43.88 GB
# run_job:   0%|          | 0/20 [00:00<?, ?tasks/s]
# Memory Usage: 13.2% - Available: 59.45 GB
# Computing time: 416.745864 s

# %%
jobs = list(Configuration.select(mesh, "DC"))
for job in jobs:
    run_job((job, grid, prefix))
# Out:
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\grid.py:514: PyVistaDeprecationWarning: `dims` argument is deprecated. Please use `dimensions`.
#   warnings.warn(
# finished job DC14
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\grid.py:514: PyVistaDeprecationWarning: `dims` argument is deprecated. Please use `dimensions`.
#   warnings.warn(
# finished job DC1

# %%
jobs = list(Configuration.select(mesh, "DC"))    # select() picks one electrode each time.
# jobs = list(Configuration.select(mesh, "RF"))    # select() picks one electrode each time.
# jobs = list(Configuration.select(mesh, "DC.*")) 



# parallel computation
mycluster = ipp.Cluster()
mycluster.start_cluster_sync()
c = mycluster.connect_client_sync()
c.wait_for_engines()

t0 = time()
# Run a parallel map, executing the wrapper function on indices 0,...,n-1
lview = c.load_balanced_view()
# Cause execution on main process to wait while tasks sent to workers finish
lview.block = True 
asyncresult = lview.map_async(run_job, ((job, grid, prefix) for job in jobs))   # Run calculation in parallel
asyncresult.wait_interactive()
print("Computing time: %f s"%(time()-t0))
# Out:
# Starting 32 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/32 [00:00<?, ?engine/s]
# run_job:   0%|          | 0/20 [00:00<?, ?tasks/s]
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-22.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-22.log'
# Output for 22:
# 2025-02-20 17:35:01.779 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:01.779 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:01.781 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:01.785 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63353']
# 2025-02-20 17:35:01.786 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:01.786 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:01.786 [IPEngine] Connecting shell to tcp://127.0.0.1:63353
# 2025-02-20 17:35:01.786 [IPEngine] Starting nanny
# 2025-02-20 17:35:02.270 [KernelNanny.22] Starting kernel nanny for engine 22, pid=27572, nanny pid=21560
# 2025-02-20 17:35:02.270 [KernelNanny.22] Nanny watching parent pid 27572.
# 2025-02-20 17:35:02.369 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:02.381 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:02.381 [IPEngine] Completed registration with id 22
# 2025-02-20 17:35:08.146 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_9
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 146320 byte request)
#  Q2M  matrix memory allocated: 1760803447373 kilobytes
#  Q2L  matrix memory allocated: 4275065654500917 kilobytes
#  Q2P  matrix memory allocated: 9558498 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 4159948264541519 kilobytes
#  Miscellaneous mem. allocated: 968973 kilobytes
#  Total memory (check w/above):4161709078516365 kilobytes
#
# 2025-02-20 17:38:53.932 [KernelNanny.22] Parent 27572 exited with status -1073741819.
# 2025-02-20 17:38:53.948 [KernelNanny.22] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-14.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-14.log'
# Output for 14:
# 2025-02-20 17:35:00.930 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:00.930 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:00.932 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:00.937 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63353']
# 2025-02-20 17:35:00.938 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:00.938 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:00.938 [IPEngine] Connecting shell to tcp://127.0.0.1:63353
# 2025-02-20 17:35:00.943 [IPEngine] Starting nanny
# 2025-02-20 17:35:01.423 [KernelNanny.14] Starting kernel nanny for engine 14, pid=27052, nanny pid=27860
# 2025-02-20 17:35:01.423 [KernelNanny.14] Nanny watching parent pid 27052.
# 2025-02-20 17:35:01.513 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:01.527 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:01.528 [IPEngine] Completed registration with id 14
# 2025-02-20 17:35:08.169 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_14
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 200144 byte request)
#  Q2M  matrix memory allocated: 2969553273356 kilobytes
#  Q2L  matrix memory allocated: 11008228057000443 kilobytes
#  Q2P  matrix memory allocated: 19716119 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 10893110667041046 kilobytes
#  Miscellaneous mem. allocated:2536941 kilobytes
#  Total memory (check w/above):10896080242567463 kilobytes
#
# 2025-02-20 17:38:54.006 [KernelNanny.14] Parent 27052 exited with status -1073741819.
# 2025-02-20 17:38:54.027 [KernelNanny.14] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-21.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-21.log'
# Output for 21:
# 2025-02-20 17:35:01.663 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:01.663 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:01.665 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:01.670 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63354']
# 2025-02-20 17:35:01.671 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:01.671 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:01.671 [IPEngine] Connecting shell to tcp://127.0.0.1:63354
# 2025-02-20 17:35:01.671 [IPEngine] Starting nanny
# 2025-02-20 17:35:02.158 [KernelNanny.21] Starting kernel nanny for engine 21, pid=24544, nanny pid=24856
# 2025-02-20 17:35:02.159 [KernelNanny.21] Nanny watching parent pid 24544.
# 2025-02-20 17:35:02.264 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:02.279 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:02.280 [IPEngine] Completed registration with id 21
# 2025-02-20 17:35:08.152 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_10
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 297824 byte request)
#  Q2M  matrix memory allocated: 1955197962158 kilobytes
#  Q2L  matrix memory allocated: 9770621273469091 kilobytes
#  Q2P  matrix memory allocated: 10838031 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 9655503883509694 kilobytes
#  Miscellaneous mem. allocated:2248552 kilobytes
#  Total memory (check w/above):9657459094558436 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-13.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-13.log'
# Output for 13:
# 2025-02-20 17:35:00.813 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:00.813 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:00.815 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:00.820 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63354']
# 2025-02-20 17:35:00.821 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:00.821 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:00.821 [IPEngine] Connecting shell to tcp://127.0.0.1:63354
# 2025-02-20 17:35:00.821 [IPEngine] Starting nanny
# 2025-02-20 17:35:01.298 [KernelNanny.13] Starting kernel nanny for engine 13, pid=24220, nanny pid=27408
# 2025-02-20 17:35:01.299 [KernelNanny.13] Nanny watching parent pid 24220.
# 2025-02-20 17:35:01.389 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:01.429 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:01.429 [IPEngine] Completed registration with id 13
# 2025-02-20 17:35:08.182 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_17
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 297824 byte request)
#  Q2M  matrix memory allocated: 1736609896595 kilobytes
#  Q2L  matrix memory allocated: 424877784330928 kilobytes
#  Q2P  matrix memory allocated: 8662056 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 309760394371530 kilobytes
#  Miscellaneous mem. allocated:  72526 kilobytes
#  Total memory (check w/above):311497013002708 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-27.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-27.log'
# Output for 27:
# 2025-02-20 17:35:02.314 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:02.314 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:02.316 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:02.344 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63354']
# 2025-02-20 17:35:02.345 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:02.345 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:02.345 [IPEngine] Connecting shell to tcp://127.0.0.1:63354
# 2025-02-20 17:35:02.346 [IPEngine] Starting nanny
# 2025-02-20 17:35:02.788 [KernelNanny.27] Starting kernel nanny for engine 27, pid=29152, nanny pid=29544
# 2025-02-20 17:35:02.789 [KernelNanny.27] Nanny watching parent pid 29152.
# 2025-02-20 17:35:02.858 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:02.867 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:02.867 [IPEngine] Completed registration with id 27
# 2025-02-20 17:35:08.133 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_6
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 297824 byte request)
#  Q2M  matrix memory allocated: 1726319154954 kilobytes
#  Q2L  matrix memory allocated: 15806792019486965 kilobytes
#  Q2P  matrix memory allocated: 7948470 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 15691674629527568 kilobytes
#  Miscellaneous mem. allocated:3653904 kilobytes
#  Total memory (check w/above):15693400960284897 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-26.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-26.log'
# Output for 26:
# 2025-02-20 17:35:02.202 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:02.202 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:02.204 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:02.208 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63353']
# 2025-02-20 17:35:02.209 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:02.209 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:02.209 [IPEngine] Connecting shell to tcp://127.0.0.1:63353
# 2025-02-20 17:35:02.209 [IPEngine] Starting nanny
# 2025-02-20 17:35:02.673 [KernelNanny.26] Starting kernel nanny for engine 26, pid=29236, nanny pid=31684
# 2025-02-20 17:35:02.673 [KernelNanny.26] Nanny watching parent pid 29236.
# 2025-02-20 17:35:02.767 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:02.776 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:02.776 [IPEngine] Completed registration with id 26
# 2025-02-20 17:35:08.157 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_11
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 297824 byte request)
#  Q2M  matrix memory allocated: 1720563898777 kilobytes
#  Q2L  matrix memory allocated: 14092738603935334 kilobytes
#  Q2P  matrix memory allocated: 7549385 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 13977621213975937 kilobytes
#  Miscellaneous mem. allocated:3254819 kilobytes
#  Total memory (check w/above):13979341788678919 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-18.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-18.log'
# Output for 18:
# 2025-02-20 17:35:01.354 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:01.354 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:01.356 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:01.361 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63353']
# 2025-02-20 17:35:01.361 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:01.362 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:01.362 [IPEngine] Connecting shell to tcp://127.0.0.1:63353
# 2025-02-20 17:35:01.366 [IPEngine] Starting nanny
# 2025-02-20 17:35:01.857 [KernelNanny.18] Starting kernel nanny for engine 18, pid=22852, nanny pid=8092
# 2025-02-20 17:35:01.858 [KernelNanny.18] Nanny watching parent pid 22852.
# 2025-02-20 17:35:01.949 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:01.964 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:01.964 [IPEngine] Completed registration with id 18
# 2025-02-20 17:35:08.176 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_16
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 297824 byte request)
#  Q2M  matrix memory allocated: 1732336404135 kilobytes
#  Q2L  matrix memory allocated: 17598873239776395 kilobytes
#  Q2P  matrix memory allocated: 8365721 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 17483755849816997 kilobytes
#  Miscellaneous mem. allocated:4071157 kilobytes
#  Total memory (check w/above):17485488198658012 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-10.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-10.log'
# Output for 10:
# 2025-02-20 17:35:00.481 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:00.481 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:00.483 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:00.488 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63353']
# 2025-02-20 17:35:00.489 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:00.489 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:00.489 [IPEngine] Connecting shell to tcp://127.0.0.1:63353
# 2025-02-20 17:35:00.490 [IPEngine] Starting nanny
# 2025-02-20 17:35:00.978 [KernelNanny.10] Starting kernel nanny for engine 10, pid=27588, nanny pid=30048
# 2025-02-20 17:35:00.979 [KernelNanny.10] Nanny watching parent pid 27588.
# 2025-02-20 17:35:01.070 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:01.105 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:01.106 [IPEngine] Completed registration with id 10
# 2025-02-20 17:35:08.193 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_19
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 146320 byte request)
#  Q2M  matrix memory allocated: 1743370175119 kilobytes
#  Q2L  matrix memory allocated: 1724229258227744 kilobytes
#  Q2P  matrix memory allocated: 8964585 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 1609111868268347 kilobytes
#  Miscellaneous mem. allocated: 375056 kilobytes
#  Total memory (check w/above):1610855247783108 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-31.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-31.log'
# Output for 31:
# 2025-02-20 17:35:02.710 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:02.710 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:02.712 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:02.721 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63354']
# 2025-02-20 17:35:02.721 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:02.721 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:02.722 [IPEngine] Connecting shell to tcp://127.0.0.1:63354
# 2025-02-20 17:35:02.722 [IPEngine] Starting nanny
# 2025-02-20 17:35:03.093 [KernelNanny.31] Starting kernel nanny for engine 31, pid=23640, nanny pid=28004
# 2025-02-20 17:35:03.094 [KernelNanny.31] Nanny watching parent pid 23640.
# 2025-02-20 17:35:03.156 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:03.176 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:03.176 [IPEngine] Completed registration with id 31
# 2025-02-20 17:35:08.106 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_1
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 297824 byte request)
#  Q2M  matrix memory allocated: 1719743560024 kilobytes
#  Q2L  matrix memory allocated: 13848422035002228 kilobytes
#  Q2P  matrix memory allocated: 7492501 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 13733304645042831 kilobytes
#  Miscellaneous mem. allocated:3197934 kilobytes
#  Total memory (check w/above):13735024399293291 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-20.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-20.log'
# Output for 20:
# 2025-02-20 17:35:01.569 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:01.569 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:01.571 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:01.576 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63353']
# 2025-02-20 17:35:01.576 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:01.577 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:01.577 [IPEngine] Connecting shell to tcp://127.0.0.1:63353
# 2025-02-20 17:35:01.577 [IPEngine] Starting nanny
# 2025-02-20 17:35:02.074 [KernelNanny.20] Starting kernel nanny for engine 20, pid=25308, nanny pid=25584
# 2025-02-20 17:35:02.074 [KernelNanny.20] Nanny watching parent pid 25308.
# 2025-02-20 17:35:02.166 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:02.176 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:02.177 [IPEngine] Completed registration with id 20
# 2025-02-20 17:35:08.141 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_8
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 146320 byte request)
#  Q2M  matrix memory allocated: 1761619491160 kilobytes
#  Q2L  matrix memory allocated: 4394469181303554 kilobytes
#  Q2P  matrix memory allocated: 9586298 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 4279351791344156 kilobytes
#  Miscellaneous mem. allocated: 996774 kilobytes
#  Total memory (check w/above):4281113421418389 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-30.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-30.log'
# Output for 30:
# 2025-02-20 17:35:02.622 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:02.622 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:02.624 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:02.628 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63353']
# 2025-02-20 17:35:02.629 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:02.629 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:02.629 [IPEngine] Connecting shell to tcp://127.0.0.1:63353
# 2025-02-20 17:35:02.629 [IPEngine] Starting nanny
# 2025-02-20 17:35:03.012 [KernelNanny.30] Starting kernel nanny for engine 30, pid=16716, nanny pid=11952
# 2025-02-20 17:35:03.012 [KernelNanny.30] Nanny watching parent pid 16716.
# 2025-02-20 17:35:03.078 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:03.087 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:03.087 [IPEngine] Completed registration with id 30
# 2025-02-20 17:35:08.164 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_13
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 297824 byte request)
#  Q2M  matrix memory allocated: 1722835936477 kilobytes
#  Q2L  matrix memory allocated: 14769405959776239 kilobytes
#  Q2P  matrix memory allocated: 7706934 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 14654288569816842 kilobytes
#  Miscellaneous mem. allocated:3412368 kilobytes
#  Total memory (check w/above):14656011416872622 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-24.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-24.log'
# Output for 24:
# 2025-02-20 17:35:01.997 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:01.997 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:01.999 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:02.003 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63353']
# 2025-02-20 17:35:02.004 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:02.004 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:02.004 [IPEngine] Connecting shell to tcp://127.0.0.1:63353
# 2025-02-20 17:35:02.004 [IPEngine] Starting nanny
# 2025-02-20 17:35:02.487 [KernelNanny.24] Starting kernel nanny for engine 24, pid=24664, nanny pid=21964
# 2025-02-20 17:35:02.488 [KernelNanny.24] Nanny watching parent pid 24664.
# 2025-02-20 17:35:02.571 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:02.582 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:02.583 [IPEngine] Completed registration with id 24
# 2025-02-20 17:35:08.121 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_3
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 146320 byte request)
#  Q2M  matrix memory allocated: 1741231281405 kilobytes
#  Q2L  matrix memory allocated: 1411266330081886 kilobytes
#  Q2P  matrix memory allocated: 8891717 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 1296148940122488 kilobytes
#  Miscellaneous mem. allocated: 302188 kilobytes
#  Total memory (check w/above):1297890180597801 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-9.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-9.log'
# Output for 9:
# 2025-02-20 17:35:00.371 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:00.371 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:00.373 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:00.377 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63354']
# 2025-02-20 17:35:00.378 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:00.378 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:00.378 [IPEngine] Connecting shell to tcp://127.0.0.1:63354
# 2025-02-20 17:35:00.379 [IPEngine] Starting nanny
# 2025-02-20 17:35:00.862 [KernelNanny.9] Starting kernel nanny for engine 9, pid=22580, nanny pid=1780
# 2025-02-20 17:35:00.863 [KernelNanny.9] Nanny watching parent pid 22580.
# 2025-02-20 17:35:00.953 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:00.967 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:00.967 [IPEngine] Completed registration with id 9
# 2025-02-20 17:35:08.172 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_15
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 297824 byte request)
#  Q2M  matrix memory allocated: 1720357740347 kilobytes
#  Q2L  matrix memory allocated: 14031339675617067 kilobytes
#  Q2P  matrix memory allocated: 7535090 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 13916222285657669 kilobytes
#  Miscellaneous mem. allocated:3240523 kilobytes
#  Total memory (check w/above):13917942654173630 kilobytes
#
# 2025-02-20 17:38:55.629 [KernelNanny.9] Parent 22580 exited with status -1073741819.
# 2025-02-20 17:38:55.633 [KernelNanny.9] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-19.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-19.log'
# Output for 19:
# 2025-02-20 17:35:01.458 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:01.458 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:01.460 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:01.464 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63354']
# 2025-02-20 17:35:01.465 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:01.465 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:01.466 [IPEngine] Connecting shell to tcp://127.0.0.1:63354
# 2025-02-20 17:35:01.466 [IPEngine] Starting nanny
# 2025-02-20 17:35:01.956 [KernelNanny.19] Starting kernel nanny for engine 19, pid=10248, nanny pid=29916
# 2025-02-20 17:35:01.956 [KernelNanny.19] Nanny watching parent pid 10248.
# 2025-02-20 17:35:02.048 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:02.071 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:02.079 [IPEngine] Completed registration with id 19
# 2025-02-20 17:35:08.116 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_2
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 297824 byte request)
#  Q2M  matrix memory allocated: 1726594032861 kilobytes
#  Q2L  matrix memory allocated: 15888657257244655 kilobytes
#  Q2P  matrix memory allocated: 7967530 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 15773539867285258 kilobytes
#  Miscellaneous mem. allocated:3672965 kilobytes
#  Total memory (check w/above):15775266472958615 kilobytes
#
# 2025-02-20 17:38:55.637 [KernelNanny.19] Parent 10248 exited with status -1073741819.
# 2025-02-20 17:38:55.641 [KernelNanny.19] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-2.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-2.log'
# Output for 2:
# 2025-02-20 17:34:59.525 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:34:59.525 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:34:59.527 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:34:59.531 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63353']
# 2025-02-20 17:34:59.532 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:34:59.532 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:34:59.532 [IPEngine] Connecting shell to tcp://127.0.0.1:63353
# 2025-02-20 17:34:59.533 [IPEngine] Starting nanny
# 2025-02-20 17:34:59.971 [KernelNanny.2] Starting kernel nanny for engine 2, pid=13676, nanny pid=29076
# 2025-02-20 17:34:59.971 [KernelNanny.2] Nanny watching parent pid 13676.
# 2025-02-20 17:35:00.058 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:00.068 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:00.069 [IPEngine] Completed registration with id 2
# 2025-02-20 17:35:08.188 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_18
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 146320 byte request)
#  Q2M  matrix memory allocated: 1752385311473 kilobytes
#  Q2L  matrix memory allocated: 3043324009589506 kilobytes
#  Q2P  matrix memory allocated: 9271710 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 2928206619630108 kilobytes
#  Miscellaneous mem. allocated: 682184 kilobytes
#  Total memory (check w/above):2929959014895477 kilobytes
#
# 2025-02-20 17:38:55.680 [KernelNanny.2] Parent 13676 exited with status -1073741819.
# 2025-02-20 17:38:55.684 [KernelNanny.2] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-29.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-29.log'
# Output for 29:
# 2025-02-20 17:35:02.524 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:02.524 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:02.526 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:02.530 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63354']
# 2025-02-20 17:35:02.531 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:02.531 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:02.531 [IPEngine] Connecting shell to tcp://127.0.0.1:63354
# 2025-02-20 17:35:02.532 [IPEngine] Starting nanny
# 2025-02-20 17:35:02.934 [KernelNanny.29] Starting kernel nanny for engine 29, pid=26736, nanny pid=27320
# 2025-02-20 17:35:02.934 [KernelNanny.29] Nanny watching parent pid 26736.
# 2025-02-20 17:35:03.003 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:03.012 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:03.013 [IPEngine] Completed registration with id 29
# 2025-02-20 17:35:08.125 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_4
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 297824 byte request)
#  Q2M  matrix memory allocated: 1735557629607 kilobytes
#  Q2L  matrix memory allocated: 111487421039771 kilobytes
#  Q2P  matrix memory allocated: 8589089 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 18443114104789925 kilobytes
#  Miscellaneous mem. allocated:4294526 kilobytes
#  Total memory (check w/above):18444849675303149 kilobytes
#
# 2025-02-20 17:38:55.699 [KernelNanny.29] Parent 26736 exited with status -1073741819.
# 2025-02-20 17:38:55.704 [KernelNanny.29] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-6.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-6.log'
# Output for 6:
# 2025-02-20 17:35:00.026 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:00.026 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:00.029 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:00.033 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63353']
# 2025-02-20 17:35:00.034 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:00.034 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:00.034 [IPEngine] Connecting shell to tcp://127.0.0.1:63353
# 2025-02-20 17:35:00.035 [IPEngine] Starting nanny
# 2025-02-20 17:35:00.503 [KernelNanny.6] Starting kernel nanny for engine 6, pid=24684, nanny pid=27232
# 2025-02-20 17:35:00.503 [KernelNanny.6] Nanny watching parent pid 24684.
# 2025-02-20 17:35:00.605 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:00.651 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:00.651 [IPEngine] Completed registration with id 6
# 2025-02-20 17:35:08.196 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_20
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 297824 byte request)
#  Q2M  matrix memory allocated: 1962662615318 kilobytes
#  Q2L  matrix memory allocated: 11993774136326356 kilobytes
#  Q2P  matrix memory allocated: 11355649 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 11878656746366959 kilobytes
#  Miscellaneous mem. allocated:2766172 kilobytes
#  Total memory (check w/above):11880619423104100 kilobytes
#
# 2025-02-20 17:38:55.750 [KernelNanny.6] Parent 24684 exited with status -1073741819.
# 2025-02-20 17:38:55.754 [KernelNanny.6] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-28.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-28.log'
# Output for 28:
# 2025-02-20 17:35:02.411 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:02.412 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:02.414 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:02.419 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63353']
# 2025-02-20 17:35:02.420 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:02.420 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:02.420 [IPEngine] Connecting shell to tcp://127.0.0.1:63353
# 2025-02-20 17:35:02.421 [IPEngine] Starting nanny
# 2025-02-20 17:35:02.848 [KernelNanny.28] Starting kernel nanny for engine 28, pid=30564, nanny pid=2928
# 2025-02-20 17:35:02.849 [KernelNanny.28] Nanny watching parent pid 30564.
# 2025-02-20 17:35:02.919 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:02.928 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:02.928 [IPEngine] Completed registration with id 28
# 2025-02-20 17:35:08.159 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_12
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 297824 byte request)
#  Q2M  matrix memory allocated: 1974194602508 kilobytes
#  Q2L  matrix memory allocated: 15428276689129439 kilobytes
#  Q2P  matrix memory allocated: 12155307 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 15313159299170041 kilobytes
#  Miscellaneous mem. allocated:3565832 kilobytes
#  Total memory (check w/above):15315133509493689 kilobytes
#
# 2025-02-20 17:38:55.777 [KernelNanny.28] Parent 30564 exited with status -1073741819.
# 2025-02-20 17:38:55.780 [KernelNanny.28] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-23.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-23.log'
# Output for 23:
# 2025-02-20 17:35:01.885 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:01.885 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:01.887 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:01.891 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63354']
# 2025-02-20 17:35:01.902 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:01.902 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:01.902 [IPEngine] Connecting shell to tcp://127.0.0.1:63354
# 2025-02-20 17:35:01.903 [IPEngine] Starting nanny
# 2025-02-20 17:35:02.386 [KernelNanny.23] Starting kernel nanny for engine 23, pid=20708, nanny pid=30268
# 2025-02-20 17:35:02.386 [KernelNanny.23] Nanny watching parent pid 20708.
# 2025-02-20 17:35:02.485 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:02.511 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:02.511 [IPEngine] Completed registration with id 23
# 2025-02-20 17:35:08.129 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_5
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 200144 byte request)
#  Q2M  matrix memory allocated: 3690192951050 kilobytes
#  Q2L  matrix memory allocated: 2409076671341658 kilobytes
#  Q2P  matrix memory allocated: 26303907 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 2293959281382260 kilobytes
#  Miscellaneous mem. allocated: 534963 kilobytes
#  Total memory (check w/above):2297649501172181 kilobytes
#
# 2025-02-20 17:38:55.908 [KernelNanny.23] Parent 20708 exited with status -1073741819.
# 2025-02-20 17:38:55.911 [KernelNanny.23] Notifying Hub that our parent has shut down
#
# Computing time: 233.023564 s
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1740101697-t04c-1740101698-25.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1740101697-t04c-1740101698-25.log'
# Output for 25:
# 2025-02-20 17:35:02.101 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-02-20 17:35:02.101 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-02-20 17:35:02.103 [IPEngine] Registering with controller at tcp://127.0.0.1:63346
# 2025-02-20 17:35:02.107 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:63348', 'tcp://127.0.0.1:63349', 'tcp://127.0.0.1:63354']
# 2025-02-20 17:35:02.107 [IPEngine] Connecting shell to tcp://127.0.0.1:63348
# 2025-02-20 17:35:02.107 [IPEngine] Connecting shell to tcp://127.0.0.1:63349
# 2025-02-20 17:35:02.107 [IPEngine] Connecting shell to tcp://127.0.0.1:63354
# 2025-02-20 17:35:02.113 [IPEngine] Starting nanny
# 2025-02-20 17:35:02.587 [KernelNanny.25] Starting kernel nanny for engine 25, pid=288, nanny pid=19860
# 2025-02-20 17:35:02.588 [KernelNanny.25] Nanny watching parent pid 288.
# 2025-02-20 17:35:02.688 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-02-20 17:35:02.698 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-02-20 17:35:02.698 [IPEngine] Completed registration with id 25
# 2025-02-20 17:35:08.137 [IPEngine] Handling apply_request: da416d73-13a778b637c1c5c4b8126b72_23564_7
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 297824 byte request)
#  Q2M  matrix memory allocated: 1735501795033 kilobytes
#  Q2L  matrix memory allocated: 94858544620240 kilobytes
#  Q2P  matrix memory allocated: 8585217 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 18426485228370395 kilobytes
#  Miscellaneous mem. allocated:4290654 kilobytes
#  Total memory (check w/above):18428220743041300 kilobytes
#
# 2025-02-20 17:39:01.072 [KernelNanny.25] Parent 288 exited with status -1073741819.
# 2025-02-20 17:39:01.075 [KernelNanny.25] Notifying Hub that our parent has shut down

# %%
Result.view(prefix, 'DC1')

# %%
Result.view(prefix, 'RF')
# Out:
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)

# %%
jobs = list(Configuration.select(mesh, "GND"))    # select() picks one electrode each time.
# jobs = list(Configuration.select(mesh, "RF"))    # select() picks one electrode each time.
# jobs = list(Configuration.select(mesh, "DC.*")) 



# parallel computation
mycluster = ipp.Cluster()
mycluster.start_cluster_sync()
c = mycluster.connect_client_sync()
c.wait_for_engines()

t0 = time()
# Run a parallel map, executing the wrapper function on indices 0,...,n-1
lview = c.load_balanced_view()
# Cause execution on main process to wait while tasks sent to workers finish
lview.block = True 
asyncresult = lview.map_async(run_job, ((job, grid, prefix) for job in jobs))   # Run calculation in parallel
asyncresult.wait_interactive()
print("Computing time: %f s"%(time()-t0))
# Out:
# Starting 32 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/32 [00:00<?, ?engine/s]
# run_job:   0%|          | 0/1 [00:00<?, ?tasks/s]
# Computing time: 120.904015 s

# %%
Result.view(prefix, 'GND')
