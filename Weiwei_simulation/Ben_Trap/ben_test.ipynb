# %%
import sys
import logging, os
from time import time
import numpy as np
import pyvista as pv
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
# %matplotlib notebook

import ipyparallel as ipp

from bem import Electrodes, Sphere, Cylinder, Mesh, Grid, Configuration, Result
from bem.formats import stl
from bem.bemColors_lib.bemColors import bemColors
from helper_functions import helper_functions
from collections import OrderedDict

# %%
prefix = "ben_trap2"

# %%
scale = 1e-7    # rescale factor 1 um.
use_stl = True

# load electrode faces from colored stl
# s_nta is intermediate processed stl file.
s_nta = stl.read_stl(open("%s.stl" % prefix, "rb"))
print("Import stl:",os.path.abspath("./"+prefix+".stl"),"\n")
print("Electrode colors (numbers):\n")
mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=scale/1e-6,rename={1:"1"})) # unit inside is um
# Out:
# Import stl: C:\Users\Photonics\Documents\Working\Photonics\Ben_Trap\ben_trap2.stl
#
# Electrode colors (numbers):
#
# dropping 19026
# dropping 4634
# dropping 10460
# dropping 590
# dropping 6218
# dropping 26892
# dropping 14612
# dropping 8836
# dropping 4436
# dropping 27406
# dropping 18886
# dropping 18444
# dropping 4288
# dropping 9094
# dropping 24912
# dropping 27536
# dropping 12306
# dropping 27078
# dropping 9038
# dropping 4884
# dropping 14848
# dropping 342
# dropping 4940
# dropping 12626
# mesh.gather() not working properly, be sure to have valid input

# %%
ele_col = bemColors(np.array(list(set(s_nta[2]))),('fusion360','export_stl'))
ele_col.set_my_color(value = (178,178,178),cl_format = ('fusion360','export_stl','RGBA64'),name = 'self_defined')
ele_col.print_stl_colors()
# Out:
# COLORS in the stl:
# ['_unkColor0']
# ['_unkColor1']
# ['_unkColor2']
# ['_unkColor3']
# ['_unkColor4']
# ['_unkColor5']
# ['_unkColor6']
# ['_unkColor7']
# ['_unkColor8']
# ['_unkColor9']
# ['_unkColor10']
# ['_unkColor11']
# ['_unkColor12']
# ['_unkColor13']
# ['_unkColor14']
# ['_unkColor15']
# ['_unkColor16']
# ['_unkColor17']
# ['_unkColor18']
# ['_unkColor19']
# ['_unkColor20']
# ['_unkColor21']
# ['_unkColor22']
# ['_unkColor23']
# TOTAL COLORS:  24

# %%
# # assign a name for each color
# ele_col.color_electrode(color = 'bem1',name = 'cutout1')
# ele_col.color_electrode(color = 'bem2',name = 'cutout2')
ele_col.color_electrode(color = '_unkColor23',name = 'GND')
ele_col.color_electrode(color = '_unkColor1',name = 'DC1')
ele_col.color_electrode(color = '_unkColor2',name = 'DC2')
ele_col.color_electrode(color = '_unkColor3',name = 'DC3')
ele_col.color_electrode(color = '_unkColor4',name = 'DC4')
ele_col.color_electrode(color = '_unkColor5',name = 'DC5')
ele_col.color_electrode(color = '_unkColor22',name = 'DC6')
ele_col.color_electrode(color = '_unkColor7',name = 'DC7')
ele_col.color_electrode(color = '_unkColor8',name = 'DC8')
ele_col.color_electrode(color = '_unkColor9',name = 'DC9')
ele_col.color_electrode(color = '_unkColor11',name = 'DC10')
ele_col.color_electrode(color = '_unkColor10',name = 'RF')
ele_col.color_electrode(color = '_unkColor12',name = 'DC11')
ele_col.color_electrode(color = '_unkColor13',name = 'DC12')
ele_col.color_electrode(color = '_unkColor14',name = 'DC13')
ele_col.color_electrode(color = '_unkColor15',name = 'DC14')
ele_col.color_electrode(color = '_unkColor16',name = 'DC15')
ele_col.color_electrode(color = '_unkColor17',name = 'DC16')
ele_col.color_electrode(color = '_unkColor18',name = 'DC17')
ele_col.color_electrode(color = '_unkColor0',name = 'DC18')
ele_col.color_electrode(color = '_unkColor20',name = 'DC19')
ele_col.color_electrode(color = '_unkColor21',name = 'DC20')

# # print colors still with no name. These meshes will be neglected in the following codes
ele_col.drop_colors()

# # read stl into mesh with electrode names
# # unnamed meshes will not be imported at all
mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=scale/1e-6,
    rename=ele_col.electrode_colors, quiet=False))
# Out:
# dropping color ['_unkColor6']
# dropping color ['_unkColor19']
# TOTAL COLORS DROPPED:  2
# dropping 19026
# 1 planes in electrode RF
# normals vectors:
#  [[2.08166830e-16 1.00000000e+00 3.70075286e-16]]
# 1 planes in electrode GND
# normals vectors:
#  [[2.22553301e-16 1.00000000e+00 2.65791236e-16]]
# 1 planes in electrode DC15
# normals vectors:
#  [[2.08166764e-16 1.00000000e+00 3.70075286e-16]]
# 1 planes in electrode DC13
# normals vectors:
#  [[2.08166764e-16 1.00000000e+00 3.70074703e-16]]
# 1 planes in electrode DC3
# normals vectors:
#  [[1.38777891e-16 1.00000000e+00 3.70074412e-16]]
# 1 planes in electrode DC8
# normals vectors:
#  [[1.38777891e-16 1.00000000e+00 3.70074253e-16]]
# 1 planes in electrode DC1
# normals vectors:
#  [[2.08166764e-16 1.00000000e+00 5.55111142e-16]]
# 1 planes in electrode DC20
# normals vectors:
#  [[2.77555783e-16 1.00000000e+00 5.55111512e-16]]
# 1 planes in electrode DC5
# normals vectors:
#  [[2.77555783e-16 1.00000000e+00 5.55111512e-16]]
# 1 planes in electrode DC11
# normals vectors:
#  [[1.38777891e-16 1.00000000e+00 5.55111406e-16]]
# 1 planes in electrode DC4
# normals vectors:
#  [[2.77555703e-16 1.00000000e+00 3.70074094e-16]]
# 1 planes in electrode DC10
# normals vectors:
#  [[2.08166764e-16 1.00000000e+00 3.70075286e-16]]
# 1 planes in electrode DC2
# normals vectors:
#  [[2.08166764e-16 1.00000000e+00 5.55111142e-16]]
# 1 planes in electrode DC17
# normals vectors:
#  [[2.08166764e-16 1.00000000e+00 3.70074094e-16]]
# dropping 27536
# 1 planes in electrode DC7
# normals vectors:
#  [[1.86418068e-16 1.00000000e+00 4.30833330e-16]]
# 1 planes in electrode DC12
# normals vectors:
#  [[2.31296455e-16 1.00000000e+00 4.00914405e-16]]
# 1 planes in electrode DC16
# normals vectors:
#  [[2.33731145e-16 1.00000000e+00 4.38246456e-16]]
# 1 planes in electrode DC9
# normals vectors:
#  [[2.36937853e-16 1.00000000e+00 4.36641037e-16]]
# 1 planes in electrode DC18
# normals vectors:
#  [[2.41352800e-16 1.00000000e+00 4.34435628e-16]]
# 1 planes in electrode DC6
# normals vectors:
#  [[1.93643524e-16 1.00000000e+00 2.77556021e-16]]
# 1 planes in electrode DC14
# normals vectors:
#  [[2.31296402e-16 1.00000000e+00 5.55112042e-16]]
# 1 planes in electrode DC19
# normals vectors:
#  [[1.63268023e-16 1.00000000e+00 2.77555703e-16]]

# %%
mesh.plot()

# %%
print(len(mesh.points))
# Out:
# 710

# %%
mesh.triangulate(opts="q20Q",new = False);
# Out:
# start triangulate RF
# final opts q20Qzr
# finish triangulate RF
# start triangulate GND
# final opts q20Qzr
# finish triangulate GND
# start triangulate DC15
# final opts q20Qzr
# finish triangulate DC15
# start triangulate DC13
# final opts q20Qzr
# finish triangulate DC13
# start triangulate DC3
# final opts q20Qzr
# finish triangulate DC3
# start triangulate DC8
# final opts q20Qzr
# finish triangulate DC8
# start triangulate DC1
# final opts q20Qzr
# finish triangulate DC1
# start triangulate DC20
# final opts q20Qzr
# finish triangulate DC20
# start triangulate DC5
# final opts q20Qzr
# finish triangulate DC5
# start triangulate DC11
# final opts q20Qzr
# finish triangulate DC11
# start triangulate DC4
# final opts q20Qzr
# finish triangulate DC4
# start triangulate DC10
# final opts q20Qzr
# finish triangulate DC10
# start triangulate DC2
# final opts q20Qzr
# finish triangulate DC2
# start triangulate DC17
# final opts q20Qzr
# finish triangulate DC17
# start triangulate DC7
# final opts q20Qzr
# finish triangulate DC7
# start triangulate DC12
# final opts q20Qzr
# finish triangulate DC12
# start triangulate DC16
# final opts q20Qzr
# finish triangulate DC16
# start triangulate DC9
# final opts q20Qzr
# finish triangulate DC9
# start triangulate DC18
# final opts q20Qzr
# finish triangulate DC18
# start triangulate DC6
# final opts q20Qzr
# finish triangulate DC6
# start triangulate DC14
# final opts q20Qzr
# finish triangulate DC14
# start triangulate DC19
# final opts q20Qzr
# finish triangulate DC19

# %%
mesh.plot()

# %%
print(len(mesh.points))
# Out:
# 1988

# %%
mesh.areas_from_constraints(Sphere(center=np.array([0., 0., 0]),
           radius=5, inside=0.01, outside=1.))    # "inside", "outside" set different mesh densities.
# mesh.areas_from_constraints(Sphere(center=np.array([0., 0., 1]),
#            radius=3.5, inside=0.1, outside=5))    # "inside", "outside" set different mesh densities.
# retriangulate quality and quiet with areas
mesh.triangulate(opts="q20Q", new=False)
# save base mesh to vtk
mesh.to_vtk(prefix)
print("Output vtk:",os.path.abspath("./"+prefix+".vtk"))    # output path
# Out:
# start triangulate RF
# final opts q20Qzra
# finish triangulate RF
# start triangulate GND
# final opts q20Qzra
# finish triangulate GND
# start triangulate DC15
# final opts q20Qzra
# finish triangulate DC15
# start triangulate DC13
# final opts q20Qzra
# finish triangulate DC13
# start triangulate DC3
# final opts q20Qzra
# finish triangulate DC3
# start triangulate DC8
# final opts q20Qzra
# finish triangulate DC8
# start triangulate DC1
# final opts q20Qzra
# finish triangulate DC1
# start triangulate DC20
# final opts q20Qzra
# finish triangulate DC20
# start triangulate DC5
# final opts q20Qzra
# finish triangulate DC5
# start triangulate DC11
# final opts q20Qzra
# finish triangulate DC11
# start triangulate DC4
# final opts q20Qzra
# finish triangulate DC4
# start triangulate DC10
# final opts q20Qzra
# finish triangulate DC10
# start triangulate DC2
# final opts q20Qzra
# finish triangulate DC2
# start triangulate DC17
# final opts q20Qzra
# finish triangulate DC17
# start triangulate DC7
# final opts q20Qzra
# finish triangulate DC7
# start triangulate DC12
# final opts q20Qzra
# finish triangulate DC12
# start triangulate DC16
# final opts q20Qzra
# finish triangulate DC16
# start triangulate DC9
# final opts q20Qzra
# finish triangulate DC9
# start triangulate DC18
# final opts q20Qzra
# finish triangulate DC18
# start triangulate DC6
# final opts q20Qzra
# finish triangulate DC6
# start triangulate DC14
# final opts q20Qzra
# finish triangulate DC14
# start triangulate DC19
# final opts q20Qzra
# finish triangulate DC19
# Output vtk: C:\Users\Photonics\Documents\Working\Photonics\Ben_Trap\ben_trap2.vtk

# %%
mesh.plot()

# %%
print(len(mesh.points))
# Out:
# 6272

# %%
def run_job(args):
    # job is Configuration instance.
    job, grid, prefix = args
    # refine twice adaptively with increasing number of triangles, min angle 15 deg.
#     job.adapt_mesh(triangles=4e2, opts="q0.1Q")
#     job.adapt_mesh(triangles=1e3, opts="q0.1Q")
    # solve for surface charges
    job.solve_singularities(num_mom=4, num_lev=3, max_iter=400)
    # get potentials and fields
    # RF_field = (job.name=="RF1") or (job.name=="RF2") or (job.name=="RF0")
    RF_field = "RF" in job.name
    result = job.simulate(grid, field=RF_field, num_lev=2)    # For "RF", field=True computes the field.
    result.to_vtk(prefix)
    print("finished job %s" % job.name)
    return job.collect_charges()

# %%
# grid to evalute potential and fields atCreate a grid in unit of scaled length l. Only choose the interested region (trap center) to save time.
s = 0.005 # step 0.01*100 (scale) = 1 um
Lx, Ly, Lz = 0.6, 0.3, 0.2   # in the unit of scaled length l, z=0 is the bottom of substrate, z = 30um is the top of metal
sx, sy, sz = s, s, s
# ni is grid point number, si is step size. Thus to fix size on i direction you need to fix ni*si.
# nx, ny, nz = [2*np.ceil(L/2.0/s).astype('int')+1 for L in (Lx, Ly, Lz)]
nx = 2*np.ceil(Lx/2.0/sx).astype('int')+1 
ny = 2*np.ceil(Ly/2.0/sy).astype('int')+1 
nz = 2*np.ceil(Lz/2.0/sz).astype('int')+1 
print("Size/l:", Lx, Ly, Lz)
print("Step/l:", sx, sy, sz)
print("Shape (grid point numbers):", nx, ny, nz)
grid = Grid(center=(0, 0, 0), step=(sx, sy, sz), shape=(nx, ny, nz))
# Grid center (nx, ny ,nz)/2 is shifted to origin
print("Grid origin/l:", grid.get_origin()[0])
x, y, z = grid.to_xyz()
# Out:
# Size/l: 0.6 0.3 0.2
# Step/l: 0.005 0.005 0.005
# Shape (grid point numbers): 121 61 41
# Grid origin/l: -0.3

# %%
pv.global_theme.notebook = False
def plot_grid_mesh_stl(grid, mesh):
    plotter = pv.Plotter()
    
    # Convert the mesh to PolyData and add it to the plotter
    pd = mesh.to_polydata()
    plotter.add_mesh(pd, scalars='electrode_name', show_edges=True)
    
    # Add the grid points
    x, y, z = np.meshgrid(grid.to_xyz()[0], grid.to_xyz()[1], grid.to_xyz()[2])
    grid_points = np.vstack([x.ravel(), y.ravel(), z.ravel()]).T
    plotter.add_points(grid_points, color='red', point_size=5)
    
    plotter.show_bounds()
    plotter.add_camera_orientation_widget()
    plotter.show()

# Call the function to plot everything together
plot_grid_mesh_stl(grid, mesh)

# %%
jobs = list(Configuration.select(mesh, "RF"))    # select() picks one electrode each time.
# jobs = list(Configuration.select(mesh, "RF"))    # select() picks one electrode each time.
# jobs = list(Configuration.select(mesh, "DC.*")) 



# parallel computation
mycluster = ipp.Cluster()
mycluster.start_cluster_sync()
c = mycluster.connect_client_sync()
c.wait_for_engines()

t0 = time()
# Run a parallel map, executing the wrapper function on indices 0,...,n-1
lview = c.load_balanced_view()
# Cause execution on main process to wait while tasks sent to workers finish
lview.block = True 
asyncresult = lview.map_async(run_job, ((job, grid, prefix) for job in jobs))   # Run calculation in parallel
asyncresult.wait_interactive()
print("Computing time: %f s"%(time()-t0))
# Out:
# Starting 32 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/32 [00:00<?, ?engine/s]
# run_job:   0%|          | 0/1 [00:00<?, ?tasks/s]
# Computing time: 218.040998 s

# %%
print(len(mesh.points))
# Out:
# 6272

# %%
import ipyparallel as ipp
from time import time
import psutil

# Select jobs
jobs = list(Configuration.select(mesh, "DC"))    

# Parallel computation setup
mycluster = ipp.Cluster()
mycluster.start_cluster_sync()
c = mycluster.connect_client_sync()
c.wait_for_engines()

# Limit engines to 30
selected_engines = c.ids[:30] if len(c.ids) > 30 else c.ids

# Track memory usage function
def check_memory():
    mem = psutil.virtual_memory()
    print(f"Memory Usage: {mem.percent}% - Available: {mem.available / 1e9:.2f} GB")

# Create a direct view on selected engines
lview = c.direct_view(targets=selected_engines)
lview.block = True

# Run calculation in parallel
t0 = time()
check_memory()

# Run in smaller batches to avoid memory overload
batch_size = min(100, len(jobs))  # Adjust batch size as needed
for i in range(0, len(jobs), batch_size):
    asyncresult = lview.map_async(run_job, ((job, grid, prefix) for job in jobs[i:i + batch_size]))
    asyncresult.wait_interactive()
    check_memory()

print("Computing time: %f s" % (time() - t0))
# Out:
# Starting 32 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/32 [00:00<?, ?engine/s]
# Memory Usage: 24.0% - Available: 52.06 GB
# run_job:   0%|          | 0/20 [00:00<?, ?tasks/s]
# Memory Usage: 12.8% - Available: 59.74 GB
# Computing time: 130.690303 s

# %%
jobs = list(Configuration.select(mesh, "DC"))
for job in jobs:
    run_job((job, grid, prefix))
# Out:
# KeyboardInterrupt

# %%
jobs = list(Configuration.select(mesh, "DC"))    # select() picks one electrode each time.
# jobs = list(Configuration.select(mesh, "RF"))    # select() picks one electrode each time.
# jobs = list(Configuration.select(mesh, "DC.*")) 



# parallel computation
mycluster = ipp.Cluster()
mycluster.start_cluster_sync()
c = mycluster.connect_client_sync()
c.wait_for_engines()

t0 = time()
# Run a parallel map, executing the wrapper function on indices 0,...,n-1
lview = c.load_balanced_view()
# Cause execution on main process to wait while tasks sent to workers finish
lview.block = True 
asyncresult = lview.map_async(run_job, ((job, grid, prefix) for job in jobs))   # Run calculation in parallel
asyncresult.wait_interactive()
print("Computing time: %f s"%(time()-t0))
# Out:
# Starting 32 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/32 [00:00<?, ?engine/s]
# run_job:   0%|          | 0/20 [00:00<?, ?tasks/s]
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-31.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-31.log'
# Output for 31:
# 2024-12-10 10:19:28.791 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:28.791 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:28.793 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:28.797 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55163']
# 2024-12-10 10:19:28.798 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:28.798 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:28.798 [IPEngine] Connecting shell to tcp://127.0.0.1:55163
# 2024-12-10 10:19:28.798 [IPEngine] Starting nanny
# 2024-12-10 10:19:29.165 [KernelNanny.31] Starting kernel nanny for engine 31, pid=19772, nanny pid=21432
# 2024-12-10 10:19:29.165 [KernelNanny.31] Nanny watching parent pid 19772.
# 2024-12-10 10:19:29.229 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:29.238 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:29.238 [IPEngine] Completed registration with id 31
# 2024-12-10 10:19:34.585 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_1
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2180078154809 kilobytes
#  Q2L  matrix memory allocated: 8440495998119182 kilobytes
#  Q2P  matrix memory allocated: 10491398 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 8166723976534425 kilobytes
#  Miscellaneous mem. allocated:1901971 kilobytes
#  Total memory (check w/above):8168904067082604 kilobytes
#
# 2024-12-10 10:22:37.837 [KernelNanny.31] Parent 19772 exited with status -1073741819.
# 2024-12-10 10:22:37.870 [KernelNanny.31] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-8.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-8.log'
# Output for 8:
# 2024-12-10 10:19:26.353 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:26.353 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:26.355 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:26.359 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55162']
# 2024-12-10 10:19:26.360 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:26.360 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:26.360 [IPEngine] Connecting shell to tcp://127.0.0.1:55162
# 2024-12-10 10:19:26.360 [IPEngine] Starting nanny
# 2024-12-10 10:19:26.815 [KernelNanny.8] Starting kernel nanny for engine 8, pid=19132, nanny pid=11004
# 2024-12-10 10:19:26.816 [KernelNanny.8] Nanny watching parent pid 19132.
# 2024-12-10 10:19:26.907 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:26.918 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:26.919 [IPEngine] Completed registration with id 8
# 2024-12-10 10:19:34.785 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_15
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2180185528991 kilobytes
#  Q2L  matrix memory allocated: 8530291738370113 kilobytes
#  Q2P  matrix memory allocated: 10512305 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 8256519716785356 kilobytes
#  Miscellaneous mem. allocated:1922878 kilobytes
#  Total memory (check w/above):8258699914749532 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-25.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-25.log'
# Output for 25:
# 2024-12-10 10:19:28.181 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:28.181 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:28.183 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:28.187 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55163']
# 2024-12-10 10:19:28.188 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:28.188 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:28.188 [IPEngine] Connecting shell to tcp://127.0.0.1:55163
# 2024-12-10 10:19:28.189 [IPEngine] Starting nanny
# 2024-12-10 10:19:28.655 [KernelNanny.25] Starting kernel nanny for engine 25, pid=10940, nanny pid=21232
# 2024-12-10 10:19:28.655 [KernelNanny.25] Nanny watching parent pid 10940.
# 2024-12-10 10:19:28.733 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:28.744 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:28.744 [IPEngine] Completed registration with id 25
# 2024-12-10 10:19:34.605 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_4
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2180636500557 kilobytes
#  Q2L  matrix memory allocated: 8907433847424024 kilobytes
#  Q2P  matrix memory allocated: 10600115 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 8633661825839267 kilobytes
#  Miscellaneous mem. allocated:2010688 kilobytes
#  Total memory (check w/above):8635842474950630 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-22.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-22.log'
# Output for 22:
# 2024-12-10 10:19:27.856 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:27.856 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:27.858 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:27.863 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55162']
# 2024-12-10 10:19:27.863 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:27.864 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:27.864 [IPEngine] Connecting shell to tcp://127.0.0.1:55162
# 2024-12-10 10:19:27.864 [IPEngine] Starting nanny
# 2024-12-10 10:19:28.349 [KernelNanny.22] Starting kernel nanny for engine 22, pid=18292, nanny pid=3060
# 2024-12-10 10:19:28.350 [KernelNanny.22] Nanny watching parent pid 18292.
# 2024-12-10 10:19:28.457 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:28.469 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:28.469 [IPEngine] Completed registration with id 22
# 2024-12-10 10:19:34.708 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_7
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2178338693054 kilobytes
#  Q2L  matrix memory allocated: 6985805006054096 kilobytes
#  Q2P  matrix memory allocated: 10152701 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 6712032984469340 kilobytes
#  Miscellaneous mem. allocated:1563274 kilobytes
#  Total memory (check w/above):6714211334878370 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-4.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-4.log'
# Output for 4:
# 2024-12-10 10:19:25.838 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:25.838 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:25.840 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:25.844 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55162']
# 2024-12-10 10:19:25.845 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:25.845 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:25.845 [IPEngine] Connecting shell to tcp://127.0.0.1:55162
# 2024-12-10 10:19:25.845 [IPEngine] Starting nanny
# 2024-12-10 10:19:26.311 [KernelNanny.4] Starting kernel nanny for engine 4, pid=14344, nanny pid=14864
# 2024-12-10 10:19:26.311 [KernelNanny.4] Nanny watching parent pid 14344.
# 2024-12-10 10:19:26.401 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:26.413 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:26.413 [IPEngine] Completed registration with id 4
# 2024-12-10 10:19:34.795 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_16
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2180048090038 kilobytes
#  Q2L  matrix memory allocated: 8415353190848921 kilobytes
#  Q2P  matrix memory allocated: 10485544 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 8141581169264164 kilobytes
#  Miscellaneous mem. allocated:1896117 kilobytes
#  Total memory (check w/above):8143761229735864 kilobytes
#
# 2024-12-10 10:22:39.407 [KernelNanny.4] Parent 14344 exited with status -1073741819.
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-27.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-27.log'
# Output for 27:
# 2024-12-10 10:19:28.396 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:28.396 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:28.398 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:28.403 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55163']
# 2024-12-10 10:19:28.404 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:28.404 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:28.404 [IPEngine] Connecting shell to tcp://127.0.0.1:55163
# 2024-12-10 10:19:28.404 [IPEngine] Starting nanny
# 2024-12-10 10:19:28.831 [KernelNanny.27] Starting kernel nanny for engine 27, pid=5324, nanny pid=9824
# 2024-12-10 10:19:28.831 [KernelNanny.27] Nanny watching parent pid 5324.
# 2024-12-10 10:19:28.913 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:28.923 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:28.923 [IPEngine] Completed registration with id 27
# 2024-12-10 10:19:34.695 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_6
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2179940715855 kilobytes
#  Q2L  matrix memory allocated: 8325557450597990 kilobytes
#  Q2P  matrix memory allocated: 10464636 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 8051785429013233 kilobytes
#  Miscellaneous mem. allocated:1875209 kilobytes
#  Total memory (check w/above):8053965382068936 kilobytes
#
# 2024-12-10 10:22:39.538 [KernelNanny.27] Parent 5324 exited with status -1073741819.
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-23.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-23.log'
# Output for 23:
# 2024-12-10 10:19:27.959 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:27.959 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:27.961 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:27.978 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55163']
# 2024-12-10 10:19:27.978 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:27.979 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:27.979 [IPEngine] Connecting shell to tcp://127.0.0.1:55163
# 2024-12-10 10:19:27.979 [IPEngine] Starting nanny
# 2024-12-10 10:19:28.454 [KernelNanny.23] Starting kernel nanny for engine 23, pid=12932, nanny pid=21252
# 2024-12-10 10:19:28.455 [KernelNanny.23] Nanny watching parent pid 12932.
# 2024-12-10 10:19:28.549 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:28.579 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:28.582 [IPEngine] Completed registration with id 23
# 2024-12-10 10:19:34.666 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_5
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2180481881735 kilobytes
#  Q2L  matrix memory allocated: 8778127981462683 kilobytes
#  Q2P  matrix memory allocated: 10570009 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 8504355959877926 kilobytes
#  Miscellaneous mem. allocated:1980582 kilobytes
#  Total memory (check w/above):8506536454310253 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-6.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-6.log'
# Output for 6:
# 2024-12-10 10:19:26.106 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:26.106 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:26.108 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:26.112 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55162']
# 2024-12-10 10:19:26.113 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:26.113 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:26.113 [IPEngine] Connecting shell to tcp://127.0.0.1:55162
# 2024-12-10 10:19:26.113 [IPEngine] Starting nanny
# 2024-12-10 10:19:26.584 [KernelNanny.6] Starting kernel nanny for engine 6, pid=13676, nanny pid=20332
# 2024-12-10 10:19:26.585 [KernelNanny.6] Nanny watching parent pid 13676.
# 2024-12-10 10:19:26.672 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:26.705 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:26.705 [IPEngine] Completed registration with id 6
# 2024-12-10 10:19:34.842 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_20
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2179803276902 kilobytes
#  Q2L  matrix memory allocated: 8210618903076798 kilobytes
#  Q2P  matrix memory allocated: 10437875 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 7936846881492041 kilobytes
#  Miscellaneous mem. allocated:1848448 kilobytes
#  Total memory (check w/above):7939026697055268 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-26.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-26.log'
# Output for 26:
# 2024-12-10 10:19:28.286 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:28.286 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:28.288 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:28.292 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55162']
# 2024-12-10 10:19:28.293 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:28.293 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:28.293 [IPEngine] Connecting shell to tcp://127.0.0.1:55162
# 2024-12-10 10:19:28.297 [IPEngine] Starting nanny
# 2024-12-10 10:19:28.751 [KernelNanny.26] Starting kernel nanny for engine 26, pid=7824, nanny pid=17476
# 2024-12-10 10:19:28.751 [KernelNanny.26] Nanny watching parent pid 7824.
# 2024-12-10 10:19:28.825 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:28.835 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:28.835 [IPEngine] Completed registration with id 26
# 2024-12-10 10:19:34.722 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_9
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2180606435786 kilobytes
#  Q2L  matrix memory allocated: 8882291040153763 kilobytes
#  Q2P  matrix memory allocated: 10594261 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 8608519018569007 kilobytes
#  Miscellaneous mem. allocated:2004834 kilobytes
#  Total memory (check w/above):8610699637603890 kilobytes
#
# 2024-12-10 10:22:39.742 [KernelNanny.26] Parent 7824 exited with status -1073741819.
# 2024-12-10 10:22:39.750 [KernelNanny.26] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-16.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-16.log'
# Output for 16:
# 2024-12-10 10:19:27.219 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:27.219 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:27.221 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:27.225 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55162']
# 2024-12-10 10:19:27.226 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:27.226 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:27.226 [IPEngine] Connecting shell to tcp://127.0.0.1:55162
# 2024-12-10 10:19:27.228 [IPEngine] Starting nanny
# 2024-12-10 10:19:27.703 [KernelNanny.16] Starting kernel nanny for engine 16, pid=21328, nanny pid=18148
# 2024-12-10 10:19:27.704 [KernelNanny.16] Nanny watching parent pid 21328.
# 2024-12-10 10:19:27.808 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:27.828 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:27.828 [IPEngine] Completed registration with id 16
# 2024-12-10 10:19:34.816 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_18
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2178793959587 kilobytes
#  Q2L  matrix memory allocated: 7366538944718045 kilobytes
#  Q2P  matrix memory allocated: 10241348 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 7092766923133288 kilobytes
#  Miscellaneous mem. allocated:1651920 kilobytes
#  Total memory (check w/above):7094945728986145 kilobytes
#
# 2024-12-10 10:22:39.746 [KernelNanny.16] Parent 21328 exited with status -1073741819.
# 2024-12-10 10:22:39.753 [KernelNanny.16] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-28.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-28.log'
# Output for 28:
# 2024-12-10 10:19:28.505 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:28.505 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:28.507 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:28.511 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55162']
# 2024-12-10 10:19:28.512 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:28.512 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:28.512 [IPEngine] Connecting shell to tcp://127.0.0.1:55162
# 2024-12-10 10:19:28.514 [IPEngine] Starting nanny
# 2024-12-10 10:19:28.917 [KernelNanny.28] Starting kernel nanny for engine 28, pid=9324, nanny pid=13360
# 2024-12-10 10:19:28.917 [KernelNanny.28] Nanny watching parent pid 9324.
# 2024-12-10 10:19:28.989 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:28.998 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:28.998 [IPEngine] Completed registration with id 28
# 2024-12-10 10:19:34.594 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_2
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2179382370107 kilobytes
#  Q2L  matrix memory allocated: 7858619601293148 kilobytes
#  Q2P  matrix memory allocated: 10355919 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 7584847579708391 kilobytes
#  Miscellaneous mem. allocated:1766492 kilobytes
#  Total memory (check w/above):7587026974200910 kilobytes
#
# 2024-12-10 10:22:39.769 [KernelNanny.28] Parent 9324 exited with status -1073741819.
# 2024-12-10 10:22:39.779 [KernelNanny.28] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-24.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-24.log'
# Output for 24:
# 2024-12-10 10:19:28.080 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:28.080 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:28.082 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:28.100 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55162']
# 2024-12-10 10:19:28.101 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:28.101 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:28.101 [IPEngine] Connecting shell to tcp://127.0.0.1:55162
# 2024-12-10 10:19:28.102 [IPEngine] Starting nanny
# 2024-12-10 10:19:28.575 [KernelNanny.24] Starting kernel nanny for engine 24, pid=14308, nanny pid=21052
# 2024-12-10 10:19:28.576 [KernelNanny.24] Nanny watching parent pid 14308.
# 2024-12-10 10:19:28.657 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:28.669 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:28.669 [IPEngine] Completed registration with id 24
# 2024-12-10 10:19:34.717 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_8
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2180348737748 kilobytes
#  Q2L  matrix memory allocated: 8666781263551528 kilobytes
#  Q2P  matrix memory allocated: 10544084 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 8393009241966772 kilobytes
#  Miscellaneous mem. allocated:1954657 kilobytes
#  Total memory (check w/above):8395189603203262 kilobytes
#
# 2024-12-10 10:22:39.776 [KernelNanny.24] Parent 14308 exited with status -1073741819.
# 2024-12-10 10:22:39.784 [KernelNanny.24] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-0.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-0.log'
# Output for 0:
# 2024-12-10 10:19:25.421 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:25.422 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:25.423 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:25.427 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55162']
# 2024-12-10 10:19:25.428 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:25.428 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:25.428 [IPEngine] Connecting shell to tcp://127.0.0.1:55162
# 2024-12-10 10:19:25.428 [IPEngine] Starting nanny
# 2024-12-10 10:19:25.823 [KernelNanny.0] Starting kernel nanny for engine 0, pid=11828, nanny pid=7544
# 2024-12-10 10:19:25.823 [KernelNanny.0] Nanny watching parent pid 11828.
# 2024-12-10 10:19:25.992 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:26.004 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:26.004 [IPEngine] Completed registration with id 0
# 2024-12-10 10:19:34.747 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_11
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2179262111023 kilobytes
#  Q2L  matrix memory allocated: 7758048372212105 kilobytes
#  Q2P  matrix memory allocated: 10332503 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 7484276350627348 kilobytes
#  Miscellaneous mem. allocated:1743076 kilobytes
#  Total memory (check w/above):7486455624813951 kilobytes
#
# 2024-12-10 10:22:39.788 [KernelNanny.0] Parent 11828 exited with status -1073741819.
# 2024-12-10 10:22:39.795 [KernelNanny.0] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-30.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-30.log'
# Output for 30:
# 2024-12-10 10:19:28.695 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:28.695 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:28.697 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:28.701 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55162']
# 2024-12-10 10:19:28.701 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:28.702 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:28.702 [IPEngine] Connecting shell to tcp://127.0.0.1:55162
# 2024-12-10 10:19:28.702 [IPEngine] Starting nanny
# 2024-12-10 10:19:29.078 [KernelNanny.30] Starting kernel nanny for engine 30, pid=13784, nanny pid=14148
# 2024-12-10 10:19:29.079 [KernelNanny.30] Nanny watching parent pid 13784.
# 2024-12-10 10:19:29.144 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:29.153 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:29.153 [IPEngine] Completed registration with id 30
# 2024-12-10 10:19:34.737 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_10
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2180417457225 kilobytes
#  Q2L  matrix memory allocated: 8724250537312124 kilobytes
#  Q2P  matrix memory allocated: 10557464 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 8450478515727368 kilobytes
#  Miscellaneous mem. allocated:1968038 kilobytes
#  Total memory (check w/above):8452658945710096 kilobytes
#
# 2024-12-10 10:22:39.794 [KernelNanny.30] Parent 13784 exited with status -1073741819.
# 2024-12-10 10:22:39.799 [KernelNanny.30] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-18.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-18.log'
# Output for 18:
# 2024-12-10 10:19:27.438 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:27.438 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:27.440 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:27.444 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55162']
# 2024-12-10 10:19:27.445 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:27.445 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:27.445 [IPEngine] Connecting shell to tcp://127.0.0.1:55162
# 2024-12-10 10:19:27.445 [IPEngine] Starting nanny
# 2024-12-10 10:19:27.909 [KernelNanny.18] Starting kernel nanny for engine 18, pid=2280, nanny pid=19448
# 2024-12-10 10:19:27.909 [KernelNanny.18] Nanny watching parent pid 2280.
# 2024-12-10 10:19:27.998 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:28.011 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:28.011 [IPEngine] Completed registration with id 18
# 2024-12-10 10:19:34.806 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_17
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2179558463766 kilobytes
#  Q2L  matrix memory allocated: 8005884615304675 kilobytes
#  Q2P  matrix memory allocated: 10390207 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 7732112593719918 kilobytes
#  Miscellaneous mem. allocated:1800780 kilobytes
#  Total memory (check w/above):7734292164374672 kilobytes
#
# 2024-12-10 10:22:39.803 [KernelNanny.18] Parent 2280 exited with status -1073741819.
# 2024-12-10 10:22:39.810 [KernelNanny.18] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-5.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-5.log'
# Output for 5:
# 2024-12-10 10:19:25.982 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:25.982 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:25.984 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:25.988 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55163']
# 2024-12-10 10:19:25.989 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:25.989 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:25.989 [IPEngine] Connecting shell to tcp://127.0.0.1:55163
# 2024-12-10 10:19:25.989 [IPEngine] Starting nanny
# 2024-12-10 10:19:26.460 [KernelNanny.5] Starting kernel nanny for engine 5, pid=10800, nanny pid=14064
# 2024-12-10 10:19:26.461 [KernelNanny.5] Nanny watching parent pid 10800.
# 2024-12-10 10:19:26.549 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:26.561 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:26.561 [IPEngine] Completed registration with id 5
# 2024-12-10 10:19:34.765 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_13
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2178531966582 kilobytes
#  Q2L  matrix memory allocated: 7147437338505773 kilobytes
#  Q2P  matrix memory allocated: 10190334 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 6873665316921016 kilobytes
#  Miscellaneous mem. allocated:1600907 kilobytes
#  Total memory (check w/above):6875843860678840 kilobytes
#
# 2024-12-10 10:22:39.799 [KernelNanny.5] Parent 10800 exited with status -1073741819.
# 2024-12-10 10:22:39.806 [KernelNanny.5] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-13.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-13.log'
# Output for 13:
# 2024-12-10 10:19:26.883 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:26.883 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:26.885 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:26.891 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55163']
# 2024-12-10 10:19:26.892 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:26.892 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:26.892 [IPEngine] Connecting shell to tcp://127.0.0.1:55163
# 2024-12-10 10:19:26.892 [IPEngine] Starting nanny
# 2024-12-10 10:19:27.366 [KernelNanny.13] Starting kernel nanny for engine 13, pid=700, nanny pid=21200
# 2024-12-10 10:19:27.367 [KernelNanny.13] Nanny watching parent pid 700.
# 2024-12-10 10:19:27.464 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:27.479 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:27.479 [IPEngine] Completed registration with id 13
# 2024-12-10 10:19:34.758 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_12
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2179592823504 kilobytes
#  Q2L  matrix memory allocated: 8034619252184973 kilobytes
#  Q2P  matrix memory allocated: 10396897 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 7760847230600216 kilobytes
#  Miscellaneous mem. allocated:1807470 kilobytes
#  Total memory (check w/above):7763026835628089 kilobytes
#
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-29.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-29.log'
# Output for 29:
# 2024-12-10 10:19:28.605 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:28.605 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:28.607 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:28.611 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55163']
# 2024-12-10 10:19:28.611 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:28.611 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:28.611 [IPEngine] Connecting shell to tcp://127.0.0.1:55163
# 2024-12-10 10:19:28.612 [IPEngine] Starting nanny
# 2024-12-10 10:19:29.002 [KernelNanny.29] Starting kernel nanny for engine 29, pid=5240, nanny pid=17588
# 2024-12-10 10:19:29.002 [KernelNanny.29] Nanny watching parent pid 5240.
# 2024-12-10 10:19:29.072 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:29.082 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:29.082 [IPEngine] Completed registration with id 29
# 2024-12-10 10:19:34.600 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_3
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2179700197687 kilobytes
#  Q2L  matrix memory allocated: 8124414992435904 kilobytes
#  Q2P  matrix memory allocated: 10417804 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 7850642970851147 kilobytes
#  Miscellaneous mem. allocated:1828377 kilobytes
#  Total memory (check w/above):7852822683295017 kilobytes
#
# 2024-12-10 10:22:40.442 [KernelNanny.29] Parent 5240 exited with status -1073741819.
# 2024-12-10 10:22:40.444 [KernelNanny.29] Notifying Hub that our parent has shut down
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-12.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-12.log'
# Output for 12:
# 2024-12-10 10:19:26.782 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:26.782 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:26.785 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:26.806 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55162']
# 2024-12-10 10:19:26.807 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:26.807 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:26.807 [IPEngine] Connecting shell to tcp://127.0.0.1:55162
# 2024-12-10 10:19:26.808 [IPEngine] Starting nanny
# 2024-12-10 10:19:27.281 [KernelNanny.12] Starting kernel nanny for engine 12, pid=2536, nanny pid=18992
# 2024-12-10 10:19:27.282 [KernelNanny.12] Nanny watching parent pid 2536.
# 2024-12-10 10:19:27.373 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:27.385 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:27.385 [IPEngine] Completed registration with id 12
# 2024-12-10 10:19:34.834 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_19
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2179279290892 kilobytes
#  Q2L  matrix memory allocated: 7772415690652254 kilobytes
#  Q2P  matrix memory allocated: 10335848 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 7498643669067497 kilobytes
#  Miscellaneous mem. allocated:1746421 kilobytes
#  Total memory (check w/above):7500822960440659 kilobytes
#
# 2024-12-10 10:22:40.469 [KernelNanny.12] Parent 2536 exited with status -1073741819.
#
# Failed to remove C:\Users\Photonics\.ipython\profile_default\log\ipengine-1733854763-v8z1-1733854764-1.log: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Photonics\\.ipython\\profile_default\\log\\ipengine-1733854763-v8z1-1733854764-1.log'
# Output for 1:
# 2024-12-10 10:19:25.515 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2024-12-10 10:19:25.515 [IPEngine] WARNING | Not using CurveZMQ security
# 2024-12-10 10:19:25.516 [IPEngine] Registering with controller at tcp://127.0.0.1:55155
# 2024-12-10 10:19:25.520 [IPEngine] Shell_addrs: ['tcp://127.0.0.1:55157', 'tcp://127.0.0.1:55158', 'tcp://127.0.0.1:55163']
# 2024-12-10 10:19:25.521 [IPEngine] Connecting shell to tcp://127.0.0.1:55157
# 2024-12-10 10:19:25.521 [IPEngine] Connecting shell to tcp://127.0.0.1:55158
# 2024-12-10 10:19:25.521 [IPEngine] Connecting shell to tcp://127.0.0.1:55163
# 2024-12-10 10:19:25.521 [IPEngine] Starting nanny
# 2024-12-10 10:19:25.929 [KernelNanny.1] Starting kernel nanny for engine 1, pid=20124, nanny pid=19024
# 2024-12-10 10:19:25.929 [KernelNanny.1] Nanny watching parent pid 20124.
# 2024-12-10 10:19:26.019 [IPEngine] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2024-12-10 10:19:26.038 [IPEngine] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2024-12-10 10:19:26.038 [IPEngine] Completed registration with id 1
# 2024-12-10 10:19:34.775 [IPEngine] Handling apply_request: a4955414-b6fa4afd2bb71e2df50ce357_13116_14
# FLE-fastlap/direct.c: out of memory at line 60
#  (NULL pointer on 836288 byte request)
#  Q2M  matrix memory allocated: 2179219161350 kilobytes
#  Q2L  matrix memory allocated: 7722130076111732 kilobytes
#  Q2P  matrix memory allocated: 10324140 kilobytes
#  L2L  matrix memory allocated:         kilobytes
#  M2M  matrix memory allocated:         kilobytes
#  M2L  matrix memory allocated:         kilobytes
#  M2P  matrix memory allocated:         kilobytes
#  L2P  matrix memory allocated: 7448358054526976 kilobytes
#  Miscellaneous mem. allocated:1734713 kilobytes
#  Total memory (check w/above):7450537285747180 kilobytes
#
# 2024-12-10 10:22:40.485 [KernelNanny.1] Parent 20124 exited with status -1073741819.
# 2024-12-10 10:22:40.489 [KernelNanny.1] Notifying Hub that our parent has shut down
#
# Computing time: 191.059791 s

# %%
Result.view(prefix, 'DC1')

# %%
Result.view(prefix, 'RF')
# Out:
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)
# C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\core\utilities\misc.py:115: UserWarning: Encountered issue in callback (most recent call last):
#   File "C:\Users\Photonics\Documents\Working\bem\bem\electrostatics.py", line 187, in callback_func_iso
#     plotter.add_mesh(iso_slider, name = 'iso', cmap = 'Greys', scalars = scalar_name, opacity = 1, show_scalar_bar = False)
#   File "C:\Users\Photonics\.conda\envs\bem39\lib\site-packages\pyvista\plotting\plotter.py", line 3438, in add_mesh
#     raise ValueError('Empty meshes cannot be plotted. Input mesh has zero points.')
# ValueError: Empty meshes cannot be plotted. Input mesh has zero points.
#   warnings.warn(formatted_exception)

# %%
jobs = list(Configuration.select(mesh, "GND"))    # select() picks one electrode each time.
# jobs = list(Configuration.select(mesh, "RF"))    # select() picks one electrode each time.
# jobs = list(Configuration.select(mesh, "DC.*")) 



# parallel computation
mycluster = ipp.Cluster()
mycluster.start_cluster_sync()
c = mycluster.connect_client_sync()
c.wait_for_engines()

t0 = time()
# Run a parallel map, executing the wrapper function on indices 0,...,n-1
lview = c.load_balanced_view()
# Cause execution on main process to wait while tasks sent to workers finish
lview.block = True 
asyncresult = lview.map_async(run_job, ((job, grid, prefix) for job in jobs))   # Run calculation in parallel
asyncresult.wait_interactive()
print("Computing time: %f s"%(time()-t0))
# Out:
# Starting 32 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/32 [00:00<?, ?engine/s]
# run_job:   0%|          | 0/1 [00:00<?, ?tasks/s]
# Computing time: 49.833177 s

# %%
Result.view(prefix, 'GND')
